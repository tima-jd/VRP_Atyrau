# %%
import pandas as pd
a = pd.read_csv('lamm(2019-2025).csv')
lamm_b = a['lamm_b']
lamm_o = a['lamm_o']
lamm_p = a['lamm_p']

b=100
o=100
p=100
i=0
newdf = pd.DataFrame(columns=['lretS_b','lretS_o','lretS_p'], index=range(12))
while i<=len(lamm_b)-1:
    b = b * ((lamm_b[i]-100)* 2.520152666701371 + 100)/100
    o = o * ((lamm_o[i]-100)* 2.520152666701371 + 100)/100
    p = p * ((lamm_p[i]-100)* 2.520152666701371 + 100)/100

    newdf.loc[i].lretS_b = b
    newdf.loc[i].lretS_o = o
    newdf.loc[i].lretS_p = p
    
    i = i+1
    
lretS_b = newdf['lretS_b']
lretS_o = newdf['lretS_o']
lretS_p = newdf['lretS_p']

newdf
# Out:
#     lretS_b  lretS_o  lretS_p
# 0   104.201  104.201  104.201
# 1   104.007  127.459  97.2652
# 2   97.0927  118.674  89.9762
# 3   91.5773  116.458  71.0734
# 4   84.8077  139.342  61.9582
# 5   74.2326  122.633  63.8088
# 6   77.3218  130.719  109.962
# 7       NaN      NaN      NaN
# 8       NaN      NaN      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN      NaN
# 11      NaN      NaN      NaN

# %%
lrett_bb = lretS_b.shift(1)
lrett_bb[0] = 100
lret_b = lretS_b/lrett_bb*100

lrett_oo = lretS_o.shift(1)
lrett_oo[0] = 100
lret_o = lretS_o/lrett_oo*100

lrett_pp = lretS_p.shift(1)
lrett_pp[0] = 100
lret_p = lretS_p/lrett_pp*100

new = pd.DataFrame(columns=['lret_b','lret_o','lret_p'])

new.lret_b = lret_b
new.lret_o = lret_o
new.lret_p = lret_p

new
# Out:
#      lret_b   lret_o   lret_p
# 0   104.201  104.201  104.201
# 1   99.8131   122.32  93.3436
# 2   93.3524  93.1078  92.5061
# 3   94.3195  98.1329  78.9913
# 4   92.6078   119.65  87.1751
# 5   87.5305   88.009  102.987
# 6   104.162  106.593  172.331
# 7       NaN      NaN      NaN
# 8       NaN      NaN      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN      NaN
# 11      NaN      NaN      NaN

# %%
new.to_csv(r'lret(2019-2025).csv', index = False)
