# %%
import pandas as pd

csv = pd.read_csv('vrp_ekz_fact.csv')
csv_vrp = pd.read_csv('vrp_fact.csv')

csv_Nagr = pd.read_csv('Nagr_AO(2019-2025).csv')
csv_Ncon = pd.read_csv('Ncon_AO(2019-2025).csv')
csv_Nelc = pd.read_csv('Nelc_AO(2019-2025).csv')
csv_Ngds = pd.read_csv('Ngds_AO(2019-2025).csv')
csv_Nest = pd.read_csv('Nest_AO(2019-2025).csv')
csv_Nimt = pd.read_csv('Nimt_AO(2019-2025).csv')
csv_Nind = pd.read_csv('Nind_AO(2019-2025).csv')
csv_Nman = pd.read_csv('Nman_AO(2019-2025).csv')
csv_Nmin = pd.read_csv('Nmin_AO(2019-2025).csv')
csv_Noth = pd.read_csv('Noth_AO(2019-2025).csv')
csv_Nret = pd.read_csv('Nret_AO(2019-2025).csv')
csv_Nsrv = pd.read_csv('Nsrv_AO(2019-2025).csv')
csv_Ntotal = pd.read_csv('Ntotal_AO(2019-2025).csv')
csv_Ntrd = pd.read_csv('Ntrd_AO(2019-2025).csv')
csv_Ntrn = pd.read_csv('Ntrn_AO(2019-2025).csv')
csv_Nwhl = pd.read_csv('Nwhl_AO(2019-2025).csv')
csv_Nwtr = pd.read_csv('Nwtr_AO(2019-2025).csv')


csv_lagr = pd.read_csv('lagr_AO(2019-2025).csv')
csv_lcon = pd.read_csv('lcon_AO(2019-2025).csv')
csv_lelc = pd.read_csv('lelc_AO(2019-2025).csv')
csv_lgds = pd.read_csv('lgds_AO(2019-2025).csv')
csv_lest = pd.read_csv('lest_AO(2019-2025).csv')
csv_limt = pd.read_csv('limt_AO(2019-2025).csv')
csv_lind = pd.read_csv('lind_AO(2019-2025).csv')
csv_lman = pd.read_csv('lman_AO(2019-2025).csv')
csv_lmin = pd.read_csv('lmin_AO(2019-2025).csv')
csv_loth = pd.read_csv('loth_AO(2019-2025).csv')
csv_lret = pd.read_csv('lret_AO(2019-2025).csv')
csv_lsrv = pd.read_csv('lsrv_AO(2019-2025).csv')
csv_ltot = pd.read_csv('ltotal_AO(2019-2025).csv')
csv_ltrd = pd.read_csv('ltrd_AO(2019-2025).csv')
csv_ltrn = pd.read_csv('ltrn_AO(2019-2025).csv')
csv_lwhl = pd.read_csv('lwhl_AO(2019-2025).csv')
csv_lwtr = pd.read_csv('lwtr_AO(2019-2025).csv')


vrp_agr = csv_vrp['o_vrp_agro']
vrp_con = csv_vrp['o_vrp_building']
vrp_elc = csv_vrp['o_vrp_energo']
vrp_est = csv_vrp['o_vrp_estate']
vrp_imt = csv_vrp['o_vrp_info']
vrp_man = csv_vrp['o_vrp_man']
vrp_min = csv_vrp['o_vrp_mining']
vrp_oth = csv_vrp['o_vrp_other']
vrp_ret = csv_vrp['o_vrp_retail']
vrp_trn = csv_vrp['o_vrp_transp']
vrp_whl = csv_vrp['o_vrp_trade']
vrp_wtr = csv_vrp['o_vrp_water']
vrp_tax = csv_vrp['o_vrp_tax']

IGRP = csv_vrp['o_ifo']

Igva_agr_f = csv['o_ifo_agro']
Igva_con_f = csv['o_ifo_building']
Igva_elc_f = csv['o_ifo_energo']
Igva_est_f = csv['o_ifo_estate']
Igva_imt_f = csv['o_ifo_info']
Igva_man_f = csv['o_ifo_man']
Igva_min_f = csv['o_ifo_mining']
Igva_oth_f = csv['o_ifo_other']
Igva_ret_f = csv['o_ifo_retail']
Igva_trn_f = csv['o_ifo_transp']
Igva_whl_f = csv['o_ifo_trade']
Igva_wtr_f = csv['o_ifo_water']

Igva_agr = csv_lagr['c1']
Igva_con = csv_lcon['c1']
Igva_elc = csv_lelc['0']
Igva_est = csv_lest['c1']
Igva_imt = csv_limt['c1']
Igva_man = csv_lman['0']
Igva_min = csv_lmin['0']
Igva_oth = csv_loth['c1']
Igva_ret = csv_lret['c1']
Igva_trn = csv_ltrn['c1']
Igva_whl = csv_lwhl['0']
Igva_wtr = csv_lwtr['0'] 


Nagr =csv_Nagr['c1']
Ncon =csv_Ncon['c1']
Nelc =csv_Nelc['Nelc']
Ngds =csv_Ngds['0']
Nest =csv_Nest['c1']
Nimt =csv_Nimt['c1']
Nind =csv_Nind['Nind']
Nman =csv_Nman['Nman']
Nmin =csv_Nmin['c1']
Noth =csv_Noth['c1']
Nret =csv_Nret['c1']
Nsrv =csv_Nsrv['0']
Ntotal =csv_Ntotal['0']
Ntrd =csv_Ntrd['Ntrd']
Ntrn =csv_Ntrn['c1']
Nwhl =csv_Nwhl['Nwhl']
Nwtr =csv_Nwtr['Nwtr']

agr = Nagr.shift(1)
agr[0] = 68562.8

con = Ncon.shift(1)
con[0] = 638235.0

elc = Nelc.shift(1)
elc[0] = 45937.0

est = Nest.shift(1)
est[0] = 45240.4

imt = Nimt.shift(1)
imt[0] = 14340.6

man =Nman.shift(1)
man[0] = 584810.0

minn = Nmin.shift(1)
minn[0] =6411496.0

oth = Noth.shift(1)
oth[0] =25547.5

ret = Nret.shift(1)
ret[0] =305715.8

trn = Ntrn.shift(1)
trn[0] = 661807.7

whl = Nwhl.shift(1)
whl[0] =2984867.2

wtr = Nwtr.shift(1)
wtr[0] =35299.0

i = 0

a = vrp_agr[7]
c =vrp_con[7]
el=vrp_elc[7]
es=vrp_est[7]
im =vrp_imt[7]
ma=vrp_man[7]
mi=vrp_min[7]
o =vrp_oth[7]
r =vrp_ret[7]
t =vrp_trn[7]
wh=vrp_whl[7]
wt=vrp_wtr[7]

newdf = pd.DataFrame(columns=['Gva_agr','Gva_con','Gva_elc','Gva_est','Gva_imt','Gva_man','Gva_min','Gva_oth','Gva_ret','Gva_trn','Gva_whl','Gva_wtr'], index=range(7))

while i<=6:
    a  = a  * Nagr[i]/agr[i]
    c  = c  * Ncon[i]/con[i]
    el = el * Nelc[i]/elc[i]
    es = es * Nest[i]/est[i]
    im = im  * Nimt[i]/imt[i]
    ma = ma * Nman[i]/man[i]
    mi = mi * Nmin[i]/minn[i]
    o  = o  * Noth[i]/oth[i]
    r  = r  * Nret[i]/ret[i]
    t  = t  * Ntrn[i]/trn[i]
    wh = wh * Nwhl[i]/whl[i]
    wt = wt * Nwtr[i]/wtr[i]
    
    newdf.loc[i].Gva_agr = a 
    newdf.loc[i].Gva_con = c 
    newdf.loc[i].Gva_elc = el
    newdf.loc[i].Gva_est = es
    newdf.loc[i].Gva_imt = im
    newdf.loc[i].Gva_man = ma
    newdf.loc[i].Gva_min = mi
    newdf.loc[i].Gva_oth = o 
    newdf.loc[i].Gva_ret = r 
    newdf.loc[i].Gva_trn = t 
    newdf.loc[i].Gva_whl = wh
    newdf.loc[i].Gva_wtr = wt
    i = i+1   
    
Gva_agr = newdf['Gva_agr']
Gva_con = newdf['Gva_con']
Gva_elc = newdf['Gva_elc']
Gva_est = newdf['Gva_est']
Gva_imt = newdf['Gva_imt']
Gva_man = newdf['Gva_man']
Gva_min = newdf['Gva_min']
Gva_oth = newdf['Gva_oth']
Gva_ret = newdf['Gva_ret']
Gva_trn = newdf['Gva_trn']
Gva_whl = newdf['Gva_whl']
Gva_wtr = newdf['Gva_wtr']

#Gva_ind for 2019-2025 years
Gva_ind = Gva_min+Gva_man+Gva_elc+Gva_wtr
#Gva_gds for 2019-2025 years
Gva_gds = Gva_agr + Gva_ind + Gva_con
#Gva_trd for 2019-2025 years
Gva_trd = Gva_ret + Gva_whl
#Gva_srv for 2019-2025 years
Gva_srv = Gva_trd + Gva_trn + Gva_imt + Gva_est + Gva_oth
#Gva_tot for 2019-2025 years
Gva_tot = Gva_gds + Gva_srv



#Gva_ind = vrp_ind, for 2011-2018 years
vrp_ind = vrp_min + vrp_man + vrp_elc + vrp_wtr
#Gva_gds = vrp_gds, for 2011-2018 years
vrp_gds = vrp_agr + vrp_ind + vrp_con
#Gva_trd = vrp_trd, for 2011-2018 years
vrp_trd = vrp_ret + vrp_whl
#Gva_srv = vrp_srv, for 2011-2018 years
vrp_srv = vrp_trd + vrp_trn + vrp_imt + vrp_est + vrp_oth
#Gva_tot = vrp_tot,  for 2011-2018 years
vrp_tot = vrp_gds + vrp_srv





l = 0
ta =vrp_tax[7]

Gva_t = Gva_tot.shift(1)
Gva_t[0] = 7150.5

new = pd.DataFrame(columns=['Tax'], index=range(7))
while l<=6:
    ta  = ta * Gva_tot[l]/Gva_t[l]
    new.loc[l].Tax = ta 
    l = l+1
Tax = new['Tax']

#Grp for 2019-2025 years
GRP = Gva_tot + Tax

#Grp = Grp_f, for 2011-2018 years
GRP_f = vrp_tot + vrp_tax 

# Igva_ind for 2019-2025 years
Igva_ind = ((Gva_min*Igva_min)+(Gva_man*Igva_man)+(Gva_elc*Igva_elc)+(Gva_wtr*Igva_wtr))/Gva_ind 

# Igva_ind_f = Igva_ind,  for 2011-2018 years
Igva_ind_f = ((vrp_min*Igva_min_f.shift(-11))+(vrp_man*Igva_man_f.shift(-11))+(vrp_elc*Igva_elc_f.shift(-11))+(vrp_wtr*Igva_wtr_f.shift(-11)))/vrp_ind 


IGRP,GRP_f
# Out:
# (0    103.2
#  1     97.7
#  2    104.0
#  3    102.5
#  4    102.8
#  5    103.7
#  6    116.0
#  7    113.3
#  Name: o_ifo, dtype: float64,
#  0    3791.56
#  1    3613.40
#  2    3977.36
#  3    4340.63
#  4    4216.75
#  5    5200.67
#  6    5947.63
#  7    7818.82
#  dtype: float64)
