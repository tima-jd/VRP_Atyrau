# %%
import pandas as pd
import numpy as np
csv_file = pd.read_csv('vrp_ekz_prog.csv')
Dmin = pd.read_csv('Dmin(2019-2025).csv')
lmin = pd.read_csv('lmin(2019-2025).csv')

Dmin_b = Dmin['Dmin_b']
Dmin_o = Dmin['Dmin_o']
Dmin_p = Dmin['Dmin_p']

lmin_b = lmin['lmin_b']
lmin_o = lmin['lmin_o']
lmin_p = lmin['lmin_p']


newdf = pd.DataFrame(columns=['Nmin_b','Nmin_o','Nmin_p'], index=range(12))

b = 6521.0
o = 6521.0
p = 6521.0
i=0

while i<=len(lmin_b)-1:
    b = b * lmin_b[i] * Dmin_b[i]/10000
    o = o * lmin_o[i] * Dmin_o[i]/10000
    p = p * lmin_p[i] * Dmin_p[i]/10000
    
    newdf.loc[i].Nmin_b = b    
    newdf.loc[i].Nmin_o = o    
    newdf.loc[i].Nmin_p = p    
    i=i+1
newdf
# Out:
#      Nmin_b   Nmin_o   Nmin_p
# 0   6198.03  6041.95  4172.19
# 1   6831.41  9087.43  4168.25
# 2   6818.72  9051.92  4231.21
# 3   7017.48  9567.54  4757.15
# 4   8722.61  14004.8  4777.66
# 5   8790.98  14187.4  4840.65
# 6   9003.44  14768.7  5321.27
# 7       NaN      NaN      NaN
# 8       NaN      NaN      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN      NaN
# 11      NaN      NaN      NaN

# %%
newdf.to_csv(r'Nmin_Kurmangazy(2019-2025).csv')
