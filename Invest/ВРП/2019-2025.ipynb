# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv = pd.read_sql('SELECT * FROM vrp_ekz_fact ORDER BY id',engine)
csv_vrp = pd.read_sql('SELECT * FROM vrp_fact ORDER BY id',engine)
vrp_prog = pd.read_sql('SELECT * FROM vrp_oblast ORDER BY index',engine)


limit = len(vrp_prog.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True))-1
limit_o = len(vrp_prog.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True))
limit_p = limit_o+limit_o

vrp_agr = csv_vrp['o_vrp_agro']
vrp_con = csv_vrp['o_vrp_building']
vrp_elc = csv_vrp['o_vrp_energo']
vrp_est = csv_vrp['o_vrp_estate']
vrp_imt = csv_vrp['o_vrp_info']
vrp_man = csv_vrp['o_vrp_man']
vrp_min = csv_vrp['o_vrp_mining']
vrp_oth = csv_vrp['o_vrp_other']
vrp_ret = csv_vrp['o_vrp_retail']
vrp_trn = csv_vrp['o_vrp_transp']
vrp_whl = csv_vrp['o_vrp_trade']
vrp_wtr = csv_vrp['o_vrp_water']
vrp_tax = csv_vrp['o_vrp_tax']

IGRP = csv_vrp['o_ifo']

Igva_agr_f = csv['o_ifo_agro']
Igva_con_f = csv['o_ifo_building']
Igva_elc_f = csv['o_ifo_energo']
Igva_est_f = csv['o_ifo_estate']
Igva_imt_f = csv['o_ifo_info']
Igva_man_f = csv['o_ifo_man']
Igva_min_f = csv['o_ifo_mining']
Igva_oth_f = csv['o_ifo_other']
Igva_ret_f = csv['o_ifo_retail']
Igva_trn_f = csv['o_ifo_transp']
Igva_whl_f = csv['o_ifo_trade']
Igva_wtr_f = csv['o_ifo_water']

Igva_agr = vrp_prog['lagr_ao']
Igva_con = vrp_prog['lcon_ao']
Igva_elc = vrp_prog['lelc_ao']
Igva_est = vrp_prog['lest_ao']
Igva_imt = vrp_prog['limt_ao']
Igva_man = vrp_prog['lman_ao']
Igva_min = vrp_prog['lmin_ao']
Igva_oth = vrp_prog['loth_ao']
Igva_ret = vrp_prog['lret_ao']
Igva_trn = vrp_prog['ltrn_ao']
Igva_whl = vrp_prog['lwhl_ao']
Igva_wtr = vrp_prog['lwtr_ao'] 


Nagr =vrp_prog['Nagr_ao']
Ncon =vrp_prog['Ncon_ao']
Nelc =vrp_prog['Nelc_ao']
Ngds =vrp_prog['Ngds_ao']
Nest =vrp_prog['Nest_ao']
Nimt =vrp_prog['Nimt_ao']
Nind =vrp_prog['Nind_ao']
Nman =vrp_prog['Nman_ao']
Nmin =vrp_prog['Nmin_ao']
Noth =vrp_prog['Noth_ao']
Nret =vrp_prog['Nret_ao']
Nsrv =vrp_prog['Nsrv_ao']
Ntotal =vrp_prog['Ntotal_ao']
Ntrd =vrp_prog['Ntrd_ao']
Ntrn =vrp_prog['Ntrn_ao']
Nwhl =vrp_prog['Nwhl_ao']
Nwtr =vrp_prog['Nwtr_ao']

agr = Nagr.shift(1)
l_b = agr.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = agr.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = agr.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 68562.8
l_o[0] = 68562.8
l_p[0] = 68562.8
agr = l_b.append(l_o).append(l_p).reset_index(drop = True)


con = Ncon.shift(1)
l_b = con.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = con.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = con.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 638235.0
l_o[0] = 638235.0
l_p[0] = 638235.0
con = l_b.append(l_o).append(l_p).reset_index(drop = True)


elc = Nelc.shift(1)
l_b = elc.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = elc.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = elc.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 45937.0
l_o[0] = 45937.0
l_p[0] = 45937.0
elc = l_b.append(l_o).append(l_p).reset_index(drop = True)


est = Nest.shift(1)
l_b = est.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = est.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = est.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 45240.4
l_o[0] = 45240.4
l_p[0] = 45240.4
est = l_b.append(l_o).append(l_p).reset_index(drop = True)


imt = Nimt.shift(1)
l_b = imt.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = imt.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = imt.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 14340.6
l_o[0] = 14340.6
l_p[0] = 14340.6
imt = l_b.append(l_o).append(l_p).reset_index(drop = True)


man =Nman.shift(1)
l_b = man.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = man.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = man.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 584810.0
l_o[0] = 584810.0
l_p[0] = 584810.0
man = l_b.append(l_o).append(l_p).reset_index(drop = True)

minn = Nmin.shift(1)
l_b = minn.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = minn.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = minn.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 6411496.0
l_o[0] = 6411496.0
l_p[0] = 6411496.0
minn = l_b.append(l_o).append(l_p).reset_index(drop = True)


oth = Noth.shift(1)
l_b = oth.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = oth.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = oth.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 25547.5
l_o[0] = 25547.5
l_p[0] = 25547.5
oth = l_b.append(l_o).append(l_p).reset_index(drop = True)


ret = Nret.shift(1)
l_b = ret.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = ret.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = ret.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 305715.8
l_o[0] = 305715.8
l_p[0] = 305715.8
ret = l_b.append(l_o).append(l_p).reset_index(drop = True)


trn = Ntrn.shift(1)
l_b = trn.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = trn.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = trn.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 661807.7
l_o[0] = 661807.7
l_p[0] = 661807.7
trn = l_b.append(l_o).append(l_p).reset_index(drop = True)


whl = Nwhl.shift(1)
l_b = whl.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = whl.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = whl.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 2984867.2
l_o[0] = 2984867.2
l_p[0] = 2984867.2
whl = l_b.append(l_o).append(l_p).reset_index(drop = True)


wtr = Nwtr.shift(1)
l_b = wtr.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = wtr.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = wtr.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0] = 35299.0
l_o[0] = 35299.0
l_p[0] = 35299.0
wtr = l_b.append(l_o).append(l_p).reset_index(drop = True)

i = 0

a = vrp_agr[7]
c =vrp_con[7]
el=vrp_elc[7]
es=vrp_est[7]
im =vrp_imt[7]
ma=vrp_man[7]
mi=vrp_min[7]
o =vrp_oth[7]
r =vrp_ret[7]
t =vrp_trn[7]
wh=vrp_whl[7]
wt=vrp_wtr[7]

a_o = vrp_agr[7]
c_o =vrp_con[7]
el_o=vrp_elc[7]
es_o=vrp_est[7]
im_o =vrp_imt[7]
ma_o=vrp_man[7]
mi_o=vrp_min[7]
o_o =vrp_oth[7]
r_o =vrp_ret[7]
t_o =vrp_trn[7]
wh_o=vrp_whl[7]
wt_o=vrp_wtr[7]

a_p = vrp_agr[7]
c_p =vrp_con[7]
el_p=vrp_elc[7]
es_p=vrp_est[7]
im_p =vrp_imt[7]
ma_p=vrp_man[7]
mi_p=vrp_min[7]
o_p =vrp_oth[7]
r_p =vrp_ret[7]
t_p =vrp_trn[7]
wh_p=vrp_whl[7]
wt_p=vrp_wtr[7]

newdf = pd.DataFrame(columns=['Gva_agr','Gva_con','Gva_elc','Gva_est','Gva_imt','Gva_man','Gva_min','Gva_oth','Gva_ret','Gva_trn','Gva_whl','Gva_wtr'], index=range(limit_o*3))

while i<=limit:
    a  = a  * Nagr[i]/agr[i]
    c  = c  * Ncon[i]/con[i]
    el = el * Nelc[i]/elc[i]
    es = es * Nest[i]/est[i]
    im = im  * Nimt[i]/imt[i]
    ma = ma * Nman[i]/man[i]
    mi = mi * Nmin[i]/minn[i]
    o  = o  * Noth[i]/oth[i]
    r  = r  * Nret[i]/ret[i]
    t  = t  * Ntrn[i]/trn[i]
    wh = wh * Nwhl[i]/whl[i]
    wt = wt * Nwtr[i]/wtr[i]
    
    a_o  = a_o  * Nagr[i+limit_o]/agr[i+limit_o]
    c_o  = c_o  * Ncon[i+limit_o]/con[i+limit_o]
    el_o = el_o * Nelc[i+limit_o]/elc[i+limit_o]
    es_o = es_o * Nest[i+limit_o]/est[i+limit_o]
    im_o = im_o  * Nimt[i+limit_o]/imt[i+limit_o]
    ma_o = ma_o * Nman[i+limit_o]/man[i+limit_o]
    mi_o = mi_o * Nmin[i+limit_o]/minn[i+limit_o]
    o_o  = o_o  * Noth[i+limit_o]/oth[i+limit_o]
    r_o  = r_o  * Nret[i+limit_o]/ret[i+limit_o]
    t_o  = t_o  * Ntrn[i+limit_o]/trn[i+limit_o]
    wh_o = wh_o * Nwhl[i+limit_o]/whl[i+limit_o]
    wt_o = wt_o * Nwtr[i+limit_o]/wtr[i+limit_o]

    a_p  = a_p  * Nagr[i+limit_p]/agr[i+limit_p]
    c_p  = c_p  * Ncon[i+limit_p]/con[i+limit_p]
    el_p = el_p * Nelc[i+limit_p]/elc[i+limit_p]
    es_p = es_p * Nest[i+limit_p]/est[i+limit_p]
    im_p = im_p  * Nimt[i+limit_p]/imt[i+limit_p]
    ma_p = ma_p * Nman[i+limit_p]/man[i+limit_p]
    mi_p = mi_p * Nmin[i+limit_p]/minn[i+limit_p]
    o_p  = o_p  * Noth[i+limit_p]/oth[i+limit_p]
    r_p  = r_p  * Nret[i+limit_p]/ret[i+limit_p]
    t_p  = t_p  * Ntrn[i+limit_p]/trn[i+limit_p]
    wh_p = wh_p * Nwhl[i+limit_p]/whl[i+limit_p]
    wt_p = wt_p * Nwtr[i+limit_p]/wtr[i+limit_p]

    newdf.loc[i].Gva_agr = a 
    newdf.loc[i].Gva_con = c 
    newdf.loc[i].Gva_elc = el
    newdf.loc[i].Gva_est = es
    newdf.loc[i].Gva_imt = im
    newdf.loc[i].Gva_man = ma
    newdf.loc[i].Gva_min = mi
    newdf.loc[i].Gva_oth = o 
    newdf.loc[i].Gva_ret = r 
    newdf.loc[i].Gva_trn = t 
    newdf.loc[i].Gva_whl = wh
    newdf.loc[i].Gva_wtr = wt

    newdf.loc[i+limit_o].Gva_agr = a_o 
    newdf.loc[i+limit_o].Gva_con = c_o 
    newdf.loc[i+limit_o].Gva_elc = el_o
    newdf.loc[i+limit_o].Gva_est = es_o
    newdf.loc[i+limit_o].Gva_imt = im_o
    newdf.loc[i+limit_o].Gva_man = ma_o
    newdf.loc[i+limit_o].Gva_min = mi_o
    newdf.loc[i+limit_o].Gva_oth = o_o 
    newdf.loc[i+limit_o].Gva_ret = r_o 
    newdf.loc[i+limit_o].Gva_trn = t_o 
    newdf.loc[i+limit_o].Gva_whl = wh_o
    newdf.loc[i+limit_o].Gva_wtr = wt_o

    newdf.loc[i+limit_p].Gva_agr = a_p 
    newdf.loc[i+limit_p].Gva_con = c_p 
    newdf.loc[i+limit_p].Gva_elc = el_p
    newdf.loc[i+limit_p].Gva_est = es_p
    newdf.loc[i+limit_p].Gva_imt = im_p
    newdf.loc[i+limit_p].Gva_man = ma_p
    newdf.loc[i+limit_p].Gva_min = mi_p
    newdf.loc[i+limit_p].Gva_oth = o_p 
    newdf.loc[i+limit_p].Gva_ret = r_p 
    newdf.loc[i+limit_p].Gva_trn = t_p 
    newdf.loc[i+limit_p].Gva_whl = wh_p
    newdf.loc[i+limit_p].Gva_wtr = wt_p
    i = i+1   
    
Gva_agr = newdf['Gva_agr']
Gva_con = newdf['Gva_con']
Gva_elc = newdf['Gva_elc']
Gva_est = newdf['Gva_est']
Gva_imt = newdf['Gva_imt']
Gva_man = newdf['Gva_man']
Gva_min = newdf['Gva_min']
Gva_oth = newdf['Gva_oth']
Gva_ret = newdf['Gva_ret']
Gva_trn = newdf['Gva_trn']
Gva_whl = newdf['Gva_whl']
Gva_wtr = newdf['Gva_wtr']

#Gva_ind for 2019-2025 years
Gva_ind = Gva_min+Gva_man+Gva_elc+Gva_wtr
#Gva_gds for 2019-2025 years
Gva_gds = Gva_agr + Gva_ind + Gva_con
#Gva_trd for 2019-2025 years
Gva_trd = Gva_ret + Gva_whl
#Gva_srv for 2019-2025 years
Gva_srv = Gva_trd + Gva_trn + Gva_imt + Gva_est + Gva_oth
#Gva_tot for 2019-2025 years
Gva_tot = Gva_gds + Gva_srv

# VRP for 2011-2018
vrp_ind = vrp_min+vrp_man+vrp_elc+vrp_wtr
vrp_gds = vrp_agr + vrp_ind + vrp_con
vrp_trd = vrp_ret + vrp_whl
vrp_srv = vrp_trd + vrp_trn + vrp_imt + vrp_est + vrp_oth
vrp_tot = vrp_gds + vrp_srv
GRP_f = vrp_tot + vrp_tax
# VRP for 2011-2018


l = 0
ta =vrp_tax[7]


Gva_tot_b = Gva_tot.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
Gva_tot_o = Gva_tot.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
Gva_tot_p = Gva_tot.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)


Gva_t = Gva_tot.shift(1)
Gva_t_b = Gva_t.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
Gva_t_o = Gva_t.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
Gva_t_p = Gva_t.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
Gva_t_b[0]= 7150.49
Gva_t_o[0]= 7150.49
Gva_t_p[0]= 7150.49

new = pd.DataFrame(columns=['Tax_b','Tax_o','Tax_p'], index=range(limit_o))
while l<=limit:
    ta_b  = ta * Gva_tot_b[l]/Gva_t_b[l]
    ta_o  = ta * Gva_tot_o[l]/Gva_t_o[l]
    ta_p  = ta * Gva_tot_p[l]/Gva_t_p[l]
    new.loc[l].Tax_b = ta_b 
    new.loc[l].Tax_o = ta_o 
    new.loc[l].Tax_p = ta_p 
    l = l+1    
Tax_b = new['Tax_b']
Tax_o = new['Tax_o']
Tax_p = new['Tax_p']
Tax = Tax_b.append(Tax_o).append(Tax_p).reset_index(drop = True)

#Grp for 2019-2025 years
GRP = Gva_tot + Tax


# Igva_ind for 2019-2025 years
Igva_ind = ((Gva_min*Igva_min)+(Gva_man*Igva_man)+(Gva_elc*Igva_elc)+(Gva_wtr*Igva_wtr))/Gva_ind 
Igva_gds = (Gva_agr*Igva_agr + Gva_ind*Igva_ind + Gva_con*Igva_con)/Gva_gds
Igva_trd = (Gva_whl*Igva_whl + Gva_ret*Igva_ret)/Gva_trd
Igva_srv = (Gva_trd*Igva_trd + Gva_trn*Igva_trn + Gva_imt*Igva_imt + Gva_est*Igva_est + Gva_oth*Igva_oth)/Gva_srv

Igva = (Igva_gds*Gva_gds + Igva_srv*Gva_srv)/Gva_tot

GRP_t = GRP.shift(1)
l_b = GRP_t.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = GRP_t.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = GRP_t.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= 7818.82
l_o[0]= 7818.82
l_p[0]= 7818.82
GRP_t = l_b.append(l_o).append(l_p).reset_index(drop = True)


Itax = Igva

Gva_agr_p = Gva_agr.shift(1)
l_b = Gva_agr_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_agr_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_agr_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_agr[7]
l_o[0]= vrp_agr[7]
l_p[0]= vrp_agr[7]
Gva_agr_p = l_b.append(l_o).append(l_p).reset_index(drop = True)


Gva_con_p = Gva_con.shift(1)
l_b = Gva_con_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_con_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_con_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_con[7]
l_o[0]= vrp_con[7]
l_p[0]= vrp_con[7]
Gva_con_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_elc_p = Gva_elc.shift(1)
l_b = Gva_elc_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_elc_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_elc_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_elc[7]
l_o[0]= vrp_elc[7]
l_p[0]= vrp_elc[7]
Gva_elc_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_est_p = Gva_est.shift(1)
l_b = Gva_est_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_est_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_est_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_est[7]
l_o[0]= vrp_est[7]
l_p[0]= vrp_est[7]
Gva_est_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_imt_p = Gva_imt.shift(1)
l_b = Gva_imt_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_imt_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_imt_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_imt[7]
l_o[0]= vrp_imt[7]
l_p[0]= vrp_imt[7]
Gva_imt_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_man_p = Gva_man.shift(1)
l_b = Gva_man_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_man_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_man_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_man[7]
l_o[0]= vrp_man[7]
l_p[0]= vrp_man[7]
Gva_man_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_min_p = Gva_min.shift(1)
l_b = Gva_min_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_min_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_min_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_min[7]
l_o[0]= vrp_min[7]
l_p[0]= vrp_min[7]
Gva_min_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_oth_p = Gva_oth.shift(1)
l_b = Gva_oth_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_oth_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_oth_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_oth[7]
l_o[0]= vrp_oth[7]
l_p[0]= vrp_oth[7]
Gva_oth_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_trn_p = Gva_trn.shift(1)
l_b = Gva_trn_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_trn_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_trn_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_trn[7]
l_o[0]= vrp_trn[7]
l_p[0]= vrp_trn[7]
Gva_trn_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_wtr_p = Gva_wtr.shift(1)
l_b = Gva_wtr_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_wtr_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_wtr_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_wtr[7]
l_o[0]= vrp_wtr[7]
l_p[0]= vrp_wtr[7]
Gva_wtr_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_ind_p = Gva_ind.shift(1)
l_b = Gva_ind_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_ind_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_ind_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_ind[7]
l_o[0]= vrp_ind[7]
l_p[0]= vrp_ind[7]
Gva_ind_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_trd_p = Gva_trd.shift(1)
l_b = Gva_trd_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_trd_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_trd_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_trd[7]
l_o[0]= vrp_trd[7]
l_p[0]= vrp_trd[7]
Gva_trd_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_ret_p = Gva_ret.shift(1)
l_b = Gva_ret_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_ret_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_ret_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_ret[7]
l_o[0]= vrp_ret[7]
l_p[0]= vrp_ret[7]
Gva_ret_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_whl_p = Gva_whl.shift(1)
l_b = Gva_whl_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_whl_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_whl_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_whl[7]
l_o[0]= vrp_whl[7]
l_p[0]= vrp_whl[7]
Gva_whl_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_gds_p=Gva_gds.shift(1)
l_b = Gva_gds_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_gds_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_gds_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_gds[7]
l_o[0]= vrp_gds[7]
l_p[0]= vrp_gds[7]
Gva_gds_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_srv_p=Gva_srv.shift(1)
l_b = Gva_srv_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_srv_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_srv_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_srv[7]
l_o[0]= vrp_srv[7]
l_p[0]= vrp_srv[7]
Gva_srv_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Gva_tot_p=Gva_tot.shift(1)
l_b = Gva_tot_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Gva_tot_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Gva_tot_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_tot[7]
l_o[0]= vrp_tot[7]
l_p[0]= vrp_tot[7]
Gva_tot_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

Tax_p = Tax.shift(1)
l_b = Tax_p.loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = True)
l_o = Tax_p.loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = True)
l_p = Tax_p.loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = True)
l_b[0]= vrp_tax[7]
l_o[0]= vrp_tax[7]
l_p[0]= vrp_tax[7]
Tax_p = l_b.append(l_o).append(l_p).reset_index(drop = True)

IGRP = (Igva*Gva_tot_p + Itax*Tax_p )/GRP_t

Dgva_agr = Gva_agr/Gva_agr_p/Igva_agr * 10000
Dgva_con = Gva_con/Gva_con_p/Igva_con * 10000
Dgva_elc = Gva_elc/Gva_elc_p/Igva_elc * 10000
Dgva_est = Gva_est/Gva_est_p/Igva_est * 10000
Dgva_imt = Gva_imt/Gva_imt_p/Igva_imt * 10000
Dgva_man = Gva_man/Gva_man_p/Igva_man * 10000
Dgva_min = Gva_min/Gva_min_p/Igva_min * 10000
Dgva_oth = Gva_oth/Gva_oth_p/Igva_oth * 10000
Dgva_trn = Gva_trn/Gva_trn_p/Igva_trn * 10000
Dgva_wtr = Gva_wtr/Gva_wtr_p/Igva_wtr * 10000
Dgva_ind = Gva_ind/Gva_ind_p/Igva_ind * 10000
Dgva_trd = Gva_trd/Gva_trd_p/Igva_trd * 10000
Dgva_ret = Gva_ret/Gva_ret_p/Igva_ret * 10000
Dgva_whl = Gva_whl/Gva_whl_p/Igva_whl * 10000
Dgva_srv = Gva_srv/Gva_srv_p/Igva_srv*10000
Dgva_gds = Gva_gds/Gva_gds_p/Igva_gds*10000

Dtot = GRP/GRP/Igva*10000

Dgrp = Gva_tot/Gva_tot.shift(1)/IGRP*10000
Dtax = Tax/Tax.shift(1)/Itax*10000

newdf = pd.DataFrame(columns=[
'Nagr_vrp',
'Ncon_vrp',
'Nelc_vrp',
'Nest_vrp',
'Nimt_vrp',
'Nman_vrp',
'Nmin_vrp',
'Noth_vrp',
'Ntrn_vrp',
'Nwtr_vrp',
'Nind_vrp',
'Ntrd_vrp',
'Nret_vrp',
'Nwhl_vrp',
'Nsrv_vrp',
'Ngds_vrp',
'Ntotal_vrp',

'lagr_vrp',
'lcon_vrp',
'lelc_vrp',
'lest_vrp',
'limt_vrp',
'lman_vrp',
'lmin_vrp',
'loth_vrp',
'ltrn_vrp',
'lwtr_vrp',
'lind_vrp',
'ltrd_vrp',
'lret_vrp',
'lwhl_vrp',
'lsrv_vrp',
'lgds_vrp',
'ltotal_vrp',

'Dagr_vrp',
'Dcon_vrp',
'Delc_vrp',
'Dest_vrp',
'Dimt_vrp',
'Dman_vrp',
'Dmin_vrp',
'Doth_vrp',
'Dtrn_vrp',
'Dwtr_vrp',
'Dind_vrp',
'Dtrd_vrp',
'Dret_vrp',
'Dwhl_vrp',
'Dsrv_vrp',
'Dgds_vrp',
'Dtotal_vrp',

'Grp',
'Tax',    
'Igrp',
'Itax',
'Dgrp',
'Dtax',
'prognoz'

])


newdf.Nagr_vrp = Gva_agr 
newdf.Ncon_vrp = Gva_con 
newdf.Nelc_vrp = Gva_elc 
newdf.Nest_vrp = Gva_est 
newdf.Nimt_vrp = Gva_imt 
newdf.Nman_vrp = Gva_man 
newdf.Nmin_vrp = Gva_min 
newdf.Noth_vrp = Gva_oth 
newdf.Ntrn_vrp = Gva_trn 
newdf.Nwtr_vrp = Gva_wtr 
newdf.Nind_vrp = Gva_ind 
newdf.Ntrd_vrp = Gva_trd 
newdf.Nret_vrp = Gva_ret 
newdf.Nwhl_vrp = Gva_whl 
newdf.Nsrv_vrp = Gva_srv 
newdf.Ngds_vrp = Gva_gds 
newdf.Ntotal_vrp = GRP


newdf.lagr_vrp = Igva_agr 
newdf.lcon_vrp = Igva_con 
newdf.lelc_vrp = Igva_elc 
newdf.lest_vrp = Igva_est 
newdf.limt_vrp = Igva_imt 
newdf.lman_vrp = Igva_man 
newdf.lmin_vrp = Igva_min 
newdf.loth_vrp = Igva_oth 
newdf.ltrn_vrp = Igva_trn 
newdf.lwtr_vrp = Igva_wtr 
newdf.lind_vrp = Igva_ind 
newdf.ltrd_vrp = Igva_trd 
newdf.lret_vrp = Igva_ret 
newdf.lwhl_vrp = Igva_whl 
newdf.lsrv_vrp = Igva_srv 
newdf.lgds_vrp = Igva_gds 
newdf.ltotal_vrp = Igva 

newdf.Dagr_vrp = Dgva_agr 
newdf.Dcon_vrp = Dgva_con 
newdf.Delc_vrp = Dgva_elc 
newdf.Dest_vrp = Dgva_est 
newdf.Dimt_vrp = Dgva_imt 
newdf.Dman_vrp = Dgva_man 
newdf.Dmin_vrp = Dgva_min 
newdf.Doth_vrp = Dgva_oth 
newdf.Dtrn_vrp = Dgva_trn 
newdf.Dwtr_vrp = Dgva_wtr 
newdf.Dind_vrp = Dgva_ind 
newdf.Dtrd_vrp = Dgva_trd 
newdf.Dret_vrp = Dgva_ret 
newdf.Dwhl_vrp = Dgva_whl 
newdf.Dsrv_vrp = Dgva_srv 
newdf.Dgds_vrp = Dgva_gds 
newdf.Dtotal_vrp = Dtot 

newdf.Grp = Gva_tot 
newdf.Tax = Tax     
newdf.Igrp = IGRP
newdf.Itax = Itax 
newdf.Dgrp = Dgrp 
newdf.Dtax = Dtax 
newdf.prognoz = vrp_prog['prognoz']

newdf.to_sql('vrp_prog_ao', engine, schema='public',if_exists='replace', index = True)

# %%
newdf
# Out:
#    Nagr_vrp Ncon_vrp Nelc_vrp Nest_vrp Nimt_vrp Nman_vrp Nmin_vrp Noth_vrp  \
# 0   67.9339  468.643  33.1627  228.539  21.8056  337.418  3315.74  1523.52
# 1   75.4546  473.127  40.8664   246.29   23.457  363.344  3497.65  1658.24
# 2     83.79  485.051  44.1954  268.365  24.8894  373.038  3598.62  1777.81
# 3   92.2382   496.54  47.2674  289.558  26.1322  380.668  3696.16  1887.24
# 4   101.886  524.716  50.0875  333.743  27.4891  411.357  4284.58  2023.88
# 5   112.337  488.999  51.8955  368.604  28.4083   425.44  4550.71  2148.33
# 6   124.257   389.69  54.6842  400.022  29.4771  430.808  4645.82  2283.42
# 7   67.9339  457.565  33.1627  228.538  21.8054  328.844  3230.47  1523.52
# 8   75.1721  554.301  42.2223  253.133  20.6704  428.839  4201.07  1669.12
# 9   83.1638  558.361  45.5678   277.83  21.6508  440.407  4313.66  1781.89
# 10  91.2027  566.953  49.5824    305.4  22.6896  454.563  4508.46  1891.09
# ...
