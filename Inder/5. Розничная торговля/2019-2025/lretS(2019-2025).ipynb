# %%
import pandas as pd
a = pd.read_csv('lamm(2019-2025).csv')
lamm_b = a['lamm_b']
lamm_o = a['lamm_o']
lamm_p = a['lamm_p']

b=100
o=100
p=100
i=0
newdf = pd.DataFrame(columns=['lretS_b','lretS_o','lretS_p'], index=range(12))
while i<=len(lamm_b)-1:
    b = b * ((lamm_b[i]-100)* 0.512150177861454 + 100)/100
    o = o * ((lamm_o[i]-100)* 0.512150177861454 + 100)/100
    p = p * ((lamm_p[i]-100)* 0.512150177861454 + 100)/100

    newdf.loc[i].lretS_b = b
    newdf.loc[i].lretS_o = o
    newdf.loc[i].lretS_p = p
    
    i = i+1
    
lretS_b = newdf['lretS_b']
lretS_o = newdf['lretS_o']
lretS_p = newdf['lretS_p']

newdf
# Out:
#     lretS_b  lretS_o  lretS_p
# 0   103.144  103.144  103.144
# 1   106.552  106.552  106.602
# 2   110.086  110.085   110.14
# 3   113.735  113.732  113.797
# 4   117.515  117.511  117.589
# 5   121.434   121.43  121.518
# 6   125.492  125.488  101.168
# 7       NaN      NaN      NaN
# 8       NaN      NaN      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN      NaN
# 11      NaN      NaN      NaN

# %%
lrett_bb = lretS_b.shift(1)
lrett_bb[0] = 100
lret_b = lretS_b/lrett_bb*100

lrett_oo = lretS_o.shift(1)
lrett_oo[0] = 100
lret_o = lretS_o/lrett_oo*100

lrett_pp = lretS_p.shift(1)
lrett_pp[0] = 100
lret_p = lretS_p/lrett_pp*100

new = pd.DataFrame(columns=['lret_b','lret_o','lret_p'])

new.lret_b = lret_b
new.lret_o = lret_o
new.lret_p = lret_p

new
# Out:
#      lret_b   lret_o   lret_p
# 0   103.144  103.144  103.144
# 1   103.304  103.305  103.352
# 2   103.317  103.315  103.319
# 3   103.314  103.313   103.32
# 4   103.324  103.323  103.333
# 5   103.335  103.335  103.341
# 6   103.342  103.342  83.2535
# 7       NaN      NaN      NaN
# 8       NaN      NaN      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN      NaN
# 11      NaN      NaN      NaN

# %%
new.to_csv(r'lret_Inder(2019-2025).csv', index = False)
