# %%
import pandas as pd
import numpy as np

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

vrp_fact = pd.read_sql("SELECT * FROM vrp_raion_fact ORDER BY index",engine)
vrp_prog = pd.read_sql("SELECT * FROM vrp_raion_prog ORDER BY index",engine)

atyrau_b = (vrp_prog['Ntot_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
zhylyoi_b = (vrp_prog['Ntot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
inder_b = (vrp_prog['Ntot_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_inder'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
isatai_b = (vrp_prog['Ntot_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
kurmangazy_b = (vrp_prog['Ntot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
kzylkoga_b = (vrp_prog['Ntot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
makat_b = (vrp_prog['Ntot_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_makat'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
makhambet_b = (vrp_prog['Ntot_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltot_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtot_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)



atyrau_o = (vrp_prog['Ntot_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
zhylyoi_o = (vrp_prog['Ntot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
inder_o = (vrp_prog['Ntot_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_inder'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
isatai_o = (vrp_prog['Ntot_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
kurmangazy_o = (vrp_prog['Ntot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
kzylkoga_o = (vrp_prog['Ntot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
makat_o = (vrp_prog['Ntot_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_makat'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
makhambet_o = (vrp_prog['Ntot_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)



atyrau_p = (vrp_prog['Ntot_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_atyrau'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
zhylyoi_p = (vrp_prog['Ntot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_zhylyoi'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
inder_p = (vrp_prog['Ntot_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_inder'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
isatai_p = (vrp_prog['Ntot_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_isatai'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
kurmangazy_p = (vrp_prog['Ntot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_kurmangazy'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
kzylkoga_p = (vrp_prog['Ntot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_kzylkoga'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
makat_p = (vrp_prog['Ntot_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_makat'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
makhambet_p = (vrp_prog['Ntot_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltot_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtot_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_makhambet'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)


Ntot_atyrau = vrp_fact['Ntot_atyrau'].append(atyrau_b['Ntot_atyrau']).reset_index(drop = True)
Ngds_atyrau = vrp_fact['Ngds_atyrau'].append(atyrau_b['Ngds_atyrau']).reset_index(drop = True)
Nagr_atyrau = vrp_fact['Nagr_atyrau'].append(atyrau_b['Nagr_atyrau']).reset_index(drop = True)
Nmin_atyrau = vrp_fact['Nmin_atyrau'].append(atyrau_b['Nmin_atyrau']).reset_index(drop = True)
Ncon_atyrau = vrp_fact['Ncon_atyrau'].append(atyrau_b['Ncon_atyrau']).reset_index(drop = True)
Nman_atyrau = vrp_fact['Nman_atyrau'].append(atyrau_b['Nman_atyrau']).reset_index(drop = True)
Nret_atyrau = vrp_fact['Nret_atyrau'].append(atyrau_b['Nret_atyrau']).reset_index(drop = True)
Nwhl_atyrau = vrp_fact['Nwhl_atyrau'].append(atyrau_b['Nwhl_atyrau']).reset_index(drop = True)
Ntrd_atyrau = vrp_fact['Ntrd_atyrau'].append(atyrau_b['Ntrd_atyrau']).reset_index(drop = True)
Nsrv_atyrau = vrp_fact['Nsrv_atyrau'].append(atyrau_b['Nsrv_atyrau']).reset_index(drop = True)
Nwtr_atyrau = vrp_fact['Nwtr_atyrau'].append(atyrau_b['Nwtr_atyrau']).reset_index(drop = True)
Nelc_atyrau = vrp_fact['Nelc_atyrau'].append(atyrau_b['Nelc_atyrau']).reset_index(drop = True)
Nind_atyrau = vrp_fact['Nind_atyrau'].append(atyrau_b['Nind_atyrau']).reset_index(drop = True)
ltot_atyrau = vrp_fact['ltot_atyrau'].append(atyrau_b['ltot_atyrau']).reset_index(drop = True)
lgds_atyrau = vrp_fact['lgds_atyrau'].append(atyrau_b['lgds_atyrau']).reset_index(drop = True)
lagr_atyrau = vrp_fact['lagr_atyrau'].append(atyrau_b['lagr_atyrau']).reset_index(drop = True)
lmin_atyrau = vrp_fact['lmin_atyrau'].append(atyrau_b['lmin_atyrau']).reset_index(drop = True)
lcon_atyrau = vrp_fact['lcon_atyrau'].append(atyrau_b['lcon_atyrau']).reset_index(drop = True)
lman_atyrau = vrp_fact['lman_atyrau'].append(atyrau_b['lman_atyrau']).reset_index(drop = True)
lret_atyrau = vrp_fact['lret_atyrau'].append(atyrau_b['lret_atyrau']).reset_index(drop = True)
lwhl_atyrau = vrp_fact['lwhl_atyrau'].append(atyrau_b['lwhl_atyrau']).reset_index(drop = True)
ltrd_atyrau = vrp_fact['ltrd_atyrau'].append(atyrau_b['ltrd_atyrau']).reset_index(drop = True)
lsrv_atyrau = vrp_fact['lsrv_atyrau'].append(atyrau_b['lsrv_atyrau']).reset_index(drop = True)
lwtr_atyrau = vrp_fact['lwtr_atyrau'].append(atyrau_b['lwtr_atyrau']).reset_index(drop = True)
lelc_atyrau = vrp_fact['lelc_atyrau'].append(atyrau_b['lelc_atyrau']).reset_index(drop = True)
lind_atyrau = vrp_fact['lind_atyrau'].append(atyrau_b['lind_atyrau']).reset_index(drop = True)
Dtot_atyrau = vrp_fact['Dtot_atyrau'].append(atyrau_b['Dtot_atyrau']).reset_index(drop = True)
Dgds_atyrau = vrp_fact['Dgds_atyrau'].append(atyrau_b['Dgds_atyrau']).reset_index(drop = True)
Dagr_atyrau = vrp_fact['Dagr_atyrau'].append(atyrau_b['Dagr_atyrau']).reset_index(drop = True)
Dmin_atyrau = vrp_fact['Dmin_atyrau'].append(atyrau_b['Dmin_atyrau']).reset_index(drop = True)
Dcon_atyrau = vrp_fact['Dcon_atyrau'].append(atyrau_b['Dcon_atyrau']).reset_index(drop = True)
Dman_atyrau = vrp_fact['Dman_atyrau'].append(atyrau_b['Dman_atyrau']).reset_index(drop = True)
Dret_atyrau = vrp_fact['Dret_atyrau'].append(atyrau_b['Dret_atyrau']).reset_index(drop = True)
Dwhl_atyrau = vrp_fact['Dwhl_atyrau'].append(atyrau_b['Dwhl_atyrau']).reset_index(drop = True)
Dtrd_atyrau = vrp_fact['Dtrd_atyrau'].append(atyrau_b['Dtrd_atyrau']).reset_index(drop = True)
Dsrv_atyrau = vrp_fact['Dsrv_atyrau'].append(atyrau_b['Dsrv_atyrau']).reset_index(drop = True)
Dwtr_atyrau = vrp_fact['Dwtr_atyrau'].append(atyrau_b['Dwtr_atyrau']).reset_index(drop = True)
Delc_atyrau = vrp_fact['Delc_atyrau'].append(atyrau_b['Delc_atyrau']).reset_index(drop = True)
Dind_atyrau = vrp_fact['Dind_atyrau'].append(atyrau_b['Dind_atyrau']).reset_index(drop = True)
Ntot_inder = vrp_fact['Ntot_inder'].append(inder_b['Ntot_inder']).reset_index(drop = True)
Ngds_inder = vrp_fact['Ngds_inder'].append(inder_b['Ngds_inder']).reset_index(drop = True)
Nagr_inder = vrp_fact['Nagr_inder'].append(inder_b['Nagr_inder']).reset_index(drop = True)
Nmin_inder = vrp_fact['Nmin_inder'].append(inder_b['Nmin_inder']).reset_index(drop = True)
Ncon_inder = vrp_fact['Ncon_inder'].append(inder_b['Ncon_inder']).reset_index(drop = True)
Nman_inder = vrp_fact['Nman_inder'].append(inder_b['Nman_inder']).reset_index(drop = True)
Nret_inder = vrp_fact['Nret_inder'].append(inder_b['Nret_inder']).reset_index(drop = True)
Nwhl_inder = vrp_fact['Nwhl_inder'].append(inder_b['Nwhl_inder']).reset_index(drop = True)
Ntrd_inder = vrp_fact['Ntrd_inder'].append(inder_b['Ntrd_inder']).reset_index(drop = True)
Nsrv_inder = vrp_fact['Nsrv_inder'].append(inder_b['Nsrv_inder']).reset_index(drop = True)
Nwtr_inder = vrp_fact['Nwtr_inder'].append(inder_b['Nwtr_inder']).reset_index(drop = True)
Nelc_inder = vrp_fact['Nelc_inder'].append(inder_b['Nelc_inder']).reset_index(drop = True)
Nind_inder = vrp_fact['Nind_inder'].append(inder_b['Nind_inder']).reset_index(drop = True)
ltot_inder = vrp_fact['ltot_inder'].append(inder_b['ltot_inder']).reset_index(drop = True)
lgds_inder = vrp_fact['lgds_inder'].append(inder_b['lgds_inder']).reset_index(drop = True)
lagr_inder = vrp_fact['lagr_inder'].append(inder_b['lagr_inder']).reset_index(drop = True)
lmin_inder = vrp_fact['lmin_inder'].append(inder_b['lmin_inder']).reset_index(drop = True)
lcon_inder = vrp_fact['lcon_inder'].append(inder_b['lcon_inder']).reset_index(drop = True)
lman_inder = vrp_fact['lman_inder'].append(inder_b['lman_inder']).reset_index(drop = True)
lret_inder = vrp_fact['lret_inder'].append(inder_b['lret_inder']).reset_index(drop = True)
lwhl_inder = vrp_fact['lwhl_inder'].append(inder_b['lwhl_inder']).reset_index(drop = True)
ltrd_inder = vrp_fact['ltrd_inder'].append(inder_b['ltrd_inder']).reset_index(drop = True)
lsrv_inder = vrp_fact['lsrv_inder'].append(inder_b['lsrv_inder']).reset_index(drop = True)
lwtr_inder = vrp_fact['lwtr_inder'].append(inder_b['lwtr_inder']).reset_index(drop = True)
lelc_inder = vrp_fact['lelc_inder'].append(inder_b['lelc_inder']).reset_index(drop = True)
lind_inder = vrp_fact['lind_inder'].append(inder_b['lind_inder']).reset_index(drop = True)
Dtot_inder = vrp_fact['Dtot_inder'].append(inder_b['Dtot_inder']).reset_index(drop = True)
Dgds_inder = vrp_fact['Dgds_inder'].append(inder_b['Dgds_inder']).reset_index(drop = True)
Dagr_inder = vrp_fact['Dagr_inder'].append(inder_b['Dagr_inder']).reset_index(drop = True)
Dmin_inder = vrp_fact['Dmin_inder'].append(inder_b['Dmin_inder']).reset_index(drop = True)
Dcon_inder = vrp_fact['Dcon_inder'].append(inder_b['Dcon_inder']).reset_index(drop = True)
Dman_inder = vrp_fact['Dman_inder'].append(inder_b['Dman_inder']).reset_index(drop = True)
Dret_inder = vrp_fact['Dret_inder'].append(inder_b['Dret_inder']).reset_index(drop = True)
Dwhl_inder = vrp_fact['Dwhl_inder'].append(inder_b['Dwhl_inder']).reset_index(drop = True)
Dtrd_inder = vrp_fact['Dtrd_inder'].append(inder_b['Dtrd_inder']).reset_index(drop = True)
Dsrv_inder = vrp_fact['Dsrv_inder'].append(inder_b['Dsrv_inder']).reset_index(drop = True)
Dwtr_inder = vrp_fact['Dwtr_inder'].append(inder_b['Dwtr_inder']).reset_index(drop = True)
Delc_inder = vrp_fact['Delc_inder'].append(inder_b['Delc_inder']).reset_index(drop = True)
Dind_inder = vrp_fact['Dind_inder'].append(inder_b['Dind_inder']).reset_index(drop = True)
Ntot_isatai = vrp_fact['Ntot_isatai'].append(isatai_b['Ntot_isatai']).reset_index(drop = True)
Ngds_isatai = vrp_fact['Ngds_isatai'].append(isatai_b['Ngds_isatai']).reset_index(drop = True)
Nagr_isatai = vrp_fact['Nagr_isatai'].append(isatai_b['Nagr_isatai']).reset_index(drop = True)
Nmin_isatai = vrp_fact['Nmin_isatai'].append(isatai_b['Nmin_isatai']).reset_index(drop = True)
Ncon_isatai = vrp_fact['Ncon_isatai'].append(isatai_b['Ncon_isatai']).reset_index(drop = True)
Nman_isatai = vrp_fact['Nman_isatai'].append(isatai_b['Nman_isatai']).reset_index(drop = True)
Nret_isatai = vrp_fact['Nret_isatai'].append(isatai_b['Nret_isatai']).reset_index(drop = True)
Nwhl_isatai = vrp_fact['Nwhl_isatai'].append(isatai_b['Nwhl_isatai']).reset_index(drop = True)
Ntrd_isatai = vrp_fact['Ntrd_isatai'].append(isatai_b['Ntrd_isatai']).reset_index(drop = True)
Nsrv_isatai = vrp_fact['Nsrv_isatai'].append(isatai_b['Nsrv_isatai']).reset_index(drop = True)
Nwtr_isatai = vrp_fact['Nwtr_isatai'].append(isatai_b['Nwtr_isatai']).reset_index(drop = True)
Nelc_isatai = vrp_fact['Nelc_isatai'].append(isatai_b['Nelc_isatai']).reset_index(drop = True)
Nind_isatai = vrp_fact['Nind_isatai'].append(isatai_b['Nind_isatai']).reset_index(drop = True)
ltot_isatai = vrp_fact['ltot_isatai'].append(isatai_b['ltot_isatai']).reset_index(drop = True)
lgds_isatai = vrp_fact['lgds_isatai'].append(isatai_b['lgds_isatai']).reset_index(drop = True)
lagr_isatai = vrp_fact['lagr_isatai'].append(isatai_b['lagr_isatai']).reset_index(drop = True)
lmin_isatai = vrp_fact['lmin_isatai'].append(isatai_b['lmin_isatai']).reset_index(drop = True)
lcon_isatai = vrp_fact['lcon_isatai'].append(isatai_b['lcon_isatai']).reset_index(drop = True)
lman_isatai = vrp_fact['lman_isatai'].append(isatai_b['lman_isatai']).reset_index(drop = True)
lret_isatai = vrp_fact['lret_isatai'].append(isatai_b['lret_isatai']).reset_index(drop = True)
lwhl_isatai = vrp_fact['lwhl_isatai'].append(isatai_b['lwhl_isatai']).reset_index(drop = True)
ltrd_isatai = vrp_fact['ltrd_isatai'].append(isatai_b['ltrd_isatai']).reset_index(drop = True)
lsrv_isatai = vrp_fact['lsrv_isatai'].append(isatai_b['lsrv_isatai']).reset_index(drop = True)
lwtr_isatai = vrp_fact['lwtr_isatai'].append(isatai_b['lwtr_isatai']).reset_index(drop = True)
lelc_isatai = vrp_fact['lelc_isatai'].append(isatai_b['lelc_isatai']).reset_index(drop = True)
lind_isatai = vrp_fact['lind_isatai'].append(isatai_b['lind_isatai']).reset_index(drop = True)
Dtot_isatai = vrp_fact['Dtot_isatai'].append(isatai_b['Dtot_isatai']).reset_index(drop = True)
Dgds_isatai = vrp_fact['Dgds_isatai'].append(isatai_b['Dgds_isatai']).reset_index(drop = True)
Dagr_isatai = vrp_fact['Dagr_isatai'].append(isatai_b['Dagr_isatai']).reset_index(drop = True)
Dmin_isatai = vrp_fact['Dmin_isatai'].append(isatai_b['Dmin_isatai']).reset_index(drop = True)
Dcon_isatai = vrp_fact['Dcon_isatai'].append(isatai_b['Dcon_isatai']).reset_index(drop = True)
Dman_isatai = vrp_fact['Dman_isatai'].append(isatai_b['Dman_isatai']).reset_index(drop = True)
Dret_isatai = vrp_fact['Dret_isatai'].append(isatai_b['Dret_isatai']).reset_index(drop = True)
Dwhl_isatai = vrp_fact['Dwhl_isatai'].append(isatai_b['Dwhl_isatai']).reset_index(drop = True)
Dtrd_isatai = vrp_fact['Dtrd_isatai'].append(isatai_b['Dtrd_isatai']).reset_index(drop = True)
Dsrv_isatai = vrp_fact['Dsrv_isatai'].append(isatai_b['Dsrv_isatai']).reset_index(drop = True)
Dwtr_isatai = vrp_fact['Dwtr_isatai'].append(isatai_b['Dwtr_isatai']).reset_index(drop = True)
Delc_isatai = vrp_fact['Delc_isatai'].append(isatai_b['Delc_isatai']).reset_index(drop = True)
Dind_isatai = vrp_fact['Dind_isatai'].append(isatai_b['Dind_isatai']).reset_index(drop = True)
Ntot_kurmangazy = vrp_fact['Ntot_kurmangazy'].append(kurmangazy_b['Ntot_kurmangazy']).reset_index(drop = True)
Ngds_kurmangazy = vrp_fact['Ngds_kurmangazy'].append(kurmangazy_b['Ngds_kurmangazy']).reset_index(drop = True)
Nagr_kurmangazy = vrp_fact['Nagr_kurmangazy'].append(kurmangazy_b['Nagr_kurmangazy']).reset_index(drop = True)
Nmin_kurmangazy = vrp_fact['Nmin_kurmangazy'].append(kurmangazy_b['Nmin_kurmangazy']).reset_index(drop = True)
Ncon_kurmangazy = vrp_fact['Ncon_kurmangazy'].append(kurmangazy_b['Ncon_kurmangazy']).reset_index(drop = True)
Nman_kurmangazy = vrp_fact['Nman_kurmangazy'].append(kurmangazy_b['Nman_kurmangazy']).reset_index(drop = True)
Nret_kurmangazy = vrp_fact['Nret_kurmangazy'].append(kurmangazy_b['Nret_kurmangazy']).reset_index(drop = True)
Nwhl_kurmangazy = vrp_fact['Nwhl_kurmangazy'].append(kurmangazy_b['Nwhl_kurmangazy']).reset_index(drop = True)
Ntrd_kurmangazy = vrp_fact['Ntrd_kurmangazy'].append(kurmangazy_b['Ntrd_kurmangazy']).reset_index(drop = True)
Nsrv_kurmangazy = vrp_fact['Nsrv_kurmangazy'].append(kurmangazy_b['Nsrv_kurmangazy']).reset_index(drop = True)
Nwtr_kurmangazy = vrp_fact['Nwtr_kurmangazy'].append(kurmangazy_b['Nwtr_kurmangazy']).reset_index(drop = True)
Nelc_kurmangazy = vrp_fact['Nelc_kurmangazy'].append(kurmangazy_b['Nelc_kurmangazy']).reset_index(drop = True)
Nind_kurmangazy = vrp_fact['Nind_kurmangazy'].append(kurmangazy_b['Nind_kurmangazy']).reset_index(drop = True)
ltot_kurmangazy = vrp_fact['ltot_kurmangazy'].append(kurmangazy_b['ltot_kurmangazy']).reset_index(drop = True)
lgds_kurmangazy = vrp_fact['lgds_kurmangazy'].append(kurmangazy_b['lgds_kurmangazy']).reset_index(drop = True)
lagr_kurmangazy = vrp_fact['lagr_kurmangazy'].append(kurmangazy_b['lagr_kurmangazy']).reset_index(drop = True)
lmin_kurmangazy = vrp_fact['lmin_kurmangazy'].append(kurmangazy_b['lmin_kurmangazy']).reset_index(drop = True)
lcon_kurmangazy = vrp_fact['lcon_kurmangazy'].append(kurmangazy_b['lcon_kurmangazy']).reset_index(drop = True)
lman_kurmangazy = vrp_fact['lman_kurmangazy'].append(kurmangazy_b['lman_kurmangazy']).reset_index(drop = True)
lret_kurmangazy = vrp_fact['lret_kurmangazy'].append(kurmangazy_b['lret_kurmangazy']).reset_index(drop = True)
lwhl_kurmangazy = vrp_fact['lwhl_kurmangazy'].append(kurmangazy_b['lwhl_kurmangazy']).reset_index(drop = True)
ltrd_kurmangazy = vrp_fact['ltrd_kurmangazy'].append(kurmangazy_b['ltrd_kurmangazy']).reset_index(drop = True)
lsrv_kurmangazy = vrp_fact['lsrv_kurmangazy'].append(kurmangazy_b['lsrv_kurmangazy']).reset_index(drop = True)
lwtr_kurmangazy = vrp_fact['lwtr_kurmangazy'].append(kurmangazy_b['lwtr_kurmangazy']).reset_index(drop = True)
lelc_kurmangazy = vrp_fact['lelc_kurmangazy'].append(kurmangazy_b['lelc_kurmangazy']).reset_index(drop = True)
lind_kurmangazy = vrp_fact['lind_kurmangazy'].append(kurmangazy_b['lind_kurmangazy']).reset_index(drop = True)
Dtot_kurmangazy = vrp_fact['Dtot_kurmangazy'].append(kurmangazy_b['Dtot_kurmangazy']).reset_index(drop = True)
Dgds_kurmangazy = vrp_fact['Dgds_kurmangazy'].append(kurmangazy_b['Dgds_kurmangazy']).reset_index(drop = True)
Dagr_kurmangazy = vrp_fact['Dagr_kurmangazy'].append(kurmangazy_b['Dagr_kurmangazy']).reset_index(drop = True)
Dmin_kurmangazy = vrp_fact['Dmin_kurmangazy'].append(kurmangazy_b['Dmin_kurmangazy']).reset_index(drop = True)
Dcon_kurmangazy = vrp_fact['Dcon_kurmangazy'].append(kurmangazy_b['Dcon_kurmangazy']).reset_index(drop = True)
Dman_kurmangazy = vrp_fact['Dman_kurmangazy'].append(kurmangazy_b['Dman_kurmangazy']).reset_index(drop = True)
Dret_kurmangazy = vrp_fact['Dret_kurmangazy'].append(kurmangazy_b['Dret_kurmangazy']).reset_index(drop = True)
Dwhl_kurmangazy = vrp_fact['Dwhl_kurmangazy'].append(kurmangazy_b['Dwhl_kurmangazy']).reset_index(drop = True)
Dtrd_kurmangazy = vrp_fact['Dtrd_kurmangazy'].append(kurmangazy_b['Dtrd_kurmangazy']).reset_index(drop = True)
Dsrv_kurmangazy = vrp_fact['Dsrv_kurmangazy'].append(kurmangazy_b['Dsrv_kurmangazy']).reset_index(drop = True)
Dwtr_kurmangazy = vrp_fact['Dwtr_kurmangazy'].append(kurmangazy_b['Dwtr_kurmangazy']).reset_index(drop = True)
Delc_kurmangazy = vrp_fact['Delc_kurmangazy'].append(kurmangazy_b['Delc_kurmangazy']).reset_index(drop = True)
Dind_kurmangazy = vrp_fact['Dind_kurmangazy'].append(kurmangazy_b['Dind_kurmangazy']).reset_index(drop = True)
Ntot_kzylkoga = vrp_fact['Ntot_kzylkoga'].append(kzylkoga_b['Ntot_kzylkoga']).reset_index(drop = True)
Ngds_kzylkoga = vrp_fact['Ngds_kzylkoga'].append(kzylkoga_b['Ngds_kzylkoga']).reset_index(drop = True)
Nagr_kzylkoga = vrp_fact['Nagr_kzylkoga'].append(kzylkoga_b['Nagr_kzylkoga']).reset_index(drop = True)
Nmin_kzylkoga = vrp_fact['Nmin_kzylkoga'].append(kzylkoga_b['Nmin_kzylkoga']).reset_index(drop = True)
Ncon_kzylkoga = vrp_fact['Ncon_kzylkoga'].append(kzylkoga_b['Ncon_kzylkoga']).reset_index(drop = True)
Nman_kzylkoga = vrp_fact['Nman_kzylkoga'].append(kzylkoga_b['Nman_kzylkoga']).reset_index(drop = True)
Nret_kzylkoga = vrp_fact['Nret_kzylkoga'].append(kzylkoga_b['Nret_kzylkoga']).reset_index(drop = True)
Nwhl_kzylkoga = vrp_fact['Nwhl_kzylkoga'].append(kzylkoga_b['Nwhl_kzylkoga']).reset_index(drop = True)
Ntrd_kzylkoga = vrp_fact['Ntrd_kzylkoga'].append(kzylkoga_b['Ntrd_kzylkoga']).reset_index(drop = True)
Nsrv_kzylkoga = vrp_fact['Nsrv_kzylkoga'].append(kzylkoga_b['Nsrv_kzylkoga']).reset_index(drop = True)
Nwtr_kzylkoga = vrp_fact['Nwtr_kzylkoga'].append(kzylkoga_b['Nwtr_kzylkoga']).reset_index(drop = True)
Nelc_kzylkoga = vrp_fact['Nelc_kzylkoga'].append(kzylkoga_b['Nelc_kzylkoga']).reset_index(drop = True)
Nind_kzylkoga = vrp_fact['Nind_kzylkoga'].append(kzylkoga_b['Nind_kzylkoga']).reset_index(drop = True)
ltot_kzylkoga = vrp_fact['ltot_kzylkoga'].append(kzylkoga_b['ltot_kzylkoga']).reset_index(drop = True)
lgds_kzylkoga = vrp_fact['lgds_kzylkoga'].append(kzylkoga_b['lgds_kzylkoga']).reset_index(drop = True)
lagr_kzylkoga = vrp_fact['lagr_kzylkoga'].append(kzylkoga_b['lagr_kzylkoga']).reset_index(drop = True)
lmin_kzylkoga = vrp_fact['lmin_kzylkoga'].append(kzylkoga_b['lmin_kzylkoga']).reset_index(drop = True)
lcon_kzylkoga = vrp_fact['lcon_kzylkoga'].append(kzylkoga_b['lcon_kzylkoga']).reset_index(drop = True)
lman_kzylkoga = vrp_fact['lman_kzylkoga'].append(kzylkoga_b['lman_kzylkoga']).reset_index(drop = True)
lret_kzylkoga = vrp_fact['lret_kzylkoga'].append(kzylkoga_b['lret_kzylkoga']).reset_index(drop = True)
lwhl_kzylkoga = vrp_fact['lwhl_kzylkoga'].append(kzylkoga_b['lwhl_kzylkoga']).reset_index(drop = True)
ltrd_kzylkoga = vrp_fact['ltrd_kzylkoga'].append(kzylkoga_b['ltrd_kzylkoga']).reset_index(drop = True)
lsrv_kzylkoga = vrp_fact['lsrv_kzylkoga'].append(kzylkoga_b['lsrv_kzylkoga']).reset_index(drop = True)
lwtr_kzylkoga = vrp_fact['lwtr_kzylkoga'].append(kzylkoga_b['lwtr_kzylkoga']).reset_index(drop = True)
lelc_kzylkoga = vrp_fact['lelc_kzylkoga'].append(kzylkoga_b['lelc_kzylkoga']).reset_index(drop = True)
lind_kzylkoga = vrp_fact['lind_kzylkoga'].append(kzylkoga_b['lind_kzylkoga']).reset_index(drop = True)
Dtot_kzylkoga = vrp_fact['Dtot_kzylkoga'].append(kzylkoga_b['Dtot_kzylkoga']).reset_index(drop = True)
Dgds_kzylkoga = vrp_fact['Dgds_kzylkoga'].append(kzylkoga_b['Dgds_kzylkoga']).reset_index(drop = True)
Dagr_kzylkoga = vrp_fact['Dagr_kzylkoga'].append(kzylkoga_b['Dagr_kzylkoga']).reset_index(drop = True)
Dmin_kzylkoga = vrp_fact['Dmin_kzylkoga'].append(kzylkoga_b['Dmin_kzylkoga']).reset_index(drop = True)
Dcon_kzylkoga = vrp_fact['Dcon_kzylkoga'].append(kzylkoga_b['Dcon_kzylkoga']).reset_index(drop = True)
Dman_kzylkoga = vrp_fact['Dman_kzylkoga'].append(kzylkoga_b['Dman_kzylkoga']).reset_index(drop = True)
Dret_kzylkoga = vrp_fact['Dret_kzylkoga'].append(kzylkoga_b['Dret_kzylkoga']).reset_index(drop = True)
Dwhl_kzylkoga = vrp_fact['Dwhl_kzylkoga'].append(kzylkoga_b['Dwhl_kzylkoga']).reset_index(drop = True)
Dtrd_kzylkoga = vrp_fact['Dtrd_kzylkoga'].append(kzylkoga_b['Dtrd_kzylkoga']).reset_index(drop = True)
Dsrv_kzylkoga = vrp_fact['Dsrv_kzylkoga'].append(kzylkoga_b['Dsrv_kzylkoga']).reset_index(drop = True)
Dwtr_kzylkoga = vrp_fact['Dwtr_kzylkoga'].append(kzylkoga_b['Dwtr_kzylkoga']).reset_index(drop = True)
Delc_kzylkoga = vrp_fact['Delc_kzylkoga'].append(kzylkoga_b['Delc_kzylkoga']).reset_index(drop = True)
Dind_kzylkoga = vrp_fact['Dind_kzylkoga'].append(kzylkoga_b['Dind_kzylkoga']).reset_index(drop = True)
Ntot_makat = vrp_fact['Ntot_makat'].append(makat_b['Ntot_makat']).reset_index(drop = True)
Ngds_makat = vrp_fact['Ngds_makat'].append(makat_b['Ngds_makat']).reset_index(drop = True)
Nagr_makat = vrp_fact['Nagr_makat'].append(makat_b['Nagr_makat']).reset_index(drop = True)
Nmin_makat = vrp_fact['Nmin_makat'].append(makat_b['Nmin_makat']).reset_index(drop = True)
Ncon_makat = vrp_fact['Ncon_makat'].append(makat_b['Ncon_makat']).reset_index(drop = True)
Nman_makat = vrp_fact['Nman_makat'].append(makat_b['Nman_makat']).reset_index(drop = True)
Nret_makat = vrp_fact['Nret_makat'].append(makat_b['Nret_makat']).reset_index(drop = True)
Nwhl_makat = vrp_fact['Nwhl_makat'].append(makat_b['Nwhl_makat']).reset_index(drop = True)
Ntrd_makat = vrp_fact['Ntrd_makat'].append(makat_b['Ntrd_makat']).reset_index(drop = True)
Nsrv_makat = vrp_fact['Nsrv_makat'].append(makat_b['Nsrv_makat']).reset_index(drop = True)
Nwtr_makat = vrp_fact['Nwtr_makat'].append(makat_b['Nwtr_makat']).reset_index(drop = True)
Nelc_makat = vrp_fact['Nelc_makat'].append(makat_b['Nelc_makat']).reset_index(drop = True)
Nind_makat = vrp_fact['Nind_makat'].append(makat_b['Nind_makat']).reset_index(drop = True)
ltot_makat = vrp_fact['ltot_makat'].append(makat_b['ltot_makat']).reset_index(drop = True)
lgds_makat = vrp_fact['lgds_makat'].append(makat_b['lgds_makat']).reset_index(drop = True)
lagr_makat = vrp_fact['lagr_makat'].append(makat_b['lagr_makat']).reset_index(drop = True)
lmin_makat = vrp_fact['lmin_makat'].append(makat_b['lmin_makat']).reset_index(drop = True)
lcon_makat = vrp_fact['lcon_makat'].append(makat_b['lcon_makat']).reset_index(drop = True)
lman_makat = vrp_fact['lman_makat'].append(makat_b['lman_makat']).reset_index(drop = True)
lret_makat = vrp_fact['lret_makat'].append(makat_b['lret_makat']).reset_index(drop = True)
lwhl_makat = vrp_fact['lwhl_makat'].append(makat_b['lwhl_makat']).reset_index(drop = True)
ltrd_makat = vrp_fact['ltrd_makat'].append(makat_b['ltrd_makat']).reset_index(drop = True)
lsrv_makat = vrp_fact['lsrv_makat'].append(makat_b['lsrv_makat']).reset_index(drop = True)
lwtr_makat = vrp_fact['lwtr_makat'].append(makat_b['lwtr_makat']).reset_index(drop = True)
lelc_makat = vrp_fact['lelc_makat'].append(makat_b['lelc_makat']).reset_index(drop = True)
lind_makat = vrp_fact['lind_makat'].append(makat_b['lind_makat']).reset_index(drop = True)
Dtot_makat = vrp_fact['Dtot_makat'].append(makat_b['Dtot_makat']).reset_index(drop = True)
Dgds_makat = vrp_fact['Dgds_makat'].append(makat_b['Dgds_makat']).reset_index(drop = True)
Dagr_makat = vrp_fact['Dagr_makat'].append(makat_b['Dagr_makat']).reset_index(drop = True)
Dmin_makat = vrp_fact['Dmin_makat'].append(makat_b['Dmin_makat']).reset_index(drop = True)
Dcon_makat = vrp_fact['Dcon_makat'].append(makat_b['Dcon_makat']).reset_index(drop = True)
Dman_makat = vrp_fact['Dman_makat'].append(makat_b['Dman_makat']).reset_index(drop = True)
Dret_makat = vrp_fact['Dret_makat'].append(makat_b['Dret_makat']).reset_index(drop = True)
Dwhl_makat = vrp_fact['Dwhl_makat'].append(makat_b['Dwhl_makat']).reset_index(drop = True)
Dtrd_makat = vrp_fact['Dtrd_makat'].append(makat_b['Dtrd_makat']).reset_index(drop = True)
Dsrv_makat = vrp_fact['Dsrv_makat'].append(makat_b['Dsrv_makat']).reset_index(drop = True)
Dwtr_makat = vrp_fact['Dwtr_makat'].append(makat_b['Dwtr_makat']).reset_index(drop = True)
Delc_makat = vrp_fact['Delc_makat'].append(makat_b['Delc_makat']).reset_index(drop = True)
Dind_makat = vrp_fact['Dind_makat'].append(makat_b['Dind_makat']).reset_index(drop = True)
Ntot_makhambet = vrp_fact['Ntot_makhambet'].append(makhambet_b['Ntot_makhambet']).reset_index(drop = True)
Ngds_makhambet = vrp_fact['Ngds_makhambet'].append(makhambet_b['Ngds_makhambet']).reset_index(drop = True)
Nagr_makhambet = vrp_fact['Nagr_makhambet'].append(makhambet_b['Nagr_makhambet']).reset_index(drop = True)
Nmin_makhambet = vrp_fact['Nmin_makhambet'].append(makhambet_b['Nmin_makhambet']).reset_index(drop = True)
Ncon_makhambet = vrp_fact['Ncon_makhambet'].append(makhambet_b['Ncon_makhambet']).reset_index(drop = True)
Nman_makhambet = vrp_fact['Nman_makhambet'].append(makhambet_b['Nman_makhambet']).reset_index(drop = True)
Nret_makhambet = vrp_fact['Nret_makhambet'].append(makhambet_b['Nret_makhambet']).reset_index(drop = True)
Nwhl_makhambet = vrp_fact['Nwhl_makhambet'].append(makhambet_b['Nwhl_makhambet']).reset_index(drop = True)
Ntrd_makhambet = vrp_fact['Ntrd_makhambet'].append(makhambet_b['Ntrd_makhambet']).reset_index(drop = True)
Nsrv_makhambet = vrp_fact['Nsrv_makhambet'].append(makhambet_b['Nsrv_makhambet']).reset_index(drop = True)
Nwtr_makhambet = vrp_fact['Nwtr_makhambet'].append(makhambet_b['Nwtr_makhambet']).reset_index(drop = True)
Nelc_makhambet = vrp_fact['Nelc_makhambet'].append(makhambet_b['Nelc_makhambet']).reset_index(drop = True)
Nind_makhambet = vrp_fact['Nind_makhambet'].append(makhambet_b['Nind_makhambet']).reset_index(drop = True)
ltot_makhambet = vrp_fact['ltot_makhambet'].append(makhambet_b['ltot_makhambet']).reset_index(drop = True)
lgds_makhambet = vrp_fact['lgds_makhambet'].append(makhambet_b['lgds_makhambet']).reset_index(drop = True)
lagr_makhambet = vrp_fact['lagr_makhambet'].append(makhambet_b['lagr_makhambet']).reset_index(drop = True)
lmin_makhambet = vrp_fact['lmin_makhambet'].append(makhambet_b['lmin_makhambet']).reset_index(drop = True)
lcon_makhambet = vrp_fact['lcon_makhambet'].append(makhambet_b['lcon_makhambet']).reset_index(drop = True)
lman_makhambet = vrp_fact['lman_makhambet'].append(makhambet_b['lman_makhambet']).reset_index(drop = True)
lret_makhambet = vrp_fact['lret_makhambet'].append(makhambet_b['lret_makhambet']).reset_index(drop = True)
lwhl_makhambet = vrp_fact['lwhl_makhambet'].append(makhambet_b['lwhl_makhambet']).reset_index(drop = True)
ltrd_makhambet = vrp_fact['ltrd_makhambet'].append(makhambet_b['ltrd_makhambet']).reset_index(drop = True)
lsrv_makhambet = vrp_fact['lsrv_makhambet'].append(makhambet_b['lsrv_makhambet']).reset_index(drop = True)
lwtr_makhambet = vrp_fact['lwtr_makhambet'].append(makhambet_b['lwtr_makhambet']).reset_index(drop = True)
lelc_makhambet = vrp_fact['lelc_makhambet'].append(makhambet_b['lelc_makhambet']).reset_index(drop = True)
lind_makhambet = vrp_fact['lind_makhambet'].append(makhambet_b['lind_makhambet']).reset_index(drop = True)
Dtot_makhambet = vrp_fact['Dtot_makhambet'].append(makhambet_b['Dtot_makhambet']).reset_index(drop = True)
Dgds_makhambet = vrp_fact['Dgds_makhambet'].append(makhambet_b['Dgds_makhambet']).reset_index(drop = True)
Dagr_makhambet = vrp_fact['Dagr_makhambet'].append(makhambet_b['Dagr_makhambet']).reset_index(drop = True)
Dmin_makhambet = vrp_fact['Dmin_makhambet'].append(makhambet_b['Dmin_makhambet']).reset_index(drop = True)
Dcon_makhambet = vrp_fact['Dcon_makhambet'].append(makhambet_b['Dcon_makhambet']).reset_index(drop = True)
Dman_makhambet = vrp_fact['Dman_makhambet'].append(makhambet_b['Dman_makhambet']).reset_index(drop = True)
Dret_makhambet = vrp_fact['Dret_makhambet'].append(makhambet_b['Dret_makhambet']).reset_index(drop = True)
Dwhl_makhambet = vrp_fact['Dwhl_makhambet'].append(makhambet_b['Dwhl_makhambet']).reset_index(drop = True)
Dtrd_makhambet = vrp_fact['Dtrd_makhambet'].append(makhambet_b['Dtrd_makhambet']).reset_index(drop = True)
Dsrv_makhambet = vrp_fact['Dsrv_makhambet'].append(makhambet_b['Dsrv_makhambet']).reset_index(drop = True)
Dwtr_makhambet = vrp_fact['Dwtr_makhambet'].append(makhambet_b['Dwtr_makhambet']).reset_index(drop = True)
Delc_makhambet = vrp_fact['Delc_makhambet'].append(makhambet_b['Delc_makhambet']).reset_index(drop = True)
Dind_makhambet = vrp_fact['Dind_makhambet'].append(makhambet_b['Dind_makhambet']).reset_index(drop = True)
Ntot_zhylyoi = vrp_fact['Ntot_zhylyoi'].append(zhylyoi_b['Ntot_zhylyoi']).reset_index(drop = True)
Ngds_zhylyoi = vrp_fact['Ngds_zhylyoi'].append(zhylyoi_b['Ngds_zhylyoi']).reset_index(drop = True)
Nagr_zhylyoi = vrp_fact['Nagr_zhylyoi'].append(zhylyoi_b['Nagr_zhylyoi']).reset_index(drop = True)
Nmin_zhylyoi = vrp_fact['Nmin_zhylyoi'].append(zhylyoi_b['Nmin_zhylyoi']).reset_index(drop = True)
Ncon_zhylyoi = vrp_fact['Ncon_zhylyoi'].append(zhylyoi_b['Ncon_zhylyoi']).reset_index(drop = True)
Nman_zhylyoi = vrp_fact['Nman_zhylyoi'].append(zhylyoi_b['Nman_zhylyoi']).reset_index(drop = True)
Nret_zhylyoi = vrp_fact['Nret_zhylyoi'].append(zhylyoi_b['Nret_zhylyoi']).reset_index(drop = True)
Nwhl_zhylyoi = vrp_fact['Nwhl_zhylyoi'].append(zhylyoi_b['Nwhl_zhylyoi']).reset_index(drop = True)
Ntrd_zhylyoi = vrp_fact['Ntrd_zhylyoi'].append(zhylyoi_b['Ntrd_zhylyoi']).reset_index(drop = True)
Nsrv_zhylyoi = vrp_fact['Nsrv_zhylyoi'].append(zhylyoi_b['Nsrv_zhylyoi']).reset_index(drop = True)
Nwtr_zhylyoi = vrp_fact['Nwtr_zhylyoi'].append(zhylyoi_b['Nwtr_zhylyoi']).reset_index(drop = True)
Nelc_zhylyoi = vrp_fact['Nelc_zhylyoi'].append(zhylyoi_b['Nelc_zhylyoi']).reset_index(drop = True)
Nind_zhylyoi = vrp_fact['Nind_zhylyoi'].append(zhylyoi_b['Nind_zhylyoi']).reset_index(drop = True)
ltot_zhylyoi = vrp_fact['ltot_zhylyoi'].append(zhylyoi_b['ltot_zhylyoi']).reset_index(drop = True)
lgds_zhylyoi = vrp_fact['lgds_zhylyoi'].append(zhylyoi_b['lgds_zhylyoi']).reset_index(drop = True)
lagr_zhylyoi = vrp_fact['lagr_zhylyoi'].append(zhylyoi_b['lagr_zhylyoi']).reset_index(drop = True)
lmin_zhylyoi = vrp_fact['lmin_zhylyoi'].append(zhylyoi_b['lmin_zhylyoi']).reset_index(drop = True)
lcon_zhylyoi = vrp_fact['lcon_zhylyoi'].append(zhylyoi_b['lcon_zhylyoi']).reset_index(drop = True)
lman_zhylyoi = vrp_fact['lman_zhylyoi'].append(zhylyoi_b['lman_zhylyoi']).reset_index(drop = True)
lret_zhylyoi = vrp_fact['lret_zhylyoi'].append(zhylyoi_b['lret_zhylyoi']).reset_index(drop = True)
lwhl_zhylyoi = vrp_fact['lwhl_zhylyoi'].append(zhylyoi_b['lwhl_zhylyoi']).reset_index(drop = True)
ltrd_zhylyoi = vrp_fact['ltrd_zhylyoi'].append(zhylyoi_b['ltrd_zhylyoi']).reset_index(drop = True)
lsrv_zhylyoi = vrp_fact['lsrv_zhylyoi'].append(zhylyoi_b['lsrv_zhylyoi']).reset_index(drop = True)
lwtr_zhylyoi = vrp_fact['lwtr_zhylyoi'].append(zhylyoi_b['lwtr_zhylyoi']).reset_index(drop = True)
lelc_zhylyoi = vrp_fact['lelc_zhylyoi'].append(zhylyoi_b['lelc_zhylyoi']).reset_index(drop = True)
lind_zhylyoi = vrp_fact['lind_zhylyoi'].append(zhylyoi_b['lind_zhylyoi']).reset_index(drop = True)
Dtot_zhylyoi = vrp_fact['Dtot_zhylyoi'].append(zhylyoi_b['Dtot_zhylyoi']).reset_index(drop = True)
Dgds_zhylyoi = vrp_fact['Dgds_zhylyoi'].append(zhylyoi_b['Dgds_zhylyoi']).reset_index(drop = True)
Dagr_zhylyoi = vrp_fact['Dagr_zhylyoi'].append(zhylyoi_b['Dagr_zhylyoi']).reset_index(drop = True)
Dmin_zhylyoi = vrp_fact['Dmin_zhylyoi'].append(zhylyoi_b['Dmin_zhylyoi']).reset_index(drop = True)
Dcon_zhylyoi = vrp_fact['Dcon_zhylyoi'].append(zhylyoi_b['Dcon_zhylyoi']).reset_index(drop = True)
Dman_zhylyoi = vrp_fact['Dman_zhylyoi'].append(zhylyoi_b['Dman_zhylyoi']).reset_index(drop = True)
Dret_zhylyoi = vrp_fact['Dret_zhylyoi'].append(zhylyoi_b['Dret_zhylyoi']).reset_index(drop = True)
Dwhl_zhylyoi = vrp_fact['Dwhl_zhylyoi'].append(zhylyoi_b['Dwhl_zhylyoi']).reset_index(drop = True)
Dtrd_zhylyoi = vrp_fact['Dtrd_zhylyoi'].append(zhylyoi_b['Dtrd_zhylyoi']).reset_index(drop = True)
Dsrv_zhylyoi = vrp_fact['Dsrv_zhylyoi'].append(zhylyoi_b['Dsrv_zhylyoi']).reset_index(drop = True)
Dwtr_zhylyoi = vrp_fact['Dwtr_zhylyoi'].append(zhylyoi_b['Dwtr_zhylyoi']).reset_index(drop = True)
Delc_zhylyoi = vrp_fact['Delc_zhylyoi'].append(zhylyoi_b['Delc_zhylyoi']).reset_index(drop = True)
Dind_zhylyoi = vrp_fact['Dind_zhylyoi'].append(zhylyoi_b['Dind_zhylyoi']).reset_index(drop = True)


Ntot_atyrau_o = vrp_fact['Ntot_atyrau'].append(atyrau_o['Ntot_atyrau']).reset_index(drop = True)
Ngds_atyrau_o = vrp_fact['Ngds_atyrau'].append(atyrau_o['Ngds_atyrau']).reset_index(drop = True)
Nagr_atyrau_o = vrp_fact['Nagr_atyrau'].append(atyrau_o['Nagr_atyrau']).reset_index(drop = True)
Nmin_atyrau_o = vrp_fact['Nmin_atyrau'].append(atyrau_o['Nmin_atyrau']).reset_index(drop = True)
Ncon_atyrau_o = vrp_fact['Ncon_atyrau'].append(atyrau_o['Ncon_atyrau']).reset_index(drop = True)
Nman_atyrau_o = vrp_fact['Nman_atyrau'].append(atyrau_o['Nman_atyrau']).reset_index(drop = True)
Nret_atyrau_o = vrp_fact['Nret_atyrau'].append(atyrau_o['Nret_atyrau']).reset_index(drop = True)
Nwhl_atyrau_o = vrp_fact['Nwhl_atyrau'].append(atyrau_o['Nwhl_atyrau']).reset_index(drop = True)
Ntrd_atyrau_o = vrp_fact['Ntrd_atyrau'].append(atyrau_o['Ntrd_atyrau']).reset_index(drop = True)
Nsrv_atyrau_o = vrp_fact['Nsrv_atyrau'].append(atyrau_o['Nsrv_atyrau']).reset_index(drop = True)
Nwtr_atyrau_o = vrp_fact['Nwtr_atyrau'].append(atyrau_o['Nwtr_atyrau']).reset_index(drop = True)
Nelc_atyrau_o = vrp_fact['Nelc_atyrau'].append(atyrau_o['Nelc_atyrau']).reset_index(drop = True)
Nind_atyrau_o = vrp_fact['Nind_atyrau'].append(atyrau_o['Nind_atyrau']).reset_index(drop = True)
ltot_atyrau_o = vrp_fact['ltot_atyrau'].append(atyrau_o['ltot_atyrau']).reset_index(drop = True)
lgds_atyrau_o = vrp_fact['lgds_atyrau'].append(atyrau_o['lgds_atyrau']).reset_index(drop = True)
lagr_atyrau_o = vrp_fact['lagr_atyrau'].append(atyrau_o['lagr_atyrau']).reset_index(drop = True)
lmin_atyrau_o = vrp_fact['lmin_atyrau'].append(atyrau_o['lmin_atyrau']).reset_index(drop = True)
lcon_atyrau_o = vrp_fact['lcon_atyrau'].append(atyrau_o['lcon_atyrau']).reset_index(drop = True)
lman_atyrau_o = vrp_fact['lman_atyrau'].append(atyrau_o['lman_atyrau']).reset_index(drop = True)
lret_atyrau_o = vrp_fact['lret_atyrau'].append(atyrau_o['lret_atyrau']).reset_index(drop = True)
lwhl_atyrau_o = vrp_fact['lwhl_atyrau'].append(atyrau_o['lwhl_atyrau']).reset_index(drop = True)
ltrd_atyrau_o = vrp_fact['ltrd_atyrau'].append(atyrau_o['ltrd_atyrau']).reset_index(drop = True)
lsrv_atyrau_o = vrp_fact['lsrv_atyrau'].append(atyrau_o['lsrv_atyrau']).reset_index(drop = True)
lwtr_atyrau_o = vrp_fact['lwtr_atyrau'].append(atyrau_o['lwtr_atyrau']).reset_index(drop = True)
lelc_atyrau_o = vrp_fact['lelc_atyrau'].append(atyrau_o['lelc_atyrau']).reset_index(drop = True)
lind_atyrau_o = vrp_fact['lind_atyrau'].append(atyrau_o['lind_atyrau']).reset_index(drop = True)
Dtot_atyrau_o = vrp_fact['Dtot_atyrau'].append(atyrau_o['Dtot_atyrau']).reset_index(drop = True)
Dgds_atyrau_o = vrp_fact['Dgds_atyrau'].append(atyrau_o['Dgds_atyrau']).reset_index(drop = True)
Dagr_atyrau_o = vrp_fact['Dagr_atyrau'].append(atyrau_o['Dagr_atyrau']).reset_index(drop = True)
Dmin_atyrau_o = vrp_fact['Dmin_atyrau'].append(atyrau_o['Dmin_atyrau']).reset_index(drop = True)
Dcon_atyrau_o = vrp_fact['Dcon_atyrau'].append(atyrau_o['Dcon_atyrau']).reset_index(drop = True)
Dman_atyrau_o = vrp_fact['Dman_atyrau'].append(atyrau_o['Dman_atyrau']).reset_index(drop = True)
Dret_atyrau_o = vrp_fact['Dret_atyrau'].append(atyrau_o['Dret_atyrau']).reset_index(drop = True)
Dwhl_atyrau_o = vrp_fact['Dwhl_atyrau'].append(atyrau_o['Dwhl_atyrau']).reset_index(drop = True)
Dtrd_atyrau_o = vrp_fact['Dtrd_atyrau'].append(atyrau_o['Dtrd_atyrau']).reset_index(drop = True)
Dsrv_atyrau_o = vrp_fact['Dsrv_atyrau'].append(atyrau_o['Dsrv_atyrau']).reset_index(drop = True)
Dwtr_atyrau_o = vrp_fact['Dwtr_atyrau'].append(atyrau_o['Dwtr_atyrau']).reset_index(drop = True)
Delc_atyrau_o = vrp_fact['Delc_atyrau'].append(atyrau_o['Delc_atyrau']).reset_index(drop = True)
Dind_atyrau_o = vrp_fact['Dind_atyrau'].append(atyrau_o['Dind_atyrau']).reset_index(drop = True)
Ntot_inder_o = vrp_fact['Ntot_inder'].append(inder_o['Ntot_inder']).reset_index(drop = True)
Ngds_inder_o = vrp_fact['Ngds_inder'].append(inder_o['Ngds_inder']).reset_index(drop = True)
Nagr_inder_o = vrp_fact['Nagr_inder'].append(inder_o['Nagr_inder']).reset_index(drop = True)
Nmin_inder_o = vrp_fact['Nmin_inder'].append(inder_o['Nmin_inder']).reset_index(drop = True)
Ncon_inder_o = vrp_fact['Ncon_inder'].append(inder_o['Ncon_inder']).reset_index(drop = True)
Nman_inder_o = vrp_fact['Nman_inder'].append(inder_o['Nman_inder']).reset_index(drop = True)
Nret_inder_o = vrp_fact['Nret_inder'].append(inder_o['Nret_inder']).reset_index(drop = True)
Nwhl_inder_o = vrp_fact['Nwhl_inder'].append(inder_o['Nwhl_inder']).reset_index(drop = True)
Ntrd_inder_o = vrp_fact['Ntrd_inder'].append(inder_o['Ntrd_inder']).reset_index(drop = True)
Nsrv_inder_o = vrp_fact['Nsrv_inder'].append(inder_o['Nsrv_inder']).reset_index(drop = True)
Nwtr_inder_o = vrp_fact['Nwtr_inder'].append(inder_o['Nwtr_inder']).reset_index(drop = True)
Nelc_inder_o = vrp_fact['Nelc_inder'].append(inder_o['Nelc_inder']).reset_index(drop = True)
Nind_inder_o = vrp_fact['Nind_inder'].append(inder_o['Nind_inder']).reset_index(drop = True)
ltot_inder_o = vrp_fact['ltot_inder'].append(inder_o['ltot_inder']).reset_index(drop = True)
lgds_inder_o = vrp_fact['lgds_inder'].append(inder_o['lgds_inder']).reset_index(drop = True)
lagr_inder_o = vrp_fact['lagr_inder'].append(inder_o['lagr_inder']).reset_index(drop = True)
lmin_inder_o = vrp_fact['lmin_inder'].append(inder_o['lmin_inder']).reset_index(drop = True)
lcon_inder_o = vrp_fact['lcon_inder'].append(inder_o['lcon_inder']).reset_index(drop = True)
lman_inder_o = vrp_fact['lman_inder'].append(inder_o['lman_inder']).reset_index(drop = True)
lret_inder_o = vrp_fact['lret_inder'].append(inder_o['lret_inder']).reset_index(drop = True)
lwhl_inder_o = vrp_fact['lwhl_inder'].append(inder_o['lwhl_inder']).reset_index(drop = True)
ltrd_inder_o = vrp_fact['ltrd_inder'].append(inder_o['ltrd_inder']).reset_index(drop = True)
lsrv_inder_o = vrp_fact['lsrv_inder'].append(inder_o['lsrv_inder']).reset_index(drop = True)
lwtr_inder_o = vrp_fact['lwtr_inder'].append(inder_o['lwtr_inder']).reset_index(drop = True)
lelc_inder_o = vrp_fact['lelc_inder'].append(inder_o['lelc_inder']).reset_index(drop = True)
lind_inder_o = vrp_fact['lind_inder'].append(inder_o['lind_inder']).reset_index(drop = True)
Dtot_inder_o = vrp_fact['Dtot_inder'].append(inder_o['Dtot_inder']).reset_index(drop = True)
Dgds_inder_o = vrp_fact['Dgds_inder'].append(inder_o['Dgds_inder']).reset_index(drop = True)
Dagr_inder_o = vrp_fact['Dagr_inder'].append(inder_o['Dagr_inder']).reset_index(drop = True)
Dmin_inder_o = vrp_fact['Dmin_inder'].append(inder_o['Dmin_inder']).reset_index(drop = True)
Dcon_inder_o = vrp_fact['Dcon_inder'].append(inder_o['Dcon_inder']).reset_index(drop = True)
Dman_inder_o = vrp_fact['Dman_inder'].append(inder_o['Dman_inder']).reset_index(drop = True)
Dret_inder_o = vrp_fact['Dret_inder'].append(inder_o['Dret_inder']).reset_index(drop = True)
Dwhl_inder_o = vrp_fact['Dwhl_inder'].append(inder_o['Dwhl_inder']).reset_index(drop = True)
Dtrd_inder_o = vrp_fact['Dtrd_inder'].append(inder_o['Dtrd_inder']).reset_index(drop = True)
Dsrv_inder_o = vrp_fact['Dsrv_inder'].append(inder_o['Dsrv_inder']).reset_index(drop = True)
Dwtr_inder_o = vrp_fact['Dwtr_inder'].append(inder_o['Dwtr_inder']).reset_index(drop = True)
Delc_inder_o = vrp_fact['Delc_inder'].append(inder_o['Delc_inder']).reset_index(drop = True)
Dind_inder_o = vrp_fact['Dind_inder'].append(inder_o['Dind_inder']).reset_index(drop = True)
Ntot_isatai_o = vrp_fact['Ntot_isatai'].append(isatai_o['Ntot_isatai']).reset_index(drop = True)
Ngds_isatai_o = vrp_fact['Ngds_isatai'].append(isatai_o['Ngds_isatai']).reset_index(drop = True)
Nagr_isatai_o = vrp_fact['Nagr_isatai'].append(isatai_o['Nagr_isatai']).reset_index(drop = True)
Nmin_isatai_o = vrp_fact['Nmin_isatai'].append(isatai_o['Nmin_isatai']).reset_index(drop = True)
Ncon_isatai_o = vrp_fact['Ncon_isatai'].append(isatai_o['Ncon_isatai']).reset_index(drop = True)
Nman_isatai_o = vrp_fact['Nman_isatai'].append(isatai_o['Nman_isatai']).reset_index(drop = True)
Nret_isatai_o = vrp_fact['Nret_isatai'].append(isatai_o['Nret_isatai']).reset_index(drop = True)
Nwhl_isatai_o = vrp_fact['Nwhl_isatai'].append(isatai_o['Nwhl_isatai']).reset_index(drop = True)
Ntrd_isatai_o = vrp_fact['Ntrd_isatai'].append(isatai_o['Ntrd_isatai']).reset_index(drop = True)
Nsrv_isatai_o = vrp_fact['Nsrv_isatai'].append(isatai_o['Nsrv_isatai']).reset_index(drop = True)
Nwtr_isatai_o = vrp_fact['Nwtr_isatai'].append(isatai_o['Nwtr_isatai']).reset_index(drop = True)
Nelc_isatai_o = vrp_fact['Nelc_isatai'].append(isatai_o['Nelc_isatai']).reset_index(drop = True)
Nind_isatai_o = vrp_fact['Nind_isatai'].append(isatai_o['Nind_isatai']).reset_index(drop = True)
ltot_isatai_o = vrp_fact['ltot_isatai'].append(isatai_o['ltot_isatai']).reset_index(drop = True)
lgds_isatai_o = vrp_fact['lgds_isatai'].append(isatai_o['lgds_isatai']).reset_index(drop = True)
lagr_isatai_o = vrp_fact['lagr_isatai'].append(isatai_o['lagr_isatai']).reset_index(drop = True)
lmin_isatai_o = vrp_fact['lmin_isatai'].append(isatai_o['lmin_isatai']).reset_index(drop = True)
lcon_isatai_o = vrp_fact['lcon_isatai'].append(isatai_o['lcon_isatai']).reset_index(drop = True)
lman_isatai_o = vrp_fact['lman_isatai'].append(isatai_o['lman_isatai']).reset_index(drop = True)
lret_isatai_o = vrp_fact['lret_isatai'].append(isatai_o['lret_isatai']).reset_index(drop = True)
lwhl_isatai_o = vrp_fact['lwhl_isatai'].append(isatai_o['lwhl_isatai']).reset_index(drop = True)
ltrd_isatai_o = vrp_fact['ltrd_isatai'].append(isatai_o['ltrd_isatai']).reset_index(drop = True)
lsrv_isatai_o = vrp_fact['lsrv_isatai'].append(isatai_o['lsrv_isatai']).reset_index(drop = True)
lwtr_isatai_o = vrp_fact['lwtr_isatai'].append(isatai_o['lwtr_isatai']).reset_index(drop = True)
lelc_isatai_o = vrp_fact['lelc_isatai'].append(isatai_o['lelc_isatai']).reset_index(drop = True)
lind_isatai_o = vrp_fact['lind_isatai'].append(isatai_o['lind_isatai']).reset_index(drop = True)
Dtot_isatai_o = vrp_fact['Dtot_isatai'].append(isatai_o['Dtot_isatai']).reset_index(drop = True)
Dgds_isatai_o = vrp_fact['Dgds_isatai'].append(isatai_o['Dgds_isatai']).reset_index(drop = True)
Dagr_isatai_o = vrp_fact['Dagr_isatai'].append(isatai_o['Dagr_isatai']).reset_index(drop = True)
Dmin_isatai_o = vrp_fact['Dmin_isatai'].append(isatai_o['Dmin_isatai']).reset_index(drop = True)
Dcon_isatai_o = vrp_fact['Dcon_isatai'].append(isatai_o['Dcon_isatai']).reset_index(drop = True)
Dman_isatai_o = vrp_fact['Dman_isatai'].append(isatai_o['Dman_isatai']).reset_index(drop = True)
Dret_isatai_o = vrp_fact['Dret_isatai'].append(isatai_o['Dret_isatai']).reset_index(drop = True)
Dwhl_isatai_o = vrp_fact['Dwhl_isatai'].append(isatai_o['Dwhl_isatai']).reset_index(drop = True)
Dtrd_isatai_o = vrp_fact['Dtrd_isatai'].append(isatai_o['Dtrd_isatai']).reset_index(drop = True)
Dsrv_isatai_o = vrp_fact['Dsrv_isatai'].append(isatai_o['Dsrv_isatai']).reset_index(drop = True)
Dwtr_isatai_o = vrp_fact['Dwtr_isatai'].append(isatai_o['Dwtr_isatai']).reset_index(drop = True)
Delc_isatai_o = vrp_fact['Delc_isatai'].append(isatai_o['Delc_isatai']).reset_index(drop = True)
Dind_isatai_o = vrp_fact['Dind_isatai'].append(isatai_o['Dind_isatai']).reset_index(drop = True)
Ntot_kurmangazy_o = vrp_fact['Ntot_kurmangazy'].append(kurmangazy_o['Ntot_kurmangazy']).reset_index(drop = True)
Ngds_kurmangazy_o = vrp_fact['Ngds_kurmangazy'].append(kurmangazy_o['Ngds_kurmangazy']).reset_index(drop = True)
Nagr_kurmangazy_o = vrp_fact['Nagr_kurmangazy'].append(kurmangazy_o['Nagr_kurmangazy']).reset_index(drop = True)
Nmin_kurmangazy_o = vrp_fact['Nmin_kurmangazy'].append(kurmangazy_o['Nmin_kurmangazy']).reset_index(drop = True)
Ncon_kurmangazy_o = vrp_fact['Ncon_kurmangazy'].append(kurmangazy_o['Ncon_kurmangazy']).reset_index(drop = True)
Nman_kurmangazy_o = vrp_fact['Nman_kurmangazy'].append(kurmangazy_o['Nman_kurmangazy']).reset_index(drop = True)
Nret_kurmangazy_o = vrp_fact['Nret_kurmangazy'].append(kurmangazy_o['Nret_kurmangazy']).reset_index(drop = True)
Nwhl_kurmangazy_o = vrp_fact['Nwhl_kurmangazy'].append(kurmangazy_o['Nwhl_kurmangazy']).reset_index(drop = True)
Ntrd_kurmangazy_o = vrp_fact['Ntrd_kurmangazy'].append(kurmangazy_o['Ntrd_kurmangazy']).reset_index(drop = True)
Nsrv_kurmangazy_o = vrp_fact['Nsrv_kurmangazy'].append(kurmangazy_o['Nsrv_kurmangazy']).reset_index(drop = True)
Nwtr_kurmangazy_o = vrp_fact['Nwtr_kurmangazy'].append(kurmangazy_o['Nwtr_kurmangazy']).reset_index(drop = True)
Nelc_kurmangazy_o = vrp_fact['Nelc_kurmangazy'].append(kurmangazy_o['Nelc_kurmangazy']).reset_index(drop = True)
Nind_kurmangazy_o = vrp_fact['Nind_kurmangazy'].append(kurmangazy_o['Nind_kurmangazy']).reset_index(drop = True)
ltot_kurmangazy_o = vrp_fact['ltot_kurmangazy'].append(kurmangazy_o['ltot_kurmangazy']).reset_index(drop = True)
lgds_kurmangazy_o = vrp_fact['lgds_kurmangazy'].append(kurmangazy_o['lgds_kurmangazy']).reset_index(drop = True)
lagr_kurmangazy_o = vrp_fact['lagr_kurmangazy'].append(kurmangazy_o['lagr_kurmangazy']).reset_index(drop = True)
lmin_kurmangazy_o = vrp_fact['lmin_kurmangazy'].append(kurmangazy_o['lmin_kurmangazy']).reset_index(drop = True)
lcon_kurmangazy_o = vrp_fact['lcon_kurmangazy'].append(kurmangazy_o['lcon_kurmangazy']).reset_index(drop = True)
lman_kurmangazy_o = vrp_fact['lman_kurmangazy'].append(kurmangazy_o['lman_kurmangazy']).reset_index(drop = True)
lret_kurmangazy_o = vrp_fact['lret_kurmangazy'].append(kurmangazy_o['lret_kurmangazy']).reset_index(drop = True)
lwhl_kurmangazy_o = vrp_fact['lwhl_kurmangazy'].append(kurmangazy_o['lwhl_kurmangazy']).reset_index(drop = True)
ltrd_kurmangazy_o = vrp_fact['ltrd_kurmangazy'].append(kurmangazy_o['ltrd_kurmangazy']).reset_index(drop = True)
lsrv_kurmangazy_o = vrp_fact['lsrv_kurmangazy'].append(kurmangazy_o['lsrv_kurmangazy']).reset_index(drop = True)
lwtr_kurmangazy_o = vrp_fact['lwtr_kurmangazy'].append(kurmangazy_o['lwtr_kurmangazy']).reset_index(drop = True)
lelc_kurmangazy_o = vrp_fact['lelc_kurmangazy'].append(kurmangazy_o['lelc_kurmangazy']).reset_index(drop = True)
lind_kurmangazy_o = vrp_fact['lind_kurmangazy'].append(kurmangazy_o['lind_kurmangazy']).reset_index(drop = True)
Dtot_kurmangazy_o = vrp_fact['Dtot_kurmangazy'].append(kurmangazy_o['Dtot_kurmangazy']).reset_index(drop = True)
Dgds_kurmangazy_o = vrp_fact['Dgds_kurmangazy'].append(kurmangazy_o['Dgds_kurmangazy']).reset_index(drop = True)
Dagr_kurmangazy_o = vrp_fact['Dagr_kurmangazy'].append(kurmangazy_o['Dagr_kurmangazy']).reset_index(drop = True)
Dmin_kurmangazy_o = vrp_fact['Dmin_kurmangazy'].append(kurmangazy_o['Dmin_kurmangazy']).reset_index(drop = True)
Dcon_kurmangazy_o = vrp_fact['Dcon_kurmangazy'].append(kurmangazy_o['Dcon_kurmangazy']).reset_index(drop = True)
Dman_kurmangazy_o = vrp_fact['Dman_kurmangazy'].append(kurmangazy_o['Dman_kurmangazy']).reset_index(drop = True)
Dret_kurmangazy_o = vrp_fact['Dret_kurmangazy'].append(kurmangazy_o['Dret_kurmangazy']).reset_index(drop = True)
Dwhl_kurmangazy_o = vrp_fact['Dwhl_kurmangazy'].append(kurmangazy_o['Dwhl_kurmangazy']).reset_index(drop = True)
Dtrd_kurmangazy_o = vrp_fact['Dtrd_kurmangazy'].append(kurmangazy_o['Dtrd_kurmangazy']).reset_index(drop = True)
Dsrv_kurmangazy_o = vrp_fact['Dsrv_kurmangazy'].append(kurmangazy_o['Dsrv_kurmangazy']).reset_index(drop = True)
Dwtr_kurmangazy_o = vrp_fact['Dwtr_kurmangazy'].append(kurmangazy_o['Dwtr_kurmangazy']).reset_index(drop = True)
Delc_kurmangazy_o = vrp_fact['Delc_kurmangazy'].append(kurmangazy_o['Delc_kurmangazy']).reset_index(drop = True)
Dind_kurmangazy_o = vrp_fact['Dind_kurmangazy'].append(kurmangazy_o['Dind_kurmangazy']).reset_index(drop = True)
Ntot_kzylkoga_o = vrp_fact['Ntot_kzylkoga'].append(kzylkoga_o['Ntot_kzylkoga']).reset_index(drop = True)
Ngds_kzylkoga_o = vrp_fact['Ngds_kzylkoga'].append(kzylkoga_o['Ngds_kzylkoga']).reset_index(drop = True)
Nagr_kzylkoga_o = vrp_fact['Nagr_kzylkoga'].append(kzylkoga_o['Nagr_kzylkoga']).reset_index(drop = True)
Nmin_kzylkoga_o = vrp_fact['Nmin_kzylkoga'].append(kzylkoga_o['Nmin_kzylkoga']).reset_index(drop = True)
Ncon_kzylkoga_o = vrp_fact['Ncon_kzylkoga'].append(kzylkoga_o['Ncon_kzylkoga']).reset_index(drop = True)
Nman_kzylkoga_o = vrp_fact['Nman_kzylkoga'].append(kzylkoga_o['Nman_kzylkoga']).reset_index(drop = True)
Nret_kzylkoga_o = vrp_fact['Nret_kzylkoga'].append(kzylkoga_o['Nret_kzylkoga']).reset_index(drop = True)
Nwhl_kzylkoga_o = vrp_fact['Nwhl_kzylkoga'].append(kzylkoga_o['Nwhl_kzylkoga']).reset_index(drop = True)
Ntrd_kzylkoga_o = vrp_fact['Ntrd_kzylkoga'].append(kzylkoga_o['Ntrd_kzylkoga']).reset_index(drop = True)
Nsrv_kzylkoga_o = vrp_fact['Nsrv_kzylkoga'].append(kzylkoga_o['Nsrv_kzylkoga']).reset_index(drop = True)
Nwtr_kzylkoga_o = vrp_fact['Nwtr_kzylkoga'].append(kzylkoga_o['Nwtr_kzylkoga']).reset_index(drop = True)
Nelc_kzylkoga_o = vrp_fact['Nelc_kzylkoga'].append(kzylkoga_o['Nelc_kzylkoga']).reset_index(drop = True)
Nind_kzylkoga_o = vrp_fact['Nind_kzylkoga'].append(kzylkoga_o['Nind_kzylkoga']).reset_index(drop = True)
ltot_kzylkoga_o = vrp_fact['ltot_kzylkoga'].append(kzylkoga_o['ltot_kzylkoga']).reset_index(drop = True)
lgds_kzylkoga_o = vrp_fact['lgds_kzylkoga'].append(kzylkoga_o['lgds_kzylkoga']).reset_index(drop = True)
lagr_kzylkoga_o = vrp_fact['lagr_kzylkoga'].append(kzylkoga_o['lagr_kzylkoga']).reset_index(drop = True)
lmin_kzylkoga_o = vrp_fact['lmin_kzylkoga'].append(kzylkoga_o['lmin_kzylkoga']).reset_index(drop = True)
lcon_kzylkoga_o = vrp_fact['lcon_kzylkoga'].append(kzylkoga_o['lcon_kzylkoga']).reset_index(drop = True)
lman_kzylkoga_o = vrp_fact['lman_kzylkoga'].append(kzylkoga_o['lman_kzylkoga']).reset_index(drop = True)
lret_kzylkoga_o = vrp_fact['lret_kzylkoga'].append(kzylkoga_o['lret_kzylkoga']).reset_index(drop = True)
lwhl_kzylkoga_o = vrp_fact['lwhl_kzylkoga'].append(kzylkoga_o['lwhl_kzylkoga']).reset_index(drop = True)
ltrd_kzylkoga_o = vrp_fact['ltrd_kzylkoga'].append(kzylkoga_o['ltrd_kzylkoga']).reset_index(drop = True)
lsrv_kzylkoga_o = vrp_fact['lsrv_kzylkoga'].append(kzylkoga_o['lsrv_kzylkoga']).reset_index(drop = True)
lwtr_kzylkoga_o = vrp_fact['lwtr_kzylkoga'].append(kzylkoga_o['lwtr_kzylkoga']).reset_index(drop = True)
lelc_kzylkoga_o = vrp_fact['lelc_kzylkoga'].append(kzylkoga_o['lelc_kzylkoga']).reset_index(drop = True)
lind_kzylkoga_o = vrp_fact['lind_kzylkoga'].append(kzylkoga_o['lind_kzylkoga']).reset_index(drop = True)
Dtot_kzylkoga_o = vrp_fact['Dtot_kzylkoga'].append(kzylkoga_o['Dtot_kzylkoga']).reset_index(drop = True)
Dgds_kzylkoga_o = vrp_fact['Dgds_kzylkoga'].append(kzylkoga_o['Dgds_kzylkoga']).reset_index(drop = True)
Dagr_kzylkoga_o = vrp_fact['Dagr_kzylkoga'].append(kzylkoga_o['Dagr_kzylkoga']).reset_index(drop = True)
Dmin_kzylkoga_o = vrp_fact['Dmin_kzylkoga'].append(kzylkoga_o['Dmin_kzylkoga']).reset_index(drop = True)
Dcon_kzylkoga_o = vrp_fact['Dcon_kzylkoga'].append(kzylkoga_o['Dcon_kzylkoga']).reset_index(drop = True)
Dman_kzylkoga_o = vrp_fact['Dman_kzylkoga'].append(kzylkoga_o['Dman_kzylkoga']).reset_index(drop = True)
Dret_kzylkoga_o = vrp_fact['Dret_kzylkoga'].append(kzylkoga_o['Dret_kzylkoga']).reset_index(drop = True)
Dwhl_kzylkoga_o = vrp_fact['Dwhl_kzylkoga'].append(kzylkoga_o['Dwhl_kzylkoga']).reset_index(drop = True)
Dtrd_kzylkoga_o = vrp_fact['Dtrd_kzylkoga'].append(kzylkoga_o['Dtrd_kzylkoga']).reset_index(drop = True)
Dsrv_kzylkoga_o = vrp_fact['Dsrv_kzylkoga'].append(kzylkoga_o['Dsrv_kzylkoga']).reset_index(drop = True)
Dwtr_kzylkoga_o = vrp_fact['Dwtr_kzylkoga'].append(kzylkoga_o['Dwtr_kzylkoga']).reset_index(drop = True)
Delc_kzylkoga_o = vrp_fact['Delc_kzylkoga'].append(kzylkoga_o['Delc_kzylkoga']).reset_index(drop = True)
Dind_kzylkoga_o = vrp_fact['Dind_kzylkoga'].append(kzylkoga_o['Dind_kzylkoga']).reset_index(drop = True)
Ntot_makat_o = vrp_fact['Ntot_makat'].append(makat_o['Ntot_makat']).reset_index(drop = True)
Ngds_makat_o = vrp_fact['Ngds_makat'].append(makat_o['Ngds_makat']).reset_index(drop = True)
Nagr_makat_o = vrp_fact['Nagr_makat'].append(makat_o['Nagr_makat']).reset_index(drop = True)
Nmin_makat_o = vrp_fact['Nmin_makat'].append(makat_o['Nmin_makat']).reset_index(drop = True)
Ncon_makat_o = vrp_fact['Ncon_makat'].append(makat_o['Ncon_makat']).reset_index(drop = True)
Nman_makat_o = vrp_fact['Nman_makat'].append(makat_o['Nman_makat']).reset_index(drop = True)
Nret_makat_o = vrp_fact['Nret_makat'].append(makat_o['Nret_makat']).reset_index(drop = True)
Nwhl_makat_o = vrp_fact['Nwhl_makat'].append(makat_o['Nwhl_makat']).reset_index(drop = True)
Ntrd_makat_o = vrp_fact['Ntrd_makat'].append(makat_o['Ntrd_makat']).reset_index(drop = True)
Nsrv_makat_o = vrp_fact['Nsrv_makat'].append(makat_o['Nsrv_makat']).reset_index(drop = True)
Nwtr_makat_o = vrp_fact['Nwtr_makat'].append(makat_o['Nwtr_makat']).reset_index(drop = True)
Nelc_makat_o = vrp_fact['Nelc_makat'].append(makat_o['Nelc_makat']).reset_index(drop = True)
Nind_makat_o = vrp_fact['Nind_makat'].append(makat_o['Nind_makat']).reset_index(drop = True)
ltot_makat_o = vrp_fact['ltot_makat'].append(makat_o['ltot_makat']).reset_index(drop = True)
lgds_makat_o = vrp_fact['lgds_makat'].append(makat_o['lgds_makat']).reset_index(drop = True)
lagr_makat_o = vrp_fact['lagr_makat'].append(makat_o['lagr_makat']).reset_index(drop = True)
lmin_makat_o = vrp_fact['lmin_makat'].append(makat_o['lmin_makat']).reset_index(drop = True)
lcon_makat_o = vrp_fact['lcon_makat'].append(makat_o['lcon_makat']).reset_index(drop = True)
lman_makat_o = vrp_fact['lman_makat'].append(makat_o['lman_makat']).reset_index(drop = True)
lret_makat_o = vrp_fact['lret_makat'].append(makat_o['lret_makat']).reset_index(drop = True)
lwhl_makat_o = vrp_fact['lwhl_makat'].append(makat_o['lwhl_makat']).reset_index(drop = True)
ltrd_makat_o = vrp_fact['ltrd_makat'].append(makat_o['ltrd_makat']).reset_index(drop = True)
lsrv_makat_o = vrp_fact['lsrv_makat'].append(makat_o['lsrv_makat']).reset_index(drop = True)
lwtr_makat_o = vrp_fact['lwtr_makat'].append(makat_o['lwtr_makat']).reset_index(drop = True)
lelc_makat_o = vrp_fact['lelc_makat'].append(makat_o['lelc_makat']).reset_index(drop = True)
lind_makat_o = vrp_fact['lind_makat'].append(makat_o['lind_makat']).reset_index(drop = True)
Dtot_makat_o = vrp_fact['Dtot_makat'].append(makat_o['Dtot_makat']).reset_index(drop = True)
Dgds_makat_o = vrp_fact['Dgds_makat'].append(makat_o['Dgds_makat']).reset_index(drop = True)
Dagr_makat_o = vrp_fact['Dagr_makat'].append(makat_o['Dagr_makat']).reset_index(drop = True)
Dmin_makat_o = vrp_fact['Dmin_makat'].append(makat_o['Dmin_makat']).reset_index(drop = True)
Dcon_makat_o = vrp_fact['Dcon_makat'].append(makat_o['Dcon_makat']).reset_index(drop = True)
Dman_makat_o = vrp_fact['Dman_makat'].append(makat_o['Dman_makat']).reset_index(drop = True)
Dret_makat_o = vrp_fact['Dret_makat'].append(makat_o['Dret_makat']).reset_index(drop = True)
Dwhl_makat_o = vrp_fact['Dwhl_makat'].append(makat_o['Dwhl_makat']).reset_index(drop = True)
Dtrd_makat_o = vrp_fact['Dtrd_makat'].append(makat_o['Dtrd_makat']).reset_index(drop = True)
Dsrv_makat_o = vrp_fact['Dsrv_makat'].append(makat_o['Dsrv_makat']).reset_index(drop = True)
Dwtr_makat_o = vrp_fact['Dwtr_makat'].append(makat_o['Dwtr_makat']).reset_index(drop = True)
Delc_makat_o = vrp_fact['Delc_makat'].append(makat_o['Delc_makat']).reset_index(drop = True)
Dind_makat_o = vrp_fact['Dind_makat'].append(makat_o['Dind_makat']).reset_index(drop = True)
Ntot_makhambet_o = vrp_fact['Ntot_makhambet'].append(makhambet_o['Ntot_makhambet']).reset_index(drop = True)
Ngds_makhambet_o = vrp_fact['Ngds_makhambet'].append(makhambet_o['Ngds_makhambet']).reset_index(drop = True)
Nagr_makhambet_o = vrp_fact['Nagr_makhambet'].append(makhambet_o['Nagr_makhambet']).reset_index(drop = True)
Nmin_makhambet_o = vrp_fact['Nmin_makhambet'].append(makhambet_o['Nmin_makhambet']).reset_index(drop = True)
Ncon_makhambet_o = vrp_fact['Ncon_makhambet'].append(makhambet_o['Ncon_makhambet']).reset_index(drop = True)
Nman_makhambet_o = vrp_fact['Nman_makhambet'].append(makhambet_o['Nman_makhambet']).reset_index(drop = True)
Nret_makhambet_o = vrp_fact['Nret_makhambet'].append(makhambet_o['Nret_makhambet']).reset_index(drop = True)
Nwhl_makhambet_o = vrp_fact['Nwhl_makhambet'].append(makhambet_o['Nwhl_makhambet']).reset_index(drop = True)
Ntrd_makhambet_o = vrp_fact['Ntrd_makhambet'].append(makhambet_o['Ntrd_makhambet']).reset_index(drop = True)
Nsrv_makhambet_o = vrp_fact['Nsrv_makhambet'].append(makhambet_o['Nsrv_makhambet']).reset_index(drop = True)
Nwtr_makhambet_o = vrp_fact['Nwtr_makhambet'].append(makhambet_o['Nwtr_makhambet']).reset_index(drop = True)
Nelc_makhambet_o = vrp_fact['Nelc_makhambet'].append(makhambet_o['Nelc_makhambet']).reset_index(drop = True)
Nind_makhambet_o = vrp_fact['Nind_makhambet'].append(makhambet_o['Nind_makhambet']).reset_index(drop = True)
ltot_makhambet_o = vrp_fact['ltot_makhambet'].append(makhambet_o['ltot_makhambet']).reset_index(drop = True)
lgds_makhambet_o = vrp_fact['lgds_makhambet'].append(makhambet_o['lgds_makhambet']).reset_index(drop = True)
lagr_makhambet_o = vrp_fact['lagr_makhambet'].append(makhambet_o['lagr_makhambet']).reset_index(drop = True)
lmin_makhambet_o = vrp_fact['lmin_makhambet'].append(makhambet_o['lmin_makhambet']).reset_index(drop = True)
lcon_makhambet_o = vrp_fact['lcon_makhambet'].append(makhambet_o['lcon_makhambet']).reset_index(drop = True)
lman_makhambet_o = vrp_fact['lman_makhambet'].append(makhambet_o['lman_makhambet']).reset_index(drop = True)
lret_makhambet_o = vrp_fact['lret_makhambet'].append(makhambet_o['lret_makhambet']).reset_index(drop = True)
lwhl_makhambet_o = vrp_fact['lwhl_makhambet'].append(makhambet_o['lwhl_makhambet']).reset_index(drop = True)
ltrd_makhambet_o = vrp_fact['ltrd_makhambet'].append(makhambet_o['ltrd_makhambet']).reset_index(drop = True)
lsrv_makhambet_o = vrp_fact['lsrv_makhambet'].append(makhambet_o['lsrv_makhambet']).reset_index(drop = True)
lwtr_makhambet_o = vrp_fact['lwtr_makhambet'].append(makhambet_o['lwtr_makhambet']).reset_index(drop = True)
lelc_makhambet_o = vrp_fact['lelc_makhambet'].append(makhambet_o['lelc_makhambet']).reset_index(drop = True)
lind_makhambet_o = vrp_fact['lind_makhambet'].append(makhambet_o['lind_makhambet']).reset_index(drop = True)
Dtot_makhambet_o = vrp_fact['Dtot_makhambet'].append(makhambet_o['Dtot_makhambet']).reset_index(drop = True)
Dgds_makhambet_o = vrp_fact['Dgds_makhambet'].append(makhambet_o['Dgds_makhambet']).reset_index(drop = True)
Dagr_makhambet_o = vrp_fact['Dagr_makhambet'].append(makhambet_o['Dagr_makhambet']).reset_index(drop = True)
Dmin_makhambet_o = vrp_fact['Dmin_makhambet'].append(makhambet_o['Dmin_makhambet']).reset_index(drop = True)
Dcon_makhambet_o = vrp_fact['Dcon_makhambet'].append(makhambet_o['Dcon_makhambet']).reset_index(drop = True)
Dman_makhambet_o = vrp_fact['Dman_makhambet'].append(makhambet_o['Dman_makhambet']).reset_index(drop = True)
Dret_makhambet_o = vrp_fact['Dret_makhambet'].append(makhambet_o['Dret_makhambet']).reset_index(drop = True)
Dwhl_makhambet_o = vrp_fact['Dwhl_makhambet'].append(makhambet_o['Dwhl_makhambet']).reset_index(drop = True)
Dtrd_makhambet_o = vrp_fact['Dtrd_makhambet'].append(makhambet_o['Dtrd_makhambet']).reset_index(drop = True)
Dsrv_makhambet_o = vrp_fact['Dsrv_makhambet'].append(makhambet_o['Dsrv_makhambet']).reset_index(drop = True)
Dwtr_makhambet_o = vrp_fact['Dwtr_makhambet'].append(makhambet_o['Dwtr_makhambet']).reset_index(drop = True)
Delc_makhambet_o = vrp_fact['Delc_makhambet'].append(makhambet_o['Delc_makhambet']).reset_index(drop = True)
Dind_makhambet_o = vrp_fact['Dind_makhambet'].append(makhambet_o['Dind_makhambet']).reset_index(drop = True)
Ntot_zhylyoi_o = vrp_fact['Ntot_zhylyoi'].append(zhylyoi_o['Ntot_zhylyoi']).reset_index(drop = True)
Ngds_zhylyoi_o = vrp_fact['Ngds_zhylyoi'].append(zhylyoi_o['Ngds_zhylyoi']).reset_index(drop = True)
Nagr_zhylyoi_o = vrp_fact['Nagr_zhylyoi'].append(zhylyoi_o['Nagr_zhylyoi']).reset_index(drop = True)
Nmin_zhylyoi_o = vrp_fact['Nmin_zhylyoi'].append(zhylyoi_o['Nmin_zhylyoi']).reset_index(drop = True)
Ncon_zhylyoi_o = vrp_fact['Ncon_zhylyoi'].append(zhylyoi_o['Ncon_zhylyoi']).reset_index(drop = True)
Nman_zhylyoi_o = vrp_fact['Nman_zhylyoi'].append(zhylyoi_o['Nman_zhylyoi']).reset_index(drop = True)
Nret_zhylyoi_o = vrp_fact['Nret_zhylyoi'].append(zhylyoi_o['Nret_zhylyoi']).reset_index(drop = True)
Nwhl_zhylyoi_o = vrp_fact['Nwhl_zhylyoi'].append(zhylyoi_o['Nwhl_zhylyoi']).reset_index(drop = True)
Ntrd_zhylyoi_o = vrp_fact['Ntrd_zhylyoi'].append(zhylyoi_o['Ntrd_zhylyoi']).reset_index(drop = True)
Nsrv_zhylyoi_o = vrp_fact['Nsrv_zhylyoi'].append(zhylyoi_o['Nsrv_zhylyoi']).reset_index(drop = True)
Nwtr_zhylyoi_o = vrp_fact['Nwtr_zhylyoi'].append(zhylyoi_o['Nwtr_zhylyoi']).reset_index(drop = True)
Nelc_zhylyoi_o = vrp_fact['Nelc_zhylyoi'].append(zhylyoi_o['Nelc_zhylyoi']).reset_index(drop = True)
Nind_zhylyoi_o = vrp_fact['Nind_zhylyoi'].append(zhylyoi_o['Nind_zhylyoi']).reset_index(drop = True)
ltot_zhylyoi_o = vrp_fact['ltot_zhylyoi'].append(zhylyoi_o['ltot_zhylyoi']).reset_index(drop = True)
lgds_zhylyoi_o = vrp_fact['lgds_zhylyoi'].append(zhylyoi_o['lgds_zhylyoi']).reset_index(drop = True)
lagr_zhylyoi_o = vrp_fact['lagr_zhylyoi'].append(zhylyoi_o['lagr_zhylyoi']).reset_index(drop = True)
lmin_zhylyoi_o = vrp_fact['lmin_zhylyoi'].append(zhylyoi_o['lmin_zhylyoi']).reset_index(drop = True)
lcon_zhylyoi_o = vrp_fact['lcon_zhylyoi'].append(zhylyoi_o['lcon_zhylyoi']).reset_index(drop = True)
lman_zhylyoi_o = vrp_fact['lman_zhylyoi'].append(zhylyoi_o['lman_zhylyoi']).reset_index(drop = True)
lret_zhylyoi_o = vrp_fact['lret_zhylyoi'].append(zhylyoi_o['lret_zhylyoi']).reset_index(drop = True)
lwhl_zhylyoi_o = vrp_fact['lwhl_zhylyoi'].append(zhylyoi_o['lwhl_zhylyoi']).reset_index(drop = True)
ltrd_zhylyoi_o = vrp_fact['ltrd_zhylyoi'].append(zhylyoi_o['ltrd_zhylyoi']).reset_index(drop = True)
lsrv_zhylyoi_o = vrp_fact['lsrv_zhylyoi'].append(zhylyoi_o['lsrv_zhylyoi']).reset_index(drop = True)
lwtr_zhylyoi_o = vrp_fact['lwtr_zhylyoi'].append(zhylyoi_o['lwtr_zhylyoi']).reset_index(drop = True)
lelc_zhylyoi_o = vrp_fact['lelc_zhylyoi'].append(zhylyoi_o['lelc_zhylyoi']).reset_index(drop = True)
lind_zhylyoi_o = vrp_fact['lind_zhylyoi'].append(zhylyoi_o['lind_zhylyoi']).reset_index(drop = True)
Dtot_zhylyoi_o = vrp_fact['Dtot_zhylyoi'].append(zhylyoi_o['Dtot_zhylyoi']).reset_index(drop = True)
Dgds_zhylyoi_o = vrp_fact['Dgds_zhylyoi'].append(zhylyoi_o['Dgds_zhylyoi']).reset_index(drop = True)
Dagr_zhylyoi_o = vrp_fact['Dagr_zhylyoi'].append(zhylyoi_o['Dagr_zhylyoi']).reset_index(drop = True)
Dmin_zhylyoi_o = vrp_fact['Dmin_zhylyoi'].append(zhylyoi_o['Dmin_zhylyoi']).reset_index(drop = True)
Dcon_zhylyoi_o = vrp_fact['Dcon_zhylyoi'].append(zhylyoi_o['Dcon_zhylyoi']).reset_index(drop = True)
Dman_zhylyoi_o = vrp_fact['Dman_zhylyoi'].append(zhylyoi_o['Dman_zhylyoi']).reset_index(drop = True)
Dret_zhylyoi_o = vrp_fact['Dret_zhylyoi'].append(zhylyoi_o['Dret_zhylyoi']).reset_index(drop = True)
Dwhl_zhylyoi_o = vrp_fact['Dwhl_zhylyoi'].append(zhylyoi_o['Dwhl_zhylyoi']).reset_index(drop = True)
Dtrd_zhylyoi_o = vrp_fact['Dtrd_zhylyoi'].append(zhylyoi_o['Dtrd_zhylyoi']).reset_index(drop = True)
Dsrv_zhylyoi_o = vrp_fact['Dsrv_zhylyoi'].append(zhylyoi_o['Dsrv_zhylyoi']).reset_index(drop = True)
Dwtr_zhylyoi_o = vrp_fact['Dwtr_zhylyoi'].append(zhylyoi_o['Dwtr_zhylyoi']).reset_index(drop = True)
Delc_zhylyoi_o = vrp_fact['Delc_zhylyoi'].append(zhylyoi_o['Delc_zhylyoi']).reset_index(drop = True)
Dind_zhylyoi_o = vrp_fact['Dind_zhylyoi'].append(zhylyoi_o['Dind_zhylyoi']).reset_index(drop = True)


Ntot_atyrau_p = vrp_fact['Ntot_atyrau'].append(atyrau_p['Ntot_atyrau']).reset_index(drop = True)
Ngds_atyrau_p = vrp_fact['Ngds_atyrau'].append(atyrau_p['Ngds_atyrau']).reset_index(drop = True)
Nagr_atyrau_p = vrp_fact['Nagr_atyrau'].append(atyrau_p['Nagr_atyrau']).reset_index(drop = True)
Nmin_atyrau_p = vrp_fact['Nmin_atyrau'].append(atyrau_p['Nmin_atyrau']).reset_index(drop = True)
Ncon_atyrau_p = vrp_fact['Ncon_atyrau'].append(atyrau_p['Ncon_atyrau']).reset_index(drop = True)
Nman_atyrau_p = vrp_fact['Nman_atyrau'].append(atyrau_p['Nman_atyrau']).reset_index(drop = True)
Nret_atyrau_p = vrp_fact['Nret_atyrau'].append(atyrau_p['Nret_atyrau']).reset_index(drop = True)
Nwhl_atyrau_p = vrp_fact['Nwhl_atyrau'].append(atyrau_p['Nwhl_atyrau']).reset_index(drop = True)
Ntrd_atyrau_p = vrp_fact['Ntrd_atyrau'].append(atyrau_p['Ntrd_atyrau']).reset_index(drop = True)
Nsrv_atyrau_p = vrp_fact['Nsrv_atyrau'].append(atyrau_p['Nsrv_atyrau']).reset_index(drop = True)
Nwtr_atyrau_p = vrp_fact['Nwtr_atyrau'].append(atyrau_p['Nwtr_atyrau']).reset_index(drop = True)
Nelc_atyrau_p = vrp_fact['Nelc_atyrau'].append(atyrau_p['Nelc_atyrau']).reset_index(drop = True)
Nind_atyrau_p = vrp_fact['Nind_atyrau'].append(atyrau_p['Nind_atyrau']).reset_index(drop = True)
ltot_atyrau_p = vrp_fact['ltot_atyrau'].append(atyrau_p['ltot_atyrau']).reset_index(drop = True)
lgds_atyrau_p = vrp_fact['lgds_atyrau'].append(atyrau_p['lgds_atyrau']).reset_index(drop = True)
lagr_atyrau_p = vrp_fact['lagr_atyrau'].append(atyrau_p['lagr_atyrau']).reset_index(drop = True)
lmin_atyrau_p = vrp_fact['lmin_atyrau'].append(atyrau_p['lmin_atyrau']).reset_index(drop = True)
lcon_atyrau_p = vrp_fact['lcon_atyrau'].append(atyrau_p['lcon_atyrau']).reset_index(drop = True)
lman_atyrau_p = vrp_fact['lman_atyrau'].append(atyrau_p['lman_atyrau']).reset_index(drop = True)
lret_atyrau_p = vrp_fact['lret_atyrau'].append(atyrau_p['lret_atyrau']).reset_index(drop = True)
lwhl_atyrau_p = vrp_fact['lwhl_atyrau'].append(atyrau_p['lwhl_atyrau']).reset_index(drop = True)
ltrd_atyrau_p = vrp_fact['ltrd_atyrau'].append(atyrau_p['ltrd_atyrau']).reset_index(drop = True)
lsrv_atyrau_p = vrp_fact['lsrv_atyrau'].append(atyrau_p['lsrv_atyrau']).reset_index(drop = True)
lwtr_atyrau_p = vrp_fact['lwtr_atyrau'].append(atyrau_p['lwtr_atyrau']).reset_index(drop = True)
lelc_atyrau_p = vrp_fact['lelc_atyrau'].append(atyrau_p['lelc_atyrau']).reset_index(drop = True)
lind_atyrau_p = vrp_fact['lind_atyrau'].append(atyrau_p['lind_atyrau']).reset_index(drop = True)
Dtot_atyrau_p = vrp_fact['Dtot_atyrau'].append(atyrau_p['Dtot_atyrau']).reset_index(drop = True)
Dgds_atyrau_p = vrp_fact['Dgds_atyrau'].append(atyrau_p['Dgds_atyrau']).reset_index(drop = True)
Dagr_atyrau_p = vrp_fact['Dagr_atyrau'].append(atyrau_p['Dagr_atyrau']).reset_index(drop = True)
Dmin_atyrau_p = vrp_fact['Dmin_atyrau'].append(atyrau_p['Dmin_atyrau']).reset_index(drop = True)
Dcon_atyrau_p = vrp_fact['Dcon_atyrau'].append(atyrau_p['Dcon_atyrau']).reset_index(drop = True)
Dman_atyrau_p = vrp_fact['Dman_atyrau'].append(atyrau_p['Dman_atyrau']).reset_index(drop = True)
Dret_atyrau_p = vrp_fact['Dret_atyrau'].append(atyrau_p['Dret_atyrau']).reset_index(drop = True)
Dwhl_atyrau_p = vrp_fact['Dwhl_atyrau'].append(atyrau_p['Dwhl_atyrau']).reset_index(drop = True)
Dtrd_atyrau_p = vrp_fact['Dtrd_atyrau'].append(atyrau_p['Dtrd_atyrau']).reset_index(drop = True)
Dsrv_atyrau_p = vrp_fact['Dsrv_atyrau'].append(atyrau_p['Dsrv_atyrau']).reset_index(drop = True)
Dwtr_atyrau_p = vrp_fact['Dwtr_atyrau'].append(atyrau_p['Dwtr_atyrau']).reset_index(drop = True)
Delc_atyrau_p = vrp_fact['Delc_atyrau'].append(atyrau_p['Delc_atyrau']).reset_index(drop = True)
Dind_atyrau_p = vrp_fact['Dind_atyrau'].append(atyrau_p['Dind_atyrau']).reset_index(drop = True)
Ntot_inder_p = vrp_fact['Ntot_inder'].append(inder_p['Ntot_inder']).reset_index(drop = True)
Ngds_inder_p = vrp_fact['Ngds_inder'].append(inder_p['Ngds_inder']).reset_index(drop = True)
Nagr_inder_p = vrp_fact['Nagr_inder'].append(inder_p['Nagr_inder']).reset_index(drop = True)
Nmin_inder_p = vrp_fact['Nmin_inder'].append(inder_p['Nmin_inder']).reset_index(drop = True)
Ncon_inder_p = vrp_fact['Ncon_inder'].append(inder_p['Ncon_inder']).reset_index(drop = True)
Nman_inder_p = vrp_fact['Nman_inder'].append(inder_p['Nman_inder']).reset_index(drop = True)
Nret_inder_p = vrp_fact['Nret_inder'].append(inder_p['Nret_inder']).reset_index(drop = True)
Nwhl_inder_p = vrp_fact['Nwhl_inder'].append(inder_p['Nwhl_inder']).reset_index(drop = True)
Ntrd_inder_p = vrp_fact['Ntrd_inder'].append(inder_p['Ntrd_inder']).reset_index(drop = True)
Nsrv_inder_p = vrp_fact['Nsrv_inder'].append(inder_p['Nsrv_inder']).reset_index(drop = True)
Nwtr_inder_p = vrp_fact['Nwtr_inder'].append(inder_p['Nwtr_inder']).reset_index(drop = True)
Nelc_inder_p = vrp_fact['Nelc_inder'].append(inder_p['Nelc_inder']).reset_index(drop = True)
Nind_inder_p = vrp_fact['Nind_inder'].append(inder_p['Nind_inder']).reset_index(drop = True)
ltot_inder_p = vrp_fact['ltot_inder'].append(inder_p['ltot_inder']).reset_index(drop = True)
lgds_inder_p = vrp_fact['lgds_inder'].append(inder_p['lgds_inder']).reset_index(drop = True)
lagr_inder_p = vrp_fact['lagr_inder'].append(inder_p['lagr_inder']).reset_index(drop = True)
lmin_inder_p = vrp_fact['lmin_inder'].append(inder_p['lmin_inder']).reset_index(drop = True)
lcon_inder_p = vrp_fact['lcon_inder'].append(inder_p['lcon_inder']).reset_index(drop = True)
lman_inder_p = vrp_fact['lman_inder'].append(inder_p['lman_inder']).reset_index(drop = True)
lret_inder_p = vrp_fact['lret_inder'].append(inder_p['lret_inder']).reset_index(drop = True)
lwhl_inder_p = vrp_fact['lwhl_inder'].append(inder_p['lwhl_inder']).reset_index(drop = True)
ltrd_inder_p = vrp_fact['ltrd_inder'].append(inder_p['ltrd_inder']).reset_index(drop = True)
lsrv_inder_p = vrp_fact['lsrv_inder'].append(inder_p['lsrv_inder']).reset_index(drop = True)
lwtr_inder_p = vrp_fact['lwtr_inder'].append(inder_p['lwtr_inder']).reset_index(drop = True)
lelc_inder_p = vrp_fact['lelc_inder'].append(inder_p['lelc_inder']).reset_index(drop = True)
lind_inder_p = vrp_fact['lind_inder'].append(inder_p['lind_inder']).reset_index(drop = True)
Dtot_inder_p = vrp_fact['Dtot_inder'].append(inder_p['Dtot_inder']).reset_index(drop = True)
Dgds_inder_p = vrp_fact['Dgds_inder'].append(inder_p['Dgds_inder']).reset_index(drop = True)
Dagr_inder_p = vrp_fact['Dagr_inder'].append(inder_p['Dagr_inder']).reset_index(drop = True)
Dmin_inder_p = vrp_fact['Dmin_inder'].append(inder_p['Dmin_inder']).reset_index(drop = True)
Dcon_inder_p = vrp_fact['Dcon_inder'].append(inder_p['Dcon_inder']).reset_index(drop = True)
Dman_inder_p = vrp_fact['Dman_inder'].append(inder_p['Dman_inder']).reset_index(drop = True)
Dret_inder_p = vrp_fact['Dret_inder'].append(inder_p['Dret_inder']).reset_index(drop = True)
Dwhl_inder_p = vrp_fact['Dwhl_inder'].append(inder_p['Dwhl_inder']).reset_index(drop = True)
Dtrd_inder_p = vrp_fact['Dtrd_inder'].append(inder_p['Dtrd_inder']).reset_index(drop = True)
Dsrv_inder_p = vrp_fact['Dsrv_inder'].append(inder_p['Dsrv_inder']).reset_index(drop = True)
Dwtr_inder_p = vrp_fact['Dwtr_inder'].append(inder_p['Dwtr_inder']).reset_index(drop = True)
Delc_inder_p = vrp_fact['Delc_inder'].append(inder_p['Delc_inder']).reset_index(drop = True)
Dind_inder_p = vrp_fact['Dind_inder'].append(inder_p['Dind_inder']).reset_index(drop = True)
Ntot_isatai_p = vrp_fact['Ntot_isatai'].append(isatai_p['Ntot_isatai']).reset_index(drop = True)
Ngds_isatai_p = vrp_fact['Ngds_isatai'].append(isatai_p['Ngds_isatai']).reset_index(drop = True)
Nagr_isatai_p = vrp_fact['Nagr_isatai'].append(isatai_p['Nagr_isatai']).reset_index(drop = True)
Nmin_isatai_p = vrp_fact['Nmin_isatai'].append(isatai_p['Nmin_isatai']).reset_index(drop = True)
Ncon_isatai_p = vrp_fact['Ncon_isatai'].append(isatai_p['Ncon_isatai']).reset_index(drop = True)
Nman_isatai_p = vrp_fact['Nman_isatai'].append(isatai_p['Nman_isatai']).reset_index(drop = True)
Nret_isatai_p = vrp_fact['Nret_isatai'].append(isatai_p['Nret_isatai']).reset_index(drop = True)
Nwhl_isatai_p = vrp_fact['Nwhl_isatai'].append(isatai_p['Nwhl_isatai']).reset_index(drop = True)
Ntrd_isatai_p = vrp_fact['Ntrd_isatai'].append(isatai_p['Ntrd_isatai']).reset_index(drop = True)
Nsrv_isatai_p = vrp_fact['Nsrv_isatai'].append(isatai_p['Nsrv_isatai']).reset_index(drop = True)
Nwtr_isatai_p = vrp_fact['Nwtr_isatai'].append(isatai_p['Nwtr_isatai']).reset_index(drop = True)
Nelc_isatai_p = vrp_fact['Nelc_isatai'].append(isatai_p['Nelc_isatai']).reset_index(drop = True)
Nind_isatai_p = vrp_fact['Nind_isatai'].append(isatai_p['Nind_isatai']).reset_index(drop = True)
ltot_isatai_p = vrp_fact['ltot_isatai'].append(isatai_p['ltot_isatai']).reset_index(drop = True)
lgds_isatai_p = vrp_fact['lgds_isatai'].append(isatai_p['lgds_isatai']).reset_index(drop = True)
lagr_isatai_p = vrp_fact['lagr_isatai'].append(isatai_p['lagr_isatai']).reset_index(drop = True)
lmin_isatai_p = vrp_fact['lmin_isatai'].append(isatai_p['lmin_isatai']).reset_index(drop = True)
lcon_isatai_p = vrp_fact['lcon_isatai'].append(isatai_p['lcon_isatai']).reset_index(drop = True)
lman_isatai_p = vrp_fact['lman_isatai'].append(isatai_p['lman_isatai']).reset_index(drop = True)
lret_isatai_p = vrp_fact['lret_isatai'].append(isatai_p['lret_isatai']).reset_index(drop = True)
lwhl_isatai_p = vrp_fact['lwhl_isatai'].append(isatai_p['lwhl_isatai']).reset_index(drop = True)
ltrd_isatai_p = vrp_fact['ltrd_isatai'].append(isatai_p['ltrd_isatai']).reset_index(drop = True)
lsrv_isatai_p = vrp_fact['lsrv_isatai'].append(isatai_p['lsrv_isatai']).reset_index(drop = True)
lwtr_isatai_p = vrp_fact['lwtr_isatai'].append(isatai_p['lwtr_isatai']).reset_index(drop = True)
lelc_isatai_p = vrp_fact['lelc_isatai'].append(isatai_p['lelc_isatai']).reset_index(drop = True)
lind_isatai_p = vrp_fact['lind_isatai'].append(isatai_p['lind_isatai']).reset_index(drop = True)
Dtot_isatai_p = vrp_fact['Dtot_isatai'].append(isatai_p['Dtot_isatai']).reset_index(drop = True)
Dgds_isatai_p = vrp_fact['Dgds_isatai'].append(isatai_p['Dgds_isatai']).reset_index(drop = True)
Dagr_isatai_p = vrp_fact['Dagr_isatai'].append(isatai_p['Dagr_isatai']).reset_index(drop = True)
Dmin_isatai_p = vrp_fact['Dmin_isatai'].append(isatai_p['Dmin_isatai']).reset_index(drop = True)
Dcon_isatai_p = vrp_fact['Dcon_isatai'].append(isatai_p['Dcon_isatai']).reset_index(drop = True)
Dman_isatai_p = vrp_fact['Dman_isatai'].append(isatai_p['Dman_isatai']).reset_index(drop = True)
Dret_isatai_p = vrp_fact['Dret_isatai'].append(isatai_p['Dret_isatai']).reset_index(drop = True)
Dwhl_isatai_p = vrp_fact['Dwhl_isatai'].append(isatai_p['Dwhl_isatai']).reset_index(drop = True)
Dtrd_isatai_p = vrp_fact['Dtrd_isatai'].append(isatai_p['Dtrd_isatai']).reset_index(drop = True)
Dsrv_isatai_p = vrp_fact['Dsrv_isatai'].append(isatai_p['Dsrv_isatai']).reset_index(drop = True)
Dwtr_isatai_p = vrp_fact['Dwtr_isatai'].append(isatai_p['Dwtr_isatai']).reset_index(drop = True)
Delc_isatai_p = vrp_fact['Delc_isatai'].append(isatai_p['Delc_isatai']).reset_index(drop = True)
Dind_isatai_p = vrp_fact['Dind_isatai'].append(isatai_p['Dind_isatai']).reset_index(drop = True)
Ntot_kurmangazy_p = vrp_fact['Ntot_kurmangazy'].append(kurmangazy_p['Ntot_kurmangazy']).reset_index(drop = True)
Ngds_kurmangazy_p = vrp_fact['Ngds_kurmangazy'].append(kurmangazy_p['Ngds_kurmangazy']).reset_index(drop = True)
Nagr_kurmangazy_p = vrp_fact['Nagr_kurmangazy'].append(kurmangazy_p['Nagr_kurmangazy']).reset_index(drop = True)
Nmin_kurmangazy_p = vrp_fact['Nmin_kurmangazy'].append(kurmangazy_p['Nmin_kurmangazy']).reset_index(drop = True)
Ncon_kurmangazy_p = vrp_fact['Ncon_kurmangazy'].append(kurmangazy_p['Ncon_kurmangazy']).reset_index(drop = True)
Nman_kurmangazy_p = vrp_fact['Nman_kurmangazy'].append(kurmangazy_p['Nman_kurmangazy']).reset_index(drop = True)
Nret_kurmangazy_p = vrp_fact['Nret_kurmangazy'].append(kurmangazy_p['Nret_kurmangazy']).reset_index(drop = True)
Nwhl_kurmangazy_p = vrp_fact['Nwhl_kurmangazy'].append(kurmangazy_p['Nwhl_kurmangazy']).reset_index(drop = True)
Ntrd_kurmangazy_p = vrp_fact['Ntrd_kurmangazy'].append(kurmangazy_p['Ntrd_kurmangazy']).reset_index(drop = True)
Nsrv_kurmangazy_p = vrp_fact['Nsrv_kurmangazy'].append(kurmangazy_p['Nsrv_kurmangazy']).reset_index(drop = True)
Nwtr_kurmangazy_p = vrp_fact['Nwtr_kurmangazy'].append(kurmangazy_p['Nwtr_kurmangazy']).reset_index(drop = True)
Nelc_kurmangazy_p = vrp_fact['Nelc_kurmangazy'].append(kurmangazy_p['Nelc_kurmangazy']).reset_index(drop = True)
Nind_kurmangazy_p = vrp_fact['Nind_kurmangazy'].append(kurmangazy_p['Nind_kurmangazy']).reset_index(drop = True)
ltot_kurmangazy_p = vrp_fact['ltot_kurmangazy'].append(kurmangazy_p['ltot_kurmangazy']).reset_index(drop = True)
lgds_kurmangazy_p = vrp_fact['lgds_kurmangazy'].append(kurmangazy_p['lgds_kurmangazy']).reset_index(drop = True)
lagr_kurmangazy_p = vrp_fact['lagr_kurmangazy'].append(kurmangazy_p['lagr_kurmangazy']).reset_index(drop = True)
lmin_kurmangazy_p = vrp_fact['lmin_kurmangazy'].append(kurmangazy_p['lmin_kurmangazy']).reset_index(drop = True)
lcon_kurmangazy_p = vrp_fact['lcon_kurmangazy'].append(kurmangazy_p['lcon_kurmangazy']).reset_index(drop = True)
lman_kurmangazy_p = vrp_fact['lman_kurmangazy'].append(kurmangazy_p['lman_kurmangazy']).reset_index(drop = True)
lret_kurmangazy_p = vrp_fact['lret_kurmangazy'].append(kurmangazy_p['lret_kurmangazy']).reset_index(drop = True)
lwhl_kurmangazy_p = vrp_fact['lwhl_kurmangazy'].append(kurmangazy_p['lwhl_kurmangazy']).reset_index(drop = True)
ltrd_kurmangazy_p = vrp_fact['ltrd_kurmangazy'].append(kurmangazy_p['ltrd_kurmangazy']).reset_index(drop = True)
lsrv_kurmangazy_p = vrp_fact['lsrv_kurmangazy'].append(kurmangazy_p['lsrv_kurmangazy']).reset_index(drop = True)
lwtr_kurmangazy_p = vrp_fact['lwtr_kurmangazy'].append(kurmangazy_p['lwtr_kurmangazy']).reset_index(drop = True)
lelc_kurmangazy_p = vrp_fact['lelc_kurmangazy'].append(kurmangazy_p['lelc_kurmangazy']).reset_index(drop = True)
lind_kurmangazy_p = vrp_fact['lind_kurmangazy'].append(kurmangazy_p['lind_kurmangazy']).reset_index(drop = True)
Dtot_kurmangazy_p = vrp_fact['Dtot_kurmangazy'].append(kurmangazy_p['Dtot_kurmangazy']).reset_index(drop = True)
Dgds_kurmangazy_p = vrp_fact['Dgds_kurmangazy'].append(kurmangazy_p['Dgds_kurmangazy']).reset_index(drop = True)
Dagr_kurmangazy_p = vrp_fact['Dagr_kurmangazy'].append(kurmangazy_p['Dagr_kurmangazy']).reset_index(drop = True)
Dmin_kurmangazy_p = vrp_fact['Dmin_kurmangazy'].append(kurmangazy_p['Dmin_kurmangazy']).reset_index(drop = True)
Dcon_kurmangazy_p = vrp_fact['Dcon_kurmangazy'].append(kurmangazy_p['Dcon_kurmangazy']).reset_index(drop = True)
Dman_kurmangazy_p = vrp_fact['Dman_kurmangazy'].append(kurmangazy_p['Dman_kurmangazy']).reset_index(drop = True)
Dret_kurmangazy_p = vrp_fact['Dret_kurmangazy'].append(kurmangazy_p['Dret_kurmangazy']).reset_index(drop = True)
Dwhl_kurmangazy_p = vrp_fact['Dwhl_kurmangazy'].append(kurmangazy_p['Dwhl_kurmangazy']).reset_index(drop = True)
Dtrd_kurmangazy_p = vrp_fact['Dtrd_kurmangazy'].append(kurmangazy_p['Dtrd_kurmangazy']).reset_index(drop = True)
Dsrv_kurmangazy_p = vrp_fact['Dsrv_kurmangazy'].append(kurmangazy_p['Dsrv_kurmangazy']).reset_index(drop = True)
Dwtr_kurmangazy_p = vrp_fact['Dwtr_kurmangazy'].append(kurmangazy_p['Dwtr_kurmangazy']).reset_index(drop = True)
Delc_kurmangazy_p = vrp_fact['Delc_kurmangazy'].append(kurmangazy_p['Delc_kurmangazy']).reset_index(drop = True)
Dind_kurmangazy_p = vrp_fact['Dind_kurmangazy'].append(kurmangazy_p['Dind_kurmangazy']).reset_index(drop = True)
Ntot_kzylkoga_p = vrp_fact['Ntot_kzylkoga'].append(kzylkoga_p['Ntot_kzylkoga']).reset_index(drop = True)
Ngds_kzylkoga_p = vrp_fact['Ngds_kzylkoga'].append(kzylkoga_p['Ngds_kzylkoga']).reset_index(drop = True)
Nagr_kzylkoga_p = vrp_fact['Nagr_kzylkoga'].append(kzylkoga_p['Nagr_kzylkoga']).reset_index(drop = True)
Nmin_kzylkoga_p = vrp_fact['Nmin_kzylkoga'].append(kzylkoga_p['Nmin_kzylkoga']).reset_index(drop = True)
Ncon_kzylkoga_p = vrp_fact['Ncon_kzylkoga'].append(kzylkoga_p['Ncon_kzylkoga']).reset_index(drop = True)
Nman_kzylkoga_p = vrp_fact['Nman_kzylkoga'].append(kzylkoga_p['Nman_kzylkoga']).reset_index(drop = True)
Nret_kzylkoga_p = vrp_fact['Nret_kzylkoga'].append(kzylkoga_p['Nret_kzylkoga']).reset_index(drop = True)
Nwhl_kzylkoga_p = vrp_fact['Nwhl_kzylkoga'].append(kzylkoga_p['Nwhl_kzylkoga']).reset_index(drop = True)
Ntrd_kzylkoga_p = vrp_fact['Ntrd_kzylkoga'].append(kzylkoga_p['Ntrd_kzylkoga']).reset_index(drop = True)
Nsrv_kzylkoga_p = vrp_fact['Nsrv_kzylkoga'].append(kzylkoga_p['Nsrv_kzylkoga']).reset_index(drop = True)
Nwtr_kzylkoga_p = vrp_fact['Nwtr_kzylkoga'].append(kzylkoga_p['Nwtr_kzylkoga']).reset_index(drop = True)
Nelc_kzylkoga_p = vrp_fact['Nelc_kzylkoga'].append(kzylkoga_p['Nelc_kzylkoga']).reset_index(drop = True)
Nind_kzylkoga_p = vrp_fact['Nind_kzylkoga'].append(kzylkoga_p['Nind_kzylkoga']).reset_index(drop = True)
ltot_kzylkoga_p = vrp_fact['ltot_kzylkoga'].append(kzylkoga_p['ltot_kzylkoga']).reset_index(drop = True)
lgds_kzylkoga_p = vrp_fact['lgds_kzylkoga'].append(kzylkoga_p['lgds_kzylkoga']).reset_index(drop = True)
lagr_kzylkoga_p = vrp_fact['lagr_kzylkoga'].append(kzylkoga_p['lagr_kzylkoga']).reset_index(drop = True)
lmin_kzylkoga_p = vrp_fact['lmin_kzylkoga'].append(kzylkoga_p['lmin_kzylkoga']).reset_index(drop = True)
lcon_kzylkoga_p = vrp_fact['lcon_kzylkoga'].append(kzylkoga_p['lcon_kzylkoga']).reset_index(drop = True)
lman_kzylkoga_p = vrp_fact['lman_kzylkoga'].append(kzylkoga_p['lman_kzylkoga']).reset_index(drop = True)
lret_kzylkoga_p = vrp_fact['lret_kzylkoga'].append(kzylkoga_p['lret_kzylkoga']).reset_index(drop = True)
lwhl_kzylkoga_p = vrp_fact['lwhl_kzylkoga'].append(kzylkoga_p['lwhl_kzylkoga']).reset_index(drop = True)
ltrd_kzylkoga_p = vrp_fact['ltrd_kzylkoga'].append(kzylkoga_p['ltrd_kzylkoga']).reset_index(drop = True)
lsrv_kzylkoga_p = vrp_fact['lsrv_kzylkoga'].append(kzylkoga_p['lsrv_kzylkoga']).reset_index(drop = True)
lwtr_kzylkoga_p = vrp_fact['lwtr_kzylkoga'].append(kzylkoga_p['lwtr_kzylkoga']).reset_index(drop = True)
lelc_kzylkoga_p = vrp_fact['lelc_kzylkoga'].append(kzylkoga_p['lelc_kzylkoga']).reset_index(drop = True)
lind_kzylkoga_p = vrp_fact['lind_kzylkoga'].append(kzylkoga_p['lind_kzylkoga']).reset_index(drop = True)
Dtot_kzylkoga_p = vrp_fact['Dtot_kzylkoga'].append(kzylkoga_p['Dtot_kzylkoga']).reset_index(drop = True)
Dgds_kzylkoga_p = vrp_fact['Dgds_kzylkoga'].append(kzylkoga_p['Dgds_kzylkoga']).reset_index(drop = True)
Dagr_kzylkoga_p = vrp_fact['Dagr_kzylkoga'].append(kzylkoga_p['Dagr_kzylkoga']).reset_index(drop = True)
Dmin_kzylkoga_p = vrp_fact['Dmin_kzylkoga'].append(kzylkoga_p['Dmin_kzylkoga']).reset_index(drop = True)
Dcon_kzylkoga_p = vrp_fact['Dcon_kzylkoga'].append(kzylkoga_p['Dcon_kzylkoga']).reset_index(drop = True)
Dman_kzylkoga_p = vrp_fact['Dman_kzylkoga'].append(kzylkoga_p['Dman_kzylkoga']).reset_index(drop = True)
Dret_kzylkoga_p = vrp_fact['Dret_kzylkoga'].append(kzylkoga_p['Dret_kzylkoga']).reset_index(drop = True)
Dwhl_kzylkoga_p = vrp_fact['Dwhl_kzylkoga'].append(kzylkoga_p['Dwhl_kzylkoga']).reset_index(drop = True)
Dtrd_kzylkoga_p = vrp_fact['Dtrd_kzylkoga'].append(kzylkoga_p['Dtrd_kzylkoga']).reset_index(drop = True)
Dsrv_kzylkoga_p = vrp_fact['Dsrv_kzylkoga'].append(kzylkoga_p['Dsrv_kzylkoga']).reset_index(drop = True)
Dwtr_kzylkoga_p = vrp_fact['Dwtr_kzylkoga'].append(kzylkoga_p['Dwtr_kzylkoga']).reset_index(drop = True)
Delc_kzylkoga_p = vrp_fact['Delc_kzylkoga'].append(kzylkoga_p['Delc_kzylkoga']).reset_index(drop = True)
Dind_kzylkoga_p = vrp_fact['Dind_kzylkoga'].append(kzylkoga_p['Dind_kzylkoga']).reset_index(drop = True)
Ntot_makat_p = vrp_fact['Ntot_makat'].append(makat_p['Ntot_makat']).reset_index(drop = True)
Ngds_makat_p = vrp_fact['Ngds_makat'].append(makat_p['Ngds_makat']).reset_index(drop = True)
Nagr_makat_p = vrp_fact['Nagr_makat'].append(makat_p['Nagr_makat']).reset_index(drop = True)
Nmin_makat_p = vrp_fact['Nmin_makat'].append(makat_p['Nmin_makat']).reset_index(drop = True)
Ncon_makat_p = vrp_fact['Ncon_makat'].append(makat_p['Ncon_makat']).reset_index(drop = True)
Nman_makat_p = vrp_fact['Nman_makat'].append(makat_p['Nman_makat']).reset_index(drop = True)
Nret_makat_p = vrp_fact['Nret_makat'].append(makat_p['Nret_makat']).reset_index(drop = True)
Nwhl_makat_p = vrp_fact['Nwhl_makat'].append(makat_p['Nwhl_makat']).reset_index(drop = True)
Ntrd_makat_p = vrp_fact['Ntrd_makat'].append(makat_p['Ntrd_makat']).reset_index(drop = True)
Nsrv_makat_p = vrp_fact['Nsrv_makat'].append(makat_p['Nsrv_makat']).reset_index(drop = True)
Nwtr_makat_p = vrp_fact['Nwtr_makat'].append(makat_p['Nwtr_makat']).reset_index(drop = True)
Nelc_makat_p = vrp_fact['Nelc_makat'].append(makat_p['Nelc_makat']).reset_index(drop = True)
Nind_makat_p = vrp_fact['Nind_makat'].append(makat_p['Nind_makat']).reset_index(drop = True)
ltot_makat_p = vrp_fact['ltot_makat'].append(makat_p['ltot_makat']).reset_index(drop = True)
lgds_makat_p = vrp_fact['lgds_makat'].append(makat_p['lgds_makat']).reset_index(drop = True)
lagr_makat_p = vrp_fact['lagr_makat'].append(makat_p['lagr_makat']).reset_index(drop = True)
lmin_makat_p = vrp_fact['lmin_makat'].append(makat_p['lmin_makat']).reset_index(drop = True)
lcon_makat_p = vrp_fact['lcon_makat'].append(makat_p['lcon_makat']).reset_index(drop = True)
lman_makat_p = vrp_fact['lman_makat'].append(makat_p['lman_makat']).reset_index(drop = True)
lret_makat_p = vrp_fact['lret_makat'].append(makat_p['lret_makat']).reset_index(drop = True)
lwhl_makat_p = vrp_fact['lwhl_makat'].append(makat_p['lwhl_makat']).reset_index(drop = True)
ltrd_makat_p = vrp_fact['ltrd_makat'].append(makat_p['ltrd_makat']).reset_index(drop = True)
lsrv_makat_p = vrp_fact['lsrv_makat'].append(makat_p['lsrv_makat']).reset_index(drop = True)
lwtr_makat_p = vrp_fact['lwtr_makat'].append(makat_p['lwtr_makat']).reset_index(drop = True)
lelc_makat_p = vrp_fact['lelc_makat'].append(makat_p['lelc_makat']).reset_index(drop = True)
lind_makat_p = vrp_fact['lind_makat'].append(makat_p['lind_makat']).reset_index(drop = True)
Dtot_makat_p = vrp_fact['Dtot_makat'].append(makat_p['Dtot_makat']).reset_index(drop = True)
Dgds_makat_p = vrp_fact['Dgds_makat'].append(makat_p['Dgds_makat']).reset_index(drop = True)
Dagr_makat_p = vrp_fact['Dagr_makat'].append(makat_p['Dagr_makat']).reset_index(drop = True)
Dmin_makat_p = vrp_fact['Dmin_makat'].append(makat_p['Dmin_makat']).reset_index(drop = True)
Dcon_makat_p = vrp_fact['Dcon_makat'].append(makat_p['Dcon_makat']).reset_index(drop = True)
Dman_makat_p = vrp_fact['Dman_makat'].append(makat_p['Dman_makat']).reset_index(drop = True)
Dret_makat_p = vrp_fact['Dret_makat'].append(makat_p['Dret_makat']).reset_index(drop = True)
Dwhl_makat_p = vrp_fact['Dwhl_makat'].append(makat_p['Dwhl_makat']).reset_index(drop = True)
Dtrd_makat_p = vrp_fact['Dtrd_makat'].append(makat_p['Dtrd_makat']).reset_index(drop = True)
Dsrv_makat_p = vrp_fact['Dsrv_makat'].append(makat_p['Dsrv_makat']).reset_index(drop = True)
Dwtr_makat_p = vrp_fact['Dwtr_makat'].append(makat_p['Dwtr_makat']).reset_index(drop = True)
Delc_makat_p = vrp_fact['Delc_makat'].append(makat_p['Delc_makat']).reset_index(drop = True)
Dind_makat_p = vrp_fact['Dind_makat'].append(makat_p['Dind_makat']).reset_index(drop = True)
Ntot_makhambet_p = vrp_fact['Ntot_makhambet'].append(makhambet_p['Ntot_makhambet']).reset_index(drop = True)
Ngds_makhambet_p = vrp_fact['Ngds_makhambet'].append(makhambet_p['Ngds_makhambet']).reset_index(drop = True)
Nagr_makhambet_p = vrp_fact['Nagr_makhambet'].append(makhambet_p['Nagr_makhambet']).reset_index(drop = True)
Nmin_makhambet_p = vrp_fact['Nmin_makhambet'].append(makhambet_p['Nmin_makhambet']).reset_index(drop = True)
Ncon_makhambet_p = vrp_fact['Ncon_makhambet'].append(makhambet_p['Ncon_makhambet']).reset_index(drop = True)
Nman_makhambet_p = vrp_fact['Nman_makhambet'].append(makhambet_p['Nman_makhambet']).reset_index(drop = True)
Nret_makhambet_p = vrp_fact['Nret_makhambet'].append(makhambet_p['Nret_makhambet']).reset_index(drop = True)
Nwhl_makhambet_p = vrp_fact['Nwhl_makhambet'].append(makhambet_p['Nwhl_makhambet']).reset_index(drop = True)
Ntrd_makhambet_p = vrp_fact['Ntrd_makhambet'].append(makhambet_p['Ntrd_makhambet']).reset_index(drop = True)
Nsrv_makhambet_p = vrp_fact['Nsrv_makhambet'].append(makhambet_p['Nsrv_makhambet']).reset_index(drop = True)
Nwtr_makhambet_p = vrp_fact['Nwtr_makhambet'].append(makhambet_p['Nwtr_makhambet']).reset_index(drop = True)
Nelc_makhambet_p = vrp_fact['Nelc_makhambet'].append(makhambet_p['Nelc_makhambet']).reset_index(drop = True)
Nind_makhambet_p = vrp_fact['Nind_makhambet'].append(makhambet_p['Nind_makhambet']).reset_index(drop = True)
ltot_makhambet_p = vrp_fact['ltot_makhambet'].append(makhambet_p['ltot_makhambet']).reset_index(drop = True)
lgds_makhambet_p = vrp_fact['lgds_makhambet'].append(makhambet_p['lgds_makhambet']).reset_index(drop = True)
lagr_makhambet_p = vrp_fact['lagr_makhambet'].append(makhambet_p['lagr_makhambet']).reset_index(drop = True)
lmin_makhambet_p = vrp_fact['lmin_makhambet'].append(makhambet_p['lmin_makhambet']).reset_index(drop = True)
lcon_makhambet_p = vrp_fact['lcon_makhambet'].append(makhambet_p['lcon_makhambet']).reset_index(drop = True)
lman_makhambet_p = vrp_fact['lman_makhambet'].append(makhambet_p['lman_makhambet']).reset_index(drop = True)
lret_makhambet_p = vrp_fact['lret_makhambet'].append(makhambet_p['lret_makhambet']).reset_index(drop = True)
lwhl_makhambet_p = vrp_fact['lwhl_makhambet'].append(makhambet_p['lwhl_makhambet']).reset_index(drop = True)
ltrd_makhambet_p = vrp_fact['ltrd_makhambet'].append(makhambet_p['ltrd_makhambet']).reset_index(drop = True)
lsrv_makhambet_p = vrp_fact['lsrv_makhambet'].append(makhambet_p['lsrv_makhambet']).reset_index(drop = True)
lwtr_makhambet_p = vrp_fact['lwtr_makhambet'].append(makhambet_p['lwtr_makhambet']).reset_index(drop = True)
lelc_makhambet_p = vrp_fact['lelc_makhambet'].append(makhambet_p['lelc_makhambet']).reset_index(drop = True)
lind_makhambet_p = vrp_fact['lind_makhambet'].append(makhambet_p['lind_makhambet']).reset_index(drop = True)
Dtot_makhambet_p = vrp_fact['Dtot_makhambet'].append(makhambet_p['Dtot_makhambet']).reset_index(drop = True)
Dgds_makhambet_p = vrp_fact['Dgds_makhambet'].append(makhambet_p['Dgds_makhambet']).reset_index(drop = True)
Dagr_makhambet_p = vrp_fact['Dagr_makhambet'].append(makhambet_p['Dagr_makhambet']).reset_index(drop = True)
Dmin_makhambet_p = vrp_fact['Dmin_makhambet'].append(makhambet_p['Dmin_makhambet']).reset_index(drop = True)
Dcon_makhambet_p = vrp_fact['Dcon_makhambet'].append(makhambet_p['Dcon_makhambet']).reset_index(drop = True)
Dman_makhambet_p = vrp_fact['Dman_makhambet'].append(makhambet_p['Dman_makhambet']).reset_index(drop = True)
Dret_makhambet_p = vrp_fact['Dret_makhambet'].append(makhambet_p['Dret_makhambet']).reset_index(drop = True)
Dwhl_makhambet_p = vrp_fact['Dwhl_makhambet'].append(makhambet_p['Dwhl_makhambet']).reset_index(drop = True)
Dtrd_makhambet_p = vrp_fact['Dtrd_makhambet'].append(makhambet_p['Dtrd_makhambet']).reset_index(drop = True)
Dsrv_makhambet_p = vrp_fact['Dsrv_makhambet'].append(makhambet_p['Dsrv_makhambet']).reset_index(drop = True)
Dwtr_makhambet_p = vrp_fact['Dwtr_makhambet'].append(makhambet_p['Dwtr_makhambet']).reset_index(drop = True)
Delc_makhambet_p = vrp_fact['Delc_makhambet'].append(makhambet_p['Delc_makhambet']).reset_index(drop = True)
Dind_makhambet_p = vrp_fact['Dind_makhambet'].append(makhambet_p['Dind_makhambet']).reset_index(drop = True)
Ntot_zhylyoi_p = vrp_fact['Ntot_zhylyoi'].append(zhylyoi_p['Ntot_zhylyoi']).reset_index(drop = True)
Ngds_zhylyoi_p = vrp_fact['Ngds_zhylyoi'].append(zhylyoi_p['Ngds_zhylyoi']).reset_index(drop = True)
Nagr_zhylyoi_p = vrp_fact['Nagr_zhylyoi'].append(zhylyoi_p['Nagr_zhylyoi']).reset_index(drop = True)
Nmin_zhylyoi_p = vrp_fact['Nmin_zhylyoi'].append(zhylyoi_p['Nmin_zhylyoi']).reset_index(drop = True)
Ncon_zhylyoi_p = vrp_fact['Ncon_zhylyoi'].append(zhylyoi_p['Ncon_zhylyoi']).reset_index(drop = True)
Nman_zhylyoi_p = vrp_fact['Nman_zhylyoi'].append(zhylyoi_p['Nman_zhylyoi']).reset_index(drop = True)
Nret_zhylyoi_p = vrp_fact['Nret_zhylyoi'].append(zhylyoi_p['Nret_zhylyoi']).reset_index(drop = True)
Nwhl_zhylyoi_p = vrp_fact['Nwhl_zhylyoi'].append(zhylyoi_p['Nwhl_zhylyoi']).reset_index(drop = True)
Ntrd_zhylyoi_p = vrp_fact['Ntrd_zhylyoi'].append(zhylyoi_p['Ntrd_zhylyoi']).reset_index(drop = True)
Nsrv_zhylyoi_p = vrp_fact['Nsrv_zhylyoi'].append(zhylyoi_p['Nsrv_zhylyoi']).reset_index(drop = True)
Nwtr_zhylyoi_p = vrp_fact['Nwtr_zhylyoi'].append(zhylyoi_p['Nwtr_zhylyoi']).reset_index(drop = True)
Nelc_zhylyoi_p = vrp_fact['Nelc_zhylyoi'].append(zhylyoi_p['Nelc_zhylyoi']).reset_index(drop = True)
Nind_zhylyoi_p = vrp_fact['Nind_zhylyoi'].append(zhylyoi_p['Nind_zhylyoi']).reset_index(drop = True)
ltot_zhylyoi_p = vrp_fact['ltot_zhylyoi'].append(zhylyoi_p['ltot_zhylyoi']).reset_index(drop = True)
lgds_zhylyoi_p = vrp_fact['lgds_zhylyoi'].append(zhylyoi_p['lgds_zhylyoi']).reset_index(drop = True)
lagr_zhylyoi_p = vrp_fact['lagr_zhylyoi'].append(zhylyoi_p['lagr_zhylyoi']).reset_index(drop = True)
lmin_zhylyoi_p = vrp_fact['lmin_zhylyoi'].append(zhylyoi_p['lmin_zhylyoi']).reset_index(drop = True)
lcon_zhylyoi_p = vrp_fact['lcon_zhylyoi'].append(zhylyoi_p['lcon_zhylyoi']).reset_index(drop = True)
lman_zhylyoi_p = vrp_fact['lman_zhylyoi'].append(zhylyoi_p['lman_zhylyoi']).reset_index(drop = True)
lret_zhylyoi_p = vrp_fact['lret_zhylyoi'].append(zhylyoi_p['lret_zhylyoi']).reset_index(drop = True)
lwhl_zhylyoi_p = vrp_fact['lwhl_zhylyoi'].append(zhylyoi_p['lwhl_zhylyoi']).reset_index(drop = True)
ltrd_zhylyoi_p = vrp_fact['ltrd_zhylyoi'].append(zhylyoi_p['ltrd_zhylyoi']).reset_index(drop = True)
lsrv_zhylyoi_p = vrp_fact['lsrv_zhylyoi'].append(zhylyoi_p['lsrv_zhylyoi']).reset_index(drop = True)
lwtr_zhylyoi_p = vrp_fact['lwtr_zhylyoi'].append(zhylyoi_p['lwtr_zhylyoi']).reset_index(drop = True)
lelc_zhylyoi_p = vrp_fact['lelc_zhylyoi'].append(zhylyoi_p['lelc_zhylyoi']).reset_index(drop = True)
lind_zhylyoi_p = vrp_fact['lind_zhylyoi'].append(zhylyoi_p['lind_zhylyoi']).reset_index(drop = True)
Dtot_zhylyoi_p = vrp_fact['Dtot_zhylyoi'].append(zhylyoi_p['Dtot_zhylyoi']).reset_index(drop = True)
Dgds_zhylyoi_p = vrp_fact['Dgds_zhylyoi'].append(zhylyoi_p['Dgds_zhylyoi']).reset_index(drop = True)
Dagr_zhylyoi_p = vrp_fact['Dagr_zhylyoi'].append(zhylyoi_p['Dagr_zhylyoi']).reset_index(drop = True)
Dmin_zhylyoi_p = vrp_fact['Dmin_zhylyoi'].append(zhylyoi_p['Dmin_zhylyoi']).reset_index(drop = True)
Dcon_zhylyoi_p = vrp_fact['Dcon_zhylyoi'].append(zhylyoi_p['Dcon_zhylyoi']).reset_index(drop = True)
Dman_zhylyoi_p = vrp_fact['Dman_zhylyoi'].append(zhylyoi_p['Dman_zhylyoi']).reset_index(drop = True)
Dret_zhylyoi_p = vrp_fact['Dret_zhylyoi'].append(zhylyoi_p['Dret_zhylyoi']).reset_index(drop = True)
Dwhl_zhylyoi_p = vrp_fact['Dwhl_zhylyoi'].append(zhylyoi_p['Dwhl_zhylyoi']).reset_index(drop = True)
Dtrd_zhylyoi_p = vrp_fact['Dtrd_zhylyoi'].append(zhylyoi_p['Dtrd_zhylyoi']).reset_index(drop = True)
Dsrv_zhylyoi_p = vrp_fact['Dsrv_zhylyoi'].append(zhylyoi_p['Dsrv_zhylyoi']).reset_index(drop = True)
Dwtr_zhylyoi_p = vrp_fact['Dwtr_zhylyoi'].append(zhylyoi_p['Dwtr_zhylyoi']).reset_index(drop = True)
Delc_zhylyoi_p = vrp_fact['Delc_zhylyoi'].append(zhylyoi_p['Delc_zhylyoi']).reset_index(drop = True)
Dind_zhylyoi_p = vrp_fact['Dind_zhylyoi'].append(zhylyoi_p['Dind_zhylyoi']).reset_index(drop = True)

atyrau_pp = (Ntot_atyrau_o.append(Ngds_atyrau_p).append(Nagr_atyrau_p).append(Nind_atyrau_p).append(Nmin_atyrau_p).append(Nman_atyrau_p).append(Nelc_atyrau_p).append(Nwtr_atyrau_p).append(Ncon_atyrau_p).append(Nsrv_atyrau_p).append(Ntrd_atyrau_p).append(Nret_atyrau_p).append(Nwhl_atyrau_p).append(ltot_atyrau_p).append(lgds_atyrau_p).append(lagr_atyrau_p).append(lind_atyrau_p).append(lmin_atyrau_p).append(lman_atyrau_p).append(lelc_atyrau_p).append(lwtr_atyrau_p).append(lcon_atyrau_p).append(lsrv_atyrau_p).append(ltrd_atyrau_p).append(lret_atyrau_p).append(lwhl_atyrau_p).append(Dtot_atyrau_p).append(Dgds_atyrau_p).append(Dagr_atyrau_p).append(Dind_atyrau_p).append(Dmin_atyrau_p).append(Dman_atyrau_p).append(Delc_atyrau_p).append(Dwtr_atyrau_p).append(Dcon_atyrau_p).append(Dsrv_atyrau_p).append(Dtrd_atyrau_p).append(Dret_atyrau_p).append(Dwhl_atyrau_p)).sort_index(kind='mergesort').reset_index(drop = True)
zhylyoi_pp = (Ntot_zhylyoi_o.append(Ngds_zhylyoi_p).append(Nagr_zhylyoi_p).append(Nind_zhylyoi_p).append(Nmin_zhylyoi_p).append(Nman_zhylyoi_p).append(Nelc_zhylyoi_p).append(Nwtr_zhylyoi_p).append(Ncon_zhylyoi_p).append(Nsrv_zhylyoi_p).append(Ntrd_zhylyoi_p).append(Nret_zhylyoi_p).append(Nwhl_zhylyoi_p).append(ltot_zhylyoi_p).append(lgds_zhylyoi_p).append(lagr_zhylyoi_p).append(lind_zhylyoi_p).append(lmin_zhylyoi_p).append(lman_zhylyoi_p).append(lelc_zhylyoi_p).append(lwtr_zhylyoi_p).append(lcon_zhylyoi_p).append(lsrv_zhylyoi_p).append(ltrd_zhylyoi_p).append(lret_zhylyoi_p).append(lwhl_zhylyoi_p).append(Dtot_zhylyoi_p).append(Dgds_zhylyoi_p).append(Dagr_zhylyoi_p).append(Dind_zhylyoi_p).append(Dmin_zhylyoi_p).append(Dman_zhylyoi_p).append(Delc_zhylyoi_p).append(Dwtr_zhylyoi_p).append(Dcon_zhylyoi_p).append(Dsrv_zhylyoi_p).append(Dtrd_zhylyoi_p).append(Dret_zhylyoi_p).append(Dwhl_zhylyoi_p)).sort_index(kind='mergesort').reset_index(drop = True)
inder_pp = (Ntot_inder_o.append(Ngds_inder).append(Nagr_inder).append(Nind_inder).append(Nmin_inder).append(Nman_inder).append(Nelc_inder).append(Nwtr_inder).append(Ncon_inder).append(Nsrv_inder).append(Ntrd_inder).append(Nret_inder).append(Nwhl_inder).append(ltot_inder).append(lgds_inder).append(lagr_inder).append(lind_inder).append(lmin_inder).append(lman_inder).append(lelc_inder).append(lwtr_inder).append(lcon_inder).append(lsrv_inder).append(ltrd_inder).append(lret_inder).append(lwhl_inder).append(Dtot_inder).append(Dgds_inder).append(Dagr_inder).append(Dind_inder).append(Dmin_inder).append(Dman_inder).append(Delc_inder).append(Dwtr_inder).append(Dcon_inder).append(Dsrv_inder).append(Dtrd_inder).append(Dret_inder).append(Dwhl_inder)).sort_index(kind='mergesort').reset_index(drop = True)
isatai_pp = (Ntot_isatai_o.append(Ngds_isatai_p).append(Nagr_isatai_p).append(Nind_isatai_p).append(Nmin_isatai_p).append(Nman_isatai_p).append(Nelc_isatai_p).append(Nwtr_isatai_p).append(Ncon_isatai_p).append(Nsrv_isatai_p).append(Ntrd_isatai_p).append(Nret_isatai_p).append(Nwhl_isatai_p).append(ltot_isatai_p).append(lgds_isatai_p).append(lagr_isatai_p).append(lind_isatai_p).append(lmin_isatai_p).append(lman_isatai_p).append(lelc_isatai_p).append(lwtr_isatai_p).append(lcon_isatai_p).append(lsrv_isatai_p).append(ltrd_isatai_p).append(lret_isatai_p).append(lwhl_isatai_p).append(Dtot_isatai_p).append(Dgds_isatai_p).append(Dagr_isatai_p).append(Dind_isatai_p).append(Dmin_isatai_p).append(Dman_isatai_p).append(Delc_isatai_p).append(Dwtr_isatai_p).append(Dcon_isatai_p).append(Dsrv_isatai_p).append(Dtrd_isatai_p).append(Dret_isatai_p).append(Dwhl_isatai_p)).sort_index(kind='mergesort').reset_index(drop = True)
kurmangazy_pp = (Ntot_kurmangazy_o.append(Ngds_kurmangazy_p).append(Nagr_kurmangazy_p).append(Nind_kurmangazy_p).append(Nmin_kurmangazy_p).append(Nman_kurmangazy_p).append(Nelc_kurmangazy_p).append(Nwtr_kurmangazy_p).append(Ncon_kurmangazy_p).append(Nsrv_kurmangazy_p).append(Ntrd_kurmangazy_p).append(Nret_kurmangazy_p).append(Nwhl_kurmangazy_p).append(ltot_kurmangazy_p).append(lgds_kurmangazy_p).append(lagr_kurmangazy_p).append(lind_kurmangazy_p).append(lmin_kurmangazy_p).append(lman_kurmangazy_p).append(lelc_kurmangazy_p).append(lwtr_kurmangazy_p).append(lcon_kurmangazy_p).append(lsrv_kurmangazy_p).append(ltrd_kurmangazy_p).append(lret_kurmangazy_p).append(lwhl_kurmangazy_p).append(Dtot_kurmangazy_p).append(Dgds_kurmangazy_p).append(Dagr_kurmangazy_p).append(Dind_kurmangazy_p).append(Dmin_kurmangazy_p).append(Dman_kurmangazy_p).append(Delc_kurmangazy_p).append(Dwtr_kurmangazy_p).append(Dcon_kurmangazy_p).append(Dsrv_kurmangazy_p).append(Dtrd_kurmangazy_p).append(Dret_kurmangazy_p).append(Dwhl_kurmangazy_p)).sort_index(kind='mergesort').reset_index(drop = True)
kzylkoga_pp = (Ntot_kzylkoga_o.append(Ngds_kzylkoga_p).append(Nagr_kzylkoga_p).append(Nind_kzylkoga_p).append(Nmin_kzylkoga_p).append(Nman_kzylkoga_p).append(Nelc_kzylkoga_p).append(Nwtr_kzylkoga_p).append(Ncon_kzylkoga_p).append(Nsrv_kzylkoga_p).append(Ntrd_kzylkoga_p).append(Nret_kzylkoga_p).append(Nwhl_kzylkoga_p).append(ltot_kzylkoga_p).append(lgds_kzylkoga_p).append(lagr_kzylkoga_p).append(lind_kzylkoga_p).append(lmin_kzylkoga_p).append(lman_kzylkoga_p).append(lelc_kzylkoga_p).append(lwtr_kzylkoga_p).append(lcon_kzylkoga_p).append(lsrv_kzylkoga_p).append(ltrd_kzylkoga_p).append(lret_kzylkoga_p).append(lwhl_kzylkoga_p).append(Dtot_kzylkoga_p).append(Dgds_kzylkoga_p).append(Dagr_kzylkoga_p).append(Dind_kzylkoga_p).append(Dmin_kzylkoga_p).append(Dman_kzylkoga_p).append(Delc_kzylkoga_p).append(Dwtr_kzylkoga_p).append(Dcon_kzylkoga_p).append(Dsrv_kzylkoga_p).append(Dtrd_kzylkoga_p).append(Dret_kzylkoga_p).append(Dwhl_kzylkoga_p)).sort_index(kind='mergesort').reset_index(drop = True)
makat_pp = (Ntot_makat_o.append(Ngds_makat_p).append(Nagr_makat_p).append(Nind_makat_p).append(Nmin_makat_p).append(Nman_makat_p).append(Nelc_makat_p).append(Nwtr_makat_p).append(Ncon_makat_p).append(Nsrv_makat_p).append(Ntrd_makat_p).append(Nret_makat_p).append(Nwhl_makat_p).append(ltot_makat_p).append(lgds_makat_p).append(lagr_makat_p).append(lind_makat_p).append(lmin_makat_p).append(lman_makat_p).append(lelc_makat_p).append(lwtr_makat_p).append(lcon_makat_p).append(lsrv_makat_p).append(ltrd_makat_p).append(lret_makat_p).append(lwhl_makat_p).append(Dtot_makat_p).append(Dgds_makat_p).append(Dagr_makat_p).append(Dind_makat_p).append(Dmin_makat_p).append(Dman_makat_p).append(Delc_makat_p).append(Dwtr_makat_p).append(Dcon_makat_p).append(Dsrv_makat_p).append(Dtrd_makat_p).append(Dret_makat_p).append(Dwhl_makat_p)).sort_index(kind='mergesort').reset_index(drop = True)
makhambet_pp = (Ntot_makhambet_o.append(Ngds_makhambet_p).append(Nagr_makhambet_p).append(Nind_makhambet_p).append(Nmin_makhambet_p).append(Nman_makhambet_p).append(Nelc_makhambet_p).append(Nwtr_makhambet_p).append(Ncon_makhambet_p).append(Nsrv_makhambet_p).append(Ntrd_makhambet_p).append(Nret_makhambet_p).append(Nwhl_makhambet_p).append(ltot_makhambet_p).append(lgds_makhambet_p).append(lagr_makhambet_p).append(lind_makhambet_p).append(lmin_makhambet_p).append(lman_makhambet_p).append(lelc_makhambet_p).append(lwtr_makhambet_p).append(lcon_makhambet_p).append(lsrv_makhambet_p).append(ltrd_makhambet_p).append(lret_makhambet_p).append(lwhl_makhambet_p).append(Dtot_makhambet_p).append(Dgds_makhambet_p).append(Dagr_makhambet_p).append(Dind_makhambet_p).append(Dmin_makhambet_p).append(Dman_makhambet_p).append(Delc_makhambet_p).append(Dwtr_makhambet_p).append(Dcon_makhambet_p).append(Dsrv_makhambet_p).append(Dtrd_makhambet_p).append(Dret_makhambet_p).append(Dwhl_makhambet_p)).sort_index(kind='mergesort').reset_index(drop = True)

pessimist =(atyrau_pp.append(zhylyoi_pp).append(inder_pp).append(isatai_pp).append(kurmangazy_pp).append(kzylkoga_pp).append(makat_pp).append(makhambet_pp)).reset_index(drop = True)


atyrau_oo = (Ntot_atyrau_o.append(Ngds_atyrau_o).append(Nagr_atyrau_o).append(Nind_atyrau_o).append(Nmin_atyrau_o).append(Nman_atyrau_o).append(Nelc_atyrau_o).append(Nwtr_atyrau_o).append(Ncon_atyrau_o).append(Nsrv_atyrau_o).append(Ntrd_atyrau_o).append(Nret_atyrau_o).append(Nwhl_atyrau_o).append(ltot_atyrau_o).append(lgds_atyrau_o).append(lagr_atyrau_o).append(lind_atyrau_o).append(lmin_atyrau_o).append(lman_atyrau_o).append(lelc_atyrau_o).append(lwtr_atyrau_o).append(lcon_atyrau_o).append(lsrv_atyrau_o).append(ltrd_atyrau_o).append(lret_atyrau_o).append(lwhl_atyrau_o).append(Dtot_atyrau_o).append(Dgds_atyrau_o).append(Dagr_atyrau_o).append(Dind_atyrau_o).append(Dmin_atyrau_o).append(Dman_atyrau_o).append(Delc_atyrau_o).append(Dwtr_atyrau_o).append(Dcon_atyrau_o).append(Dsrv_atyrau_o).append(Dtrd_atyrau_o).append(Dret_atyrau_o).append(Dwhl_atyrau_o)).sort_index(kind='mergesort').reset_index(drop = True)
zhylyoi_oo = (Ntot_zhylyoi_o.append(Ngds_zhylyoi_o).append(Nagr_zhylyoi_o).append(Nind_zhylyoi_o).append(Nmin_zhylyoi_o).append(Nman_zhylyoi_o).append(Nelc_zhylyoi_o).append(Nwtr_zhylyoi_o).append(Ncon_zhylyoi_o).append(Nsrv_zhylyoi_o).append(Ntrd_zhylyoi_o).append(Nret_zhylyoi_o).append(Nwhl_zhylyoi_o).append(ltot_zhylyoi_o).append(lgds_zhylyoi_o).append(lagr_zhylyoi_o).append(lind_zhylyoi_o).append(lmin_zhylyoi_o).append(lman_zhylyoi_o).append(lelc_zhylyoi_o).append(lwtr_zhylyoi_o).append(lcon_zhylyoi_o).append(lsrv_zhylyoi_o).append(ltrd_zhylyoi_o).append(lret_zhylyoi_o).append(lwhl_zhylyoi_o).append(Dtot_zhylyoi_o).append(Dgds_zhylyoi_o).append(Dagr_zhylyoi_o).append(Dind_zhylyoi_o).append(Dmin_zhylyoi_o).append(Dman_zhylyoi_o).append(Delc_zhylyoi_o).append(Dwtr_zhylyoi_o).append(Dcon_zhylyoi_o).append(Dsrv_zhylyoi_o).append(Dtrd_zhylyoi_o).append(Dret_zhylyoi_o).append(Dwhl_zhylyoi_o)).sort_index(kind='mergesort').reset_index(drop = True)
inder_oo = (Ntot_inder_o.append(Ngds_inder).append(Nagr_inder).append(Nind_inder).append(Nmin_inder).append(Nman_inder).append(Nelc_inder).append(Nwtr_inder).append(Ncon_inder).append(Nsrv_inder).append(Ntrd_inder).append(Nret_inder).append(Nwhl_inder).append(ltot_inder).append(lgds_inder).append(lagr_inder).append(lind_inder).append(lmin_inder).append(lman_inder).append(lelc_inder).append(lwtr_inder).append(lcon_inder).append(lsrv_inder).append(ltrd_inder).append(lret_inder).append(lwhl_inder).append(Dtot_inder).append(Dgds_inder).append(Dagr_inder).append(Dind_inder).append(Dmin_inder).append(Dman_inder).append(Delc_inder).append(Dwtr_inder).append(Dcon_inder).append(Dsrv_inder).append(Dtrd_inder).append(Dret_inder).append(Dwhl_inder)).sort_index(kind='mergesort').reset_index(drop = True)
isatai_oo = (Ntot_isatai_o.append(Ngds_isatai_o).append(Nagr_isatai_o).append(Nind_isatai_o).append(Nmin_isatai_o).append(Nman_isatai_o).append(Nelc_isatai_o).append(Nwtr_isatai_o).append(Ncon_isatai_o).append(Nsrv_isatai_o).append(Ntrd_isatai_o).append(Nret_isatai_o).append(Nwhl_isatai_o).append(ltot_isatai_o).append(lgds_isatai_o).append(lagr_isatai_o).append(lind_isatai_o).append(lmin_isatai_o).append(lman_isatai_o).append(lelc_isatai_o).append(lwtr_isatai_o).append(lcon_isatai_o).append(lsrv_isatai_o).append(ltrd_isatai_o).append(lret_isatai_o).append(lwhl_isatai_o).append(Dtot_isatai_o).append(Dgds_isatai_o).append(Dagr_isatai_o).append(Dind_isatai_o).append(Dmin_isatai_o).append(Dman_isatai_o).append(Delc_isatai_o).append(Dwtr_isatai_o).append(Dcon_isatai_o).append(Dsrv_isatai_o).append(Dtrd_isatai_o).append(Dret_isatai_o).append(Dwhl_isatai_o)).sort_index(kind='mergesort').reset_index(drop = True)
kurmangazy_oo = (Ntot_kurmangazy_o.append(Ngds_kurmangazy_o).append(Nagr_kurmangazy_o).append(Nind_kurmangazy_o).append(Nmin_kurmangazy_o).append(Nman_kurmangazy_o).append(Nelc_kurmangazy_o).append(Nwtr_kurmangazy_o).append(Ncon_kurmangazy_o).append(Nsrv_kurmangazy_o).append(Ntrd_kurmangazy_o).append(Nret_kurmangazy_o).append(Nwhl_kurmangazy_o).append(ltot_kurmangazy_o).append(lgds_kurmangazy_o).append(lagr_kurmangazy_o).append(lind_kurmangazy_o).append(lmin_kurmangazy_o).append(lman_kurmangazy_o).append(lelc_kurmangazy_o).append(lwtr_kurmangazy_o).append(lcon_kurmangazy_o).append(lsrv_kurmangazy_o).append(ltrd_kurmangazy_o).append(lret_kurmangazy_o).append(lwhl_kurmangazy_o).append(Dtot_kurmangazy_o).append(Dgds_kurmangazy_o).append(Dagr_kurmangazy_o).append(Dind_kurmangazy_o).append(Dmin_kurmangazy_o).append(Dman_kurmangazy_o).append(Delc_kurmangazy_o).append(Dwtr_kurmangazy_o).append(Dcon_kurmangazy_o).append(Dsrv_kurmangazy_o).append(Dtrd_kurmangazy_o).append(Dret_kurmangazy_o).append(Dwhl_kurmangazy_o)).sort_index(kind='mergesort').reset_index(drop = True)
kzylkoga_oo = (Ntot_kzylkoga_o.append(Ngds_kzylkoga_o).append(Nagr_kzylkoga_o).append(Nind_kzylkoga_o).append(Nmin_kzylkoga_o).append(Nman_kzylkoga_o).append(Nelc_kzylkoga_o).append(Nwtr_kzylkoga_o).append(Ncon_kzylkoga_o).append(Nsrv_kzylkoga_o).append(Ntrd_kzylkoga_o).append(Nret_kzylkoga_o).append(Nwhl_kzylkoga_o).append(ltot_kzylkoga_o).append(lgds_kzylkoga_o).append(lagr_kzylkoga_o).append(lind_kzylkoga_o).append(lmin_kzylkoga_o).append(lman_kzylkoga_o).append(lelc_kzylkoga_o).append(lwtr_kzylkoga_o).append(lcon_kzylkoga_o).append(lsrv_kzylkoga_o).append(ltrd_kzylkoga_o).append(lret_kzylkoga_o).append(lwhl_kzylkoga_o).append(Dtot_kzylkoga_o).append(Dgds_kzylkoga_o).append(Dagr_kzylkoga_o).append(Dind_kzylkoga_o).append(Dmin_kzylkoga_o).append(Dman_kzylkoga_o).append(Delc_kzylkoga_o).append(Dwtr_kzylkoga_o).append(Dcon_kzylkoga_o).append(Dsrv_kzylkoga_o).append(Dtrd_kzylkoga_o).append(Dret_kzylkoga_o).append(Dwhl_kzylkoga_o)).sort_index(kind='mergesort').reset_index(drop = True)
makat_oo = (Ntot_makat_o.append(Ngds_makat_o).append(Nagr_makat_o).append(Nind_makat_o).append(Nmin_makat_o).append(Nman_makat_o).append(Nelc_makat_o).append(Nwtr_makat_o).append(Ncon_makat_o).append(Nsrv_makat_o).append(Ntrd_makat_o).append(Nret_makat_o).append(Nwhl_makat_o).append(ltot_makat_o).append(lgds_makat_o).append(lagr_makat_o).append(lind_makat_o).append(lmin_makat_o).append(lman_makat_o).append(lelc_makat_o).append(lwtr_makat_o).append(lcon_makat_o).append(lsrv_makat_o).append(ltrd_makat_o).append(lret_makat_o).append(lwhl_makat_o).append(Dtot_makat_o).append(Dgds_makat_o).append(Dagr_makat_o).append(Dind_makat_o).append(Dmin_makat_o).append(Dman_makat_o).append(Delc_makat_o).append(Dwtr_makat_o).append(Dcon_makat_o).append(Dsrv_makat_o).append(Dtrd_makat_o).append(Dret_makat_o).append(Dwhl_makat_o)).sort_index(kind='mergesort').reset_index(drop = True)
makhambet_oo = (Ntot_makhambet_o.append(Ngds_makhambet_o).append(Nagr_makhambet_o).append(Nind_makhambet_o).append(Nmin_makhambet_o).append(Nman_makhambet_o).append(Nelc_makhambet_o).append(Nwtr_makhambet_o).append(Ncon_makhambet_o).append(Nsrv_makhambet_o).append(Ntrd_makhambet_o).append(Nret_makhambet_o).append(Nwhl_makhambet_o).append(ltot_makhambet_o).append(lgds_makhambet_o).append(lagr_makhambet_o).append(lind_makhambet_o).append(lmin_makhambet_o).append(lman_makhambet_o).append(lelc_makhambet_o).append(lwtr_makhambet_o).append(lcon_makhambet_o).append(lsrv_makhambet_o).append(ltrd_makhambet_o).append(lret_makhambet_o).append(lwhl_makhambet_o).append(Dtot_makhambet_o).append(Dgds_makhambet_o).append(Dagr_makhambet_o).append(Dind_makhambet_o).append(Dmin_makhambet_o).append(Dman_makhambet_o).append(Delc_makhambet_o).append(Dwtr_makhambet_o).append(Dcon_makhambet_o).append(Dsrv_makhambet_o).append(Dtrd_makhambet_o).append(Dret_makhambet_o).append(Dwhl_makhambet_o)).sort_index(kind='mergesort').reset_index(drop = True)

optimist =(atyrau_oo.append(zhylyoi_oo).append(inder_oo).append(isatai_oo).append(kurmangazy_oo).append(kzylkoga_oo).append(makat_oo).append(makhambet_oo)).reset_index(drop = True)

atyrau = (Ntot_atyrau.append(Ngds_atyrau).append(Nagr_atyrau).append(Nind_atyrau).append(Nmin_atyrau).append(Nman_atyrau).append(Nelc_atyrau).append(Nwtr_atyrau).append(Ncon_atyrau).append(Nsrv_atyrau).append(Ntrd_atyrau).append(Nret_atyrau).append(Nwhl_atyrau).append(ltot_atyrau).append(lgds_atyrau).append(lagr_atyrau).append(lind_atyrau).append(lmin_atyrau).append(lman_atyrau).append(lelc_atyrau).append(lwtr_atyrau).append(lcon_atyrau).append(lsrv_atyrau).append(ltrd_atyrau).append(lret_atyrau).append(lwhl_atyrau).append(Dtot_atyrau).append(Dgds_atyrau).append(Dagr_atyrau).append(Dind_atyrau).append(Dmin_atyrau).append(Dman_atyrau).append(Delc_atyrau).append(Dwtr_atyrau).append(Dcon_atyrau).append(Dsrv_atyrau).append(Dtrd_atyrau).append(Dret_atyrau).append(Dwhl_atyrau)).sort_index(kind='mergesort').reset_index(drop = True)
zhylyoi = (Ntot_zhylyoi.append(Ngds_zhylyoi).append(Nagr_zhylyoi).append(Nind_zhylyoi).append(Nmin_zhylyoi).append(Nman_zhylyoi).append(Nelc_zhylyoi).append(Nwtr_zhylyoi).append(Ncon_zhylyoi).append(Nsrv_zhylyoi).append(Ntrd_zhylyoi).append(Nret_zhylyoi).append(Nwhl_zhylyoi).append(ltot_zhylyoi).append(lgds_zhylyoi).append(lagr_zhylyoi).append(lind_zhylyoi).append(lmin_zhylyoi).append(lman_zhylyoi).append(lelc_zhylyoi).append(lwtr_zhylyoi).append(lcon_zhylyoi).append(lsrv_zhylyoi).append(ltrd_zhylyoi).append(lret_zhylyoi).append(lwhl_zhylyoi).append(Dtot_zhylyoi).append(Dgds_zhylyoi).append(Dagr_zhylyoi).append(Dind_zhylyoi).append(Dmin_zhylyoi).append(Dman_zhylyoi).append(Delc_zhylyoi).append(Dwtr_zhylyoi).append(Dcon_zhylyoi).append(Dsrv_zhylyoi).append(Dtrd_zhylyoi).append(Dret_zhylyoi).append(Dwhl_zhylyoi)).sort_index(kind='mergesort').reset_index(drop = True)
inder = (Ntot_inder.append(Ngds_inder).append(Nagr_inder).append(Nind_inder).append(Nmin_inder).append(Nman_inder).append(Nelc_inder).append(Nwtr_inder).append(Ncon_inder).append(Nsrv_inder).append(Ntrd_inder).append(Nret_inder).append(Nwhl_inder).append(ltot_inder).append(lgds_inder).append(lagr_inder).append(lind_inder).append(lmin_inder).append(lman_inder).append(lelc_inder).append(lwtr_inder).append(lcon_inder).append(lsrv_inder).append(ltrd_inder).append(lret_inder).append(lwhl_inder).append(Dtot_inder).append(Dgds_inder).append(Dagr_inder).append(Dind_inder).append(Dmin_inder).append(Dman_inder).append(Delc_inder).append(Dwtr_inder).append(Dcon_inder).append(Dsrv_inder).append(Dtrd_inder).append(Dret_inder).append(Dwhl_inder)).sort_index(kind='mergesort').reset_index(drop = True)
isatai = (Ntot_isatai.append(Ngds_isatai).append(Nagr_isatai).append(Nind_isatai).append(Nmin_isatai).append(Nman_isatai).append(Nelc_isatai).append(Nwtr_isatai).append(Ncon_isatai).append(Nsrv_isatai).append(Ntrd_isatai).append(Nret_isatai).append(Nwhl_isatai).append(ltot_isatai).append(lgds_isatai).append(lagr_isatai).append(lind_isatai).append(lmin_isatai).append(lman_isatai).append(lelc_isatai).append(lwtr_isatai).append(lcon_isatai).append(lsrv_isatai).append(ltrd_isatai).append(lret_isatai).append(lwhl_isatai).append(Dtot_isatai).append(Dgds_isatai).append(Dagr_isatai).append(Dind_isatai).append(Dmin_isatai).append(Dman_isatai).append(Delc_isatai).append(Dwtr_isatai).append(Dcon_isatai).append(Dsrv_isatai).append(Dtrd_isatai).append(Dret_isatai).append(Dwhl_isatai)).sort_index(kind='mergesort').reset_index(drop = True)
kurmangazy = (Ntot_kurmangazy.append(Ngds_kurmangazy).append(Nagr_kurmangazy).append(Nind_kurmangazy).append(Nmin_kurmangazy).append(Nman_kurmangazy).append(Nelc_kurmangazy).append(Nwtr_kurmangazy).append(Ncon_kurmangazy).append(Nsrv_kurmangazy).append(Ntrd_kurmangazy).append(Nret_kurmangazy).append(Nwhl_kurmangazy).append(ltot_kurmangazy).append(lgds_kurmangazy).append(lagr_kurmangazy).append(lind_kurmangazy).append(lmin_kurmangazy).append(lman_kurmangazy).append(lelc_kurmangazy).append(lwtr_kurmangazy).append(lcon_kurmangazy).append(lsrv_kurmangazy).append(ltrd_kurmangazy).append(lret_kurmangazy).append(lwhl_kurmangazy).append(Dtot_kurmangazy).append(Dgds_kurmangazy).append(Dagr_kurmangazy).append(Dind_kurmangazy).append(Dmin_kurmangazy).append(Dman_kurmangazy).append(Delc_kurmangazy).append(Dwtr_kurmangazy).append(Dcon_kurmangazy).append(Dsrv_kurmangazy).append(Dtrd_kurmangazy).append(Dret_kurmangazy).append(Dwhl_kurmangazy)).sort_index(kind='mergesort').reset_index(drop = True)
kzylkoga = (Ntot_kzylkoga.append(Ngds_kzylkoga).append(Nagr_kzylkoga).append(Nind_kzylkoga).append(Nmin_kzylkoga).append(Nman_kzylkoga).append(Nelc_kzylkoga).append(Nwtr_kzylkoga).append(Ncon_kzylkoga).append(Nsrv_kzylkoga).append(Ntrd_kzylkoga).append(Nret_kzylkoga).append(Nwhl_kzylkoga).append(ltot_kzylkoga).append(lgds_kzylkoga).append(lagr_kzylkoga).append(lind_kzylkoga).append(lmin_kzylkoga).append(lman_kzylkoga).append(lelc_kzylkoga).append(lwtr_kzylkoga).append(lcon_kzylkoga).append(lsrv_kzylkoga).append(ltrd_kzylkoga).append(lret_kzylkoga).append(lwhl_kzylkoga).append(Dtot_kzylkoga).append(Dgds_kzylkoga).append(Dagr_kzylkoga).append(Dind_kzylkoga).append(Dmin_kzylkoga).append(Dman_kzylkoga).append(Delc_kzylkoga).append(Dwtr_kzylkoga).append(Dcon_kzylkoga).append(Dsrv_kzylkoga).append(Dtrd_kzylkoga).append(Dret_kzylkoga).append(Dwhl_kzylkoga)).sort_index(kind='mergesort').reset_index(drop = True)
makat = (Ntot_makat.append(Ngds_makat).append(Nagr_makat).append(Nind_makat).append(Nmin_makat).append(Nman_makat).append(Nelc_makat).append(Nwtr_makat).append(Ncon_makat).append(Nsrv_makat).append(Ntrd_makat).append(Nret_makat).append(Nwhl_makat).append(ltot_makat).append(lgds_makat).append(lagr_makat).append(lind_makat).append(lmin_makat).append(lman_makat).append(lelc_makat).append(lwtr_makat).append(lcon_makat).append(lsrv_makat).append(ltrd_makat).append(lret_makat).append(lwhl_makat).append(Dtot_makat).append(Dgds_makat).append(Dagr_makat).append(Dind_makat).append(Dmin_makat).append(Dman_makat).append(Delc_makat).append(Dwtr_makat).append(Dcon_makat).append(Dsrv_makat).append(Dtrd_makat).append(Dret_makat).append(Dwhl_makat)).sort_index(kind='mergesort').reset_index(drop = True)
makhambet = (Ntot_makhambet.append(Ngds_makhambet).append(Nagr_makhambet).append(Nind_makhambet).append(Nmin_makhambet).append(Nman_makhambet).append(Nelc_makhambet).append(Nwtr_makhambet).append(Ncon_makhambet).append(Nsrv_makhambet).append(Ntrd_makhambet).append(Nret_makhambet).append(Nwhl_makhambet).append(ltot_makhambet).append(lgds_makhambet).append(lagr_makhambet).append(lind_makhambet).append(lmin_makhambet).append(lman_makhambet).append(lelc_makhambet).append(lwtr_makhambet).append(lcon_makhambet).append(lsrv_makhambet).append(ltrd_makhambet).append(lret_makhambet).append(lwhl_makhambet).append(Dtot_makhambet).append(Dgds_makhambet).append(Dagr_makhambet).append(Dind_makhambet).append(Dmin_makhambet).append(Dman_makhambet).append(Delc_makhambet).append(Dwtr_makhambet).append(Dcon_makhambet).append(Dsrv_makhambet).append(Dtrd_makhambet).append(Dret_makhambet).append(Dwhl_makhambet)).sort_index(kind='mergesort').reset_index(drop = True)

bazovyi = (atyrau.append(zhylyoi).append(inder).append(isatai).append(kurmangazy).append(kzylkoga).append(makat).append(makhambet)).reset_index(drop = True)



i = (bazovyi.append(optimist).append(pessimist)).reset_index(drop = True)

itog = pd.DataFrame(columns = ['o_value'])
itog.o_value = i.replace([np.inf], np.nan).fillna(0)
itog.index = itog.index + 1

itog
# Out:
#             o_value
# 1      68340.500000
# 2      59680.500000
# 3        503.500000
# 4      28273.000000
# 5      11972.000000
# ...             ...
# 23396    113.407390
# 23397    107.438931
# 23398    107.438931
# 23399    106.557866
# 23400    146.170390
#
# [23400 rows x 1 columns]

# %%
itog.to_sql('vrp_2_raion', engine, schema='public',if_exists='append', index = False)
