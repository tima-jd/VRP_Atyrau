# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv = pd.read_sql("SELECT * FROM vrp_ekz_fact ORDER BY id",engine)

csv_dgds_atyrau = pd.read_sql("SELECT * FROM dgds_fact_atyrau ORDER BY index",engine)
csv_dagr_atyrau = pd.read_sql("SELECT * FROM dagr_fact_atyrau ORDER BY index",engine)
csv_dmin_atyrau = pd.read_sql("SELECT * FROM dmin_fact_atyrau ORDER BY index",engine)
csv_dcon_atyrau = pd.read_sql("SELECT * FROM dcon_fact_atyrau ORDER BY index",engine)
csv_dman_atyrau = pd.read_sql("SELECT * FROM dman_fact_atyrau ORDER BY index",engine)
csv_dret_atyrau = pd.read_sql("SELECT * FROM dret_fact_atyrau ORDER BY index",engine)
csv_dwhl_atyrau = pd.read_sql("SELECT * FROM dwhl_fact_atyrau ORDER BY index",engine)
csv_dtrd_atyrau = pd.read_sql("SELECT * FROM dtrd_fact_atyrau ORDER BY index",engine)
csv_dwtr_atyrau = pd.read_sql("SELECT * FROM dwtr_fact_atyrau ORDER BY index",engine)
csv_delc_atyrau = pd.read_sql("SELECT * FROM delc_fact_atyrau ORDER BY index",engine)
csv_dind_atyrau = pd.read_sql("SELECT * FROM dind_lind_nind_fact_atyrau ORDER BY index",engine)

csv_dgds_inder = pd.read_sql("SELECT * FROM dgds_fact_inder ORDER BY index",engine)
csv_dagr_inder = pd.read_sql("SELECT * FROM dagr_fact_inder ORDER BY index",engine)
csv_dmin_inder = pd.read_sql("SELECT * FROM dmin_fact_inder ORDER BY index",engine)
csv_dcon_inder = pd.read_sql("SELECT * FROM dcon_fact_inder ORDER BY index",engine)
csv_dman_inder = pd.read_sql("SELECT * FROM dman_fact_inder ORDER BY index",engine)
csv_dret_inder = pd.read_sql("SELECT * FROM dret_fact_inder ORDER BY index",engine)
csv_dwhl_inder = pd.read_sql("SELECT * FROM dwhl_fact_inder ORDER BY index",engine)
csv_dtrd_inder = pd.read_sql("SELECT * FROM dtrd_fact_inder ORDER BY index",engine)
csv_dwtr_inder = pd.read_sql("SELECT * FROM dwtr_fact_inder ORDER BY index",engine)
csv_delc_inder = pd.read_sql("SELECT * FROM delc_fact_inder ORDER BY index",engine)
csv_dind_inder = pd.read_sql("SELECT * FROM dind_lind_nind_fact_inder ORDER BY index",engine)

csv_dgds_isatai = pd.read_sql("SELECT * FROM dgds_fact_isatai ORDER BY index",engine)
csv_dagr_isatai = pd.read_sql("SELECT * FROM dagr_fact_isatai ORDER BY index",engine)
csv_dmin_isatai = pd.read_sql("SELECT * FROM dmin_fact_isatai ORDER BY index",engine)
csv_dcon_isatai = pd.read_sql("SELECT * FROM dcon_fact_isatai ORDER BY index",engine)
csv_dman_isatai = pd.read_sql("SELECT * FROM dman_fact_isatai ORDER BY index",engine)
csv_dret_isatai = pd.read_sql("SELECT * FROM dret_fact_isatai ORDER BY index",engine)
csv_dwhl_isatai = pd.read_sql("SELECT * FROM dwhl_fact_isatai ORDER BY index",engine)
csv_dtrd_isatai = pd.read_sql("SELECT * FROM dtrd_fact_isatai ORDER BY index",engine)
csv_dwtr_isatai = pd.read_sql("SELECT * FROM dwtr_fact_isatai ORDER BY index",engine)
csv_delc_isatai = pd.read_sql("SELECT * FROM delc_fact_isatai ORDER BY index",engine)
csv_dind_isatai = pd.read_sql("SELECT * FROM dind_lind_nind_fact_isatai ORDER BY index",engine)

csv_dgds_kurmangazy = pd.read_sql("SELECT * FROM dgds_fact_kurmangazy ORDER BY index",engine)
csv_dagr_kurmangazy = pd.read_sql("SELECT * FROM dagr_fact_kurmangazy ORDER BY index",engine)
csv_dmin_kurmangazy = pd.read_sql("SELECT * FROM dmin_fact_kurmangazy ORDER BY index",engine)
csv_dcon_kurmangazy = pd.read_sql("SELECT * FROM dcon_fact_kurmangazy ORDER BY index",engine)
csv_dman_kurmangazy = pd.read_sql("SELECT * FROM dman_fact_kurmangazy ORDER BY index",engine)
csv_dret_kurmangazy = pd.read_sql("SELECT * FROM dret_fact_kurmangazy ORDER BY index",engine)
csv_dwhl_kurmangazy = pd.read_sql("SELECT * FROM dwhl_fact_kurmangazy ORDER BY index",engine)
csv_dtrd_kurmangazy = pd.read_sql("SELECT * FROM dtrd_fact_kurmangazy ORDER BY index",engine)
csv_dwtr_kurmangazy = pd.read_sql("SELECT * FROM dwtr_fact_kurmangazy ORDER BY index",engine)
csv_delc_kurmangazy = pd.read_sql("SELECT * FROM delc_fact_kurmangazy ORDER BY index",engine)
csv_dind_kurmangazy = pd.read_sql("SELECT * FROM dind_lind_nind_fact_kurmangazy ORDER BY index",engine)

csv_dgds_kzylkoga = pd.read_sql("SELECT * FROM dgds_fact_kzylkoga ORDER BY index",engine)
csv_dagr_kzylkoga = pd.read_sql("SELECT * FROM dagr_fact_kzylkoga ORDER BY index",engine)
csv_dmin_kzylkoga = pd.read_sql("SELECT * FROM dmin_fact_kzylkoga ORDER BY index",engine)
csv_dcon_kzylkoga = pd.read_sql("SELECT * FROM dcon_fact_kzylkoga ORDER BY index",engine)
csv_dman_kzylkoga = pd.read_sql("SELECT * FROM dman_fact_kzylkoga ORDER BY index",engine)
csv_dret_kzylkoga = pd.read_sql("SELECT * FROM dret_fact_kzylkoga ORDER BY index",engine)
csv_dwhl_kzylkoga = pd.read_sql("SELECT * FROM dwhl_fact_kzylkoga ORDER BY index",engine)
csv_dtrd_kzylkoga = pd.read_sql("SELECT * FROM dtrd_fact_kzylkoga ORDER BY index",engine)
csv_dwtr_kzylkoga = pd.read_sql("SELECT * FROM dwtr_fact_kzylkoga ORDER BY index",engine)
csv_delc_kzylkoga = pd.read_sql("SELECT * FROM delc_fact_kzylkoga ORDER BY index",engine)
csv_dind_kzylkoga = pd.read_sql("SELECT * FROM dind_lind_nind_fact_kzylkoga ORDER BY index",engine)

csv_dgds_makhambet = pd.read_sql("SELECT * FROM dgds_fact_makhambet ORDER BY index",engine)
csv_dagr_makhambet = pd.read_sql("SELECT * FROM dagr_fact_makhambet ORDER BY index",engine)
csv_dmin_makhambet = pd.read_sql("SELECT * FROM dmin_fact_makhambet ORDER BY index",engine)
csv_dcon_makhambet = pd.read_sql("SELECT * FROM dcon_fact_makhambet ORDER BY index",engine)
csv_dman_makhambet = pd.read_sql("SELECT * FROM dman_fact_makhambet ORDER BY index",engine)
csv_dret_makhambet = pd.read_sql("SELECT * FROM dret_fact_makhambet ORDER BY index",engine)
csv_dwhl_makhambet = pd.read_sql("SELECT * FROM dwhl_fact_makhambet ORDER BY index",engine)
csv_dtrd_makhambet = pd.read_sql("SELECT * FROM dtrd_fact_makhambet ORDER BY index",engine)
csv_dwtr_makhambet = pd.read_sql("SELECT * FROM dwtr_fact_makhambet ORDER BY index",engine)
csv_delc_makhambet = pd.read_sql("SELECT * FROM delc_fact_makhambet ORDER BY index",engine)
csv_dind_makhambet = pd.read_sql("SELECT * FROM dind_lind_nind_fact_makhambet ORDER BY index",engine)

csv_dgds_makat = pd.read_sql("SELECT * FROM dgds_fact_makat ORDER BY index",engine)
csv_dagr_makat = pd.read_sql("SELECT * FROM dagr_fact_makat ORDER BY index",engine)
csv_dmin_makat = pd.read_sql("SELECT * FROM dmin_fact_makat ORDER BY index",engine)
csv_dcon_makat = pd.read_sql("SELECT * FROM dcon_fact_makat ORDER BY index",engine)
csv_dman_makat = pd.read_sql("SELECT * FROM dman_fact_makat ORDER BY index",engine)
csv_dret_makat = pd.read_sql("SELECT * FROM dret_fact_makat ORDER BY index",engine)
csv_dwhl_makat = pd.read_sql("SELECT * FROM dwhl_fact_makat ORDER BY index",engine)
csv_dtrd_makat = pd.read_sql("SELECT * FROM dtrd_fact_makat ORDER BY index",engine)
csv_dwtr_makat = pd.read_sql("SELECT * FROM dwtr_fact_makat ORDER BY index",engine)
csv_delc_makat = pd.read_sql("SELECT * FROM delc_fact_makat ORDER BY index",engine)
csv_dind_makat = pd.read_sql("SELECT * FROM dind_lind_nind_fact_makat ORDER BY index",engine)

csv_dgds_zhylyoi = pd.read_sql("SELECT * FROM dgds_fact_zhylyoi ORDER BY index",engine)
csv_dagr_zhylyoi = pd.read_sql("SELECT * FROM dagr_fact_zhylyoi ORDER BY index",engine)
csv_dmin_zhylyoi = pd.read_sql("SELECT * FROM dmin_fact_zhylyoi ORDER BY index",engine)
csv_dcon_zhylyoi = pd.read_sql("SELECT * FROM dcon_fact_zhylyoi ORDER BY index",engine)
csv_dman_zhylyoi = pd.read_sql("SELECT * FROM dman_fact_zhylyoi ORDER BY index",engine)
csv_dret_zhylyoi = pd.read_sql("SELECT * FROM dret_fact_zhylyoi ORDER BY index",engine)
csv_dwhl_zhylyoi = pd.read_sql("SELECT * FROM dwhl_fact_zhylyoi ORDER BY index",engine)
csv_dtrd_zhylyoi = pd.read_sql("SELECT * FROM dtrd_fact_zhylyoi ORDER BY index",engine)
csv_dwtr_zhylyoi = pd.read_sql("SELECT * FROM dwtr_fact_zhylyoi ORDER BY index",engine)
csv_delc_zhylyoi = pd.read_sql("SELECT * FROM delc_fact_zhylyoi ORDER BY index",engine)
csv_dind_zhylyoi = pd.read_sql("SELECT * FROM dind_lind_nind_fact_zhylyoi ORDER BY index",engine)

Ngds_atyrau_ngds = pd.read_sql("SELECT * FROM ngds_fact_atyrau ORDER BY index",engine)
Ntrd_atyrau_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_atyrau ORDER BY index",engine)
Nind_atyrau_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_atyrau ORDER BY index",engine)
lgds_atyrau_lgds = pd.read_sql("SELECT * FROM lgds_fact_atyrau ORDER BY index",engine)
ltrd_atyrau_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_atyrau ORDER BY index",engine)
lind_atyrau_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_atyrau ORDER BY index",engine)

Ngds_inder_ngds = pd.read_sql("SELECT * FROM ngds_fact_inder ORDER BY index",engine)
Ntrd_inder_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_inder ORDER BY index",engine)
Nind_inder_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_inder ORDER BY index",engine)
lgds_inder_lgds = pd.read_sql("SELECT * FROM lgds_fact_inder ORDER BY index",engine)
ltrd_inder_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_inder ORDER BY index",engine)
lind_inder_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_inder ORDER BY index",engine)

Ngds_isatai_ngds = pd.read_sql("SELECT * FROM ngds_fact_isatai ORDER BY index",engine)
Ntrd_isatai_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_isatai ORDER BY index",engine)
Nind_isatai_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_isatai ORDER BY index",engine)
lgds_isatai_lgds = pd.read_sql("SELECT * FROM lgds_fact_isatai ORDER BY index",engine)
ltrd_isatai_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_isatai ORDER BY index",engine)
lind_isatai_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_isatai ORDER BY index",engine)

Ngds_makhambet_ngds = pd.read_sql("SELECT * FROM ngds_fact_makhambet ORDER BY index",engine)
Ntrd_makhambet_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_makhambet ORDER BY index",engine)
Nind_makhambet_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_makhambet ORDER BY index",engine)
lgds_makhambet_lgds = pd.read_sql("SELECT * FROM lgds_fact_makhambet ORDER BY index",engine)
ltrd_makhambet_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_makhambet ORDER BY index",engine)
lind_makhambet_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_makhambet ORDER BY index",engine)

Ngds_makat_ngds = pd.read_sql("SELECT * FROM ngds_fact_makat ORDER BY index",engine)
Ntrd_makat_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_makat ORDER BY index",engine)
Nind_makat_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_makat ORDER BY index",engine)
lgds_makat_lgds = pd.read_sql("SELECT * FROM lgds_fact_makat ORDER BY index",engine)
ltrd_makat_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_makat ORDER BY index",engine)
lind_makat_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_makat ORDER BY index",engine)

Ngds_kurmangazy_ngds = pd.read_sql("SELECT * FROM ngds_fact_kurmangazy ORDER BY index",engine)
Ntrd_kurmangazy_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_kurmangazy ORDER BY index",engine)
Nind_kurmangazy_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_kurmangazy ORDER BY index",engine)
lgds_kurmangazy_lgds = pd.read_sql("SELECT * FROM lgds_fact_kurmangazy ORDER BY index",engine)
ltrd_kurmangazy_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_kurmangazy ORDER BY index",engine)
lind_kurmangazy_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_kurmangazy ORDER BY index",engine)

Ngds_kzylkoga_ngds = pd.read_sql("SELECT * FROM ngds_fact_kzylkoga ORDER BY index",engine)
Ntrd_kzylkoga_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_kzylkoga ORDER BY index",engine)
Nind_kzylkoga_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_kzylkoga ORDER BY index",engine)
lgds_kzylkoga_lgds = pd.read_sql("SELECT * FROM lgds_fact_kzylkoga ORDER BY index",engine)
ltrd_kzylkoga_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_kzylkoga ORDER BY index",engine)
lind_kzylkoga_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_kzylkoga ORDER BY index",engine)

Ngds_zhylyoi_ngds = pd.read_sql("SELECT * FROM ngds_fact_zhylyoi ORDER BY index",engine)
Ntrd_zhylyoi_ntrd = pd.read_sql("SELECT * FROM ntrd_fact_zhylyoi ORDER BY index",engine)
Nind_zhylyoi_nind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_zhylyoi ORDER BY index",engine)
lgds_zhylyoi_lgds = pd.read_sql("SELECT * FROM lgds_fact_zhylyoi ORDER BY index",engine)
ltrd_zhylyoi_ltrd = pd.read_sql("SELECT * FROM ltrd_fact_zhylyoi ORDER BY index",engine)
lind_zhylyoi_lind = pd.read_sql("SELECT * FROM dind_lind_nind_fact_zhylyoi ORDER BY index",engine)

Ngds_atyrau = Ngds_atyrau_ngds['Ngds_atyrau']
Nagr_atyrau = csv['o_prod_agro_atyrau']
Nmin_atyrau = csv['o_prod_mining_atyrau']
Ncon_atyrau = csv['o_prod_building_atyrau']
Nman_atyrau = csv['o_prod_man_atyrau']
Nret_atyrau = csv['o_prod_retail_atyrau']
Nwhl_atyrau = csv['o_prod_trade_atyrau']
Ntrd_atyrau = Ntrd_atyrau_ntrd['Ntrd_atyrau']
Nwtr_atyrau = csv['o_prod_water_atyrau']
Nelc_atyrau = csv['o_prod_energo_atyrau']
Nind_atyrau = Nind_atyrau_nind['Nind_atyrau']

lgds_atyrau = lgds_atyrau_lgds['lgds_atyrau']
lagr_atyrau = csv['o_ifo_agro_atyrau']
lmin_atyrau = csv['o_ifo_mining_atyrau']
lcon_atyrau = csv['o_ifo_building_atyrau']
lman_atyrau = csv['o_ifo_man_atyrau']
lret_atyrau = csv['o_ifo_retail_atyrau']
lwhl_atyrau = csv['o_ifo_trade_atyrau']
ltrd_atyrau = ltrd_atyrau_ltrd['ltrd_atyrau']
lwtr_atyrau = csv['o_ifo_water_atyrau']
lelc_atyrau = csv['o_ifo_energo_atyrau']
lind_atyrau = lind_atyrau_lind['lind_atyrau']
                                                
Dgds_atyrau = csv_dgds_atyrau['Dgds_atyrau']
Dagr_atyrau = csv_dagr_atyrau['Dagr_atyrau']
Dmin_atyrau = csv_dmin_atyrau['Dmin_atyrau']
Dcon_atyrau = csv_dcon_atyrau['Dcon_atyrau']
Dman_atyrau = csv_dman_atyrau['Dman_atyrau']
Dret_atyrau = csv_dret_atyrau['Dret_atyrau']
Dwhl_atyrau = csv_dwhl_atyrau['Dwhl_atyrau']
Dtrd_atyrau = csv_dtrd_atyrau['Dtrd_atyrau']
Dwtr_atyrau = csv_dwtr_atyrau['Dwtr_atyrau']
Delc_atyrau = csv_delc_atyrau['Delc_atyrau']
Dind_atyrau = csv_dind_atyrau['Dind_atyrau']

Ngds_inder = Ngds_inder_ngds['Ngds_inder']
Nagr_inder = csv['o_prod_agro_inder']
Nmin_inder = csv['o_prod_mining_inder']
Ncon_inder = csv['o_prod_building_inder']
Nman_inder = csv['o_prod_man_inder']
Nret_inder = csv['o_prod_retail_inder']
Nwhl_inder = csv['o_prod_trade_inder']
Ntrd_inder = Ntrd_inder_ntrd['Ntrd_inder']
Nwtr_inder = csv['o_prod_water_inder']
Nelc_inder = csv['o_prod_energo_inder']
Nind_inder = Nind_inder_nind['Nind_inder']

lgds_inder = lgds_inder_lgds['lgds_inder']
lagr_inder = csv['o_ifo_agro_inder']
lmin_inder = csv['o_ifo_mining_inder']
lcon_inder = csv['o_ifo_building_inder']
lman_inder = csv['o_ifo_man_inder']
lret_inder = csv['o_ifo_retail_inder']
lwhl_inder = csv['o_ifo_trade_inder']
ltrd_inder = ltrd_inder_ltrd['ltrd_inder']
lwtr_inder = csv['o_ifo_water_inder']
lelc_inder = csv['o_ifo_energo_inder']
lind_inder = lind_inder_lind['lind_inder']

Dgds_inder = csv_dgds_inder['Dgds_inder']
Dagr_inder = csv_dagr_inder['Dagr_inder']
Dmin_inder = csv_dmin_inder['Dmin_inder']
Dcon_inder = csv_dcon_inder['Dcon_inder']
Dman_inder = csv_dman_inder['Dman_inder']
Dret_inder = csv_dret_inder['Dret_inder']
Dwhl_inder = csv_dwhl_inder['Dwhl_inder']
Dtrd_inder = csv_dtrd_inder['Dtrd_inder']
Dwtr_inder = csv_dwtr_inder['Dwtr_inder']
Delc_inder = csv_delc_inder['Delc_inder']
Dind_inder = csv_dind_inder['Dind_inder']

Ngds_isatai = Ngds_isatai_ngds['Ngds_isatai']
Nagr_isatai = csv['o_prod_agro_isatai']
Nmin_isatai = csv['o_prod_mining_isatai']
Ncon_isatai = csv['o_prod_building_isatai']
Nman_isatai = csv['o_prod_man_isatai']
Nret_isatai = csv['o_prod_retail_isatai']
Nwhl_isatai = csv['o_prod_trade_isatai']
Ntrd_isatai = Ntrd_isatai_ntrd['Ntrd_isatai']
Nwtr_isatai = csv['o_prod_water_isatai']
Nelc_isatai = csv['o_prod_energo_isatai']
Nind_isatai = Nind_isatai_nind['Nind_isatai']

lgds_isatai = lgds_isatai_lgds['lgds_isatai']
lagr_isatai = csv['o_ifo_agro_isatai']
lmin_isatai = csv['o_ifo_mining_isatai']
lcon_isatai = csv['o_ifo_building_isatai']
lman_isatai = csv['o_ifo_man_isatai']
lret_isatai = csv['o_ifo_retail_isatai']
lwhl_isatai = csv['o_ifo_trade_isatai']
ltrd_isatai = ltrd_isatai_ltrd['ltrd_isatai']
lwtr_isatai = csv['o_ifo_water_isatai']
lelc_isatai = csv['o_ifo_energo_isatai']
lind_isatai = lind_isatai_lind['lind_isatai']

Dgds_isatai = csv_dgds_isatai['Dgds_isatai']
Dagr_isatai = csv_dagr_isatai['Dagr_isatai']
Dmin_isatai = csv_dmin_isatai['Dmin_isatai']
Dcon_isatai = csv_dcon_isatai['Dcon_isatai']
Dman_isatai = csv_dman_isatai['Dman_isatai']
Dret_isatai = csv_dret_isatai['Dret_isatai']
Dwhl_isatai = csv_dwhl_isatai['Dwhl_isatai']
Dtrd_isatai = csv_dtrd_isatai['Dtrd_isatai']
Dwtr_isatai = csv_dwtr_isatai['Dwtr_isatai']
Delc_isatai = csv_delc_isatai['Delc_isatai']
Dind_isatai = csv_dind_isatai['Dind_isatai']

Ngds_kurmangazy = Ngds_kurmangazy_ngds['Ngds_kurmangazy']
Nagr_kurmangazy = csv['o_prod_agro_kurmangazy']
Nmin_kurmangazy = csv['o_prod_mining_kurmangazy']
Ncon_kurmangazy = csv['o_prod_building_kurmangazy']
Nman_kurmangazy = csv['o_prod_man_kurmangazy']
Nret_kurmangazy = csv['o_prod_retail_kurmangazy']
Nwhl_kurmangazy = csv['o_prod_trade_kurmangazy']
Ntrd_kurmangazy = Ntrd_kurmangazy_ntrd['Ntrd_kurmangazy']
Nwtr_kurmangazy = csv['o_prod_water_kurmangazy']
Nelc_kurmangazy = csv['o_prod_energo_kurmangazy']
Nind_kurmangazy = Nind_kurmangazy_nind['Nind_kurmangazy']

lgds_kurmangazy = lgds_kurmangazy_lgds['lgds_kurmangazy']
lagr_kurmangazy = csv['o_ifo_agro_kurmangazy']
lmin_kurmangazy = csv['o_ifo_mining_kurmangazy']
lcon_kurmangazy = csv['o_ifo_building_kurmangazy']
lman_kurmangazy = csv['o_ifo_man_kurmangazy']
lret_kurmangazy = csv['o_ifo_retail_kurmangazy']
lwhl_kurmangazy = csv['o_ifo_trade_kurmangazy']
ltrd_kurmangazy = ltrd_kurmangazy_ltrd['ltrd_kurmangazy']
lwtr_kurmangazy = csv['o_ifo_water_kurmangazy']
lelc_kurmangazy = csv['o_ifo_energo_kurmangazy']
lind_kurmangazy = lind_kurmangazy_lind['lind_kurmangazy']

Dgds_kurmangazy = csv_dgds_kurmangazy['Dgds_kurmangazy']
Dagr_kurmangazy = csv_dagr_kurmangazy['Dagr_kurmangazy']
Dmin_kurmangazy = csv_dmin_kurmangazy['Dmin_kurmangazy']
Dcon_kurmangazy = csv_dcon_kurmangazy['Dcon_kurmangazy']
Dman_kurmangazy = csv_dman_kurmangazy['Dman_kurmangazy']
Dret_kurmangazy = csv_dret_kurmangazy['Dret_kurmangazy']
Dwhl_kurmangazy = csv_dwhl_kurmangazy['Dwhl_kurmangazy']
Dtrd_kurmangazy = csv_dtrd_kurmangazy['Dtrd_kurmangazy']
Dwtr_kurmangazy = csv_dwtr_kurmangazy['Dwtr_kurmangazy']
Delc_kurmangazy = csv_delc_kurmangazy['Delc_kurmangazy']
Dind_kurmangazy = csv_dind_kurmangazy['Dind_kurmangazy']

Ngds_kzylkoga = Ngds_kzylkoga_ngds['Ngds_kzylkoga']
Nagr_kzylkoga = csv['o_ifo_agro_kzylkoga']
Nmin_kzylkoga = csv['o_ifo_mining_kzylkoga']
Ncon_kzylkoga = csv['o_ifo_building_kzylkoga']
Nman_kzylkoga = csv['o_ifo_man_kzylkoga']
Nret_kzylkoga = csv['o_ifo_retail_kzylkoga']
Nwhl_kzylkoga = csv['o_ifo_trade_kzylkoga']
Ntrd_kzylkoga = Ntrd_kzylkoga_ntrd['Ntrd_kzylkoga']
Nwtr_kzylkoga = csv['o_ifo_water_kzylkoga']
Nelc_kzylkoga = csv['o_ifo_energo_kzylkoga']
Nind_kzylkoga = Nind_kzylkoga_nind['lind_kzylkoga']

lgds_kzylkoga = lgds_kzylkoga_lgds['lgds_kzylkoga']
lagr_kzylkoga = csv['o_ifo_agro_kzylkoga']
lmin_kzylkoga = csv['o_ifo_mining_kzylkoga']
lcon_kzylkoga = csv['o_ifo_building_kzylkoga']
lman_kzylkoga = csv['o_ifo_man_kzylkoga']
lret_kzylkoga = csv['o_ifo_retail_kzylkoga']
lwhl_kzylkoga = csv['o_ifo_trade_kzylkoga']
ltrd_kzylkoga = ltrd_kzylkoga_ltrd['ltrd_kzylkoga']
lwtr_kzylkoga = csv['o_ifo_water_kzylkoga']
lelc_kzylkoga = csv['o_ifo_energo_kzylkoga']
lind_kzylkoga = lind_kzylkoga_lind['lind_kzylkoga']

Dgds_kzylkoga = csv_dgds_kzylkoga['Dgds_kzylkoga']
Dagr_kzylkoga = csv_dagr_kzylkoga['Dagr_kzylkoga']
Dmin_kzylkoga = csv_dmin_kzylkoga['Dmin_kzylkoga']
Dcon_kzylkoga = csv_dcon_kzylkoga['Dcon_kzylkoga']
Dman_kzylkoga = csv_dman_kzylkoga['Dman_kzylkoga']
Dret_kzylkoga = csv_dret_kzylkoga['Dret_kzylkoga']
Dwhl_kzylkoga = csv_dwhl_kzylkoga['Dwhl_kzylkoga']
Dtrd_kzylkoga = csv_dtrd_kzylkoga['Dtrd_kzylkoga']
Dwtr_kzylkoga = csv_dwtr_kzylkoga['Dwtr_kzylkoga']
Delc_kzylkoga = csv_delc_kzylkoga['Delc_kzylkoga']
Dind_kzylkoga = csv_dind_kzylkoga['Dind_kzylkoga']

Ngds_makat = Ngds_makat_ngds['Ngds_makat']
Nagr_makat = csv['o_ifo_agro_makat']
Nmin_makat = csv['o_ifo_mining_makat']
Ncon_makat = csv['o_ifo_building_makat']
Nman_makat = csv['o_ifo_man_makat']
Nret_makat = csv['o_ifo_retail_makat']
Nwhl_makat = csv['o_ifo_trade_makat']
Ntrd_makat = Ntrd_makat_ntrd['Ntrd_makat']
Nwtr_makat = csv['o_ifo_water_makat']
Nelc_makat = csv['o_ifo_energo_makat']
Nind_makat = Nind_makat_nind['lind_makat']

lgds_makat = lgds_makat_lgds['lgds_makat']
lagr_makat = csv['o_ifo_agro_makat']
lmin_makat = csv['o_ifo_mining_makat']
lcon_makat = csv['o_ifo_building_makat']
lman_makat = csv['o_ifo_man_makat']
lret_makat = csv['o_ifo_retail_makat']
lwhl_makat = csv['o_ifo_trade_makat']
ltrd_makat = ltrd_makat_ltrd['ltrd_makat']
lwtr_makat = csv['o_ifo_water_makat']
lelc_makat = csv['o_ifo_energo_makat']
lind_makat = lind_makat_lind['lind_makat']

Dgds_makat = csv_dgds_makat['Dgds_makat']
Dagr_makat = csv_dagr_makat['Dagr_makat']
Dmin_makat = csv_dmin_makat['Dmin_makat']
Dcon_makat = csv_dcon_makat['Dcon_makat']
Dman_makat = csv_dman_makat['Dman_makat']
Dret_makat = csv_dret_makat['Dret_makat']
Dwhl_makat = csv_dwhl_makat['Dwhl_makat']
Dtrd_makat = csv_dtrd_makat['Dtrd_makat']
Dwtr_makat = csv_dwtr_makat['Dwtr_makat']
Delc_makat = csv_delc_makat['Delc_makat']
Dind_makat = csv_dind_makat['Dind_makat']

Ngds_makhambet = Ngds_makhambet_ngds['Ngds_makhambet']
Nagr_makhambet = csv['o_ifo_agro_makhambet']
Nmin_makhambet = csv['o_ifo_mining_makhambet']
Ncon_makhambet = csv['o_ifo_building_makhambet']
Nman_makhambet = csv['o_ifo_man_makhambet']
Nret_makhambet = csv['o_ifo_retail_makhambet']
Nwhl_makhambet = csv['o_ifo_trade_makhambet']
Ntrd_makhambet = Ntrd_makhambet_ntrd['Ntrd_makhambet']
Nwtr_makhambet = csv['o_ifo_water_makhambet']
Nelc_makhambet = csv['o_ifo_energo_makhambet']
Nind_makhambet = Nind_makhambet_nind['lind_makhambet']

lgds_makhambet = lgds_makhambet_lgds['lgds_makhambet']
lagr_makhambet = csv['o_ifo_agro_makhambet']
lmin_makhambet = csv['o_ifo_mining_makhambet']
lcon_makhambet = csv['o_ifo_building_makhambet']
lman_makhambet = csv['o_ifo_man_makhambet']
lret_makhambet = csv['o_ifo_retail_makhambet']
lwhl_makhambet = csv['o_ifo_trade_makhambet']
ltrd_makhambet = ltrd_makhambet_ltrd['ltrd_makhambet']
lwtr_makhambet = csv['o_ifo_water_makhambet']
lelc_makhambet = csv['o_ifo_energo_makhambet']
lind_makhambet = lind_makhambet_lind['lind_makhambet']

Dgds_makhambet = csv_dgds_makhambet['Dgds_makhambet']
Dagr_makhambet = csv_dagr_makhambet['Dagr_makhambet']
Dmin_makhambet = csv_dmin_makhambet['Dmin_makhambet']
Dcon_makhambet = csv_dcon_makhambet['Dcon_makhambet']
Dman_makhambet = csv_dman_makhambet['Dman_makhambet']
Dret_makhambet = csv_dret_makhambet['Dret_makhambet']
Dwhl_makhambet = csv_dwhl_makhambet['Dwhl_makhambet']
Dtrd_makhambet = csv_dtrd_makhambet['Dtrd_makhambet']
Dwtr_makhambet = csv_dwtr_makhambet['Dwtr_makhambet']
Delc_makhambet = csv_delc_makhambet['Delc_makhambet']
Dind_makhambet = csv_dind_makhambet['Dind_makhambet']

Ngds_zhylyoi = Ngds_zhylyoi_ngds['Ngds_zhylyoi']
Nagr_zhylyoi = csv['o_ifo_agro_zhylyoi']
Nmin_zhylyoi = csv['o_ifo_mining_zhylyoi']
Ncon_zhylyoi = csv['o_ifo_building_zhylyoi']
Nman_zhylyoi = csv['o_ifo_man_zhylyoi']
Nret_zhylyoi = csv['o_ifo_retail_zhylyoi']
Nwhl_zhylyoi = csv['o_ifo_trade_zhylyoi']
Ntrd_zhylyoi = Ntrd_zhylyoi_ntrd['Ntrd_zhylyoi']
Nwtr_zhylyoi = csv['o_ifo_water_zhylyoi']
Nelc_zhylyoi = csv['o_ifo_energo_zhylyoi']
Nind_zhylyoi = Nind_zhylyoi_nind['lind_zhylyoi']

lgds_zhylyoi = lgds_zhylyoi_lgds['lgds_zhylyoi']
lagr_zhylyoi = csv['o_ifo_agro_zhylyoi']
lmin_zhylyoi = csv['o_ifo_mining_zhylyoi']
lcon_zhylyoi = csv['o_ifo_building_zhylyoi']
lman_zhylyoi = csv['o_ifo_man_zhylyoi']
lret_zhylyoi = csv['o_ifo_retail_zhylyoi']
lwhl_zhylyoi = csv['o_ifo_trade_zhylyoi']
ltrd_zhylyoi = ltrd_zhylyoi_ltrd['ltrd_zhylyoi']
lwtr_zhylyoi = csv['o_ifo_water_zhylyoi']
lelc_zhylyoi = csv['o_ifo_energo_zhylyoi']
lind_zhylyoi = lind_zhylyoi_lind['lind_zhylyoi']

Dgds_zhylyoi = csv_dgds_zhylyoi['Dgds_zhylyoi']
Dagr_zhylyoi = csv_dagr_zhylyoi['Dagr_zhylyoi']
Dmin_zhylyoi = csv_dmin_zhylyoi['Dmin_zhylyoi']
Dcon_zhylyoi = csv_dcon_zhylyoi['Dcon_zhylyoi']
Dman_zhylyoi = csv_dman_zhylyoi['Dman_zhylyoi']
Dret_zhylyoi = csv_dret_zhylyoi['Dret_zhylyoi']
Dwhl_zhylyoi = csv_dwhl_zhylyoi['Dwhl_zhylyoi']
Dtrd_zhylyoi = csv_dtrd_zhylyoi['Dtrd_zhylyoi']
Dwtr_zhylyoi = csv_dwtr_zhylyoi['Dwtr_zhylyoi']
Delc_zhylyoi = csv_delc_zhylyoi['Delc_zhylyoi']
Dind_zhylyoi = csv_dind_zhylyoi['Dind_zhylyoi']

vrp_fact = pd.DataFrame(columns = [
                        'Ntot_atyrau',
                        'Ngds_atyrau',
                        'Nagr_atyrau',
                        'Nmin_atyrau',
                        'Ncon_atyrau',
                        'Nman_atyrau',
                        'Nret_atyrau',
                        'Nwhl_atyrau',
                        'Ntrd_atyrau',
                        'Nsrv_atyrau',
                        'Nwtr_atyrau',
                        'Nelc_atyrau',
                        'Nind_atyrau',
                        'ltot_atyrau',
                        'lgds_atyrau',
                        'lagr_atyrau',
                        'lmin_atyrau',
                        'lcon_atyrau',
                        'lman_atyrau',
                        'lret_atyrau',
                        'lwhl_atyrau',
                        'ltrd_atyrau',
                        'lsrv_atyrau',
                        'lwtr_atyrau',
                        'lelc_atyrau',
                        'lind_atyrau',                                              
                        'Dtot_atyrau',
                        'Dgds_atyrau',
                        'Dagr_atyrau',
                        'Dmin_atyrau',
                        'Dcon_atyrau',
                        'Dman_atyrau',
                        'Dret_atyrau',
                        'Dwhl_atyrau',
                        'Dtrd_atyrau',
                        'Dsrv_atyrau',
                        'Dwtr_atyrau',
                        'Delc_atyrau',
                        'Dind_atyrau',
                        'Ntot_inder',
                        'Ngds_inder',
                        'Nagr_inder',
                        'Nmin_inder',
                        'Ncon_inder',
                        'Nman_inder',
                        'Nret_inder',
                        'Nwhl_inder',
                        'Ntrd_inder',
                        'Nsrv_inder',
                        'Nwtr_inder',
                        'Nelc_inder',
                        'Nind_inder',
                        'ltot_inder',
                        'lgds_inder',
                        'lagr_inder',
                        'lmin_inder',
                        'lcon_inder',
                        'lman_inder',
                        'lret_inder',
                        'lwhl_inder',
                        'ltrd_inder',
                        'lsrv_inder',
                        'lwtr_inder',
                        'lelc_inder',
                        'lind_inder',
                        'Dtot_inder',
                        'Dgds_inder',
                        'Dagr_inder',
                        'Dmin_inder',
                        'Dcon_inder',
                        'Dman_inder',
                        'Dret_inder',
                        'Dwhl_inder',
                        'Dtrd_inder',
                        'Dsrv_inder',
                        'Dwtr_inder',
                        'Delc_inder',
                        'Dind_inder',
                        'Ntot_isatai',
                        'Ngds_isatai',
                        'Nagr_isatai',
                        'Nmin_isatai',
                        'Ncon_isatai',
                        'Nman_isatai',
                        'Nret_isatai',
                        'Nwhl_isatai',
                        'Ntrd_isatai',
                        'Nsrv_isatai',
                        'Nwtr_isatai',
                        'Nelc_isatai',
                        'Nind_isatai',
                        'ltot_isatai',
                        'lgds_isatai',
                        'lagr_isatai',
                        'lmin_isatai',
                        'lcon_isatai',
                        'lman_isatai',
                        'lret_isatai',
                        'lwhl_isatai',
                        'ltrd_isatai',
                        'lsrv_isatai',
                        'lwtr_isatai',
                        'lelc_isatai',
                        'lind_isatai',
                        'Dtot_isatai',
                        'Dgds_isatai',
                        'Dagr_isatai',
                        'Dmin_isatai',
                        'Dcon_isatai',
                        'Dman_isatai',
                        'Dret_isatai',
                        'Dwhl_isatai',
                        'Dtrd_isatai',
                        'Dsrv_isatai',
                        'Dwtr_isatai',
                        'Delc_isatai',
                        'Dind_isatai',
                        'Ntot_kurmangazy',
                        'Ngds_kurmangazy',
                        'Nagr_kurmangazy',
                        'Nmin_kurmangazy',
                        'Ncon_kurmangazy',
                        'Nman_kurmangazy',
                        'Nret_kurmangazy',
                        'Nwhl_kurmangazy',
                        'Ntrd_kurmangazy',
                        'Nsrv_kurmangazy',
                        'Nwtr_kurmangazy',
                        'Nelc_kurmangazy',
                        'Nind_kurmangazy',
                        'ltot_kurmangazy',
                        'lgds_kurmangazy',
                        'lagr_kurmangazy',
                        'lmin_kurmangazy',
                        'lcon_kurmangazy',
                        'lman_kurmangazy',
                        'lret_kurmangazy',
                        'lwhl_kurmangazy',
                        'ltrd_kurmangazy',
                        'lsrv_kurmangazy',
                        'lwtr_kurmangazy',
                        'lelc_kurmangazy',
                        'lind_kurmangazy',
                        'Dtot_kurmangazy',
                        'Dgds_kurmangazy',
                        'Dagr_kurmangazy',
                        'Dmin_kurmangazy',
                        'Dcon_kurmangazy',
                        'Dman_kurmangazy',
                        'Dret_kurmangazy',
                        'Dwhl_kurmangazy',
                        'Dtrd_kurmangazy',
                        'Dsrv_kurmangazy',
                        'Dwtr_kurmangazy',
                        'Delc_kurmangazy',
                        'Dind_kurmangazy',
                        'Ntot_kzylkoga',
                        'Ngds_kzylkoga',
                        'Nagr_kzylkoga',
                        'Nmin_kzylkoga',
                        'Ncon_kzylkoga',
                        'Nman_kzylkoga',
                        'Nret_kzylkoga',
                        'Nwhl_kzylkoga',
                        'Ntrd_kzylkoga',
                        'Nsrv_kzylkoga',
                        'Nwtr_kzylkoga',
                        'Nelc_kzylkoga',
                        'Nind_kzylkoga',
                        'ltot_kzylkoga',
                        'lgds_kzylkoga',
                        'lagr_kzylkoga',
                        'lmin_kzylkoga',
                        'lcon_kzylkoga',
                        'lman_kzylkoga',
                        'lret_kzylkoga',
                        'lwhl_kzylkoga',
                        'ltrd_kzylkoga',
                        'lsrv_kzylkoga',
                        'lwtr_kzylkoga',
                        'lelc_kzylkoga',
                        'lind_kzylkoga',
                        'Dtot_kzylkoga',
                        'Dgds_kzylkoga',
                        'Dagr_kzylkoga',
                        'Dmin_kzylkoga',
                        'Dcon_kzylkoga',
                        'Dman_kzylkoga',
                        'Dret_kzylkoga',
                        'Dwhl_kzylkoga',
                        'Dtrd_kzylkoga',
                        'Dsrv_kzylkoga',
                        'Dwtr_kzylkoga',
                        'Delc_kzylkoga',
                        'Dind_kzylkoga',
                        'Ntot_makat',
                        'Ngds_makat',
                        'Nagr_makat',
                        'Nmin_makat',
                        'Ncon_makat',
                        'Nman_makat',
                        'Nret_makat',
                        'Nwhl_makat',
                        'Ntrd_makat',
                        'Nsrv_makat',
                        'Nwtr_makat',
                        'Nelc_makat',
                        'Nind_makat',
                        'ltot_makat',
                        'lgds_makat',
                        'lagr_makat',
                        'lmin_makat',
                        'lcon_makat',
                        'lman_makat',
                        'lret_makat',
                        'lwhl_makat',
                        'ltrd_makat',
                        'lsrv_makat',
                        'lwtr_makat',
                        'lelc_makat',
                        'lind_makat',
                        'Dtot_makat',
                        'Dgds_makat',
                        'Dagr_makat',
                        'Dmin_makat',
                        'Dcon_makat',
                        'Dman_makat',
                        'Dret_makat',
                        'Dwhl_makat',
                        'Dtrd_makat',
                        'Dsrv_makat',
                        'Dwtr_makat',
                        'Delc_makat',
                        'Dind_makat',
                        'Ntot_makhambet',
                        'Ngds_makhambet',
                        'Nagr_makhambet',
                        'Nmin_makhambet',
                        'Ncon_makhambet',
                        'Nman_makhambet',
                        'Nret_makhambet',
                        'Nwhl_makhambet',
                        'Ntrd_makhambet',
                        'Nsrv_makhambet',
                        'Nwtr_makhambet',
                        'Nelc_makhambet',
                        'Nind_makhambet',
                        'ltot_makhambet',
                        'lgds_makhambet',
                        'lagr_makhambet',
                        'lmin_makhambet',
                        'lcon_makhambet',
                        'lman_makhambet',
                        'lret_makhambet',
                        'lwhl_makhambet',
                        'ltrd_makhambet',
                        'lsrv_makhambet',
                        'lwtr_makhambet',
                        'lelc_makhambet',
                        'lind_makhambet',
                        'Dtot_makhambet',
                        'Dgds_makhambet',
                        'Dagr_makhambet',
                        'Dmin_makhambet',
                        'Dcon_makhambet',
                        'Dman_makhambet',
                        'Dret_makhambet',
                        'Dwhl_makhambet',
                        'Dtrd_makhambet',
                        'Dsrv_makhambet',
                        'Dwtr_makhambet',
                        'Delc_makhambet',
                        'Dind_makhambet',
                        'Ntot_zhylyoi',
                        'Ngds_zhylyoi',
                        'Nagr_zhylyoi',
                        'Nmin_zhylyoi',
                        'Ncon_zhylyoi',
                        'Nman_zhylyoi',
                        'Nret_zhylyoi',
                        'Nwhl_zhylyoi',
                        'Ntrd_zhylyoi',
                        'Nsrv_zhylyoi',
                        'Nwtr_zhylyoi',
                        'Nelc_zhylyoi',
                        'Nind_zhylyoi',
                        'ltot_zhylyoi',
                        'lgds_zhylyoi',
                        'lagr_zhylyoi',
                        'lmin_zhylyoi',
                        'lcon_zhylyoi',
                        'lman_zhylyoi',
                        'lret_zhylyoi',
                        'lwhl_zhylyoi',
                        'ltrd_zhylyoi',
                        'lsrv_zhylyoi',
                        'lwtr_zhylyoi',
                        'lelc_zhylyoi',
                        'lind_zhylyoi',
                        'Dtot_zhylyoi',
                        'Dgds_zhylyoi',
                        'Dagr_zhylyoi',
                        'Dmin_zhylyoi',
                        'Dcon_zhylyoi',
                        'Dman_zhylyoi',
                        'Dret_zhylyoi',
                        'Dwhl_zhylyoi',
                        'Dtrd_zhylyoi',
                        'Dsrv_zhylyoi',
                        'Dwtr_zhylyoi',
                        'Delc_zhylyoi',
                        'Dind_zhylyoi',])
vrp_fact.Ngds_atyrau = Ngds_atyrau

vrp_fact.Ntot_atyrau = Ngds_atyrau + Ntrd_atyrau
vrp_fact.Nagr_atyrau = Nagr_atyrau
vrp_fact.Nmin_atyrau = Nmin_atyrau
vrp_fact.Ncon_atyrau = Ncon_atyrau
vrp_fact.Nman_atyrau = Nman_atyrau
vrp_fact.Nret_atyrau = Nret_atyrau
vrp_fact.Nwhl_atyrau = Nwhl_atyrau
vrp_fact.Ntrd_atyrau = Ntrd_atyrau
vrp_fact.Nsrv_atyrau = Ntrd_atyrau
vrp_fact.Nwtr_atyrau = Nwtr_atyrau
vrp_fact.Nelc_atyrau = Nelc_atyrau
vrp_fact.Nind_atyrau = Nind_atyrau

vrp_fact.ltot_atyrau = lgds_atyrau + ltrd_atyrau
vrp_fact.lgds_atyrau = lgds_atyrau
vrp_fact.lagr_atyrau = lagr_atyrau
vrp_fact.lmin_atyrau = lmin_atyrau
vrp_fact.lcon_atyrau = lcon_atyrau
vrp_fact.lman_atyrau = lman_atyrau
vrp_fact.lret_atyrau = lret_atyrau
vrp_fact.lwhl_atyrau = lwhl_atyrau
vrp_fact.ltrd_atyrau = ltrd_atyrau
vrp_fact.lsrv_atyrau = ltrd_atyrau
vrp_fact.lwtr_atyrau = lwtr_atyrau
vrp_fact.lelc_atyrau = lelc_atyrau
vrp_fact.lind_atyrau = lind_atyrau

vrp_fact.Dtot_atyrau = Dgds_atyrau + Dtrd_atyrau
vrp_fact.Dgds_atyrau = Dgds_atyrau
vrp_fact.Dagr_atyrau = Dagr_atyrau
vrp_fact.Dmin_atyrau = Dmin_atyrau
vrp_fact.Dcon_atyrau = Dcon_atyrau
vrp_fact.Dman_atyrau = Dman_atyrau
vrp_fact.Dret_atyrau = Dret_atyrau
vrp_fact.Dwhl_atyrau = Dwhl_atyrau
vrp_fact.Dtrd_atyrau = Dtrd_atyrau
vrp_fact.Dsrv_atyrau = Dtrd_atyrau
vrp_fact.Dwtr_atyrau = Dwtr_atyrau
vrp_fact.Delc_atyrau = Delc_atyrau
vrp_fact.Dind_atyrau = Dind_atyrau

vrp_fact.Ntot_inder = Ngds_inder + Ntrd_inder
vrp_fact.Ngds_inder = Ngds_inder
vrp_fact.Nagr_inder = Nagr_inder
vrp_fact.Nmin_inder = Nmin_inder
vrp_fact.Ncon_inder = Ncon_inder
vrp_fact.Nman_inder = Nman_inder
vrp_fact.Nret_inder = Nret_inder
vrp_fact.Nwhl_inder = Nwhl_inder
vrp_fact.Ntrd_inder = Ntrd_inder
vrp_fact.Nsrv_inder = Ntrd_inder
vrp_fact.Nwtr_inder = Nwtr_inder
vrp_fact.Nelc_inder = Nelc_inder
vrp_fact.Nind_inder = Nind_inder

vrp_fact.ltot_inder = lgds_inder + ltrd_inder
vrp_fact.lgds_inder = lgds_inder
vrp_fact.lagr_inder = lagr_inder
vrp_fact.lmin_inder = lmin_inder
vrp_fact.lcon_inder = lcon_inder
vrp_fact.lman_inder = lman_inder
vrp_fact.lret_inder = lret_inder
vrp_fact.lwhl_inder = lwhl_inder
vrp_fact.ltrd_inder = ltrd_inder
vrp_fact.lsrv_inder = ltrd_inder
vrp_fact.lwtr_inder = lwtr_inder
vrp_fact.lelc_inder = lelc_inder
vrp_fact.lind_inder = lind_inder

vrp_fact.Dtot_inder = Dgds_inder + Dtrd_inder
vrp_fact.Dgds_inder = Dgds_inder
vrp_fact.Dagr_inder = Dagr_inder
vrp_fact.Dmin_inder = Dmin_inder
vrp_fact.Dcon_inder = Dcon_inder
vrp_fact.Dman_inder = Dman_inder
vrp_fact.Dret_inder = Dret_inder
vrp_fact.Dwhl_inder = Dwhl_inder
vrp_fact.Dtrd_inder = Dtrd_inder
vrp_fact.Dsrv_inder = Dtrd_inder
vrp_fact.Dwtr_inder = Dwtr_inder
vrp_fact.Delc_inder = Delc_inder
vrp_fact.Dind_inder = Dind_inder

vrp_fact.Ntot_isatai = Ngds_isatai + Ntrd_isatai
vrp_fact.Ngds_isatai = Ngds_isatai
vrp_fact.Nagr_isatai = Nagr_isatai
vrp_fact.Nmin_isatai = Nmin_isatai
vrp_fact.Ncon_isatai = Ncon_isatai
vrp_fact.Nman_isatai = Nman_isatai
vrp_fact.Nret_isatai = Nret_isatai
vrp_fact.Nwhl_isatai = Nwhl_isatai
vrp_fact.Ntrd_isatai = Ntrd_isatai
vrp_fact.Nsrv_isatai = Ntrd_isatai
vrp_fact.Nwtr_isatai = Nwtr_isatai
vrp_fact.Nelc_isatai = Nelc_isatai
vrp_fact.Nind_isatai = Nind_isatai

vrp_fact.ltot_isatai = lgds_isatai + ltrd_isatai
vrp_fact.lgds_isatai = lgds_isatai
vrp_fact.lagr_isatai = lagr_isatai
vrp_fact.lmin_isatai = lmin_isatai
vrp_fact.lcon_isatai = lcon_isatai
vrp_fact.lman_isatai = lman_isatai
vrp_fact.lret_isatai = lret_isatai
vrp_fact.lwhl_isatai = lwhl_isatai
vrp_fact.ltrd_isatai = ltrd_isatai
vrp_fact.lsrv_isatai = ltrd_isatai
vrp_fact.lwtr_isatai = lwtr_isatai
vrp_fact.lelc_isatai = lelc_isatai
vrp_fact.lind_isatai = lind_isatai

vrp_fact.Dtot_isatai = Dgds_isatai + Dtrd_isatai
vrp_fact.Dgds_isatai = Dgds_isatai
vrp_fact.Dagr_isatai = Dagr_isatai
vrp_fact.Dmin_isatai = Dmin_isatai
vrp_fact.Dcon_isatai = Dcon_isatai
vrp_fact.Dman_isatai = Dman_isatai
vrp_fact.Dret_isatai = Dret_isatai
vrp_fact.Dwhl_isatai = Dwhl_isatai
vrp_fact.Dtrd_isatai = Dtrd_isatai
vrp_fact.Dsrv_isatai = Dtrd_isatai
vrp_fact.Dwtr_isatai = Dwtr_isatai
vrp_fact.Delc_isatai = Delc_isatai
vrp_fact.Dind_isatai = Dind_isatai

vrp_fact.Ntot_kurmangazy = Ngds_kurmangazy + Ntrd_kurmangazy
vrp_fact.Ngds_kurmangazy = Ngds_kurmangazy
vrp_fact.Nagr_kurmangazy = Nagr_kurmangazy
vrp_fact.Nmin_kurmangazy = Nmin_kurmangazy
vrp_fact.Ncon_kurmangazy = Ncon_kurmangazy
vrp_fact.Nman_kurmangazy = Nman_kurmangazy
vrp_fact.Nret_kurmangazy = Nret_kurmangazy
vrp_fact.Nwhl_kurmangazy = Nwhl_kurmangazy
vrp_fact.Ntrd_kurmangazy = Ntrd_kurmangazy
vrp_fact.Nsrv_kurmangazy = Ntrd_kurmangazy
vrp_fact.Nwtr_kurmangazy = Nwtr_kurmangazy
vrp_fact.Nelc_kurmangazy = Nelc_kurmangazy
vrp_fact.Nind_kurmangazy = Nind_kurmangazy

vrp_fact.ltot_kurmangazy = lgds_kurmangazy + ltrd_kurmangazy
vrp_fact.lgds_kurmangazy = lgds_kurmangazy
vrp_fact.lagr_kurmangazy = lagr_kurmangazy
vrp_fact.lmin_kurmangazy = lmin_kurmangazy
vrp_fact.lcon_kurmangazy = lcon_kurmangazy
vrp_fact.lman_kurmangazy = lman_kurmangazy
vrp_fact.lret_kurmangazy = lret_kurmangazy
vrp_fact.lwhl_kurmangazy = lwhl_kurmangazy
vrp_fact.ltrd_kurmangazy = ltrd_kurmangazy
vrp_fact.lsrv_kurmangazy = ltrd_kurmangazy
vrp_fact.lwtr_kurmangazy = lwtr_kurmangazy
vrp_fact.lelc_kurmangazy = lelc_kurmangazy
vrp_fact.lind_kurmangazy = lind_kurmangazy

vrp_fact.Dtot_kurmangazy = Dgds_kurmangazy + Dtrd_kurmangazy
vrp_fact.Dgds_kurmangazy = Dgds_kurmangazy
vrp_fact.Dagr_kurmangazy = Dagr_kurmangazy
vrp_fact.Dmin_kurmangazy = Dmin_kurmangazy
vrp_fact.Dcon_kurmangazy = Dcon_kurmangazy
vrp_fact.Dman_kurmangazy = Dman_kurmangazy
vrp_fact.Dret_kurmangazy = Dret_kurmangazy
vrp_fact.Dwhl_kurmangazy = Dwhl_kurmangazy
vrp_fact.Dtrd_kurmangazy = Dtrd_kurmangazy
vrp_fact.Dsrv_kurmangazy = Dtrd_kurmangazy
vrp_fact.Dwtr_kurmangazy = Dwtr_kurmangazy
vrp_fact.Delc_kurmangazy = Delc_kurmangazy
vrp_fact.Dind_kurmangazy = Dind_kurmangazy

vrp_fact.Ntot_kzylkoga = Ngds_kzylkoga + Ntrd_kzylkoga
vrp_fact.Ngds_kzylkoga = Ngds_kzylkoga
vrp_fact.Nagr_kzylkoga = Nagr_kzylkoga
vrp_fact.Nmin_kzylkoga = Nmin_kzylkoga
vrp_fact.Ncon_kzylkoga = Ncon_kzylkoga
vrp_fact.Nman_kzylkoga = Nman_kzylkoga
vrp_fact.Nret_kzylkoga = Nret_kzylkoga
vrp_fact.Nwhl_kzylkoga = Nwhl_kzylkoga
vrp_fact.Ntrd_kzylkoga = Ntrd_kzylkoga
vrp_fact.Nsrv_kzylkoga = Ntrd_kzylkoga
vrp_fact.Nwtr_kzylkoga = Nwtr_kzylkoga
vrp_fact.Nelc_kzylkoga = Nelc_kzylkoga
vrp_fact.Nind_kzylkoga = Nind_kzylkoga

vrp_fact.ltot_kzylkoga = lgds_kzylkoga + ltrd_kzylkoga
vrp_fact.lgds_kzylkoga = lgds_kzylkoga
vrp_fact.lagr_kzylkoga = lagr_kzylkoga
vrp_fact.lmin_kzylkoga = lmin_kzylkoga
vrp_fact.lcon_kzylkoga = lcon_kzylkoga
vrp_fact.lman_kzylkoga = lman_kzylkoga
vrp_fact.lret_kzylkoga = lret_kzylkoga
vrp_fact.lwhl_kzylkoga = lwhl_kzylkoga
vrp_fact.ltrd_kzylkoga = ltrd_kzylkoga
vrp_fact.lsrv_kzylkoga = ltrd_kzylkoga
vrp_fact.lwtr_kzylkoga = lwtr_kzylkoga
vrp_fact.lelc_kzylkoga = lelc_kzylkoga
vrp_fact.lind_kzylkoga = lind_kzylkoga

vrp_fact.Dtot_kzylkoga = Dgds_kzylkoga + Dtrd_kzylkoga
vrp_fact.Dgds_kzylkoga = Dgds_kzylkoga
vrp_fact.Dagr_kzylkoga = Dagr_kzylkoga
vrp_fact.Dmin_kzylkoga = Dmin_kzylkoga
vrp_fact.Dcon_kzylkoga = Dcon_kzylkoga
vrp_fact.Dman_kzylkoga = Dman_kzylkoga
vrp_fact.Dret_kzylkoga = Dret_kzylkoga
vrp_fact.Dwhl_kzylkoga = Dwhl_kzylkoga
vrp_fact.Dtrd_kzylkoga = Dtrd_kzylkoga
vrp_fact.Dsrv_kzylkoga = Dtrd_kzylkoga
vrp_fact.Dwtr_kzylkoga = Dwtr_kzylkoga
vrp_fact.Delc_kzylkoga = Delc_kzylkoga
vrp_fact.Dind_kzylkoga = Dind_kzylkoga

vrp_fact.Ntot_makat = Ngds_makat + Ntrd_makat
vrp_fact.Ngds_makat = Ngds_makat
vrp_fact.Nagr_makat = Nagr_makat
vrp_fact.Nmin_makat = Nmin_makat
vrp_fact.Ncon_makat = Ncon_makat
vrp_fact.Nman_makat = Nman_makat
vrp_fact.Nret_makat = Nret_makat
vrp_fact.Nwhl_makat = Nwhl_makat
vrp_fact.Ntrd_makat = Ntrd_makat
vrp_fact.Nsrv_makat = Ntrd_makat
vrp_fact.Nwtr_makat = Nwtr_makat
vrp_fact.Nelc_makat = Nelc_makat
vrp_fact.Nind_makat = Nind_makat

vrp_fact.ltot_makat = lgds_makat + ltrd_makat
vrp_fact.lgds_makat = lgds_makat
vrp_fact.lagr_makat = lagr_makat
vrp_fact.lmin_makat = lmin_makat
vrp_fact.lcon_makat = lcon_makat
vrp_fact.lman_makat = lman_makat
vrp_fact.lret_makat = lret_makat
vrp_fact.lwhl_makat = lwhl_makat
vrp_fact.ltrd_makat = ltrd_makat
vrp_fact.lsrv_makat = ltrd_makat
vrp_fact.lwtr_makat = lwtr_makat
vrp_fact.lelc_makat = lelc_makat
vrp_fact.lind_makat = lind_makat

vrp_fact.Dtot_makat = Dgds_makat + Dtrd_makat
vrp_fact.Dgds_makat = Dgds_makat
vrp_fact.Dagr_makat = Dagr_makat
vrp_fact.Dmin_makat = Dmin_makat
vrp_fact.Dcon_makat = Dcon_makat
vrp_fact.Dman_makat = Dman_makat
vrp_fact.Dret_makat = Dret_makat
vrp_fact.Dwhl_makat = Dwhl_makat
vrp_fact.Dtrd_makat = Dtrd_makat
vrp_fact.Dsrv_makat = Dtrd_makat
vrp_fact.Dwtr_makat = Dwtr_makat
vrp_fact.Delc_makat = Delc_makat
vrp_fact.Dind_makat = Dind_makat

vrp_fact.Ntot_makhambet = Ngds_makhambet + Ntrd_makhambet
vrp_fact.Ngds_makhambet = Ngds_makhambet
vrp_fact.Nagr_makhambet = Nagr_makhambet
vrp_fact.Nmin_makhambet = Nmin_makhambet
vrp_fact.Ncon_makhambet = Ncon_makhambet
vrp_fact.Nman_makhambet = Nman_makhambet
vrp_fact.Nret_makhambet = Nret_makhambet
vrp_fact.Nwhl_makhambet = Nwhl_makhambet
vrp_fact.Ntrd_makhambet = Ntrd_makhambet
vrp_fact.Nsrv_makhambet = Ntrd_makhambet
vrp_fact.Nwtr_makhambet = Nwtr_makhambet
vrp_fact.Nelc_makhambet = Nelc_makhambet
vrp_fact.Nind_makhambet = Nind_makhambet

vrp_fact.ltot_makhambet = lgds_makhambet + ltrd_makhambet
vrp_fact.lgds_makhambet = lgds_makhambet
vrp_fact.lagr_makhambet = lagr_makhambet
vrp_fact.lmin_makhambet = lmin_makhambet
vrp_fact.lcon_makhambet = lcon_makhambet
vrp_fact.lman_makhambet = lman_makhambet
vrp_fact.lret_makhambet = lret_makhambet
vrp_fact.lwhl_makhambet = lwhl_makhambet
vrp_fact.ltrd_makhambet = ltrd_makhambet
vrp_fact.lsrv_makhambet = ltrd_makhambet
vrp_fact.lwtr_makhambet = lwtr_makhambet
vrp_fact.lelc_makhambet = lelc_makhambet
vrp_fact.lind_makhambet = lind_makhambet

vrp_fact.Dtot_makhambet = Dgds_makhambet + Dtrd_makhambet
vrp_fact.Dgds_makhambet = Dgds_makhambet
vrp_fact.Dagr_makhambet = Dagr_makhambet
vrp_fact.Dmin_makhambet = Dmin_makhambet
vrp_fact.Dcon_makhambet = Dcon_makhambet
vrp_fact.Dman_makhambet = Dman_makhambet
vrp_fact.Dret_makhambet = Dret_makhambet
vrp_fact.Dwhl_makhambet = Dwhl_makhambet
vrp_fact.Dtrd_makhambet = Dtrd_makhambet
vrp_fact.Dsrv_makhambet = Dtrd_makhambet
vrp_fact.Dwtr_makhambet = Dwtr_makhambet
vrp_fact.Delc_makhambet = Delc_makhambet
vrp_fact.Dind_makhambet = Dind_makhambet

vrp_fact.Ntot_zhylyoi = Ngds_zhylyoi + Ntrd_zhylyoi
vrp_fact.Ngds_zhylyoi = Ngds_zhylyoi
vrp_fact.Nagr_zhylyoi = Nagr_zhylyoi
vrp_fact.Nmin_zhylyoi = Nmin_zhylyoi
vrp_fact.Ncon_zhylyoi = Ncon_zhylyoi
vrp_fact.Nman_zhylyoi = Nman_zhylyoi
vrp_fact.Nret_zhylyoi = Nret_zhylyoi
vrp_fact.Nwhl_zhylyoi = Nwhl_zhylyoi
vrp_fact.Ntrd_zhylyoi = Ntrd_zhylyoi
vrp_fact.Nsrv_zhylyoi = Ntrd_zhylyoi
vrp_fact.Nwtr_zhylyoi = Nwtr_zhylyoi
vrp_fact.Nelc_zhylyoi = Nelc_zhylyoi
vrp_fact.Nind_zhylyoi = Nind_zhylyoi

vrp_fact.ltot_zhylyoi = lgds_zhylyoi + ltrd_zhylyoi
vrp_fact.lgds_zhylyoi = lgds_zhylyoi
vrp_fact.lagr_zhylyoi = lagr_zhylyoi
vrp_fact.lmin_zhylyoi = lmin_zhylyoi
vrp_fact.lcon_zhylyoi = lcon_zhylyoi
vrp_fact.lman_zhylyoi = lman_zhylyoi
vrp_fact.lret_zhylyoi = lret_zhylyoi
vrp_fact.lwhl_zhylyoi = lwhl_zhylyoi
vrp_fact.ltrd_zhylyoi = ltrd_zhylyoi
vrp_fact.lsrv_zhylyoi = ltrd_zhylyoi
vrp_fact.lwtr_zhylyoi = lwtr_zhylyoi
vrp_fact.lelc_zhylyoi = lelc_zhylyoi
vrp_fact.lind_zhylyoi = lind_zhylyoi

vrp_fact.Dtot_zhylyoi = Dgds_zhylyoi + Dtrd_zhylyoi
vrp_fact.Dgds_zhylyoi = Dgds_zhylyoi
vrp_fact.Dagr_zhylyoi = Dagr_zhylyoi
vrp_fact.Dmin_zhylyoi = Dmin_zhylyoi
vrp_fact.Dcon_zhylyoi = Dcon_zhylyoi
vrp_fact.Dman_zhylyoi = Dman_zhylyoi
vrp_fact.Dret_zhylyoi = Dret_zhylyoi
vrp_fact.Dwhl_zhylyoi = Dwhl_zhylyoi
vrp_fact.Dtrd_zhylyoi = Dtrd_zhylyoi
vrp_fact.Dsrv_zhylyoi = Dtrd_zhylyoi
vrp_fact.Dwtr_zhylyoi = Dwtr_zhylyoi
vrp_fact.Delc_zhylyoi = Delc_zhylyoi
vrp_fact.Dind_zhylyoi = Dind_zhylyoi

vrp_fact.drop([0], inplace=True)


vrp_fact
# Out:
#     Ntot_atyrau  Ngds_atyrau  Nagr_atyrau  Nmin_atyrau  Ncon_atyrau  \
# 1       68340.5      59680.5        503.5      11972.0      30904.0
# 2       73168.9      62646.9        576.9      15742.0      28965.0
# 3      106316.0      91619.7        672.7      27031.0      43334.0
# 4      192842.7     123834.9        755.9      33033.0      62490.0
# 5      330992.6     236530.5       1108.5      44363.0     152124.0
# 6      432853.9     304767.7       1492.7      41890.0     199700.0
# 7      401272.6     248145.4       2411.4      45625.0     146135.0
# 8      553942.6     363861.5       2661.5      32325.0     267565.0
# 9      584289.7     374282.6       2387.6      34610.0     284225.0
# 10     743348.3     441519.8       5817.8      38207.0     321938.0
# 11     709040.9     462877.0       7339.0      52426.0     313312.0
# 12     658221.0     372609.1       8708.1      38153.0     229870.0
# 13     631985.3     319158.1       9704.1      14681.0     177778.0
# ...

# %%
vrp_fact.to_sql('vrp_raion_fact', engine, schema='public',if_exists='replace', index = True)
