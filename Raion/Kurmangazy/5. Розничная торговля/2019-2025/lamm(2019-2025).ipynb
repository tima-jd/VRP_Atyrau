# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')
c = pd.read_sql("SELECT * FROM vrp_ekz_prog ORDER BY id",engine)

q = pd.read_sql('SELECT * FROM lagr_prog_kurmangazy ORDER BY index',engine)
w = pd.read_sql('SELECT * FROM lmin_prog_kurmangazy ORDER BY index',engine)
d = pd.read_sql('SELECT * FROM dmin_prog_kurmangazy ORDER BY index',engine)
e = pd.read_sql('SELECT * FROM nagr_prog_kurmangazy ORDER BY index',engine)
r = pd.read_sql('SELECT * FROM nmin_prog_kurmangazy ORDER BY index',engine)

t = pd.read_sql('SELECT * FROM lman_nman_prog_kurmangazy ORDER BY index',engine)

lman_b = t['lman_b']
lman_o = t['lman_o']
lman_p = t['lman_p']

Nman_b = t['Nman_b']
Nman_o = t['Nman_o']
Nman_p = t['Nman_p']

Nmin_b = r['Nmin_b']
Nmin_o = r['Nmin_o']
Nmin_p = r['Nmin_p']

Nagr_b = e['Nagr_b']
Nagr_o = e['Nagr_o']
Nagr_p = e['Nagr_p']

Dmin_b = d['Dmin_b']
Dmin_o = d['Dmin_o']
Dmin_p = d['Dmin_p']

lagr_b = q['lagr_b']
lagr_o = q['lagr_o']
lagr_p = q['lagr_p']

lmin_b = w['lmin_b']
lmin_o = w['lmin_o']
lmin_p = w['lmin_p']

i=0
newdf = pd.DataFrame(columns=['lamm_b','lamm_o','lamm_p'], index=range(12))

while i< len(lagr_b)-1:
    b = (lagr_b[i+1]*Nagr_b[i]+lmin_b[i+1]*Nmin_b[i]+lman_b[i+1]*Nman_b[i])/(Nagr_b[i]+Nmin_b[i]+Nman_b[i])    
    o = (lagr_o[i+1]*Nagr_o[i]+lmin_o[i+1]*Nmin_o[i]+lman_o[i+1]*Nman_o[i])/(Nagr_o[i]+Nmin_o[i]+Nman_o[i])    
    p = (lagr_p[i+1]*Nagr_p[i]+lmin_p[i+1]*Nmin_p[i]+lman_p[i+1]*Nman_p[i])/(Nagr_p[i]+Nmin_p[i]+Nman_p[i])    

    newdf.loc[i+1].lamm_b = b
    newdf.loc[i+1].lamm_o = o
    newdf.loc[i+1].lamm_p = p
    i=i+1
lam_b = newdf['lamm_b']
lam_b[0] = 102.55303428833697
lamm_b = lam_b

lam_o = newdf['lamm_o']
lam_o[0] = 102.55303428833697
lamm_o = lam_o

lam_p = newdf['lamm_p']
lam_p[0] = 102.55303428833697
lamm_p = lam_p

newdf.to_sql('lamm_prog_kurmangazy', engine, schema='public',if_exists='replace', index = True)
