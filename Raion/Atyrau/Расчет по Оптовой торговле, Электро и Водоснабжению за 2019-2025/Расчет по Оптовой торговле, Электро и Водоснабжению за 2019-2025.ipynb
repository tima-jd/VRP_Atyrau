# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv = pd.read_sql('SELECT * FROM vrp_ekz_fact ORDER BY id',engine)
csv_p = pd.read_sql('SELECT * FROM vrp_ekz_prog ORDER BY id',engine)


lret_csv = pd.read_sql("SELECT * FROM lret_prog_atyrau ORDER BY index",engine)
lwhl_csv = pd.read_sql("SELECT * FROM lwhl_prog_atyrau ORDER BY index",engine)
lagr_csv = pd.read_sql("SELECT * FROM lagr_prog_atyrau ORDER BY index",engine)
lmin_csv = pd.read_sql("SELECT * FROM lmin_prog_atyrau ORDER BY index",engine)
lcon_csv = pd.read_sql("SELECT * FROM lcon_prog_atyrau ORDER BY index",engine)
ltrd_csv = pd.read_sql("SELECT * FROM ltrd_fact_atyrau ORDER BY index",engine)
man_csv =  pd.read_sql("SELECT * FROM lman_nman_prog_atyrau ORDER BY index",engine)
Ncon_csv = pd.read_sql("SELECT * FROM ncon_prog_atyrau ORDER BY index",engine)
Ntrd_csv = pd.read_sql("SELECT * FROM ntrd_fact_atyrau ORDER BY index",engine)
Nmin_csv = pd.read_sql("SELECT * FROM nmin_prog_atyrau ORDER BY index",engine)
Nret_csv = pd.read_sql("SELECT * FROM nret_prog_atyrau ORDER BY index",engine)
Nagr_csv = pd.read_sql("SELECT * FROM nagr_prog_atyrau ORDER BY index",engine)

Nret_f =   csv['o_prod_retail_atyrau']
Nwhl_f =    csv['o_prod_trade_atyrau']
Nagr_f =     csv['o_prod_agro_atyrau']
Nmin_f =   csv['o_prod_mining_atyrau']
Nman_f =      csv['o_prod_man_atyrau']
Ncon_f = csv['o_prod_building_atyrau']
Nelc_f =   csv['o_prod_energo_atyrau']
Nwtr_f =    csv['o_prod_water_atyrau']
Nind_f =    csv['o_prod_water_atyrau']

lelc_f =    csv['o_ifo_energo_atyrau']
lwtr_f =     csv['o_ifo_water_atyrau']


Ntrd_f = Ntrd_csv['Ntrd_atyrau']
ltrd_f = ltrd_csv['ltrd_atyrau']

Nmin_b = Nmin_csv['Nmin_b']
Nmin_o = Nmin_csv['Nmin_o']
Nmin_p = Nmin_csv['Nmin_p']


Nman_b =  man_csv['Nman_b']
Nman_o =  man_csv['Nman_o']
Nman_p =  man_csv['Nman_p']

lman_b =  man_csv['lman_b']
lman_o =  man_csv['lman_o']
lman_p =  man_csv['lman_p']

lret_b = lret_csv['lret_b']
lret_o = lret_csv['lret_o']
lret_p = lret_csv['lret_p']

lwhl_b = lwhl_csv['lwhl_b']
lwhl_o = lwhl_csv['lwhl_o']
lwhl_p = lwhl_csv['lwhl_p']

lagr_b = lagr_csv['lagr_b']
lagr_o = lagr_csv['lagr_o']
lagr_p = lagr_csv['lagr_p']

lmin_b = lmin_csv['lmin_b']
lmin_o = lmin_csv['lmin_o']
lmin_p = lmin_csv['lmin_p']

lcon_b = lcon_csv['lcon_b']
lcon_o = lcon_csv['lcon_o']
lcon_p = lcon_csv['lcon_p']

Ncon_b = Ncon_csv['Ncon_b']
Ncon_o = Ncon_csv['Ncon_o']
Ncon_p = Ncon_csv['Ncon_p']

Nret_b = Nret_csv['Nret_b']
Nret_o = Nret_csv['Nret_o']
Nret_p = Nret_csv['Nret_p']

Nagr_b = Nagr_csv['Nagr_b']
Nagr_o = Nagr_csv['Nagr_o']
Nagr_p = Nagr_csv['Nagr_p']

inf = csv_p['o_inflation']

ltrd_b = (lret_b[0]*Nret_f[18] + lwhl_b[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_b = (lagr_b[0]*Nagr_f[18] + lmin_b[0]*Nmin_f[18] + lman_b[0]*Nman_f[18] + lcon_b[0]*Ncon_f[18] + ltrd_b * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_b= (100*((lammct_b-100)*1.5024317564210523 +100))/100
K_b= (100*((lammct_b-100)*0.6356716742567134 +100))/100
lelc_b= S_b/100 * 100
lwtr_b= K_b/100 * 100

Delc = inf * 0.9524230169082659 + 100
Dwtr = inf * 1.0248473801986724 + 100

Delc_b = Delc.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True)
Dwtr_b = Dwtr.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True)
Delc_o = Delc.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Dwtr_o = Dwtr.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Delc_p = Delc.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True)
Dwtr_p = Dwtr.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True)



Nelc_b = (Nelc_f[18]*lelc_b*Delc_b[0])/10000
Nwtr_b = (Nwtr_f[18]*lwtr_b*Dwtr_b[0])/10000
Nind_b = Nmin_b[0]+Nman_b[0]+Nelc_b+Nwtr_b
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_b = ((lmin_b[0]*Nmin_f[18])+(lman_b[0]*Nman_f[18])+(lelc_b*Nelc_f[18])+(lwtr_b*Nwtr_f[18]))/ Nind_f[18]
Nind_b = Nmin_b[0]+Nman_b[0]+Nelc_b+Nwtr_b
Dind_b= (Nind_b/Nind_f[18]/lind_b)*10000
Dwhl_b = inf[0] * 0.9627018135086216 + (Dind_b-100)*1.0043958806337958+100
Nwhl_b = (Nwhl_f[18]*lwhl_b[0]*Dwhl_b)/10000
Ntrd_b = Nret_b[0]+Nwhl_b
Dtrd_b = Ntrd_b/(Nret_f[18] + Nwhl_f[18])/ltrd_b *10000


ltrd_o = (lret_o[0]*Nret_f[18] + lwhl_o[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_o = (lagr_o[0]*Nagr_f[18] + lmin_o[0]*Nmin_f[18] + lman_o[0]*Nman_f[18] + lcon_o[0]*Ncon_f[18] + ltrd_o * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_o= (100*((lammct_o-100)*1.5024317564210523 +100))/100
K_o= (100*((lammct_o-100)*0.6356716742567134 +100))/100
lelc_o= S_o/100 * 100
lwtr_o= K_o/100 * 100

Nelc_o = (Nelc_f[18]*lelc_o*Delc_o[0])/10000
Nwtr_o = (Nwtr_f[18]*lwtr_o*Dwtr_o[0])/10000
Nind_o = Nmin_o[0]+Nman_o[0]+Nelc_o+Nwtr_o
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_o = ((lmin_o[0]*Nmin_f[18])+(lman_o[0]*Nman_f[18])+(lelc_o*Nelc_f[18])+(lwtr_o*Nwtr_f[18]))/ Nind_f[18]
Nind_o = Nmin_o[0]+Nman_o[0]+Nelc_o+Nwtr_o
Dind_o= (Nind_o/Nind_f[18]/lind_o)*10000
Dwhl_o = inf[0] * 0.9627018135086216 + (Dind_o-100)*1.0043958806337958+100
Nwhl_o = (Nwhl_f[18]*lwhl_o[0]*Dwhl_o)/10000
Ntrd_o = Nret_o[0]+Nwhl_o
Dtrd_o = Ntrd_o/(Nret_f[18] + Nwhl_f[18])/ltrd_o *10000


ltrd_p = (lret_p[0]*Nret_f[18] + lwhl_p[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_p = (lagr_p[0]*Nagr_f[18] + lmin_p[0]*Nmin_f[18] + lman_p[0]*Nman_f[18] + lcon_p[0]*Ncon_f[18] + ltrd_p * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_p= (100*((lammct_p-100)*1.5024317564210523 +100))/100
K_p= (100*((lammct_p-100)*0.6356716742567134 +100))/100
lelc_p= S_p/100 * 100
lwtr_p= K_p/100 * 100
Nelc_p = (Nelc_f[18]*lelc_p*Delc_p[0])/10000
Nwtr_p = (Nwtr_f[18]*lwtr_p*Dwtr_p[0])/10000
Nind_p = Nmin_p[0]+Nman_p[0]+Nelc_p+Nwtr_p
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_p = ((lmin_p[0]*Nmin_f[18])+(lman_p[0]*Nman_f[18])+(lelc_p*Nelc_f[18])+(lwtr_p*Nwtr_f[18]))/ Nind_f[18]
Nind_p = Nmin_p[0]+Nman_p[0]+Nelc_p+Nwtr_p
Dind_p= (Nind_p/Nind_f[18]/lind_p)*10000
Dwhl_p = inf[0] * 0.9627018135086216 + (Dind_p-100)*1.0043958806337958+100
Nwhl_p = (Nwhl_f[18]*lwhl_p[0]*Dwhl_p)/10000
Ntrd_p = Nret_p[0]+Nwhl_p
Dtrd_p = Ntrd_p/(Nret_f[18] + Nwhl_f[18])/ltrd_p *10000

ltrd_bb = ltrd_b
lelc_bb = lelc_b
lwtr_bb = lwtr_b
lind_bb = lind_b
Ntrd_bb = Ntrd_b
Nelc_bb = Nelc_b
Nwtr_bb = Nwtr_b
Nind_bb = Nind_b
Nwhl_bb = Nwhl_b
Dtrd_bb = Dtrd_b
Dwhl_bb = Dwhl_b
Dind_bb = Dind_b

ltrd_oo = ltrd_o
lelc_oo = lelc_o
lwtr_oo = lwtr_o
lind_oo = lind_o
Ntrd_oo = Ntrd_o
Nelc_oo = Nelc_o
Nwtr_oo = Nwtr_o
Nind_oo = Nind_o
Nwhl_oo = Nwhl_o
Dtrd_oo = Dtrd_o
Dwhl_oo = Dwhl_o
Dind_oo = Dind_o

ltrd_pp = ltrd_p
lelc_pp = lelc_p
lwtr_pp = lwtr_p
lind_pp = lind_p
Ntrd_pp = Ntrd_p
Nelc_pp = Nelc_p
Nwtr_pp = Nwtr_p
Nind_pp = Nind_p
Nwhl_pp = Nwhl_p
Dtrd_pp = Dtrd_p
Dwhl_pp = Dwhl_p
Dind_pp = Dind_p

# %%
ltrd_b = ltrd_bb
lelc_b = lelc_bb
lwtr_b = lwtr_bb
lind_b = lind_bb
Ntrd_b = Ntrd_bb
Nelc_b = Nelc_bb
Nwtr_b = Nwtr_bb
Nind_b = Nind_bb
Nwhl_b = Nwhl_bb
Dtrd_b = Dtrd_bb
Dwhl_b = Dwhl_bb
Dind_b = Dind_bb

i = 0

newdf_1 = pd.DataFrame(columns=['ltrd_b',
                              'lsrv_b',
                              'lelc_b',
                              'lwtr_b',
                              'lind_b',
                              'Ntrd_b',
                              'Nsrv_b',
                              'Nelc_b',
                              'Nwtr_b',
                              'Nind_b',
                              'Nwhl_b',
                              'Dtrd_b',
                              'Dsrv_b',
                              'Delc_b',
                              'Dwtr_b',
                              'Dwhl_b',
                              'Dind_b',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True))-2:
    
    Nind_b_p = Nmin_b[i]+Nman_b[i]+Nelc_b+Nwtr_b
    ltrd_b = (lret_b[i+1]*Nret_b[i] + lwhl_b[i+1]*Nwhl_b)/Ntrd_b
    
    lammct_b = (lagr_b[i+1]*Nagr_b[i] + lmin_b[i+1]*Nmin_b[i] + lman_b[i+1]*Nman_b[i] + lcon_b[i+1]*Ncon_b[i] + ltrd_b * Ntrd_b)/(Nagr_b[i]+Nmin_b[i]+Nman_b[i]+Ncon_b[i]+Ntrd_b) 
    
    
    
    S_b= (100*((lammct_b-100)*1.5024317564210523 +100))/100
    K_b = (100*((lammct_b-100)*0.6356716742567134 +100))/100
    
    lelc_b= S_b/100 * 100
    lwtr_b= K_b/100 * 100
    
    Nelc_b = (Nelc_b*lelc_b*Delc_b[i+1])/10000
    Nwtr_b = (Nwtr_b*lwtr_b*Dwtr_b[i+1])/10000
    Nind_b = Nmin_b[i+1]+Nman_b[i+1]+Nelc_b+Nwtr_b
    lind_b = ((lmin_b[i+1]*Nmin_b[i])+(lman_b[i+1]*Nman_b[0])+(lelc_b*Nelc_b)+(lwtr_b*Nwtr_b))/ Nind_b
    Nind_b = Nmin_b[i+1]+Nman_b[i+1]+Nelc_b+Nwtr_b    
    Dind_b= (Nind_b/Nind_b_p/lind_b)*10000
    Dwhl_b = inf[i+1] * 0.9627018135086216 + (Dind_b-100)*1.0043958806337958+100
    
    Ntrd_b_p = Nret_b[i]+Nwhl_b
    Nwhl_b = (Nwhl_b*lwhl_b[i+1]*Dwhl_b)/10000
    Ntrd_b = Nret_b[i+1]+Nwhl_b   
    
    Dtrd_b = Ntrd_b/Ntrd_b_p/ltrd_b*10000
    
    i = i+1
    newdf_1.loc[i].ltrd_b = ltrd_b
    newdf_1.loc[i].lsrv_b = ltrd_b
    newdf_1.loc[i].lelc_b = lelc_b
    newdf_1.loc[i].lwtr_b = lwtr_b
    newdf_1.loc[i].lind_b = lind_b
    newdf_1.loc[i].Ntrd_b = Ntrd_b
    newdf_1.loc[i].Nsrv_b = Ntrd_b
    newdf_1.loc[i].Nelc_b = Nelc_b
    newdf_1.loc[i].Nwtr_b = Nwtr_b
    newdf_1.loc[i].Nind_b = Nind_b
    newdf_1.loc[i].Nwhl_b = Nwhl_b
    
    newdf_1.loc[i].Dtrd_b = Dtrd_b     
    newdf_1.loc[i].Dsrv_b = Dtrd_b     
    newdf_1.loc[i].Dwhl_b = Dwhl_b
    newdf_1.loc[i].Dind_b = Dind_b
    newdf_1.loc[i].prognoz = "базовый"

newdf_1.loc[0].prognoz = "базовый"
    
newdf_1.loc[0].ltrd_b = ltrd_bb
newdf_1.loc[0].lsrv_b = ltrd_bb
newdf_1.loc[0].lelc_b = lelc_bb
newdf_1.loc[0].lwtr_b = lwtr_bb
newdf_1.loc[0].lind_b = lind_bb
newdf_1.loc[0].Ntrd_b = Ntrd_bb
newdf_1.loc[0].Nsrv_b = Ntrd_bb
newdf_1.loc[0].Nelc_b = Nelc_bb
newdf_1.loc[0].Nwtr_b = Nwtr_bb
newdf_1.loc[0].Nind_b = Nind_bb
newdf_1.loc[0].Nwhl_b = Nwhl_bb
newdf_1.loc[0].Dtrd_b = Dtrd_bb
newdf_1.loc[0].Dsrv_b = Dtrd_bb
newdf_1.loc[0].Dwhl_b = Dwhl_bb
newdf_1.loc[0].Dind_b = Dind_bb

newdf_1.Delc_b = Delc_b 
newdf_1.Dwtr_b = Dwtr_b

lind_b = newdf_1['lind_b']
lelc_b = newdf_1['lelc_b']
lwtr_b = newdf_1['lwtr_b']
ltrd_b = newdf_1['ltrd_b']

Nind_b = newdf_1['Nind_b']
Nelc_b = newdf_1['Nelc_b']
Nwtr_b = newdf_1['Nwtr_b']
Ntrd_b = newdf_1['Ntrd_b']
Nwhl_b = newdf_1['Nwhl_b']

newdf_1
# Out:
#      ltrd_b   lsrv_b   lelc_b   lwtr_b   lind_b       Ntrd_b       Nsrv_b  \
# 0   103.652  103.652  105.577   102.36  103.188  3.51356e+06  3.51356e+06
# 1   111.609  111.609  117.022  107.202    98.14   4.7748e+06   4.7748e+06
# 2   101.437  101.437  102.338  100.989  96.0024  5.40008e+06  5.40008e+06
# 3   101.286  101.286  102.124  100.899  95.0449  6.09017e+06  6.09017e+06
# 4   100.573  100.573  101.086   100.46  94.4397  6.82267e+06  6.82267e+06
# 5   99.0325  99.0325  98.8386  99.5086   93.927  7.46973e+06  7.46973e+06
# 6   100.234  100.234  100.587  100.248  94.2717  8.33468e+06  8.33468e+06
# 7       NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 8       NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 9       NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 10      NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 11      NaN      NaN      NaN      NaN      NaN          NaN          NaN
#
#      Nelc_b   Nwtr_b  Nind_b       Nwhl_b   Dtrd_b   Dsrv_b      Delc_b  \
# 0   49847.6  9807.11  627050  3.24568e+06  105.151  105.151  105.714538
# 1   61665.9  11159.9  720627  4.47853e+06  121.761  121.761  105.714538
# 2   66714.3  11963.3  733583  5.08383e+06  111.493  111.493  105.714538
# 3   71375.8  12689.4  745233  5.75607e+06  111.347  111.347  104.762115
# 4   75586.9  13400.9  752392  6.47059e+06  111.389  111.389  104.762115
# 5   78266.8  14018.4  749163  7.10071e+06  110.554  110.554  104.762115
# 6   82475.4  14773.3  754234  7.94627e+06  111.319  111.319  104.762115
# 7       NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 8       NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 9       NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 10      NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 11      NaN      NaN     NaN          NaN      NaN      NaN         NaN
#
#         Dwtr_b   Dwhl_b   Dind_b  prognoz
# 0   106.149084  105.065  99.2917  базовый
# 1   106.149084  122.953  117.102  базовый
# 2   106.149084   111.84  106.037  базовый
# 3   105.124237  111.728  106.884  базовый
# 4   105.124237  111.749  106.905  базовый
# 5   105.124237  110.849  106.009  базовый
# 6   105.124237  111.638  106.794  базовый
# 7          NaN      NaN      NaN      NaN
# 8          NaN      NaN      NaN      NaN
# 9          NaN      NaN      NaN      NaN
# 10         NaN      NaN      NaN      NaN
# 11         NaN      NaN      NaN      NaN

# %%
ltrd_o = ltrd_oo
lelc_o = lelc_oo
lwtr_o = lwtr_oo
lind_o = lind_oo
Ntrd_o = Ntrd_oo
Nelc_o = Nelc_oo
Nwtr_o = Nwtr_oo
Nind_o = Nind_oo
Nwhl_o = Nwhl_oo
Dtrd_o = Dtrd_oo
Dwhl_o = Dwhl_oo
Dind_o = Dind_oo

i = 0

newdf_2 = pd.DataFrame(columns=['ltrd_o',
                                'lsrv_o',
                              'lelc_o',
                              'lwtr_o',
                              'lind_o',
                              'Ntrd_o',
                              'Nsrv_o',
                              'Nelc_o',
                              'Nwtr_o',
                              'Nind_o',
                              'Nwhl_o',
                              'Dtrd_o',
                              'Dsrv_o',
                              'Delc_o',
                              'Dwtr_o',
                              'Dwhl_o',
                              'Dind_o',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True))-2:
    Nind_o_p = Nmin_o[i] + Nman_o[i] + Nelc_o + Nwtr_o
    ltrd_o =  (lret_o[i+1]*Nret_o[i] + lwhl_o[i+1]*Nwhl_o)/Ntrd_o
    
    lammct_o = (lagr_o[i+1]*Nagr_o[i] + lmin_o[i+1]*Nmin_o[i] + lman_o[i+1]*Nman_o[i] + lcon_o[i+1]*Ncon_o[i] + ltrd_o * Ntrd_o)/(Nagr_o[i]+Nmin_o[i]+Nman_o[i]+Ncon_o[i]+Ntrd_o) 
    
    
    
    S_o=  (100*((lammct_o-100)*1.5024317564210523 +100))/100
    K_o = (100*((lammct_o-100)*0.6356716742567134 +100))/100
    
    lelc_o= S_o/100 * 100
    lwtr_o= K_o/100 * 100
    
    Nelc_o = (Nelc_o*lelc_o*Delc_o[i+1])/10000
    Nwtr_o = (Nwtr_o*lwtr_o*Dwtr_o[i+1])/10000
    Nind_o =   Nmin_o[i+1]+Nman_o[i+1]+Nelc_o+Nwtr_o
    lind_o = ((lmin_o[i+1]*Nmin_o[i])+(lman_o[i+1]*Nman_o[0])+(lelc_o*Nelc_o)+(lwtr_o*Nwtr_o))/ Nind_o
    Nind_o =   Nmin_o[i+1]+Nman_o[i+1]+Nelc_o+Nwtr_o    
    Dind_o=   (Nind_o/Nind_o_p/lind_o)*10000
    Dwhl_o = inf[i+1] * 0.9627018135086216 + (Dind_o-100)*1.0043958806337958+100
    
    Ntrd_o_p = Nret_o[i]+Nwhl_o
    Nwhl_o = (Nwhl_o*lwhl_o[i+1]*Dwhl_o)/10000
    Ntrd_o = Nret_o[i+1]+Nwhl_o   
    
    Dtrd_o = Ntrd_o/Ntrd_o_p/ltrd_o*10000
    
    i = i+1
    newdf_2.loc[i].ltrd_o = ltrd_o
    newdf_2.loc[i].lsrv_o = ltrd_o
    newdf_2.loc[i].lelc_o = lelc_o
    newdf_2.loc[i].lwtr_o = lwtr_o
    newdf_2.loc[i].lind_o = lind_o
    newdf_2.loc[i].Ntrd_o = Ntrd_o
    newdf_2.loc[i].Nsrv_o = Ntrd_o
    newdf_2.loc[i].Nelc_o = Nelc_o
    newdf_2.loc[i].Nwtr_o = Nwtr_o
    newdf_2.loc[i].Nind_o = Nind_o
    newdf_2.loc[i].Nwhl_o = Nwhl_o
    
    newdf_2.loc[i].Dtrd_o = Dtrd_o     
    newdf_2.loc[i].Dsrv_o = Dtrd_o     
    newdf_2.loc[i].Dwhl_o = Dwhl_o
    newdf_2.loc[i].Dind_o = Dind_o
    newdf_2.loc[i].prognoz = "оптимистичный"
    
newdf_2.loc[0].prognoz = "оптимистичный"
    
newdf_2.loc[0].ltrd_o = ltrd_oo
newdf_2.loc[0].lsrv_o = ltrd_oo
newdf_2.loc[0].lelc_o = lelc_oo
newdf_2.loc[0].lwtr_o = lwtr_oo
newdf_2.loc[0].lind_o = lind_oo
newdf_2.loc[0].Ntrd_o = Ntrd_oo
newdf_2.loc[0].Nsrv_o = Ntrd_oo
newdf_2.loc[0].Nelc_o = Nelc_oo
newdf_2.loc[0].Nwtr_o = Nwtr_oo
newdf_2.loc[0].Nind_o = Nind_oo
newdf_2.loc[0].Nwhl_o = Nwhl_oo
newdf_2.loc[0].Dtrd_o = Dtrd_oo
newdf_2.loc[0].Dsrv_o = Dtrd_oo
newdf_2.loc[0].Dwhl_o = Dwhl_oo
newdf_2.loc[0].Dind_o = Dind_oo
    
newdf_2.Delc_o = Delc_o 
newdf_2.Dwtr_o = Dwtr_o

lind_o = newdf_2['lind_o']
lelc_o = newdf_2['lelc_o']
lwtr_o = newdf_2['lwtr_o']
ltrd_o = newdf_2['ltrd_o']

Nind_o = newdf_2['Nind_o']
Nelc_o = newdf_2['Nelc_o']
Nwtr_o = newdf_2['Nwtr_o']
Ntrd_o = newdf_2['Ntrd_o']
Nwhl_o = newdf_2['Nwhl_o']

newdf_2
# Out:
#      ltrd_o   lsrv_o   lelc_o   lwtr_o   lind_o       Ntrd_o       Nsrv_o  \
# 0   103.652  103.652  105.577   102.36  103.188   3.4438e+06   3.4438e+06
# 1   114.487  114.487  121.397  109.053  84.9268  6.40778e+06  6.40778e+06
# 2   101.428  101.428  102.482   101.05  89.4458  7.72731e+06  7.72731e+06
# 3   102.682  102.682  104.297  101.818  88.8506  9.51145e+06  9.51145e+06
# 4   110.342  110.342  115.463  106.542  89.7517  1.32502e+07  1.32502e+07
# 5   100.306  100.306  100.746  100.316   86.468  1.60642e+07  1.60642e+07
# 6   101.489  101.489  102.471  101.045  86.2285  1.99662e+07  1.99662e+07
# 7       NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 8       NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 9       NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 10      NaN      NaN      NaN      NaN      NaN          NaN          NaN
# 11      NaN      NaN      NaN      NaN      NaN          NaN          NaN
#
#      Nelc_o   Nwtr_o  Nind_o       Nwhl_o   Dtrd_o   Dsrv_o      Delc_o  \
# 0   49847.6  9807.11  612850  3.17592e+06  103.063  103.063  105.714538
# 1   63752.4  11310.9  837149  6.10968e+06  162.523  162.523  105.352617
# 2   68831.9    12088  851313  7.41031e+06  118.895  118.895  105.352617
# 3   74948.1  12890.5  874593  9.17621e+06  119.874  119.874  104.400194
# 4   90345.3  14384.1  958242  1.28863e+07  126.251  126.251  104.400194
# 5   95024.4  15112.7  964749  1.56826e+07  120.867  120.867  104.400194
# 6    101657  15993.7  981628  1.95643e+07  122.466  122.466  104.400194
# 7       NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 8       NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 9       NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 10      NaN      NaN     NaN          NaN      NaN      NaN         NaN
# 11      NaN      NaN     NaN          NaN      NaN      NaN         NaN
#
#         Dwtr_o   Dwhl_o   Dind_o        prognoz
# 0   106.149084  102.807  97.0433  оптимистичный
# 1   105.759642  166.887  160.843  оптимистичный
# 2   105.759642  119.528  113.691  оптимистичный
# 3   104.734795  120.509  115.626  оптимистичный
# 4   104.734795  126.986  122.075  оптимистичный
# 5   104.734795  121.321  116.435  оптимистичный
# 6   104.734795  122.893      118  оптимистичный
# 7          NaN      NaN      NaN            NaN
# 8          NaN      NaN      NaN            NaN
# 9          NaN      NaN      NaN            NaN
# 10         NaN      NaN      NaN            NaN
# 11         NaN      NaN      NaN            NaN

# %%
ltrd_p = ltrd_pp
lelc_p = lelc_pp
lwtr_p = lwtr_pp
lind_p = lind_pp
Ntrd_p = Ntrd_pp
Nelc_p = Nelc_pp
Nwtr_p = Nwtr_pp
Nind_p = Nind_pp
Nwhl_p = Nwhl_pp
Dtrd_p = Dtrd_pp
Dwhl_p = Dwhl_pp
Dind_p = Dind_pp

i = 0

newdf_3 = pd.DataFrame(columns=['ltrd_p',
                              'lelc_p',
                              'lwtr_p',
                              'lind_p',
                              'Ntrd_p',
                              'Nelc_p',
                              'Nwtr_p',
                              'Nind_p',
                              'Nwhl_p',
                              'Dtrd_p',
                              'Delc_p',
                              'Dwtr_p',
                              'Dwhl_p',
                              'Dind_p',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True))-2:
    Nind_p_p = Nmin_p[i] + Nman_p[i] + Nelc_p + Nwtr_p
    ltrd_p =  (lret_p[i+1]*Nret_p[i] + lwhl_p[i+1]*Nwhl_p)/Ntrd_p
    
    lammct_p = (lagr_p[i+1]*Nagr_p[i] + lmin_p[i+1]*Nmin_p[i] + lman_p[i+1]*Nman_p[i] + lcon_p[i+1]*Ncon_p[i] + ltrd_p * Ntrd_p)/(Nagr_p[i]+Nmin_p[i]+Nman_p[i]+Ncon_p[i]+Ntrd_p) 
    
    
    
    S_p=  (100*((lammct_p-100)*1.5024317564210523 +100))/100
    K_p = (100*((lammct_p-100)*0.6356716742567134 +100))/100
    
    lelc_p= S_p/100 * 100
    lwtr_p= K_p/100 * 100
    
    Nelc_p = (Nelc_p*lelc_p*Delc_p[i+1])/10000
    Nwtr_p = (Nwtr_p*lwtr_p*Dwtr_p[i+1])/10000
    Nind_p =   Nmin_p[i+1]+Nman_p[i+1]+Nelc_p+Nwtr_p
    lind_p = ((lmin_p[i+1]*Nmin_p[i])+(lman_p[i+1]*Nman_p[0])+(lelc_p*Nelc_p)+(lwtr_p*Nwtr_p))/ Nind_p
    Nind_p =   Nmin_p[i+1]+Nman_p[i+1]+Nelc_p+Nwtr_p    
    Dind_p=   (Nind_p/Nind_p_p/lind_p)*10000
    Dwhl_p = inf[i+1] * 0.9627018135086216 + (Dind_p-100)*1.0043958806337958+100
    
    Ntrd_p_p = Nret_p[i]+Nwhl_p
    Nwhl_p = (Nwhl_p*lwhl_p[i+1]*Dwhl_p)/10000
    Ntrd_p = Nret_p[i+1]+Nwhl_p
    
    Dtrd_p = Ntrd_p/Ntrd_p_p/ltrd_p*10000
    
    i = i+1
    newdf_3.loc[i].ltrd_p = ltrd_p
    newdf_3.loc[i].lelc_p = lelc_p
    newdf_3.loc[i].lwtr_p = lwtr_p
    newdf_3.loc[i].lind_p = lind_p
    newdf_3.loc[i].Ntrd_p = Ntrd_p
    newdf_3.loc[i].Nelc_p = Nelc_p
    newdf_3.loc[i].Nwtr_p = Nwtr_p
    newdf_3.loc[i].Nind_p = Nind_p
    newdf_3.loc[i].Nwhl_p = Nwhl_p
    
    newdf_3.loc[i].Dtrd_p = Dtrd_p     
    newdf_3.loc[i].Dwhl_p = Dwhl_p
    newdf_3.loc[i].Dind_p = Dind_p
    newdf_3.loc[i].prognoz = "пессимистичный"
    
newdf_3.loc[0].prognoz = "пессимистичный"    
    
newdf_3.loc[0].ltrd_p = ltrd_pp
newdf_3.loc[0].lelc_p = lelc_pp
newdf_3.loc[0].lwtr_p = lwtr_pp
newdf_3.loc[0].lind_p = lind_pp
newdf_3.loc[0].Ntrd_p = Ntrd_pp
newdf_3.loc[0].Nelc_p = Nelc_pp
newdf_3.loc[0].Nwtr_p = Nwtr_pp
newdf_3.loc[0].Nind_p = Nind_pp
newdf_3.loc[0].Nwhl_p = Nwhl_pp
newdf_3.loc[0].Dtrd_p = Dtrd_pp
newdf_3.loc[0].Dwhl_p = Dwhl_pp
newdf_3.loc[0].Dind_p = Dind_pp

newdf_3.Delc_p = Delc_p 
newdf_3.Dwtr_p = Dwtr_p

lind_p = newdf_3['lind_p']
lelc_p = newdf_3['lelc_p']
lwtr_p = newdf_3['lwtr_p']
ltrd_p = newdf_3['ltrd_p']

Nind_p = newdf_3['Nind_p']
Nelc_p = newdf_3['Nelc_p']
Nwtr_p = newdf_3['Nwtr_p']
Ntrd_p = newdf_3['Ntrd_p']
Nwhl_p = newdf_3['Nwhl_p']

newdf_3
# Out:
#      ltrd_p   lelc_p   lwtr_p   lind_p       Ntrd_p   Nelc_p   Nwtr_p  Nind_p  \
# 0   103.652   107.71  103.262  110.816  2.75651e+06  51560.2  10040.7  507046
# 1   102.085  103.185  101.348  100.377  3.04157e+06    57023  10962.3  520829
# 2   100.871  101.445  100.611  98.6929  3.32757e+06  61450.3  11768.6  528680
# 3   95.8053  94.1149    97.51  97.1203  3.33555e+06  61436.2  12244.7  511329
# 4   98.5024  98.0346  99.1685  98.3566  3.47814e+06  63980.3  12956.7  507662
# 5   99.6551  99.7034  99.8745  99.1289  3.68027e+06    67764  13807.8  509743
# 6    96.752  94.1809   97.538  88.2443  4.54042e+06  67467.8    14296  562618
# 7       NaN      NaN      NaN      NaN          NaN      NaN      NaN     NaN
# 8       NaN      NaN      NaN      NaN          NaN      NaN      NaN     NaN
# 9       NaN      NaN      NaN      NaN          NaN      NaN      NaN     NaN
# 10      NaN      NaN      NaN      NaN          NaN      NaN      NaN     NaN
# 11      NaN      NaN      NaN      NaN          NaN      NaN      NaN     NaN
#
#          Nwhl_p   Dtrd_p      Delc_p      Dwtr_p   Dwhl_p   Dind_p  \
# 0   2.48461e+06  82.4942  107.181270  107.727349  80.4284  74.7631
# 1   2.74626e+06  108.087  107.181270  107.727349  108.119  102.332
# 2   3.01131e+06  108.459  106.228847  106.702502   108.64  102.852
# 3   3.00302e+06  104.629  106.228847  106.702502  104.398  99.5859
# 4   3.12505e+06   105.86  106.228847  106.702502  105.759  100.942
# 5   3.30378e+06  106.177  106.228847  106.702502  106.111  101.292
# 6   4.14529e+06  127.514  105.714538  106.149084      130  125.076
# 7           NaN      NaN         NaN         NaN      NaN      NaN
# 8           NaN      NaN         NaN         NaN      NaN      NaN
# 9           NaN      NaN         NaN         NaN      NaN      NaN
# 10          NaN      NaN         NaN         NaN      NaN      NaN
# 11          NaN      NaN         NaN         NaN      NaN      NaN
#
#            prognoz
# 0   пессимистичный
# 1   пессимистичный
# 2   пессимистичный
# 3   пессимистичный
# 4   пессимистичный
# 5   пессимистичный
# 6   пессимистичный
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN

# %%
csv_Dman_atyrau  = pd.read_sql('SELECT * FROM dman_prog_atyrau ORDER BY index',engine)
csv_Dcon_atyrau  = pd.read_sql('SELECT * FROM dcon_prog_atyrau ORDER BY index',engine)
csv_Dmin_atyrau  = pd.read_sql('SELECT * FROM dmin_prog_atyrau ORDER BY index',engine)
csv_Dret_atyrau  = pd.read_sql('SELECT * FROM dret_prog_atyrau ORDER BY index',engine)
csv_Dagr_atyrau  = pd.read_sql('SELECT * FROM dagr_prog_atyrau ORDER BY index',engine)

Dman = csv_Dman_atyrau.rename({'0': 'Dman_atyrau'}, axis='columns')

Dcon_b = csv_Dcon_atyrau['Dcon_b']
Dcon_o = csv_Dcon_atyrau['Dcon_o']
Dcon_p = csv_Dcon_atyrau['Dcon_p']
Dcon = Dcon_b.append(Dcon_o).append(Dcon_p).dropna().reset_index(drop = True)

Dmin_b = csv_Dmin_atyrau['Dmin_b']
Dmin_o = csv_Dmin_atyrau['Dmin_o']
Dmin_p = csv_Dmin_atyrau['Dmin_p']
Dmin = Dmin_b.append(Dmin_o).append(Dmin_p).dropna().reset_index(drop = True)

Dret_b = csv_Dret_atyrau['Dret_b']
Dret_o = csv_Dret_atyrau['Dret_o']
Dret_p = csv_Dret_atyrau['Dret_p']
Dret = Dret_b.append(Dret_o).append(Dret_p).dropna().reset_index(drop = True)

Dagr_b = csv_Dagr_atyrau['Dagr_b']
Dagr_o = csv_Dagr_atyrau['Dagr_o']
Dagr_p = csv_Dagr_atyrau['Dagr_p']
Dagr = Dagr_b.append(Dagr_o).append(Dagr_p).dropna().reset_index(drop = True)
                    

prognoz = newdf_1['prognoz'].append(newdf_2['prognoz']).append(newdf_3['prognoz']).dropna().reset_index(drop = True)

ltrd = newdf_1['ltrd_b'].append(newdf_2['ltrd_o']).append(newdf_3['ltrd_p']).dropna().reset_index(drop = True)

lelc = newdf_1['lelc_b'].append(newdf_2['lelc_o']).append(newdf_3['lelc_p']).dropna().reset_index(drop = True)
lwtr = newdf_1['lwtr_b'].append(newdf_2['lwtr_o']).append(newdf_3['lwtr_p']).dropna().reset_index(drop = True)
lind = newdf_1['lind_b'].append(newdf_2['lind_o']).append(newdf_3['lind_p']).dropna().reset_index(drop = True)
Ntrd = newdf_1['Ntrd_b'].append(newdf_2['Ntrd_o']).append(newdf_3['Ntrd_p']).dropna().reset_index(drop = True)
Nelc = newdf_1['Nelc_b'].append(newdf_2['Nelc_o']).append(newdf_3['Nelc_p']).dropna().reset_index(drop = True)
Nwtr = newdf_1['Nwtr_b'].append(newdf_2['Nwtr_o']).append(newdf_3['Nwtr_p']).dropna().reset_index(drop = True)
Nind = newdf_1['Nind_b'].append(newdf_2['Nind_o']).append(newdf_3['Nind_p']).dropna().reset_index(drop = True)
Nwhl = newdf_1['Nwhl_b'].append(newdf_2['Nwhl_o']).append(newdf_3['Nwhl_p']).dropna().reset_index(drop = True)
Dtrd = newdf_1['Dtrd_b'].append(newdf_2['Dtrd_o']).append(newdf_3['Dtrd_p']).dropna().reset_index(drop = True)
Delc = newdf_1['Delc_b'].append(newdf_2['Delc_o']).append(newdf_3['Delc_p']).dropna().reset_index(drop = True)
Dwtr = newdf_1['Dwtr_b'].append(newdf_2['Dwtr_o']).append(newdf_3['Dwtr_p']).dropna().reset_index(drop = True)
Dwhl = newdf_1['Dwhl_b'].append(newdf_2['Dwhl_o']).append(newdf_3['Dwhl_p']).dropna().reset_index(drop = True)
Dind = newdf_1['Dind_b'].append(newdf_2['Dind_o']).append(newdf_3['Dind_p']).dropna().reset_index(drop = True)

lret = lret_csv['lret_b'].append(lret_csv['lret_o']).append(lret_csv['lret_p']).dropna().reset_index(drop = True)
lwhl = lwhl_csv['lwhl_b'].append(lwhl_csv['lwhl_o']).append(lwhl_csv['lwhl_p']).dropna().reset_index(drop = True)
lagr = lagr_csv['lagr_b'].append(lagr_csv['lagr_o']).append(lagr_csv['lagr_p']).dropna().reset_index(drop = True)
lmin = lmin_csv['lmin_b'].append(lmin_csv['lmin_o']).append(lmin_csv['lmin_p']).dropna().reset_index(drop = True)
lcon = lcon_csv['lcon_b'].append(lcon_csv['lcon_o']).append(lcon_csv['lcon_p']).dropna().reset_index(drop = True)
lman = man_csv['lman_b'].append(man_csv['lman_o']).append(man_csv['lman_p']).dropna().reset_index(drop = True)
Nman = man_csv['Nman_b'].append(man_csv['Nman_o']).append(man_csv['Nman_p']).dropna().reset_index(drop = True)
Ncon = Ncon_csv['Ncon_b'].append(Ncon_csv['Ncon_o']).append(Ncon_csv['Ncon_p']).dropna().reset_index(drop = True)
Nmin = Nmin_csv['Nmin_b'].append(Nmin_csv['Nmin_o']).append(Nmin_csv['Nmin_p']).dropna().reset_index(drop = True)
Nret = Nret_csv['Nret_b'].append(Nret_csv['Nret_o']).append(Nret_csv['Nret_p']).dropna().reset_index(drop = True)
Nagr = Nagr_csv['Nagr_b'].append(Nagr_csv['Nagr_o']).append(Nagr_csv['Nagr_p']).dropna().reset_index(drop = True)

newdf = pd.DataFrame(columns = ['prognoz',
                                'Nman_atyrau',
                                'Ncon_atyrau',
                                'Nmin_atyrau',
                                'Nret_atyrau',
                                'Nagr_atyrau',
                                'Ntrd_atyrau',
                                'Nsrv_atyrau',
                                'Nelc_atyrau',
                                'Nwtr_atyrau',
                                'Nind_atyrau',
                                'Nwhl_atyrau',
                                'lman_atyrau',
                                'lcon_atyrau',
                                'lmin_atyrau',
                                'lret_atyrau',
                                'lagr_atyrau',
                                'ltrd_atyrau',
                                'lsrv_atyrau',
                                'lelc_atyrau',
                                'lwtr_atyrau',
                                'lind_atyrau',
                                'lwhl_atyrau',
                                'Dman_atyrau',
                                'Dcon_atyrau',
                                'Dmin_atyrau',
                                'Dret_atyrau',
                                'Dagr_atyrau',
                                'Dtrd_atyrau',
                                'Dsrv_atyrau',
                                'Delc_atyrau',
                                'Dwtr_atyrau',
                                'Dind_atyrau',
                                'Dwhl_atyrau',])
newdf.lret_atyrau= lret
newdf.lwhl_atyrau= lwhl
newdf.lagr_atyrau= lagr
newdf.lmin_atyrau= lmin
newdf.lcon_atyrau= lcon
newdf.lman_atyrau= lman
newdf.Nman_atyrau= Nman
newdf.Ncon_atyrau= Ncon
newdf.Nmin_atyrau= Nmin
newdf.Nret_atyrau= Nret
newdf.Nagr_atyrau= Nagr

newdf.ltrd_atyrau= ltrd
newdf.lsrv_atyrau= ltrd
newdf.lelc_atyrau= lelc
newdf.lwtr_atyrau= lwtr
newdf.lind_atyrau= lind
newdf.Ntrd_atyrau= Ntrd
newdf.Nsrv_atyrau= Ntrd
newdf.Nelc_atyrau= Nelc
newdf.Nwtr_atyrau= Nwtr
newdf.Nind_atyrau= Nind
newdf.Nwhl_atyrau= Nwhl

newdf.Dtrd_atyrau= Dtrd
newdf.Dsrv_atyrau= Dtrd
newdf.Dsrv_atyrau= Dtrd
newdf.Delc_atyrau= Delc
newdf.Dwtr_atyrau= Dwtr
newdf.Dwhl_atyrau= Dwhl
newdf.Dind_atyrau= Dind

newdf.Dman_atyrau = Dman
newdf.Dcon_atyrau = Dcon
newdf.Dmin_atyrau = Dmin
newdf.Dret_atyrau = Dret
newdf.Dagr_atyrau = Dagr

newdf.prognoz = prognoz

newdf
# Out:
#            prognoz    Nman_atyrau    Ncon_atyrau    Nmin_atyrau  \
# 0          базовый  271391.892037  121571.267218  296003.047637
# 1          базовый  301615.098993  140162.741796  346186.184000
# 2          базовый  309408.769131  150466.128691  345496.869252
# 3          базовый  313807.086815  161845.265929  347360.610850
# 4          базовый  316043.749953  173840.118804  347360.610850
# 5          базовый  315102.766025  185920.291771  341775.259387
# 6          базовый  315210.220449  199694.254154  341775.259387
# 7    оптимистичный  264252.576165  118627.071712  288943.157523
# 8    оптимистичный  353527.909656  169652.935650  408557.736970
# 9    оптимистичный  363069.885081  190588.909864  407323.011964
# 10   оптимистичный  370967.430873  215085.206084  415787.379395
# 11   оптимистичный  393216.536328  247659.943210  460296.429739
# 12   оптимистичный  400360.803051  276303.623168  454251.020547
# 13   оптимистичный  405524.474361  309613.517428  458453.108369
# 14  пессимистичный  202915.188854   96096.921476  242530.244790
# 15  пессимистичный  210665.795711  100688.040371  242178.120813
# 16  пессимистичный  213921.987040  105482.835974  241539.026503
# 17  пессимистичный  209988.027498  108865.456564  227660.261558
# 18  пессимистичный  207161.740508  113599.863266  223563.607202
# 19  пессимистичный  205960.228905  118943.214076  222211.006914
# 20  пессимистичный  231592.607789   97946.346857  249261.322882
#
#       Nret_atyrau   Nagr_atyrau  Ntrd_atyrau  Nsrv_atyrau Nelc_atyrau  \
# 0   267880.167979  13721.433100  3.51356e+06  3.51356e+06     49847.6
# 1   296271.254111  15355.641385   4.7748e+06   4.7748e+06     61665.9
# 2   316245.491057  17188.796881  5.40008e+06  5.40008e+06     66714.3
# 3   334099.300241  19042.280332  6.09017e+06  6.09017e+06     71375.8
# 4   352076.993657  21099.333492  6.82267e+06  6.82267e+06     75586.9
# 5   369020.791242  23380.697569  7.46973e+06  7.46973e+06     78266.8
# 6   388414.260659  25909.287324  8.33468e+06  8.33468e+06     82475.4
# 7   267880.167979  13721.433100   3.4438e+06   3.4438e+06     49847.6
# 8   298099.581477  15296.411085  6.40778e+06  6.40778e+06     63752.4
# 9   316992.477310  17056.450203  7.72731e+06  7.72731e+06     68831.9
# 10  335232.417632  18822.030189  9.51145e+06  9.51145e+06     74948.1
# 11  363835.509558  20774.022043  1.32502e+07  1.32502e+07     90345.3
# 12  381615.967778  22930.506940  1.60642e+07  1.60642e+07     95024.4
# 13  401891.589672  25311.390214  1.99662e+07  1.99662e+07      101657
# 14  271896.007809  14663.432496  2.75651e+06  2.75651e+06     51560.2
# 15  295304.264085  16670.534178  3.04157e+06  3.04157e+06       57023
# 16  316263.588214  18759.786242  3.32757e+06  3.32757e+06     61450.3
# 17  332530.614575  21114.585596  3.33555e+06  3.33555e+06     61436.2
# 18  353086.995025  23767.099504  3.47814e+06  3.47814e+06     63980.3
# 19  376488.381275  26753.406090  3.68027e+06  3.68027e+06       67764
# 20  395126.427847  21684.475202  4.54042e+06  4.54042e+06     67467.8
#
#    Nwtr_atyrau  ... Dcon_atyrau Dmin_atyrau  Dret_atyrau  Dagr_atyrau  \
# 0      9807.11  ...   98.697837   98.717323   106.203021   106.485351
# 1      11159.9  ...  103.843697  103.786178   106.203021   106.485351
# 2      11963.3  ...  100.000000  100.000000   106.203021   106.485351
# 3      12689.4  ...  100.000000  100.000000   105.169184   105.404459
# 4      13400.9  ...  100.000000  100.000000   105.169184   105.404459
# 5      14018.4  ...  100.000000  100.000000   105.169184   105.404459
# 6      14773.3  ...  100.000000  100.000000   105.169184   105.404459
# 7      9807.11  ...   96.307587   96.362842   106.203021   106.485351
# 8      11310.9  ...  121.991419  121.662324   105.810163   106.074612
# 9        12088  ...  100.000000  100.000000   105.810163   106.074612
# 10     12890.5  ...  100.000000  100.000000   104.776326   104.993720
# 11     14384.1  ...  100.000000  100.000000   104.776326   104.993720
# 12     15112.7  ...  100.000000  100.000000   104.776326   104.993720
# 13     15993.7  ...  100.000000  100.000000   104.776326   104.993720
# 14     10040.7  ...   72.619345   73.029088   107.795129   108.149924
# 15     10962.3  ...  100.000000  100.000000   107.795129   108.149924
# 16     11768.6  ...  100.000000  100.000000   106.761292   107.069033
# 17     12244.7  ...  100.000000  100.000000   106.761292   107.069033
# 18     12956.7  ...  100.000000  100.000000   106.761292   107.069033
# 19     13807.8  ...  100.000000  100.000000   106.761292   107.069033
# 20       14296  ...  113.507829  113.305689   106.203021   106.485351
#
#     Dtrd_atyrau  Dsrv_atyrau  Delc_atyrau Dwtr_atyrau Dind_atyrau Dwhl_atyrau
# 0       105.151      105.151   105.714538  106.149084     99.2917     105.065
# 1       121.761      121.761   105.714538  106.149084     117.102     122.953
# 2       111.493      111.493   105.714538  106.149084     106.037      111.84
# 3       111.347      111.347   104.762115  105.124237     106.884     111.728
# 4       111.389      111.389   104.762115  105.124237     106.905     111.749
# 5       110.554      110.554   104.762115  105.124237     106.009     110.849
# 6       111.319      111.319   104.762115  105.124237     106.794     111.638
# 7       103.063      103.063   105.714538  106.149084     97.0433     102.807
# 8       162.523      162.523   105.352617  105.759642     160.843     166.887
# 9       118.895      118.895   105.352617  105.759642     113.691     119.528
# 10      119.874      119.874   104.400194  104.734795     115.626     120.509
# 11      126.251      126.251   104.400194  104.734795     122.075     126.986
# 12      120.867      120.867   104.400194  104.734795     116.435     121.321
# 13      122.466      122.466   104.400194  104.734795         118     122.893
# 14      82.4942      82.4942   107.181270  107.727349     74.7631     80.4284
# 15      108.087      108.087   107.181270  107.727349     102.332     108.119
# 16      108.459      108.459   106.228847  106.702502     102.852      108.64
# 17      104.629      104.629   106.228847  106.702502     99.5859     104.398
# 18       105.86       105.86   106.228847  106.702502     100.942     105.759
# 19      106.177      106.177   106.228847  106.702502     101.292     106.111
# 20      127.514      127.514   105.714538  106.149084     125.076         130
#
# [21 rows x 34 columns]

# %%
newdf.to_sql('vrp_prognoz_atyrau', engine, schema='public',if_exists='replace', index = True)
