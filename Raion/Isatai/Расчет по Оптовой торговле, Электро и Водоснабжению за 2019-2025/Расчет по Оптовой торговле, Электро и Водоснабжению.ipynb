# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv = pd.read_sql('SELECT * FROM vrp_ekz_fact ORDER BY id',engine)
csv_p = pd.read_sql('SELECT * FROM vrp_ekz_prog ORDER BY id',engine)


lret_csv = pd.read_sql("SELECT * FROM lret_prog_isatai ORDER BY index",engine)
lwhl_csv = pd.read_sql("SELECT * FROM lwhl_prog_isatai ORDER BY index",engine)
lagr_csv = pd.read_sql("SELECT * FROM lagr_prog_isatai ORDER BY index",engine)
lmin_csv = pd.read_sql("SELECT * FROM lmin_prog_isatai ORDER BY index",engine)
lcon_csv = pd.read_sql("SELECT * FROM lcon_prog_isatai ORDER BY index",engine)
ltrd_csv = pd.read_sql("SELECT * FROM ltrd_fact_isatai ORDER BY index",engine)
man_csv =  pd.read_sql("SELECT * FROM lman_nman_prog_isatai ORDER BY index",engine)
Ncon_csv = pd.read_sql("SELECT * FROM ncon_prog_isatai ORDER BY index",engine)
Ntrd_csv = pd.read_sql("SELECT * FROM ntrd_fact_isatai ORDER BY index",engine)
Nmin_csv = pd.read_sql("SELECT * FROM nmin_prog_isatai ORDER BY index",engine)
Nret_csv = pd.read_sql("SELECT * FROM nret_prog_isatai ORDER BY index",engine)
Nagr_csv = pd.read_sql("SELECT * FROM nagr_prog_isatai ORDER BY index",engine)

Nret_f =   csv['o_prod_retail_isatai']
Nwhl_f =    csv['o_prod_trade_isatai']
Nagr_f =     csv['o_prod_agro_isatai']
Nmin_f =   csv['o_prod_mining_isatai']
Nman_f =      csv['o_prod_man_isatai']
Ncon_f = csv['o_prod_building_isatai']
Nelc_f =   csv['o_prod_energo_isatai']
Nwtr_f =    csv['o_prod_water_isatai']
Nind_f =    csv['o_prod_water_isatai']

lelc_f =    csv['o_ifo_energo_isatai']
lwtr_f =     csv['o_ifo_water_isatai']


Ntrd_f = Ntrd_csv['Ntrd_isatai']
ltrd_f = ltrd_csv['ltrd_isatai']

Nmin_b = Nmin_csv['Nmin_b']
Nmin_o = Nmin_csv['Nmin_o']
Nmin_p = Nmin_csv['Nmin_p']


Nman_b =  man_csv['Nman_b']
Nman_o =  man_csv['Nman_o']
Nman_p =  man_csv['Nman_p']

lman_b =  man_csv['lman_b']
lman_o =  man_csv['lman_o']
lman_p =  man_csv['lman_p']

lret_b = lret_csv['lret_b']
lret_o = lret_csv['lret_o']
lret_p = lret_csv['lret_p']

lwhl_b = lwhl_csv['lwhl_b']
lwhl_o = lwhl_csv['lwhl_o']
lwhl_p = lwhl_csv['lwhl_p']

lagr_b = lagr_csv['lagr_b']
lagr_o = lagr_csv['lagr_o']
lagr_p = lagr_csv['lagr_p']

lmin_b = lmin_csv['lmin_b']
lmin_o = lmin_csv['lmin_o']
lmin_p = lmin_csv['lmin_p']

lcon_b = lcon_csv['lcon_b']
lcon_o = lcon_csv['lcon_o']
lcon_p = lcon_csv['lcon_p']

Ncon_b = Ncon_csv['Ncon_b']
Ncon_o = Ncon_csv['Ncon_o']
Ncon_p = Ncon_csv['Ncon_p']

Nret_b = Nret_csv['Nret_b']
Nret_o = Nret_csv['Nret_o']
Nret_p = Nret_csv['Nret_p']

Nagr_b = Nagr_csv['Nagr_b']
Nagr_o = Nagr_csv['Nagr_o']
Nagr_p = Nagr_csv['Nagr_p']

inf = csv_p['o_inflation']

ltrd_b = (lret_b[0]*Nret_f[18] + lwhl_b[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_b = (lagr_b[0]*Nagr_f[18] + lmin_b[0]*Nmin_f[18] + lman_b[0]*Nman_f[18] + lcon_b[0]*Ncon_f[18] + ltrd_b * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_b= (100*((lammct_b-100)* 1.7392975437150846 +100 ))/100
K_b= (100*((lammct_b-100)* 1.284434216402586  +100))/100
lelc_b= S_b/100 * 100
lwtr_b= K_b/100 * 100

Delc = inf * 0.45027373242169055 + 100
Dwtr = inf * 0.6785394105107511  + 100

Delc_b = Delc.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True)
Dwtr_b = Dwtr.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True)
Delc_o = Delc.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Dwtr_o = Dwtr.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Delc_p = Delc.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True)
Dwtr_p = Dwtr.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True)


Nelc_b = (Nelc_f[18]*lelc_b*Delc_b[0])/10000
Nwtr_b = (Nwtr_f[18]*lwtr_b*Dwtr_b[0])/10000
Nind_b = Nmin_b[0]+Nman_b[0]+Nelc_b+Nwtr_b
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_b = ((lmin_b[0]*Nmin_f[18])+(lman_b[0]*Nman_f[18])+(lelc_b*Nelc_f[18])+(lwtr_b*Nwtr_f[18]))/ Nind_f[18]
Nind_b = Nmin_b[0]+Nman_b[0]+Nelc_b+Nwtr_b
Dind_b= (Nind_b/Nind_f[18]/lind_b)*10000
Dwhl_b = inf[0] + 100
Nwhl_b = (Nwhl_f[18]*lwhl_b[0]*Dwhl_b)/10000
Ntrd_b = Nret_b[0]+Nwhl_b
Dtrd_b = Ntrd_b/(Nret_f[18] + Nwhl_f[18])/ltrd_b *10000


ltrd_o = (lret_o[0]*Nret_f[18] + lwhl_o[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_o = (lagr_o[0]*Nagr_f[18] + lmin_o[0]*Nmin_f[18] + lman_o[0]*Nman_f[18] + lcon_o[0]*Ncon_f[18] + ltrd_o * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_o= (100*((lammct_o-100)* 1.7392975437150846 +100))/100
K_o= (100*((lammct_o-100)* 1.284434216402586  +100))/100
lelc_o= S_o/100 * 100
lwtr_o= K_o/100 * 100

Nelc_o = (Nelc_f[18]*lelc_o*Delc_o[0])/10000
Nwtr_o = (Nwtr_f[18]*lwtr_o*Dwtr_o[0])/10000
Nind_o = Nmin_o[0]+Nman_o[0]+Nelc_o+Nwtr_o
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_o = ((lmin_o[0]*Nmin_f[18])+(lman_o[0]*Nman_f[18])+(lelc_o*Nelc_f[18])+(lwtr_o*Nwtr_f[18]))/ Nind_f[18]
Nind_o = Nmin_o[0]+Nman_o[0]+Nelc_o+Nwtr_o
Dind_o= (Nind_o/Nind_f[18]/lind_o)*10000
Dwhl_o = inf[0] +100
Nwhl_o = (Nwhl_f[18]*lwhl_o[0]*Dwhl_o)/10000
Ntrd_o = Nret_o[0]+Nwhl_o
Dtrd_o = Ntrd_o/(Nret_f[18] + Nwhl_f[18])/ltrd_o *10000


ltrd_p = (lret_p[0]*Nret_f[18] + lwhl_p[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_p = (lagr_p[0]*Nagr_f[18] + lmin_p[0]*Nmin_f[18] + lman_p[0]*Nman_f[18] + lcon_p[0]*Ncon_f[18] + ltrd_p * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_p= (100*((lammct_p-100)* 1.7392975437150846 +100))/100
K_p= (100*((lammct_p-100)* 1.284434216402586  +100))/100
lelc_p= S_p/100 * 100
lwtr_p= K_p/100 * 100
Nelc_p = (Nelc_f[18]*lelc_p*Delc_p[0])/10000
Nwtr_p = (Nwtr_f[18]*lwtr_p*Dwtr_p[0])/10000
Nind_p = Nmin_p[0]+Nman_p[0]+Nelc_p+Nwtr_p
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_p = ((lmin_p[0]*Nmin_f[18])+(lman_p[0]*Nman_f[18])+(lelc_p*Nelc_f[18])+(lwtr_p*Nwtr_f[18]))/ Nind_f[18]
Nind_p = Nmin_p[0]+Nman_p[0]+Nelc_p+Nwtr_p
Dind_p= (Nind_p/Nind_f[18]/lind_p)*10000
Dwhl_p = inf[0] +100
Nwhl_p = (Nwhl_f[18]*lwhl_p[0]*Dwhl_p)/10000
Ntrd_p = Nret_p[0]+Nwhl_p
Dtrd_p = Ntrd_p/(Nret_f[18] + Nwhl_f[18])/ltrd_p *10000

ltrd_bb = ltrd_b
lelc_bb = lelc_b
lwtr_bb = lwtr_b
lind_bb = lind_b
Ntrd_bb = Ntrd_b
Nelc_bb = Nelc_b
Nwtr_bb = Nwtr_b
Nind_bb = Nind_b
Nwhl_bb = Nwhl_b
Dtrd_bb = Dtrd_b
Dwhl_bb = Dwhl_b
Dind_bb = Dind_b

ltrd_oo = ltrd_o
lelc_oo = lelc_o
lwtr_oo = lwtr_o
lind_oo = lind_o
Ntrd_oo = Ntrd_o
Nelc_oo = Nelc_o
Nwtr_oo = Nwtr_o
Nind_oo = Nind_o
Nwhl_oo = Nwhl_o
Dtrd_oo = Dtrd_o
Dwhl_oo = Dwhl_o
Dind_oo = Dind_o

ltrd_pp = ltrd_p
lelc_pp = lelc_p
lwtr_pp = lwtr_p
lind_pp = lind_p
Ntrd_pp = Ntrd_p
Nelc_pp = Nelc_p
Nwtr_pp = Nwtr_p
Nind_pp = Nind_p
Nwhl_pp = Nwhl_p
Dtrd_pp = Dtrd_p
Dwhl_pp = Dwhl_p
Dind_pp = Dind_p

# %%
ltrd_b = ltrd_bb
lelc_b = lelc_bb
lwtr_b = lwtr_bb
lind_b = lind_bb
Ntrd_b = Ntrd_bb
Nelc_b = Nelc_bb
Nwtr_b = Nwtr_bb
Nind_b = Nind_bb
Nwhl_b = Nwhl_bb
Dtrd_b = Dtrd_bb
Dwhl_b = Dwhl_bb
Dind_b = Dind_bb

i = 0

newdf_1 = pd.DataFrame(columns=['ltrd_b',
                              'lelc_b',
                              'lwtr_b',
                              'lind_b',
                              'Ntrd_b',
                              'Nelc_b',
                              'Nwtr_b',
                              'Nind_b',
                              'Nwhl_b',
                              'Dtrd_b',
                              'Delc_b',
                              'Dwtr_b',
                              'Dwhl_b',
                              'Dind_b',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True))-2:
    
    Nind_b_p = Nmin_b[i]+Nman_b[i]+Nelc_b+Nwtr_b
    ltrd_b = (lret_b[i+1]*Nret_b[i] + lwhl_b[i+1]*Nwhl_b)/Ntrd_b
    
    lammct_b = (lagr_b[i+1]*Nagr_b[i] + lmin_b[i+1]*Nmin_b[i] + lman_b[i+1]*Nman_b[i] + lcon_b[i+1]*Ncon_b[i] + ltrd_b * Ntrd_b)/(Nagr_b[i]+Nmin_b[i]+Nman_b[i]+Ncon_b[i]+Ntrd_b) 
    
    
    
    S_b= (100*((lammct_b-100)*  1.7392975437150846 +100))/100
    K_b = (100*((lammct_b-100)* 1.284434216402586  +100))/100
    
    lelc_b= S_b/100 * 100
    lwtr_b= K_b/100 * 100
    
    Nelc_b = (Nelc_b*lelc_b*Delc_b[i+1])/10000
    Nwtr_b = (Nwtr_b*lwtr_b*Dwtr_b[i+1])/10000
    Nind_b = Nmin_b[i+1]+Nman_b[i+1]+Nelc_b+Nwtr_b
    lind_b = ((lmin_b[i+1]*Nmin_b[i])+(lman_b[i+1]*Nman_b[0])+(lelc_b*Nelc_b)+(lwtr_b*Nwtr_b))/ Nind_b
    Nind_b = Nmin_b[i+1]+Nman_b[i+1]+Nelc_b+Nwtr_b    
    Dind_b= (Nind_b/Nind_b_p/lind_b)*10000
    Dwhl_b = inf[i+1]+100
    
    Ntrd_b_p = Nret_b[i]+Nwhl_b
    Nwhl_b = (Nwhl_b*lwhl_b[i+1]*Dwhl_b)/10000
    Ntrd_b = Nret_b[i+1]+Nwhl_b   
    
    Dtrd_b = Ntrd_b/Ntrd_b_p/ltrd_b*10000
    
    i = i+1
    newdf_1.loc[i].ltrd_b = ltrd_b
    newdf_1.loc[i].lelc_b = lelc_b
    newdf_1.loc[i].lwtr_b = lwtr_b
    newdf_1.loc[i].lind_b = lind_b
    newdf_1.loc[i].Ntrd_b = Ntrd_b
    newdf_1.loc[i].Nelc_b = Nelc_b
    newdf_1.loc[i].Nwtr_b = Nwtr_b
    newdf_1.loc[i].Nind_b = Nind_b
    newdf_1.loc[i].Nwhl_b = Nwhl_b
    
    newdf_1.loc[i].Dtrd_b = Dtrd_b     
    newdf_1.loc[i].Dwhl_b = Dwhl_b
    newdf_1.loc[i].Dind_b = Dind_b
    newdf_1.loc[i].prognoz = "базовый"

newdf_1.loc[0].prognoz = "базовый"
    
newdf_1.loc[0].ltrd_b = ltrd_bb
newdf_1.loc[0].lelc_b = lelc_bb
newdf_1.loc[0].lwtr_b = lwtr_bb
newdf_1.loc[0].lind_b = lind_bb
newdf_1.loc[0].Ntrd_b = Ntrd_bb
newdf_1.loc[0].Nelc_b = Nelc_bb
newdf_1.loc[0].Nwtr_b = Nwtr_bb
newdf_1.loc[0].Nind_b = Nind_bb
newdf_1.loc[0].Nwhl_b = Nwhl_bb
newdf_1.loc[0].Dtrd_b = Dtrd_bb
newdf_1.loc[0].Dwhl_b = Dwhl_bb
newdf_1.loc[0].Dind_b = Dind_bb

newdf_1.Delc_b = Delc_b 
newdf_1.Dwtr_b = Dwtr_b

lind_b = newdf_1['lind_b']
lelc_b = newdf_1['lelc_b']
lwtr_b = newdf_1['lwtr_b']
ltrd_b = newdf_1['ltrd_b']

Nind_b = newdf_1['Nind_b']
Nelc_b = newdf_1['Nelc_b']
Nwtr_b = newdf_1['Nwtr_b']
Ntrd_b = newdf_1['Ntrd_b']
Nwhl_b = newdf_1['Nwhl_b']

newdf_1
# Out:
#      ltrd_b   lelc_b   lwtr_b   lind_b   Ntrd_b   Nelc_b   Nwtr_b   Nind_b  \
# 0   96.5633   89.119  91.9646  96.1093  5100.45  6.40686  158.876    44326
# 1   97.1765  94.6718  96.0653  96.2401  5282.04  6.22936  158.839  44483.6
# 2   99.7444  99.5516  99.6688  100.093  5614.66  6.36897  164.758  44261.8
# 3   96.3155  92.7925  94.6774  100.086  5702.91  6.04298  161.281  42251.3
# 4   100.418  100.784  100.579  100.338  6039.49   6.2275  167.719  42141.3
# 5    99.658  99.3798   99.542  100.315  6347.49  6.32821  172.615    41936
# 6   102.089  104.197  103.099   100.37  6834.74  6.74223  184.002  42685.8
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nwhl_b   Dtrd_b      Delc_b      Dwtr_b Dwhl_b   Dind_b  prognoz
# 0   1829.68  106.584  102.701642  104.071236    106  98.6954  базовый
# 1   1977.99  106.569  102.701642  104.071236    106  104.276  базовый
# 2   2100.61   106.57  102.701642  104.071236    106  99.4093  базовый
# 3   2265.27  105.457  102.251369  103.392697    105  95.3757  базовый
# 4   2370.73  105.461  102.251369  103.392697    105   99.404  базовый
# 5   2495.85   105.46  102.251369  103.392697    105  99.2007  базовый
# 6   2578.23  105.473  102.251369  103.392697    105  101.413  базовый
# 7       NaN      NaN         NaN         NaN    NaN      NaN      NaN
# 8       NaN      NaN         NaN         NaN    NaN      NaN      NaN
# 9       NaN      NaN         NaN         NaN    NaN      NaN      NaN
# 10      NaN      NaN         NaN         NaN    NaN      NaN      NaN
# 11      NaN      NaN         NaN         NaN    NaN      NaN      NaN

# %%
ltrd_o = ltrd_oo
lelc_o = lelc_oo
lwtr_o = lwtr_oo
lind_o = lind_oo
Ntrd_o = Ntrd_oo
Nelc_o = Nelc_oo
Nwtr_o = Nwtr_oo
Nind_o = Nind_oo
Nwhl_o = Nwhl_oo
Dtrd_o = Dtrd_oo
Dwhl_o = Dwhl_oo
Dind_o = Dind_oo

i = 0

newdf_2 = pd.DataFrame(columns=['ltrd_o',
                              'lelc_o',
                              'lwtr_o',
                              'lind_o',
                              'Ntrd_o',
                              'Nelc_o',
                              'Nwtr_o',
                              'Nind_o',
                              'Nwhl_o',
                              'Dtrd_o',
                              'Delc_o',
                              'Dwtr_o',
                              'Dwhl_o',
                              'Dind_o',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True))-2:
    Nind_o_p = Nmin_o[i] + Nman_o[i] + Nelc_o + Nwtr_o
    ltrd_o =  (lret_o[i+1]*Nret_o[i] + lwhl_o[i+1]*Nwhl_o)/Ntrd_o
    
    lammct_o = (lagr_o[i+1]*Nagr_o[i] + lmin_o[i+1]*Nmin_o[i] + lman_o[i+1]*Nman_o[i] + lcon_o[i+1]*Ncon_o[i] + ltrd_o * Ntrd_o)/(Nagr_o[i]+Nmin_o[i]+Nman_o[i]+Ncon_o[i]+Ntrd_o) 
    
    
    
    S_o=  (100*((lammct_o-100)* 1.7392975437150846 +100))/100
    K_o = (100*((lammct_o-100)* 1.284434216402586  +100))/100
    
    lelc_o= S_o/100 * 100
    lwtr_o= K_o/100 * 100
    
    Nelc_o = (Nelc_o*lelc_o*Delc_o[i+1])/10000
    Nwtr_o = (Nwtr_o*lwtr_o*Dwtr_o[i+1])/10000
    Nind_o =   Nmin_o[i+1]+Nman_o[i+1]+Nelc_o+Nwtr_o
    lind_o = ((lmin_o[i+1]*Nmin_o[i])+(lman_o[i+1]*Nman_o[0])+(lelc_o*Nelc_o)+(lwtr_o*Nwtr_o))/ Nind_o
    Nind_o =   Nmin_o[i+1]+Nman_o[i+1]+Nelc_o+Nwtr_o    
    Dind_o=   (Nind_o/Nind_o_p/lind_o)*10000
    Dwhl_o = inf[i+1]+100
    
    Ntrd_o_p = Nret_o[i]+Nwhl_o
    Nwhl_o = (Nwhl_o*lwhl_o[i+1]*Dwhl_o)/10000
    Ntrd_o = Nret_o[i+1]+Nwhl_o   
    
    Dtrd_o = Ntrd_o/Ntrd_o_p/ltrd_o*10000
    
    i = i+1
    newdf_2.loc[i].ltrd_o = ltrd_o
    newdf_2.loc[i].lelc_o = lelc_o
    newdf_2.loc[i].lwtr_o = lwtr_o
    newdf_2.loc[i].lind_o = lind_o
    newdf_2.loc[i].Ntrd_o = Ntrd_o
    newdf_2.loc[i].Nelc_o = Nelc_o
    newdf_2.loc[i].Nwtr_o = Nwtr_o
    newdf_2.loc[i].Nind_o = Nind_o
    newdf_2.loc[i].Nwhl_o = Nwhl_o
    
    newdf_2.loc[i].Dtrd_o = Dtrd_o     
    newdf_2.loc[i].Dwhl_o = Dwhl_o
    newdf_2.loc[i].Dind_o = Dind_o
    newdf_2.loc[i].prognoz = "оптимистичный"
    
newdf_2.loc[0].prognoz = "оптимистичный"
    
newdf_2.loc[0].ltrd_o = ltrd_oo
newdf_2.loc[0].lelc_o = lelc_oo
newdf_2.loc[0].lwtr_o = lwtr_oo
newdf_2.loc[0].lind_o = lind_oo
newdf_2.loc[0].Ntrd_o = Ntrd_oo
newdf_2.loc[0].Nelc_o = Nelc_oo
newdf_2.loc[0].Nwtr_o = Nwtr_oo
newdf_2.loc[0].Nind_o = Nind_oo
newdf_2.loc[0].Nwhl_o = Nwhl_oo
newdf_2.loc[0].Dtrd_o = Dtrd_oo
newdf_2.loc[0].Dwhl_o = Dwhl_oo
newdf_2.loc[0].Dind_o = Dind_oo
    
newdf_2.Delc_o = Delc_o 
newdf_2.Dwtr_o = Dwtr_o

lind_o = newdf_2['lind_o']
lelc_o = newdf_2['lelc_o']
lwtr_o = newdf_2['lwtr_o']
ltrd_o = newdf_2['ltrd_o']

Nind_o = newdf_2['Nind_o']
Nelc_o = newdf_2['Nelc_o']
Nwtr_o = newdf_2['Nwtr_o']
Ntrd_o = newdf_2['Ntrd_o']
Nwhl_o = newdf_2['Nwhl_o']

newdf_2
# Out:
#      ltrd_o   lelc_o   lwtr_o   lind_o   Ntrd_o   Nelc_o   Nwtr_o   Nind_o  \
# 0   96.5633   89.119  91.9646  96.1093  5100.45  6.40686  158.876  43238.8
# 1   101.976  104.019  102.968  81.8008  5529.48  6.83298   169.83  53920.5
# 2   99.6176   99.575  99.6862  99.5465   5855.9  6.97612  175.753  53612.8
# 3   96.9036  94.5326  95.9624  99.5737  5969.94  6.73189  173.944  51750.7
# 4   107.451  114.604  110.785  99.7275  6749.55  7.87551  198.744    55851
# 5   99.7941  99.9539   99.966  99.3675  7087.18  8.03564  204.905  55715.6
# 6   103.123  105.655  104.176  99.3388  7690.38   8.6667  220.154  57129.8
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nwhl_o   Dtrd_o      Delc_o      Dwtr_o Dwhl_o   Dind_o        prognoz
# 0   1829.68  106.584  102.701642  104.071236    106  96.2747  оптимистичный
# 1   1912.49   106.31  102.530538  103.813391    106  152.448  оптимистичный
# 2   2032.51   106.31  102.530538  103.813391    106  99.8824  оптимистичный
# 3   2179.24  105.205  102.080265  103.134852    105  96.9401  оптимистичный
# 4   2166.19  105.219  102.080265  103.134852    105  108.218  оптимистичный
# 5   2277.49  105.219  102.080265  103.134852    105  100.393  оптимистичный
# 6   2343.55  105.224  102.080265  103.134852    105  103.221  оптимистичный
# 7       NaN      NaN         NaN         NaN    NaN      NaN            NaN
# 8       NaN      NaN         NaN         NaN    NaN      NaN            NaN
# 9       NaN      NaN         NaN         NaN    NaN      NaN            NaN
# 10      NaN      NaN         NaN         NaN    NaN      NaN            NaN
# 11      NaN      NaN         NaN         NaN    NaN      NaN            NaN

# %%
ltrd_p = ltrd_pp
lelc_p = lelc_pp
lwtr_p = lwtr_pp
lind_p = lind_pp
Ntrd_p = Ntrd_pp
Nelc_p = Nelc_pp
Nwtr_p = Nwtr_pp
Nind_p = Nind_pp
Nwhl_p = Nwhl_pp
Dtrd_p = Dtrd_pp
Dwhl_p = Dwhl_pp
Dind_p = Dind_pp

i = 0

newdf_3 = pd.DataFrame(columns=['ltrd_p',
                              'lelc_p',
                              'lwtr_p',
                              'lind_p',
                              'Ntrd_p',
                              'Nelc_p',
                              'Nwtr_p',
                              'Nind_p',
                              'Nwhl_p',
                              'Dtrd_p',
                              'Delc_p',
                              'Dwtr_p',
                              'Dwhl_p',
                              'Dind_p',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True))-2:
    Nind_p_p = Nmin_p[i] + Nman_p[i] + Nelc_p + Nwtr_p
    ltrd_p =  (lret_p[i+1]*Nret_p[i] + lwhl_p[i+1]*Nwhl_p)/Ntrd_p
    
    lammct_p = (lagr_p[i+1]*Nagr_p[i] + lmin_p[i+1]*Nmin_p[i] + lman_p[i+1]*Nman_p[i] + lcon_p[i+1]*Ncon_p[i] + ltrd_p * Ntrd_p)/(Nagr_p[i]+Nmin_p[i]+Nman_p[i]+Ncon_p[i]+Ntrd_p) 
    
    
    
    S_p=  (100*((lammct_p-100)* 1.7392975437150846 +100))/100
    K_p = (100*((lammct_p-100)* 1.284434216402586  +100))/100
    
    lelc_p= S_p/100 * 100
    lwtr_p= K_p/100 * 100
    
    Nelc_p = (Nelc_p*lelc_p*Delc_p[i+1])/10000
    Nwtr_p = (Nwtr_p*lwtr_p*Dwtr_p[i+1])/10000
    Nind_p =   Nmin_p[i+1]+Nman_p[i+1]+Nelc_p+Nwtr_p
    lind_p = ((lmin_p[i+1]*Nmin_p[i])+(lman_p[i+1]*Nman_p[0])+(lelc_p*Nelc_p)+(lwtr_p*Nwtr_p))/ Nind_p
    Nind_p =   Nmin_p[i+1]+Nman_p[i+1]+Nelc_p+Nwtr_p    
    Dind_p=   (Nind_p/Nind_p_p/lind_p)*10000
    Dwhl_p = inf[i+1]+100
    
    Ntrd_p_p = Nret_p[i]+Nwhl_p
    Nwhl_p = (Nwhl_p*lwhl_p[i+1]*Dwhl_p)/10000
    Ntrd_p = Nret_p[i+1]+Nwhl_p
    
    Dtrd_p = Ntrd_p/Ntrd_p_p/ltrd_p*10000
    
    i = i+1
    newdf_3.loc[i].ltrd_p = ltrd_p
    newdf_3.loc[i].lelc_p = lelc_p
    newdf_3.loc[i].lwtr_p = lwtr_p
    newdf_3.loc[i].lind_p = lind_p
    newdf_3.loc[i].Ntrd_p = Ntrd_p
    newdf_3.loc[i].Nelc_p = Nelc_p
    newdf_3.loc[i].Nwtr_p = Nwtr_p
    newdf_3.loc[i].Nind_p = Nind_p
    newdf_3.loc[i].Nwhl_p = Nwhl_p
    
    newdf_3.loc[i].Dtrd_p = Dtrd_p     
    newdf_3.loc[i].Dwhl_p = Dwhl_p
    newdf_3.loc[i].Dind_p = Dind_p
    newdf_3.loc[i].prognoz = "пессимистичный"
    
newdf_3.loc[0].prognoz = "пессимистичный"    
    
newdf_3.loc[0].ltrd_p = ltrd_pp
newdf_3.loc[0].lelc_p = lelc_pp
newdf_3.loc[0].lwtr_p = lwtr_pp
newdf_3.loc[0].lind_p = lind_pp
newdf_3.loc[0].Ntrd_p = Ntrd_pp
newdf_3.loc[0].Nelc_p = Nelc_pp
newdf_3.loc[0].Nwtr_p = Nwtr_pp
newdf_3.loc[0].Nind_p = Nind_pp
newdf_3.loc[0].Nwhl_p = Nwhl_pp
newdf_3.loc[0].Dtrd_p = Dtrd_pp
newdf_3.loc[0].Dwhl_p = Dwhl_pp
newdf_3.loc[0].Dind_p = Dind_pp

newdf_3.Delc_p = Delc_p 
newdf_3.Dwtr_p = Dwtr_p

lind_p = newdf_3['lind_p']
lelc_p = newdf_3['lelc_p']
lwtr_p = newdf_3['lwtr_p']
ltrd_p = newdf_3['ltrd_p']

Nind_p = newdf_3['Nind_p']
Nelc_p = newdf_3['Nelc_p']
Nwtr_p = newdf_3['Nwtr_p']
Ntrd_p = newdf_3['Ntrd_p']
Nwhl_p = newdf_3['Nwhl_p']

newdf_3
# Out:
#      ltrd_p   lelc_p   lwtr_p   lind_p   Ntrd_p   Nelc_p   Nwtr_p   Nind_p  \
# 0   96.5633  77.1659  83.1375  88.6949  5154.73    5.585  145.069  29964.9
# 1    99.837  99.6488  99.7406  99.9986  5544.18  5.75433  152.095  29824.5
# 2   95.9016  92.4227  94.4043  100.006  5686.96  5.47492  149.956    28314
# 3   97.3669   94.709  96.0927  100.193  5899.78  5.33794  150.492  27017.5
# 4   99.5963  99.1951  99.4056   100.35  6261.14   5.4509  156.236  26849.5
# 5    102.04  103.771  102.785  100.419  6810.75  5.82302  167.713  27204.9
# 6   114.703  127.692   120.45  88.4422  8309.93  7.63644  210.235  37258.8
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nwhl_p   Dtrd_p      Delc_p      Dwtr_p Dwhl_p   Dind_p         prognoz
# 0   1829.68  107.718  103.395064  105.116187    106  72.2966  пессимистичный
# 1   1941.66  107.731  103.395064  105.116187    106   99.533  пессимистичный
# 2   2116.21  106.959  102.944790  104.437648    106  94.9296  пессимистичный
# 3   2264.71  106.548  102.944790  104.437648    105  95.2371  пессимистичный
# 4   2385.18  106.555  102.944790  104.437648    105  99.0315  пессимистичный
# 5   2466.23  106.603  102.944790  104.437648    105  100.901  пессимистичный
# 6   2319.19  106.372  102.701642  104.071236    105  154.854  пессимистичный
# 7       NaN      NaN         NaN         NaN    NaN      NaN             NaN
# 8       NaN      NaN         NaN         NaN    NaN      NaN             NaN
# 9       NaN      NaN         NaN         NaN    NaN      NaN             NaN
# 10      NaN      NaN         NaN         NaN    NaN      NaN             NaN
# 11      NaN      NaN         NaN         NaN    NaN      NaN             NaN

# %%
csv_Dman_isatai  = pd.read_sql('SELECT * FROM dman_prog_isatai ORDER BY index',engine)
csv_Dcon_isatai  = pd.read_sql('SELECT * FROM dcon_prog_isatai ORDER BY index',engine)
csv_Dmin_isatai  = pd.read_sql('SELECT * FROM dmin_prog_isatai ORDER BY index',engine)
csv_Dret_isatai  = pd.read_sql('SELECT * FROM dret_prog_isatai ORDER BY index',engine)
csv_Dagr_isatai  = pd.read_sql('SELECT * FROM dagr_prog_isatai ORDER BY index',engine)

Dman = csv_Dman_isatai.rename({'0': 'Dman_isatai'}, axis='columns')
Dman = Dman['Dman_isatai']

Dcon_b = csv_Dcon_isatai['Dcon_b']
Dcon_o = csv_Dcon_isatai['Dcon_o']
Dcon_p = csv_Dcon_isatai['Dcon_p']
Dcon = Dcon_b.append(Dcon_o).append(Dcon_p).dropna().reset_index(drop = True)

Dmin_b = csv_Dmin_isatai['Dmin_b']
Dmin_o = csv_Dmin_isatai['Dmin_o']
Dmin_p = csv_Dmin_isatai['Dmin_p']
Dmin = Dmin_b.append(Dmin_o).append(Dmin_p).dropna().reset_index(drop = True)

Dret_b = csv_Dret_isatai['Dret_b']
Dret_o = csv_Dret_isatai['Dret_o']
Dret_p = csv_Dret_isatai['Dret_p']
Dret = Dret_b.append(Dret_o).append(Dret_p).dropna().reset_index(drop = True)

Dagr_b = csv_Dagr_isatai['Dagr_b']
Dagr_o = csv_Dagr_isatai['Dagr_o']
Dagr_p = csv_Dagr_isatai['Dagr_p']
Dagr = Dagr_b.append(Dagr_o).append(Dagr_p).dropna().reset_index(drop = True)
                    

prognoz = newdf_1['prognoz'].append(newdf_2['prognoz']).append(newdf_3['prognoz']).dropna().reset_index(drop = True)

ltrd = newdf_1['ltrd_b'].append(newdf_2['ltrd_o']).append(newdf_3['ltrd_p']).dropna().reset_index(drop = True)

lelc = newdf_1['lelc_b'].append(newdf_2['lelc_o']).append(newdf_3['lelc_p']).dropna().reset_index(drop = True)
lwtr = newdf_1['lwtr_b'].append(newdf_2['lwtr_o']).append(newdf_3['lwtr_p']).dropna().reset_index(drop = True)
lind = newdf_1['lind_b'].append(newdf_2['lind_o']).append(newdf_3['lind_p']).dropna().reset_index(drop = True)
Ntrd = newdf_1['Ntrd_b'].append(newdf_2['Ntrd_o']).append(newdf_3['Ntrd_p']).dropna().reset_index(drop = True)
Nelc = newdf_1['Nelc_b'].append(newdf_2['Nelc_o']).append(newdf_3['Nelc_p']).dropna().reset_index(drop = True)
Nwtr = newdf_1['Nwtr_b'].append(newdf_2['Nwtr_o']).append(newdf_3['Nwtr_p']).dropna().reset_index(drop = True)
Nind = newdf_1['Nind_b'].append(newdf_2['Nind_o']).append(newdf_3['Nind_p']).dropna().reset_index(drop = True)
Nwhl = newdf_1['Nwhl_b'].append(newdf_2['Nwhl_o']).append(newdf_3['Nwhl_p']).dropna().reset_index(drop = True)
Dtrd = newdf_1['Dtrd_b'].append(newdf_2['Dtrd_o']).append(newdf_3['Dtrd_p']).dropna().reset_index(drop = True)
Delc = newdf_1['Delc_b'].append(newdf_2['Delc_o']).append(newdf_3['Delc_p']).dropna().reset_index(drop = True)
Dwtr = newdf_1['Dwtr_b'].append(newdf_2['Dwtr_o']).append(newdf_3['Dwtr_p']).dropna().reset_index(drop = True)
Dwhl = newdf_1['Dwhl_b'].append(newdf_2['Dwhl_o']).append(newdf_3['Dwhl_p']).dropna().reset_index(drop = True)
Dind = newdf_1['Dind_b'].append(newdf_2['Dind_o']).append(newdf_3['Dind_p']).dropna().reset_index(drop = True)

lret = lret_csv['lret_b'].append(lret_csv['lret_o']).append(lret_csv['lret_p']).dropna().reset_index(drop = True)
lwhl = lwhl_csv['lwhl_b'].append(lwhl_csv['lwhl_o']).append(lwhl_csv['lwhl_p']).dropna().reset_index(drop = True)
lagr = lagr_csv['lagr_b'].append(lagr_csv['lagr_o']).append(lagr_csv['lagr_p']).dropna().reset_index(drop = True)
lmin = lmin_csv['lmin_b'].append(lmin_csv['lmin_o']).append(lmin_csv['lmin_p']).dropna().reset_index(drop = True)
lcon = lcon_csv['lcon_b'].append(lcon_csv['lcon_o']).append(lcon_csv['lcon_p']).dropna().reset_index(drop = True)
lman = man_csv['lman_b'].append(man_csv['lman_o']).append(man_csv['lman_p']).dropna().reset_index(drop = True)
Nman = man_csv['Nman_b'].append(man_csv['Nman_o']).append(man_csv['Nman_p']).dropna().reset_index(drop = True)
Ncon = Ncon_csv['Ncon_b'].append(Ncon_csv['Ncon_o']).append(Ncon_csv['Ncon_p']).dropna().reset_index(drop = True)
Nmin = Nmin_csv['Nmin_b'].append(Nmin_csv['Nmin_o']).append(Nmin_csv['Nmin_p']).dropna().reset_index(drop = True)
Nret = Nret_csv['Nret_b'].append(Nret_csv['Nret_o']).append(Nret_csv['Nret_p']).dropna().reset_index(drop = True)
Nagr = Nagr_csv['Nagr_b'].append(Nagr_csv['Nagr_o']).append(Nagr_csv['Nagr_p']).dropna().reset_index(drop = True)

newdf = pd.DataFrame(columns = ['prognoz',
                                'Ntot_isatai',
                                'Nman_isatai',
                                'Ncon_isatai',
                                'Nmin_isatai',
                                'Nret_isatai',
                                'Nagr_isatai',
                                'Ntrd_isatai',
                                'Nsrv_isatai',
                                'Nelc_isatai',
                                'Nwtr_isatai',
                                'Nind_isatai',
                                'Nwhl_isatai',
                                'ltot_isatai',
                                'lman_isatai',
                                'lcon_isatai',
                                'lmin_isatai',
                                'lret_isatai',
                                'lagr_isatai',
                                'ltrd_isatai',
                                'lsrv_isatai',
                                'lelc_isatai',
                                'lwtr_isatai',
                                'lind_isatai',
                                'lwhl_isatai',
                                'Dtot_isatai',
                                'Dman_isatai',
                                'Dcon_isatai',
                                'Dmin_isatai',
                                'Dret_isatai',
                                'Dagr_isatai',
                                'Dtrd_isatai',
                                'Dsrv_isatai',
                                'Delc_isatai',
                                'Dwtr_isatai',
                                'Dind_isatai',
                                'Dwhl_isatai',])
Ntot = Nind+Ntrd
newdf.Ntot_isatai= Ntot
ltot = lind+ltrd
newdf.ltot_isatai= ltot
Dtot = Dind+Dtrd
newdf.Dtot_isatai= Dtot

newdf.lret_isatai= lret
newdf.lwhl_isatai= lwhl
newdf.lagr_isatai= lagr
newdf.lmin_isatai= lmin
newdf.lcon_isatai= lcon
newdf.lman_isatai= lman
newdf.Nman_isatai= Nman
newdf.Ncon_isatai= Ncon
newdf.Nmin_isatai= Nmin
newdf.Nret_isatai= Nret
newdf.Nagr_isatai= Nagr

newdf.ltrd_isatai= ltrd
newdf.lsrv_isatai= ltrd
newdf.lelc_isatai= lelc
newdf.lwtr_isatai= lwtr
newdf.lind_isatai= lind
newdf.Ntrd_isatai= Ntrd
newdf.Nsrv_isatai= Ntrd
newdf.Nelc_isatai= Nelc
newdf.Nwtr_isatai= Nwtr
newdf.Nind_isatai= Nind
newdf.Nwhl_isatai= Nwhl

newdf.Dtrd_isatai= Dtrd
newdf.Dsrv_isatai= Dtrd
newdf.Dsrv_isatai= Dtrd
newdf.Delc_isatai= Delc
newdf.Dwtr_isatai= Dwtr
newdf.Dwhl_isatai= Dwhl
newdf.Dind_isatai= Dind

newdf.Dman_isatai = Dman
newdf.Dcon_isatai = Dcon
newdf.Dmin_isatai = Dmin
newdf.Dret_isatai = Dret
newdf.Dagr_isatai = Dagr

newdf.prognoz = prognoz

newdf
# Out:
#            prognoz Ntot_isatai  Nman_isatai  Ncon_isatai   Nmin_isatai  \
# 0          базовый     49426.4   776.969633  3821.283788  43383.739258
# 1          базовый     49765.6   734.876406  3694.131228  43583.658274
# 2          базовый     49876.4   725.316536  3688.085817  43365.330217
# 3          базовый     47954.2   636.934934  3342.041886  41447.005405
# 4          базовый     48180.8   642.684485  3353.242949  41324.676252
# 5          базовый     48283.5   635.262345  3348.674904  41121.770288
# 6          базовый     49520.5   681.315240  3514.594058  41813.727492
# 7    оптимистичный     48339.2   755.201672  3732.174286  42318.313231
# 8    оптимистичный     59449.9  1000.077604  4854.103242  52743.713452
# 9    оптимистичный     59468.7   990.685881  4923.546782  52439.341056
# 10   оптимистичный     57720.7   896.934620  4669.112852  50673.118148
# 11   оптимистичный     62600.5  1105.945790  5629.198027  54538.435253
# 12   оптимистичный     62802.8  1110.960625  5740.891880  54391.701125
# 13   оптимистичный     64820.1  1209.895023  6210.663754  55691.035082
# 14  пессимистичный     35119.6   416.579643  2116.843051  29397.621863
# 15  пессимистичный     35368.7   404.496101  2095.610646  29262.154346
# 16  пессимистичный       34001   352.392567  1853.327445  27806.184192
# 17  пессимистичный     32917.2   319.971130  1656.942257  26541.649487
# 18  пессимистичный     33110.6   314.572060  1634.208983  26373.215626
# 19  пессимистичный     34015.6   336.316146  1682.932682  26695.002796
# 20  пессимистичный     45568.8   574.675964  2790.308419  36466.284679
#
#     Nret_isatai  Nagr_isatai Ntrd_isatai Nsrv_isatai Nelc_isatai  ...  \
# 0   3270.765881  5801.400825     5100.45     5100.45     6.40686  ...
# 1   3304.041763  6275.294112     5282.04     5282.04     6.22936  ...
# 2   3514.045574  6764.220372     5614.66     5614.66     6.36897  ...
# 3   3437.638415  7184.084279     5702.91     5702.91     6.04298  ...
# 4   3668.758145  7917.746967     6039.49     6039.49      6.2275  ...
# 5   3851.634268  8352.462803     6347.49     6347.49     6.32821  ...
# 6   4256.512315  9211.668752     6834.74     6834.74     6.74223  ...
# 7   3270.765881  5801.400825     5100.45     5100.45     6.40686  ...
# 8   3616.989236  6252.081031     5529.48     5529.48     6.83298  ...
# 9   3823.388926  6714.269573      5855.9      5855.9     6.97612  ...
# 10  3790.696147  7104.395099     5969.94     5969.94     6.73189  ...
# 11  4583.361289  7800.671109     6749.55     6749.55     7.87551  ...
# 12  4809.693837  8198.219856     7087.18     7087.18     8.03564  ...
# 13  5346.823682  9007.784440     7690.38     7690.38      8.6667  ...
# 14  3325.048402  6026.386669     5154.73     5154.73       5.585  ...
# 15  3602.521002  6593.301336     5544.18     5544.18     5.75433  ...
# 16  3570.748759  7108.564600     5686.96     5686.96     5.47492  ...
# 17  3635.069729  7953.118137     5899.78     5899.78     5.33794  ...
# 18  3875.956948  8516.785006     6261.14     6261.14      5.4509  ...
# 19  4344.526650  9535.089320     6810.75     6810.75     5.82302  ...
# 20  5990.736669  9964.357634     8309.93     8309.93     7.63644  ...
#
#    Dcon_isatai Dmin_isatai Dret_isatai Dagr_isatai  Dtrd_isatai  Dsrv_isatai  \
# 0    98.745547   98.679779  106.913086  106.203021      106.584      106.584
# 1   103.702867  103.896999  106.913086  106.203021      106.569      106.569
# 2   100.000000  100.000000  106.913086  106.203021       106.57       106.57
# 3   100.000000  100.000000  105.760905  105.169184      105.457      105.457
# 4   100.000000  100.000000  105.760905  105.169184      105.461      105.461
# 5   100.000000  100.000000  105.760905  105.169184       105.46       105.46
# 6   100.000000  100.000000  105.760905  105.169184      105.473      105.473
# 7    96.442874   96.256382  106.913086  106.203021      106.584      106.584
# 8   121.185668  122.296383  106.475257  105.810163       106.31       106.31
# 9   100.000000  100.000000  106.475257  105.810163       106.31       106.31
# 10  100.000000  100.000000  105.323076  104.776326      105.205      105.205
# 11  100.000000  100.000000  105.323076  104.776326      105.219      105.219
# 12  100.000000  100.000000  105.323076  104.776326      105.219      105.219
# 13  100.000000  100.000000  105.323076  104.776326      105.224      105.224
# 14   73.622554   72.239646  108.687445  107.795129      107.718      107.718
# 15  100.000000  100.000000  108.687445  107.795129      107.731      107.731
# 16  100.000000  100.000000  107.535264  106.761292      106.959      106.959
# 17  100.000000  100.000000  107.535264  106.761292      106.548      106.548
# 18  100.000000  100.000000  107.535264  106.761292      106.555      106.555
# 19  100.000000  100.000000  107.535264  106.761292      106.603      106.603
# 20  113.012911  113.695148  106.913086  106.203021      106.372      106.372
#
#     Delc_isatai  Dwtr_isatai  Dind_isatai Dwhl_isatai
# 0    102.701642   104.071236      98.6954         106
# 1    102.701642   104.071236      104.276         106
# 2    102.701642   104.071236      99.4093         106
# 3    102.251369   103.392697      95.3757         105
# 4    102.251369   103.392697       99.404         105
# 5    102.251369   103.392697      99.2007         105
# 6    102.251369   103.392697      101.413         105
# 7    102.701642   104.071236      96.2747         106
# 8    102.530538   103.813391      152.448         106
# 9    102.530538   103.813391      99.8824         106
# 10   102.080265   103.134852      96.9401         105
# 11   102.080265   103.134852      108.218         105
# 12   102.080265   103.134852      100.393         105
# 13   102.080265   103.134852      103.221         105
# 14   103.395064   105.116187      72.2966         106
# 15   103.395064   105.116187       99.533         106
# 16   102.944790   104.437648      94.9296         106
# 17   102.944790   104.437648      95.2371         105
# 18   102.944790   104.437648      99.0315         105
# 19   102.944790   104.437648      100.901         105
# 20   102.701642   104.071236      154.854         105
#
# [21 rows x 37 columns]

# %%
newdf.to_sql('vrp_prognoz_isatai', engine, schema='public',if_exists='replace', index = True)

# %%
Dman
# Out:
# 0      98.496660
# 1     104.437527
# 2     100.000000
# 3     100.000000
# 4     100.000000
# 5     100.000000
# 6     100.000000
# 7      95.737129
# 8     125.388972
# 9     100.000000
# 10    100.000000
# 11    100.000000
# 12    100.000000
# 13    100.000000
# 14     68.389184
# 15    100.000000
# 16    100.000000
# 17    100.000000
# 18    100.000000
# 19    100.000000
# 20    115.594715
# Name: Dman_isatai, dtype: float64
