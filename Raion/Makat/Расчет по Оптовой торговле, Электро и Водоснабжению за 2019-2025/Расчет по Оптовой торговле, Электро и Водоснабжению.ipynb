# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv = pd.read_sql('SELECT * FROM vrp_ekz_fact ORDER BY id',engine)
csv_p = pd.read_sql('SELECT * FROM vrp_ekz_prog ORDER BY id',engine)


lret_csv = pd.read_sql("SELECT * FROM lret_prog_makat ORDER BY index",engine)
lwhl_csv = pd.read_sql("SELECT * FROM lwhl_prog_makat ORDER BY index",engine)
lagr_csv = pd.read_sql("SELECT * FROM lagr_prog_makat ORDER BY index",engine)
lmin_csv = pd.read_sql("SELECT * FROM lmin_prog_makat ORDER BY index",engine)
lcon_csv = pd.read_sql("SELECT * FROM lcon_prog_makat ORDER BY index",engine)
ltrd_csv = pd.read_sql("SELECT * FROM ltrd_fact_makat ORDER BY index",engine)
man_csv =  pd.read_sql("SELECT * FROM lman_nman_prog_makat ORDER BY index",engine)
Ncon_csv = pd.read_sql("SELECT * FROM ncon_prog_makat ORDER BY index",engine)
Ntrd_csv = pd.read_sql("SELECT * FROM ntrd_fact_makat ORDER BY index",engine)
Nmin_csv = pd.read_sql("SELECT * FROM nmin_prog_makat ORDER BY index",engine)
Nret_csv = pd.read_sql("SELECT * FROM nret_prog_makat ORDER BY index",engine)
Nagr_csv = pd.read_sql("SELECT * FROM nagr_prog_makat ORDER BY index",engine)

Nret_f =   csv['o_prod_retail_makat']
Nwhl_f =    csv['o_prod_trade_makat']
Nagr_f =     csv['o_prod_agro_makat']
Nmin_f =   csv['o_prod_mining_makat']
Nman_f =      csv['o_prod_man_makat']
Ncon_f = csv['o_prod_building_makat']
Nelc_f =   csv['o_prod_energo_makat']
Nwtr_f =    csv['o_prod_water_makat']
Nind_f =    csv['o_prod_water_makat']
 
lelc_f =    csv['o_ifo_energo_makat']
lwtr_f =     csv['o_ifo_water_makat']


Ntrd_f = Ntrd_csv['Ntrd_makat']
ltrd_f = ltrd_csv['ltrd_makat']

Nmin_b = Nmin_csv['Nmin_b']
Nmin_o = Nmin_csv['Nmin_o']
Nmin_p = Nmin_csv['Nmin_p']


Nman_b =  man_csv['Nman_b']
Nman_o =  man_csv['Nman_o']
Nman_p =  man_csv['Nman_p']

lman_b =  man_csv['lman_b']
lman_o =  man_csv['lman_o']
lman_p =  man_csv['lman_p']

lret_b = lret_csv['lret_b']
lret_o = lret_csv['lret_o']
lret_p = lret_csv['lret_p']

lwhl_b = lwhl_csv['lwhl_b']
lwhl_o = lwhl_csv['lwhl_o']
lwhl_p = lwhl_csv['lwhl_p']

lagr_b = lagr_csv['lagr_b']
lagr_o = lagr_csv['lagr_o']
lagr_p = lagr_csv['lagr_p']

lmin_b = lmin_csv['lmin_b']
lmin_o = lmin_csv['lmin_o']
lmin_p = lmin_csv['lmin_p']

lcon_b = lcon_csv['lcon_b']
lcon_o = lcon_csv['lcon_o']
lcon_p = lcon_csv['lcon_p']

Ncon_b = Ncon_csv['Ncon_b']
Ncon_o = Ncon_csv['Ncon_o']
Ncon_p = Ncon_csv['Ncon_p']

Nret_b = Nret_csv['Nret_b']
Nret_o = Nret_csv['Nret_o']
Nret_p = Nret_csv['Nret_p']

Nagr_b = Nagr_csv['Nagr_b']
Nagr_o = Nagr_csv['Nagr_o']
Nagr_p = Nagr_csv['Nagr_p']

inf = csv_p['o_inflation']

ltrd_b = (lret_b[0]*Nret_f[18] + lwhl_b[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_b = (lagr_b[0]*Nagr_f[18] + lmin_b[0]*Nmin_f[18] + lman_b[0]*Nman_f[18] + lcon_b[0]*Ncon_f[18] + ltrd_b * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_b= (100*((lammct_b-100)* (-1.9748362951242386) +100 ))/100
K_b= (100*((lammct_b-100)*  0.33968756231368225  +100))/100
lelc_b= S_b/100 * 100
lwtr_b= K_b/100 * 100

Delc = inf *  0.859486933458211  + 100
Dwtr = inf *  1.1746265013388206 + 100

Delc_b = Delc.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True)
Dwtr_b = Dwtr.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True)
Delc_o = Delc.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Dwtr_o = Dwtr.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Delc_p = Delc.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True)
Dwtr_p = Dwtr.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True)


Nelc_b = (Nelc_f[18]*lelc_b*Delc_b[0])/10000
Nwtr_b = (Nwtr_f[18]*lwtr_b*Dwtr_b[0])/10000
Nind_b = Nmin_b[0]+Nman_b[0]+Nelc_b+Nwtr_b
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_b = ((lmin_b[0]*Nmin_f[18])+(lman_b[0]*Nman_f[18])+(lelc_b*Nelc_f[18])+(lwtr_b*Nwtr_f[18]))/ Nind_f[18]
Nind_b = Nmin_b[0]+Nman_b[0]+Nelc_b+Nwtr_b
Dind_b= (Nind_b/Nind_f[18]/lind_b)*10000
Dwhl_b = inf[0] * 0.8574762712379193 + (Dind_b-100)*0.9269933771713703+100
Nwhl_b = (Nwhl_f[18]*lwhl_b[0]*Dwhl_b)/10000
Ntrd_b = Nret_b[0]+Nwhl_b
Dtrd_b = Ntrd_b/(Nret_f[18] + Nwhl_f[18])/ltrd_b *10000


ltrd_o = (lret_o[0]*Nret_f[18] + lwhl_o[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_o = (lagr_o[0]*Nagr_f[18] + lmin_o[0]*Nmin_f[18] + lman_o[0]*Nman_f[18] + lcon_o[0]*Ncon_f[18] + ltrd_o * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_o= (100*((lammct_o-100)* (-1.9748362951242386) +100))/100
K_o= (100*((lammct_o-100)*  0.33968756231368225  +100))/100
lelc_o= S_o/100 * 100
lwtr_o= K_o/100 * 100

Nelc_o = (Nelc_f[18]*lelc_o*Delc_o[0])/10000
Nwtr_o = (Nwtr_f[18]*lwtr_o*Dwtr_o[0])/10000
Nind_o = Nmin_o[0]+Nman_o[0]+Nelc_o+Nwtr_o
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_o = ((lmin_o[0]*Nmin_f[18])+(lman_o[0]*Nman_f[18])+(lelc_o*Nelc_f[18])+(lwtr_o*Nwtr_f[18]))/ Nind_f[18]
Nind_o = Nmin_o[0]+Nman_o[0]+Nelc_o+Nwtr_o
Dind_o= (Nind_o/Nind_f[18]/lind_o)*10000
Dwhl_o = inf[0] * 0.8574762712379193 + (Dind_o-100)*0.9269933771713703+100
Nwhl_o = (Nwhl_f[18]*lwhl_o[0]*Dwhl_o)/10000
Ntrd_o = Nret_o[0]+Nwhl_o
Dtrd_o = Ntrd_o/(Nret_f[18] + Nwhl_f[18])/ltrd_o *10000


ltrd_p = (lret_p[0]*Nret_f[18] + lwhl_p[0]*Nwhl_f[18])/Ntrd_f[18]
lammct_p = (lagr_p[0]*Nagr_f[18] + lmin_p[0]*Nmin_f[18] + lman_p[0]*Nman_f[18] + lcon_p[0]*Ncon_f[18] + ltrd_p * Ntrd_f[18])/(Nagr_f[18]+Nmin_f[18]+Nman_f[18]+Ncon_f[18]+Ntrd_f[18])
S_p= (100*((lammct_p-100)* (-1.9748362951242386) +100))/100
K_p= (100*((lammct_p-100)*  0.33968756231368225  +100))/100
lelc_p= S_p/100 * 100
lwtr_p= K_p/100 * 100
Nelc_p = (Nelc_f[18]*lelc_p*Delc_p[0])/10000
Nwtr_p = (Nwtr_f[18]*lwtr_p*Dwtr_p[0])/10000
Nind_p = Nmin_p[0]+Nman_p[0]+Nelc_p+Nwtr_p
Nind_f = Nmin_f+Nman_f+Nelc_f+Nwtr_f
lind_p = ((lmin_p[0]*Nmin_f[18])+(lman_p[0]*Nman_f[18])+(lelc_p*Nelc_f[18])+(lwtr_p*Nwtr_f[18]))/ Nind_f[18]
Nind_p = Nmin_p[0]+Nman_p[0]+Nelc_p+Nwtr_p
Dind_p= (Nind_p/Nind_f[18]/lind_p)*10000
Dwhl_p = inf[0] * 0.8574762712379193 + (Dind_p-100)* 0.9269933771713703 +100
Nwhl_p = (Nwhl_f[18]*lwhl_p[0]*Dwhl_p)/10000
Ntrd_p = Nret_p[0]+Nwhl_p
Dtrd_p = Ntrd_p/(Nret_f[18] + Nwhl_f[18])/ltrd_p *10000

ltrd_bb = ltrd_b
lelc_bb = lelc_b
lwtr_bb = lwtr_b
lind_bb = lind_b
Ntrd_bb = Ntrd_b
Nelc_bb = Nelc_b
Nwtr_bb = Nwtr_b
Nind_bb = Nind_b
Nwhl_bb = Nwhl_b
Dtrd_bb = Dtrd_b
Dwhl_bb = Dwhl_b
Dind_bb = Dind_b

ltrd_oo = ltrd_o
lelc_oo = lelc_o
lwtr_oo = lwtr_o
lind_oo = lind_o
Ntrd_oo = Ntrd_o
Nelc_oo = Nelc_o
Nwtr_oo = Nwtr_o
Nind_oo = Nind_o
Nwhl_oo = Nwhl_o
Dtrd_oo = Dtrd_o
Dwhl_oo = Dwhl_o
Dind_oo = Dind_o

ltrd_pp = ltrd_p
lelc_pp = lelc_p
lwtr_pp = lwtr_p
lind_pp = lind_p
Ntrd_pp = Ntrd_p
Nelc_pp = Nelc_p
Nwtr_pp = Nwtr_p
Nind_pp = Nind_p
Nwhl_pp = Nwhl_p
Dtrd_pp = Dtrd_p
Dwhl_pp = Dwhl_p
Dind_pp = Dind_p

Ntrd_f
# Out:
# 0        71.8
# 1        53.9
# 2       104.0
# 3       164.0
# 4       174.0
# 5       257.3
# 6      2238.2
# 7      1787.7
# 8      4268.4
# 9      2728.2
# 10     6136.4
# 11    11044.5
# 12     4318.5
# 13     2292.6
# 14     1815.4
# 15     3128.9
# 16     3129.7
# 17     3442.6
# 18     5029.0
# Name: Ntrd_makat, dtype: float64

# %%
ltrd_b = ltrd_bb
lelc_b = lelc_bb
lwtr_b = lwtr_bb
lind_b = lind_bb
Ntrd_b = Ntrd_bb
Nelc_b = Nelc_bb
Nwtr_b = Nwtr_bb
Nind_b = Nind_bb
Nwhl_b = Nwhl_bb
Dtrd_b = Dtrd_bb
Dwhl_b = Dwhl_bb
Dind_b = Dind_bb

i = 0

newdf_1 = pd.DataFrame(columns=['ltrd_b',
                              'lelc_b',
                              'lwtr_b',
                              'lind_b',
                              'Ntrd_b',
                              'Nelc_b',
                              'Nwtr_b',
                              'Nind_b',
                              'Nwhl_b',
                              'Dtrd_b',
                              'Delc_b',
                              'Dwtr_b',
                              'Dwhl_b',
                              'Dind_b',
                              'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'базовый')].reset_index(drop = True))-2:
    
    Nind_b_p = Nmin_b[i]+Nman_b[i]+Nelc_b+Nwtr_b
    ltrd_b = (lret_b[i+1]*Nret_b[i] + lwhl_b[i+1]*Nwhl_b)/Ntrd_b
    
    lammct_b = (lagr_b[i+1]*Nagr_b[i] + lmin_b[i+1]*Nmin_b[i] + lman_b[i+1]*Nman_b[i] + lcon_b[i+1]*Ncon_b[i] + ltrd_b * Ntrd_b)/(Nagr_b[i]+Nmin_b[i]+Nman_b[i]+Ncon_b[i]+Ntrd_b) 
    
    
    
    S_b= (100*((lammct_b-100)*   (-1.9748362951242386)  +100))/100
    K_b = (100*((lammct_b-100)*   0.33968756231368225   +100))/100
    
    lelc_b= S_b/100 * 100
    lwtr_b= K_b/100 * 100
    
    Nelc_b = (Nelc_b*lelc_b*Delc_b[i+1])/10000
    Nwtr_b = (Nwtr_b*lwtr_b*Dwtr_b[i+1])/10000
    Nind_b = Nmin_b[i+1]+Nman_b[i+1]+Nelc_b+Nwtr_b
    lind_b = ((lmin_b[i+1]*Nmin_b[i])+(lman_b[i+1]*Nman_b[0])+(lelc_b*Nelc_b)+(lwtr_b*Nwtr_b))/ Nind_b
    Nind_b = Nmin_b[i+1]+Nman_b[i+1]+Nelc_b+Nwtr_b    
    Dind_b= (Nind_b/Nind_b_p/lind_b)*10000
    Dwhl_b = inf[i+1] * 0.8574762712379193 + (Dind_b-100)*0.9269933771713703+100
    
    Ntrd_b_p = Nret_b[i]+Nwhl_b
    Nwhl_b = (Nwhl_b*lwhl_b[i+1]*Dwhl_b)/10000
    Ntrd_b = Nret_b[i+1]+Nwhl_b   
    
    Dtrd_b = Ntrd_b/Ntrd_b_p/ltrd_b*10000
    
    i = i+1
    newdf_1.loc[i].ltrd_b = ltrd_b
    newdf_1.loc[i].lelc_b = lelc_b
    newdf_1.loc[i].lwtr_b = lwtr_b
    newdf_1.loc[i].lind_b = lind_b
    newdf_1.loc[i].Ntrd_b = Ntrd_b
    newdf_1.loc[i].Nelc_b = Nelc_b
    newdf_1.loc[i].Nwtr_b = Nwtr_b
    newdf_1.loc[i].Nind_b = Nind_b
    newdf_1.loc[i].Nwhl_b = Nwhl_b
    
    newdf_1.loc[i].Dtrd_b = Dtrd_b     
    newdf_1.loc[i].Dwhl_b = Dwhl_b
    newdf_1.loc[i].Dind_b = Dind_b
    newdf_1.loc[i].prognoz = "базовый"

newdf_1.loc[0].prognoz = "базовый"
    
newdf_1.loc[0].ltrd_b = ltrd_bb
newdf_1.loc[0].lelc_b = lelc_bb
newdf_1.loc[0].lwtr_b = lwtr_bb
newdf_1.loc[0].lind_b = lind_bb
newdf_1.loc[0].Ntrd_b = Ntrd_bb
newdf_1.loc[0].Nelc_b = Nelc_bb
newdf_1.loc[0].Nwtr_b = Nwtr_bb
newdf_1.loc[0].Nind_b = Nind_bb
newdf_1.loc[0].Nwhl_b = Nwhl_bb
newdf_1.loc[0].Dtrd_b = Dtrd_bb
newdf_1.loc[0].Dwhl_b = Dwhl_bb
newdf_1.loc[0].Dind_b = Dind_bb

newdf_1.Delc_b = Delc_b 
newdf_1.Dwtr_b = Dwtr_b

lind_b = newdf_1['lind_b']
lelc_b = newdf_1['lelc_b']
lwtr_b = newdf_1['lwtr_b']
ltrd_b = newdf_1['ltrd_b']

Nind_b = newdf_1['Nind_b']
Nelc_b = newdf_1['Nelc_b']
Nwtr_b = newdf_1['Nwtr_b']
Ntrd_b = newdf_1['Ntrd_b']
Nwhl_b = newdf_1['Nwhl_b']

newdf_1
# Out:
#      ltrd_b   lelc_b   lwtr_b   lind_b   Ntrd_b   Nelc_b   Nwtr_b   Nind_b  \
# 0   102.305  96.2123  100.652  101.951  5419.39  2.02348  110.978  24594.3
# 1   99.8945  100.124  99.9787  96.2419   5905.4  2.13047  118.774  25543.4
# 2     96.34  105.747  99.0114  99.8496  5964.74  2.36909  125.888  24922.4
# 3   96.9229  104.959   99.147   99.733  6010.23  2.59344  132.144  24351.6
# 4   96.0502  106.458  98.8892  99.6208  5983.97  2.87957  138.351  23622.6
# 5   93.4693  110.797  98.1429   99.442  5750.34  3.32758  143.756  22497.2
# 6   102.092  96.4364  100.613  99.2701  6211.67   3.3469  153.132    22811
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nwhl_b   Dtrd_b      Delc_b      Dwtr_b   Dwhl_b   Dind_b  prognoz
# 0   2368.78  105.335  105.156922  107.047759  103.945   98.706  базовый
# 1   2664.42  109.083  105.156922  107.047759  112.482  107.915  базовый
# 2   2744.38  104.842  105.156922  107.047759  103.028   97.716  базовый
# 3   2809.81  103.962  104.297435  105.873133  102.407  97.9713  базовый
# 4    2861.1  103.657  104.297435  105.873133  101.854  97.3755  базовый
# 5    2870.2   102.81  104.297435  105.873133  100.367  95.7705  базовый
# 6   3050.68  105.809  104.297435  105.873133  106.271   102.14  базовый
# 7       NaN      NaN         NaN         NaN      NaN      NaN      NaN
# 8       NaN      NaN         NaN         NaN      NaN      NaN      NaN
# 9       NaN      NaN         NaN         NaN      NaN      NaN      NaN
# 10      NaN      NaN         NaN         NaN      NaN      NaN      NaN
# 11      NaN      NaN         NaN         NaN      NaN      NaN      NaN

# %%
ltrd_o = ltrd_oo
lelc_o = lelc_oo
lwtr_o = lwtr_oo
lind_o = lind_oo
Ntrd_o = Ntrd_oo
Nelc_o = Nelc_oo
Nwtr_o = Nwtr_oo
Nind_o = Nind_oo
Nwhl_o = Nwhl_oo
Dtrd_o = Dtrd_oo
Dwhl_o = Dwhl_oo
Dind_o = Dind_oo

i = 0

newdf_2 = pd.DataFrame(columns=['ltrd_o',
                              'lelc_o',
                              'lwtr_o',
                              'lind_o',
                              'Ntrd_o',
                              'Nelc_o',
                              'Nwtr_o',
                              'Nind_o',
                              'Nwhl_o',
                              'Dtrd_o',
                              'Delc_o',
                              'Dwtr_o',
                              'Dwhl_o',
                              'Dind_o',
                              'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'оптимистичный')].reset_index(drop = True))-2:
    Nind_o_p = Nmin_o[i] + Nman_o[i] + Nelc_o + Nwtr_o
    ltrd_o =  (lret_o[i+1]*Nret_o[i] + lwhl_o[i+1]*Nwhl_o)/Ntrd_o
    
    lammct_o = (lagr_o[i+1]*Nagr_o[i] + lmin_o[i+1]*Nmin_o[i] + lman_o[i+1]*Nman_o[i] + lcon_o[i+1]*Ncon_o[i] + ltrd_o * Ntrd_o)/(Nagr_o[i]+Nmin_o[i]+Nman_o[i]+Ncon_o[i]+Ntrd_o) 
    
    
    
    S_o=  (100*((lammct_o-100)*  (-1.9748362951242386)  +100))/100
    K_o = (100*((lammct_o-100)*   0.33968756231368225   +100))/100
    
    lelc_o= S_o/100 * 100
    lwtr_o= K_o/100 * 100
    
    Nelc_o = (Nelc_o*lelc_o*Delc_o[i+1])/10000
    Nwtr_o = (Nwtr_o*lwtr_o*Dwtr_o[i+1])/10000
    Nind_o =   Nmin_o[i+1]+Nman_o[i+1]+Nelc_o+Nwtr_o
    lind_o = ((lmin_o[i+1]*Nmin_o[i])+(lman_o[i+1]*Nman_o[0])+(lelc_o*Nelc_o)+(lwtr_o*Nwtr_o))/ Nind_o
    Nind_o =   Nmin_o[i+1]+Nman_o[i+1]+Nelc_o+Nwtr_o    
    Dind_o=   (Nind_o/Nind_o_p/lind_o)*10000
    Dwhl_o = inf[i+1] * 0.8574762712379193 + (Dind_o-100)*0.9269933771713703 +100
    
    Ntrd_o_p = Nret_o[i]+Nwhl_o
    Nwhl_o = (Nwhl_o*lwhl_o[i+1]*Dwhl_o)/10000
    Ntrd_o = Nret_o[i+1]+Nwhl_o   
    
    Dtrd_o = Ntrd_o/Ntrd_o_p/ltrd_o*10000
    
    i = i+1
    newdf_2.loc[i].ltrd_o = ltrd_o
    newdf_2.loc[i].lelc_o = lelc_o
    newdf_2.loc[i].lwtr_o = lwtr_o
    newdf_2.loc[i].lind_o = lind_o
    newdf_2.loc[i].Ntrd_o = Ntrd_o
    newdf_2.loc[i].Nelc_o = Nelc_o
    newdf_2.loc[i].Nwtr_o = Nwtr_o
    newdf_2.loc[i].Nind_o = Nind_o
    newdf_2.loc[i].Nwhl_o = Nwhl_o
    
    newdf_2.loc[i].Dtrd_o = Dtrd_o     
    newdf_2.loc[i].Dwhl_o = Dwhl_o
    newdf_2.loc[i].Dind_o = Dind_o
    newdf_2.loc[i].prognoz = "оптимистичный"
    
newdf_2.loc[0].prognoz = "оптимистичный"
    
newdf_2.loc[0].ltrd_o = ltrd_oo
newdf_2.loc[0].lelc_o = lelc_oo
newdf_2.loc[0].lwtr_o = lwtr_oo
newdf_2.loc[0].lind_o = lind_oo
newdf_2.loc[0].Ntrd_o = Ntrd_oo
newdf_2.loc[0].Nelc_o = Nelc_oo
newdf_2.loc[0].Nwtr_o = Nwtr_oo
newdf_2.loc[0].Nind_o = Nind_oo
newdf_2.loc[0].Nwhl_o = Nwhl_oo
newdf_2.loc[0].Dtrd_o = Dtrd_oo
newdf_2.loc[0].Dwhl_o = Dwhl_oo
newdf_2.loc[0].Dind_o = Dind_oo
    
newdf_2.Delc_o = Delc_o 
newdf_2.Dwtr_o = Dwtr_o

lind_o = newdf_2['lind_o']
lelc_o = newdf_2['lelc_o']
lwtr_o = newdf_2['lwtr_o']
ltrd_o = newdf_2['ltrd_o']

Nind_o = newdf_2['Nind_o']
Nelc_o = newdf_2['Nelc_o']
Nwtr_o = newdf_2['Nwtr_o']
Ntrd_o = newdf_2['Ntrd_o']
Nwhl_o = newdf_2['Nwhl_o']

newdf_2
# Out:
#      ltrd_o   lelc_o   lwtr_o   lind_o   Ntrd_o   Nelc_o   Nwtr_o   Nind_o  \
# 0   102.305  96.2123  100.652  101.951  5368.06  2.02348  110.978  23988.9
# 1   112.721  80.0733  103.428   81.752  7757.27  1.69853  122.359  32033.5
# 2   96.4715  105.811  99.0004  99.7169  7820.33  1.88405  129.132  31209.1
# 3   99.0638   101.49  99.7436  99.6221  8091.96  1.98805  135.791  30979.6
# 4   109.808   82.793   102.96  99.6791  9614.44  1.71133  147.397  33461.8
# 5   93.6766  110.388  98.2131   99.871  9232.15  1.96412  152.619  31914.2
# 6   103.346  94.1832  101.001  99.7494  10098.5  1.92332  162.511  32699.6
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nwhl_o   Dtrd_o      Delc_o      Dwtr_o   Dwhl_o   Dind_o        prognoz
# 0   2317.45  104.337  105.156922  107.047759  101.693  96.2761  оптимистичный
# 1   3800.71  128.199  104.830317  106.601401  163.862  163.341  оптимистичный
# 2   3914.27    104.5  104.830317  106.601401  103.016   97.703  оптимистичный
# 3   4068.78  104.451  103.970830  105.426774  103.955  99.6412  оптимистичный
# 4   4562.03  108.202  103.970830  105.426774  112.037   108.36  оптимистичный
# 5   4565.11  102.506  103.970830  105.426774  100.114   95.498  оптимистичный
# 6   4877.12  105.843  103.970830  105.426774  106.807  102.718  оптимистичный
# 7       NaN      NaN         NaN         NaN      NaN      NaN            NaN
# 8       NaN      NaN         NaN         NaN      NaN      NaN            NaN
# 9       NaN      NaN         NaN         NaN      NaN      NaN            NaN
# 10      NaN      NaN         NaN         NaN      NaN      NaN            NaN
# 11      NaN      NaN         NaN         NaN      NaN      NaN            NaN

# %%
ltrd_p = ltrd_pp
lelc_p = lelc_pp
lwtr_p = lwtr_pp
lind_p = lind_pp
Ntrd_p = Ntrd_pp
Nelc_p = Nelc_pp
Nwtr_p = Nwtr_pp
Nind_p = Nind_pp
Nwhl_p = Nwhl_pp
Dtrd_p = Dtrd_pp
Dwhl_p = Dwhl_pp
Dind_p = Dind_pp

i = 0

newdf_3 = pd.DataFrame(columns=['ltrd_p',
                              'lelc_p',
                              'lwtr_p',
                              'lind_p',
                              'Ntrd_p',
                              'Nelc_p',
                              'Nwtr_p',
                              'Nind_p',
                              'Nwhl_p',
                              'Dtrd_p',
                              'Delc_p',
                              'Dwtr_p',
                              'Dwhl_p',
                              'Dind_p',
                               'prognoz'],index = range(12))

while i<=len(csv_p.loc[csv_p.o_script.str.match(r'пессимистичный')].reset_index(drop = True))-2:
    Nind_p_p = Nmin_p[i] + Nman_p[i] + Nelc_p + Nwtr_p
    ltrd_p =  (lret_p[i+1]*Nret_p[i] + lwhl_p[i+1]*Nwhl_p)/Ntrd_p
    
    lammct_p = (lagr_p[i+1]*Nagr_p[i] + lmin_p[i+1]*Nmin_p[i] + lman_p[i+1]*Nman_p[i] + lcon_p[i+1]*Ncon_p[i] + ltrd_p * Ntrd_p)/(Nagr_p[i]+Nmin_p[i]+Nman_p[i]+Ncon_p[i]+Ntrd_p) 
    
    
    
    S_p=  (100*((lammct_p-100)*  (-1.9748362951242386)  +100))/100
    K_p = (100*((lammct_p-100)*   0.33968756231368225   +100))/100
    
    lelc_p= S_p/100 * 100
    lwtr_p= K_p/100 * 100
    
    Nelc_p = (Nelc_p*lelc_p*Delc_p[i+1])/10000
    Nwtr_p = (Nwtr_p*lwtr_p*Dwtr_p[i+1])/10000
    Nind_p =   Nmin_p[i+1]+Nman_p[i+1]+Nelc_p+Nwtr_p
    lind_p = ((lmin_p[i+1]*Nmin_p[i])+(lman_p[i+1]*Nman_p[0])+(lelc_p*Nelc_p)+(lwtr_p*Nwtr_p))/ Nind_p
    Nind_p =   Nmin_p[i+1]+Nman_p[i+1]+Nelc_p+Nwtr_p    
    Dind_p=   (Nind_p/Nind_p_p/lind_p)*10000
    Dwhl_p = inf[i+1] * 0.8574762712379193 + (Dind_p-100)*0.9269933771713703 +100
    
    Ntrd_p_p = Nret_p[i]+Nwhl_p
    Nwhl_p = (Nwhl_p*lwhl_p[i+1]*Dwhl_p)/10000
    Ntrd_p = Nret_p[i+1]+Nwhl_p
    
    Dtrd_p = Ntrd_p/Ntrd_p_p/ltrd_p*10000
    
    i = i+1
    newdf_3.loc[i].ltrd_p = ltrd_p
    newdf_3.loc[i].lelc_p = lelc_p
    newdf_3.loc[i].lwtr_p = lwtr_p
    newdf_3.loc[i].lind_p = lind_p
    newdf_3.loc[i].Ntrd_p = Ntrd_p
    newdf_3.loc[i].Nelc_p = Nelc_p
    newdf_3.loc[i].Nwtr_p = Nwtr_p
    newdf_3.loc[i].Nind_p = Nind_p
    newdf_3.loc[i].Nwhl_p = Nwhl_p
    
    newdf_3.loc[i].Dtrd_p = Dtrd_p     
    newdf_3.loc[i].Dwhl_p = Dwhl_p
    newdf_3.loc[i].Dind_p = Dind_p
    newdf_3.loc[i].prognoz = "пессимистичный"
    
newdf_3.loc[0].prognoz = "пессимистичный"    
    
newdf_3.loc[0].ltrd_p = ltrd_pp
newdf_3.loc[0].lelc_p = lelc_pp
newdf_3.loc[0].lwtr_p = lwtr_pp
newdf_3.loc[0].lind_p = lind_pp
newdf_3.loc[0].Ntrd_p = Ntrd_pp
newdf_3.loc[0].Nelc_p = Nelc_pp
newdf_3.loc[0].Nwtr_p = Nwtr_pp
newdf_3.loc[0].Nind_p = Nind_pp
newdf_3.loc[0].Nwhl_p = Nwhl_pp
newdf_3.loc[0].Dtrd_p = Dtrd_pp
newdf_3.loc[0].Dwhl_p = Dwhl_pp
newdf_3.loc[0].Dind_p = Dind_pp

newdf_3.Delc_p = Delc_p 
newdf_3.Dwtr_p = Dwtr_p

lind_p = newdf_3['lind_p']
lelc_p = newdf_3['lelc_p']
lwtr_p = newdf_3['lwtr_p']
ltrd_p = newdf_3['ltrd_p']

Nind_p = newdf_3['Nind_p']
Nelc_p = newdf_3['Nelc_p']
Nwtr_p = newdf_3['Nwtr_p']
Ntrd_p = newdf_3['Ntrd_p']
Nwhl_p = newdf_3['Nwhl_p']

newdf_3
# Out:
#      ltrd_p   lelc_p   lwtr_p   lind_p   Ntrd_p   Nelc_p   Nwtr_p   Nind_p  \
# 0   102.305  109.161  98.4243  94.5547  4906.92   2.3247  110.356  16685.9
# 1   95.7879  106.037  98.9615  99.9934  4988.36   2.6248  118.882  16297.4
# 2   95.2933  106.915  98.8105  99.8751  5001.82  2.96405  126.492  15800.8
# 3   86.9714  119.364  96.6693  99.6638  4455.58  3.73688  131.672  14429.8
# 4   92.4497  111.509  98.0204  99.1455  4290.54  4.40117  138.981  13739.7
# 5   101.704  97.4395   100.44  98.9263  4650.97  4.52954  150.316  13842.5
# 6    141.95  34.4346  111.278  87.6473  8236.62  1.64016  179.057  20463.1
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nwhl_p   Dtrd_p      Delc_p      Dwtr_p   Dwhl_p   Dind_p         prognoz
# 0   1808.94   95.374  106.480531  108.856684  79.3789  72.2048  пессимистичный
# 1   1862.59   106.13  106.480531  108.856684  102.992  97.6781  пессимистичный
# 2   1907.34  105.222  105.621045  107.682057  102.432  97.0739  пессимистичный
# 3   1839.65  102.424  105.621045  107.682057  96.5299  91.6315  пессимистичный
# 4   1850.04   104.16  105.621045  107.682057  100.615  96.0381  пессимистичный
# 5   1961.17  106.585  105.621045  107.682057  105.995  101.842  пессимистичный
# 6   3302.79  124.759  105.156922  107.047759  167.937  168.662  пессимистичный
# 7       NaN      NaN         NaN         NaN      NaN      NaN             NaN
# 8       NaN      NaN         NaN         NaN      NaN      NaN             NaN
# 9       NaN      NaN         NaN         NaN      NaN      NaN             NaN
# 10      NaN      NaN         NaN         NaN      NaN      NaN             NaN
# 11      NaN      NaN         NaN         NaN      NaN      NaN             NaN

# %%
csv_Dman_makat  = pd.read_sql('SELECT * FROM dman_prog_makat ORDER BY index',engine)
csv_Dcon_makat  = pd.read_sql('SELECT * FROM dcon_prog_makat ORDER BY index',engine)
csv_Dmin_makat  = pd.read_sql('SELECT * FROM dmin_prog_makat ORDER BY index',engine)
csv_Dret_makat  = pd.read_sql('SELECT * FROM dret_prog_makat ORDER BY index',engine)
csv_Dagr_makat  = pd.read_sql('SELECT * FROM dagr_prog_makat ORDER BY index',engine)

Dman = csv_Dman_makat.rename({'0': 'Dman_makat'}, axis='columns')
Dman = Dman['Dman_makat']

Dcon_b = csv_Dcon_makat['Dcon_b']
Dcon_o = csv_Dcon_makat['Dcon_o']
Dcon_p = csv_Dcon_makat['Dcon_p']
Dcon = Dcon_b.append(Dcon_o).append(Dcon_p).dropna().reset_index(drop = True)

Dmin_b = csv_Dmin_makat['Dmin_b']
Dmin_o = csv_Dmin_makat['Dmin_o']
Dmin_p = csv_Dmin_makat['Dmin_p']
Dmin = Dmin_b.append(Dmin_o).append(Dmin_p).dropna().reset_index(drop = True)

Dret_b = csv_Dret_makat['Dret_b']
Dret_o = csv_Dret_makat['Dret_o']
Dret_p = csv_Dret_makat['Dret_p']
Dret = Dret_b.append(Dret_o).append(Dret_p).dropna().reset_index(drop = True)

Dagr_b = csv_Dagr_makat['Dagr_b']
Dagr_o = csv_Dagr_makat['Dagr_o']
Dagr_p = csv_Dagr_makat['Dagr_p']
Dagr = Dagr_b.append(Dagr_o).append(Dagr_p).dropna().reset_index(drop = True)
                    

prognoz = newdf_1['prognoz'].append(newdf_2['prognoz']).append(newdf_3['prognoz']).dropna().reset_index(drop = True)

ltrd = newdf_1['ltrd_b'].append(newdf_2['ltrd_o']).append(newdf_3['ltrd_p']).dropna().reset_index(drop = True)

lelc = newdf_1['lelc_b'].append(newdf_2['lelc_o']).append(newdf_3['lelc_p']).dropna().reset_index(drop = True)
lwtr = newdf_1['lwtr_b'].append(newdf_2['lwtr_o']).append(newdf_3['lwtr_p']).dropna().reset_index(drop = True)
lind = newdf_1['lind_b'].append(newdf_2['lind_o']).append(newdf_3['lind_p']).dropna().reset_index(drop = True)
Ntrd = newdf_1['Ntrd_b'].append(newdf_2['Ntrd_o']).append(newdf_3['Ntrd_p']).dropna().reset_index(drop = True)
Nelc = newdf_1['Nelc_b'].append(newdf_2['Nelc_o']).append(newdf_3['Nelc_p']).dropna().reset_index(drop = True)
Nwtr = newdf_1['Nwtr_b'].append(newdf_2['Nwtr_o']).append(newdf_3['Nwtr_p']).dropna().reset_index(drop = True)
Nind = newdf_1['Nind_b'].append(newdf_2['Nind_o']).append(newdf_3['Nind_p']).dropna().reset_index(drop = True)
Nwhl = newdf_1['Nwhl_b'].append(newdf_2['Nwhl_o']).append(newdf_3['Nwhl_p']).dropna().reset_index(drop = True)
Dtrd = newdf_1['Dtrd_b'].append(newdf_2['Dtrd_o']).append(newdf_3['Dtrd_p']).dropna().reset_index(drop = True)
Delc = newdf_1['Delc_b'].append(newdf_2['Delc_o']).append(newdf_3['Delc_p']).dropna().reset_index(drop = True)
Dwtr = newdf_1['Dwtr_b'].append(newdf_2['Dwtr_o']).append(newdf_3['Dwtr_p']).dropna().reset_index(drop = True)
Dwhl = newdf_1['Dwhl_b'].append(newdf_2['Dwhl_o']).append(newdf_3['Dwhl_p']).dropna().reset_index(drop = True)
Dind = newdf_1['Dind_b'].append(newdf_2['Dind_o']).append(newdf_3['Dind_p']).dropna().reset_index(drop = True)

lret = lret_csv['lret_b'].append(lret_csv['lret_o']).append(lret_csv['lret_p']).dropna().reset_index(drop = True)
lwhl = lwhl_csv['lwhl_b'].append(lwhl_csv['lwhl_o']).append(lwhl_csv['lwhl_p']).dropna().reset_index(drop = True)
lagr = lagr_csv['lagr_b'].append(lagr_csv['lagr_o']).append(lagr_csv['lagr_p']).dropna().reset_index(drop = True)
lmin = lmin_csv['lmin_b'].append(lmin_csv['lmin_o']).append(lmin_csv['lmin_p']).dropna().reset_index(drop = True)
lcon = lcon_csv['lcon_b'].append(lcon_csv['lcon_o']).append(lcon_csv['lcon_p']).dropna().reset_index(drop = True)
lman = man_csv['lman_b'].append(man_csv['lman_o']).append(man_csv['lman_p']).dropna().reset_index(drop = True)
Nman = man_csv['Nman_b'].append(man_csv['Nman_o']).append(man_csv['Nman_p']).dropna().reset_index(drop = True)
Ncon = Ncon_csv['Ncon_b'].append(Ncon_csv['Ncon_o']).append(Ncon_csv['Ncon_p']).dropna().reset_index(drop = True)
Nmin = Nmin_csv['Nmin_b'].append(Nmin_csv['Nmin_o']).append(Nmin_csv['Nmin_p']).dropna().reset_index(drop = True)
Nret = Nret_csv['Nret_b'].append(Nret_csv['Nret_o']).append(Nret_csv['Nret_p']).dropna().reset_index(drop = True)
Nagr = Nagr_csv['Nagr_b'].append(Nagr_csv['Nagr_o']).append(Nagr_csv['Nagr_p']).dropna().reset_index(drop = True)

newdf = pd.DataFrame(columns = ['prognoz',
                                'Ntot_makat',
                                'Nman_makat',
                                'Ncon_makat',
                                'Nmin_makat',
                                'Nret_makat',
                                'Nagr_makat',
                                'Ntrd_makat',
                                'Nsrv_makat',
                                'Nelc_makat',
                                'Nwtr_makat',
                                'Nind_makat',
                                'Nwhl_makat',
                                'ltot_makat',
                                'lman_makat',
                                'lcon_makat',
                                'lmin_makat',
                                'lret_makat',
                                'lagr_makat',
                                'ltrd_makat',
                                'lsrv_makat',
                                'lelc_makat',
                                'lwtr_makat',
                                'lind_makat',
                                'lwhl_makat',
                                'Dtot_makat',
                                'Dman_makat',
                                'Dcon_makat',
                                'Dmin_makat',
                                'Dret_makat',
                                'Dagr_makat',
                                'Dtrd_makat',
                                'Dsrv_makat',
                                'Delc_makat',
                                'Dwtr_makat',
                                'Dind_makat',
                                'Dwhl_makat',])
Ntot = Nind+Ntrd
newdf.Ntot_makat= Ntot
ltot = lind+ltrd
newdf.ltot_makat= ltot
Dtot = Dind+Dtrd
newdf.Dtot_makat= Dtot

newdf.lret_makat= lret
newdf.lwhl_makat= lwhl
newdf.lagr_makat= lagr
newdf.lmin_makat= lmin
newdf.lcon_makat= lcon
newdf.lman_makat= lman
newdf.Nman_makat= Nman
newdf.Ncon_makat= Ncon
newdf.Nmin_makat= Nmin
newdf.Nret_makat= Nret
newdf.Nagr_makat= Nagr

newdf.ltrd_makat= ltrd
newdf.lsrv_makat= ltrd
newdf.lelc_makat= lelc
newdf.lwtr_makat= lwtr
newdf.lind_makat= lind
newdf.Ntrd_makat= Ntrd
newdf.Nsrv_makat= Ntrd
newdf.Nelc_makat= Nelc
newdf.Nwtr_makat= Nwtr
newdf.Nind_makat= Nind
newdf.Nwhl_makat= Nwhl

newdf.Dtrd_makat= Dtrd
newdf.Dsrv_makat= Dtrd
newdf.Dsrv_makat= Dtrd
newdf.Delc_makat= Delc
newdf.Dwtr_makat= Dwtr
newdf.Dwhl_makat= Dwhl
newdf.Dind_makat= Dind

newdf.Dman_makat = Dman
newdf.Dcon_makat = Dcon
newdf.Dmin_makat = Dmin
newdf.Dret_makat = Dret
newdf.Dagr_makat = Dagr

newdf.prognoz = prognoz

newdf
# Out:
#            prognoz Ntot_makat  Nman_makat   Ncon_makat    Nmin_makat  \
# 0          базовый    30013.7  826.949806  3412.183813  23654.353862
# 1          базовый    31448.8  862.222354  3568.804022  24560.277523
# 2          базовый    30887.2  889.372499  3437.688842  23904.812291
# 3          базовый    30361.9  912.270874  3319.242264  23304.625734
# 4          базовый    29606.6  943.403462  3167.086422  22537.965587
# 5          базовый    28247.6  998.182463  2930.951732  21351.977959
# 6          базовый    29022.6  975.345693  3002.860776  21679.149220
# 7    оптимистичный    29356.9  805.660459  3315.285060  23070.195745
# 8    оптимистичный    39790.7  889.836481  4793.890472  31019.568770
# 9    оптимистичный    39029.4  921.515630  4630.220654  30156.531604
# 10   оптимистичный    39071.5  928.551770  4605.057398  29913.242534
# 11   оптимистичный    43076.3  842.162585  5208.044279  32470.578880
# 12   оптимистичный    41146.3  891.952405  4864.521637  30867.628437
# 13   оптимистичный    42798.1  862.594864  5078.221545  31672.561538
# 14  пессимистичный    21592.8  647.007271  2088.381368  15926.238446
# 15  пессимистичный    21285.8  664.829743  2008.966674  15511.076588
# 16  пессимистичный    20802.6  687.811186  1909.129603  14983.503761
# 17  пессимистичный    18885.4  755.979273  1640.533819  13538.428924
# 18  пессимистичный    18030.2  798.954414  1509.407529  12797.364641
# 19  пессимистичный    18493.5  784.375858  1527.633671  12903.295371
# 20  пессимистичный    28699.7  583.108228  2651.795484  19699.297444
#
#      Nret_makat   Nagr_makat Ntrd_makat Nsrv_makat Nelc_makat  ...  \
# 0   3050.610159   786.743802    5419.39    5419.39    2.02348  ...
# 1   3240.979574   834.562518     5905.4     5905.4    2.13047  ...
# 2   3220.355583   817.100096    5964.74    5964.74    2.36909  ...
# 3   3200.413139   858.491947    6010.23    6010.23    2.59344  ...
# 4   3122.871994   901.982744    5983.97    5983.97    2.87957  ...
# 5   2880.145504   868.603469    5750.34    5750.34    3.32758  ...
# 6   3160.986173   995.686958    6211.67    6211.67     3.3469  ...
# 7   3050.610159   786.743802    5368.06    5368.06    2.02348  ...
# 8   3956.559487   831.533710    7757.27    7757.27    1.69853  ...
# 9   3906.056586   811.179993    7820.33    7820.33    1.88405  ...
# 10  4023.184151   849.149045    8091.96    8091.96    1.98805  ...
# 11  5052.403831   888.897448    9614.44    9614.44    1.71133  ...
# 12  4667.043176   852.865841    9232.15    9232.15    1.96412  ...
# 13  5221.417548   974.064487    10098.5    10098.5    1.92332  ...
# 14  3097.978877   798.310202    4906.92    4906.92     2.3247  ...
# 15  3125.766274   793.102094    4988.36    4988.36     2.6248  ...
# 16  3094.474468   845.652209    5001.82    5001.82    2.96405  ...
# 17  2615.929715   901.686397    4455.58    4455.58    3.73688  ...
# 18  2440.498200   881.212350    4290.54    4290.54    4.40117  ...
# 19  2689.799209  1025.140900    4650.97    4650.97    4.52954  ...
# 20  4933.828966  1178.181307    8236.62    8236.62    1.64016  ...
#
#     Dcon_makat  Dmin_makat  Dret_makat  Dagr_makat  Dtrd_makat  Dsrv_makat  \
# 0    98.476507   98.672491  106.439281  106.078669     105.335     105.335
# 1   104.497014  103.918513  106.439281  106.078669     109.083     109.083
# 2   100.000000  100.000000  106.439281  106.078669     104.842     104.842
# 3   100.000000  100.000000  105.366068  105.065558     103.962     103.962
# 4   100.000000  100.000000  105.366068  105.065558     103.657     103.657
# 5   100.000000  100.000000  105.366068  105.065558      102.81      102.81
# 6   100.000000  100.000000  105.366068  105.065558     105.809     105.809
# 7    95.679984   96.235716  106.439281  106.078669     104.337     104.337
# 8   125.729321  122.419470  106.031460  105.693687     128.199     128.199
# 9   100.000000  100.000000  106.031460  105.693687       104.5       104.5
# 10  100.000000  100.000000  104.958246  104.680575     104.451     104.451
# 11  100.000000  100.000000  104.958246  104.680575     108.202     108.202
# 12  100.000000  100.000000  104.958246  104.680575     102.506     102.506
# 13  100.000000  100.000000  104.958246  104.680575     105.843     105.843
# 14   67.965429   72.086395  108.092030  107.638861      95.374      95.374
# 15  100.000000  100.000000  108.092030  107.638861      106.13      106.13
# 16  100.000000  100.000000  107.018816  106.625750     105.222     105.222
# 17  100.000000  100.000000  107.018816  106.625750     102.424     102.424
# 18  100.000000  100.000000  107.018816  106.625750      104.16      104.16
# 19  100.000000  100.000000  107.018816  106.625750     106.585     106.585
# 20  115.803768  113.770752  106.439281  106.078669     124.759     124.759
#
#     Delc_makat  Dwtr_makat  Dind_makat Dwhl_makat
# 0   105.156922  107.047759      98.706    103.945
# 1   105.156922  107.047759     107.915    112.482
# 2   105.156922  107.047759      97.716    103.028
# 3   104.297435  105.873133     97.9713    102.407
# 4   104.297435  105.873133     97.3755    101.854
# 5   104.297435  105.873133     95.7705    100.367
# 6   104.297435  105.873133      102.14    106.271
# 7   105.156922  107.047759     96.2761    101.693
# 8   104.830317  106.601401     163.341    163.862
# 9   104.830317  106.601401      97.703    103.016
# 10  103.970830  105.426774     99.6412    103.955
# 11  103.970830  105.426774      108.36    112.037
# 12  103.970830  105.426774      95.498    100.114
# 13  103.970830  105.426774     102.718    106.807
# 14  106.480531  108.856684     72.2048    79.3789
# 15  106.480531  108.856684     97.6781    102.992
# 16  105.621045  107.682057     97.0739    102.432
# 17  105.621045  107.682057     91.6315    96.5299
# 18  105.621045  107.682057     96.0381    100.615
# 19  105.621045  107.682057     101.842    105.995
# 20  105.156922  107.047759     168.662    167.937
#
# [21 rows x 37 columns]

# %%
newdf.to_sql('vrp_prognoz_makat', engine, schema='public',if_exists='replace', index = True)
