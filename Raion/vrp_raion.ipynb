# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

inder =    pd.read_sql('SELECT * FROM vrp_prognoz_inder ORDER BY index',engine) 
isatai =   pd.read_sql('SELECT * FROM vrp_prognoz_isatai ORDER BY index',engine)
atyrau =   pd.read_sql('SELECT * FROM vrp_prognoz_atyrau ORDER BY index',engine)
kurmangazy=pd.read_sql('SELECT * FROM vrp_prognoz_kurmangazy ORDER BY index',engine)
kzylkoga = pd.read_sql('SELECT * FROM vrp_prognoz_kzylkoga ORDER BY index',engine)
makat =    pd.read_sql('SELECT * FROM vrp_prognoz_makat ORDER BY index',engine) 
makhambet =pd.read_sql('SELECT * FROM vrp_prognoz_makhambet ORDER BY index',engine) 
zhylyoi =  pd.read_sql('SELECT * FROM vrp_prognoz_zhylyoi ORDER BY index',engine)

inder_n       =    pd.read_sql('SELECT * FROM ngds_prog_inder ORDER BY index',engine) 
isatai_n      =   pd.read_sql('SELECT * FROM ngds_prog_isatai ORDER BY index',engine)
atyrau_n      =   pd.read_sql('SELECT * FROM ngds_prog_atyrau ORDER BY index',engine)
kurmangazy_n  = pd.read_sql('SELECT * FROM ngds_prog_kurmangazy ORDER BY index',engine)
kzylkoga_n    = pd.read_sql('SELECT * FROM ngds_prog_kzylkoga ORDER BY index',engine)
makat_n       =    pd.read_sql('SELECT * FROM ngds_prog_makat ORDER BY index',engine) 
makhambet_n   = pd.read_sql('SELECT * FROM ngds_prog_makhambet ORDER BY index',engine) 
zhylyoi_n     = pd.read_sql('SELECT * FROM ngds_prog_zhylyoi ORDER BY index',engine)

inder_l       = pd.read_sql('SELECT * FROM lgds_prog_inder ORDER BY index',engine) 
isatai_l      = pd.read_sql('SELECT * FROM lgds_prog_isatai ORDER BY index',engine)
atyrau_l      = pd.read_sql('SELECT * FROM lgds_prog_atyrau ORDER BY index',engine)
kurmangazy_l  = pd.read_sql('SELECT * FROM lgds_prog_kurmangazy ORDER BY index',engine)
kzylkoga_l    = pd.read_sql('SELECT * FROM lgds_prog_kzylkoga ORDER BY index',engine)
makat_l       = pd.read_sql('SELECT * FROM lgds_prog_makat ORDER BY index',engine) 
makhambet_l   = pd.read_sql('SELECT * FROM lgds_prog_makhambet ORDER BY index',engine) 
zhylyoi_l     = pd.read_sql('SELECT * FROM lgds_prog_zhylyoi ORDER BY index',engine)

inder_d       = pd.read_sql('SELECT * FROM dgds_prog_inder ORDER BY index',engine) 
isatai_d      = pd.read_sql('SELECT * FROM dgds_prog_isatai ORDER BY index',engine)
atyrau_d      = pd.read_sql('SELECT * FROM dgds_prog_atyrau ORDER BY index',engine)
kurmangazy_d  = pd.read_sql('SELECT * FROM dgds_prog_kurmangazy ORDER BY index',engine)
kzylkoga_d    = pd.read_sql('SELECT * FROM dgds_prog_kzylkoga ORDER BY index',engine)
makat_d       = pd.read_sql('SELECT * FROM dgds_prog_makat ORDER BY index',engine) 
makhambet_d   = pd.read_sql('SELECT * FROM dgds_prog_makhambet ORDER BY index',engine) 
zhylyoi_d     = pd.read_sql('SELECT * FROM dgds_prog_zhylyoi ORDER BY index',engine)

Ngds_inder = inder_n['Ngds_inder'] 
Ngds_isatai = isatai_n['Ngds_isatai'] 
Ngds_atyrau = atyrau_n['Ngds_atyrau'] 
Ngds_kurmangazy = kurmangazy_n['Ngds_kurmangazy'] 
Ngds_kzylkoga = kzylkoga_n['Ngds_kzylkoga'] 
Ngds_makat = makat_n['Ngds_makat'] 
Ngds_makhambet = makhambet_n['Ngds_makhambet'] 
Ngds_zhylyoi = zhylyoi_n['Ngds_zhylyoi'] 

lgds_inder = inder_l['lgds_inder'] 
lgds_isatai = isatai_l['lgds_isatai'] 
lgds_atyrau = atyrau_l['lgds_atyrau'] 
lgds_kurmangazy = kurmangazy_l['lgds_kurmangazy'] 
lgds_kzylkoga = kzylkoga_l['lgds_kzylkoga'] 
lgds_makat = makat_l['lgds_makat'] 
lgds_makhambet = makhambet_l['lgds_makhambet'] 
lgds_zhylyoi = zhylyoi_l['lgds_zhylyoi'] 

Dgds_inder = inder_d['Dgds_inder']
Dgds_isatai = isatai_d['Dgds_isatai']
Dgds_atyrau = atyrau_d['Dgds_atyrau']
Dgds_kurmangazy = kurmangazy_d['Dgds_kurmangazy']
Dgds_kzylkoga = kzylkoga_d['Dgds_kzylkoga']
Dgds_makat = makat_d['Dgds_makat']
Dgds_makhambet = makhambet_d['Dgds_makhambet']
Dgds_zhylyoi = zhylyoi_d['Dgds_zhylyoi']



vrp = atyrau.merge(isatai, copy=False).merge(inder, copy=False).merge(kurmangazy, copy=False).merge(kzylkoga, copy=False).merge(makat, copy=False).merge(makhambet, copy=False).merge(zhylyoi, copy=False)

n = atyrau_n.merge(isatai_n, copy=False).merge(inder_n, copy=False).merge(kurmangazy, copy=False).merge(kzylkoga_n, copy=False).merge(makat_n, copy=False).merge(makhambet_n, copy=False).merge(zhylyoi_n, copy=False)
l = atyrau_l.merge(isatai_l, copy=False).merge(inder_l, copy=False).merge(kurmangazy, copy=False).merge(kzylkoga_l, copy=False).merge(makat_l, copy=False).merge(makhambet_l, copy=False).merge(zhylyoi_l, copy=False)
d = atyrau_d.merge(isatai_d, copy=False).merge(inder_d, copy=False).merge(kurmangazy, copy=False).merge(kzylkoga_d, copy=False).merge(makat_d, copy=False).merge(makhambet_d, copy=False).merge(zhylyoi_d, copy=False)

vrp_raion = vrp.merge(n).merge(l).merge(d)

vrp_raion.to_sql('vrp_raion', engine, schema='public',if_exists='replace', index = False)
