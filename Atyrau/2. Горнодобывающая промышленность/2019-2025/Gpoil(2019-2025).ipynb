# %%
import pandas as pd
csv = pd.read_csv('vrp_ekz_prog.csv')
poil = csv['o_oil_price']
c=csv['o_year']
l=poil.shift(1)
l[0]= 71.64
l[7]= 71.64
l[14]= 71.64
Gpoil= poil/l*100

Gpoil_b = Gpoil.loc[csv.o_script.str.match(r'базовый')].reset_index(drop = True)
Gpoil_o = Gpoil.loc[csv.o_script.str.match(r'оптимистичный')].reset_index(drop = True)
Gpoil_p = Gpoil.loc[csv.o_script.str.match(r'пессимистичный')].reset_index(drop = True)

newdf = pd.DataFrame(columns=['Gpoil_b','Gpoil_o','Gpoil_p'], index=range(12))

newdf.Gpoil_b = Gpoil_b 
newdf.Gpoil_o = Gpoil_o 
newdf.Gpoil_p = Gpoil_p 
newdf
# Out:
#        Gpoil_b     Gpoil_o     Gpoil_p
# 0    88.637633   88.637633   72.473479
# 1   102.362205  122.960630  100.000000
# 2   100.000000  100.000000  100.000000
# 3   100.000000  100.000000  100.000000
# 4   100.000000  100.000000  100.000000
# 5   100.000000  100.000000  100.000000
# 6   100.000000  100.000000  122.303544
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
