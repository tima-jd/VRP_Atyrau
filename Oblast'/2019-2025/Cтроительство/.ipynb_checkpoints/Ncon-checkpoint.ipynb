# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv_inder_n =    pd.read_sql('SELECT * FROM vrp_prognoz_inder ORDER BY index',engine) 
csv_isatai_n =   pd.read_sql('SELECT * FROM vrp_prognoz_isatai ORDER BY index',engine)
csv_atyrau_n =   pd.read_sql('SELECT * FROM vrp_prognoz_atyrau ORDER BY index',engine)
csv_kurmangazy_n=pd.read_sql('SELECT * FROM vrp_prognoz_kurmangazy ORDER BY index',engine)
csv_kzylkoga_n = pd.read_sql('SELECT * FROM vrp_prognoz_kzylkoga ORDER BY index',engine)
csv_makat_n =    pd.read_sql('SELECT * FROM vrp_prognoz_makat ORDER BY index',engine) 
csv_makhambet_n =pd.read_sql('SELECT * FROM vrp_prognoz_makhambet ORDER BY index',engine) 
csv_zhylyoi_n =  pd.read_sql('SELECT * FROM vrp_prognoz_zhylyoi ORDER BY index',engine)

inder =         csv_inder_n['Ncon_inder']
isatai =       csv_isatai_n['Ncon_isatai']
atyrau =       csv_atyrau_n['Ncon_atyrau']
kurmangazy=csv_kurmangazy_n['Ncon_kurmangazy'] 
kzylkoga =   csv_kzylkoga_n['Ncon_kzylkoga'] 
makat=          csv_makat_n['Ncon_makat']
makhambet=  csv_makhambet_n['Ncon_makhambet']
zhylyoi =     csv_zhylyoi_n['Ncon_zhylyoi']


Nagr = (inder+isatai+atyrau+kurmangazy+kzylkoga+makat+makhambet+zhylyoi)

Nagr.to_sql('ncon_ao', engine, schema='public',if_exists='replace', index = True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
csv_isatai_n.to_sql('v',engine,schema='public',if_exists='append',index = False)
csv_atyrau_n.to_sql('v',engine,schema='public',if_exists='append',index = False,method = 'callable' )
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: ОШИБКА:  столбец "ltrd" в таблице "v" не существует
# LINE 1: INSERT INTO public.v (index, ltrd, lelc, lwtr, lind, "Ntrd",...
#                                      ^
#
#
# ...
