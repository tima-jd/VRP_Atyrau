# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv_nagr = pd.read_sql('SELECT * FROM nagr_ao ORDER BY index',engine)
csv_lagr = pd.read_sql('SELECT * FROM lagr_ao ORDER BY index',engine)
csv_dagr = pd.read_sql('SELECT * FROM dagr_ao ORDER BY index',engine)
csv_nmin = pd.read_sql('SELECT * FROM nmin_ao ORDER BY index',engine)
csv_lmin = pd.read_sql('SELECT * FROM lmin_ao ORDER BY index',engine)
csv_dmin = pd.read_sql('SELECT * FROM dmin_ao ORDER BY index',engine)
csv_ncon = pd.read_sql('SELECT * FROM ncon_ao ORDER BY index',engine)
csv_lcon = pd.read_sql('SELECT * FROM lcon_ao ORDER BY index',engine)
csv_dcon = pd.read_sql('SELECT * FROM dcon_ao ORDER BY index',engine)
csv_nman = pd.read_sql('SELECT * FROM nman_ao ORDER BY index',engine)
csv_lman = pd.read_sql('SELECT * FROM lman_ao ORDER BY index',engine)
csv_dman = pd.read_sql('SELECT * FROM dman_ao ORDER BY index',engine)
csv_nret = pd.read_sql('SELECT * FROM nret_ao ORDER BY index',engine)
csv_lret = pd.read_sql('SELECT * FROM lret_ao ORDER BY index',engine)
csv_dret = pd.read_sql('SELECT * FROM dret_ao ORDER BY index',engine)
csv_nwhl = pd.read_sql('SELECT * FROM nwhl_ao ORDER BY index',engine)
csv_lwhl = pd.read_sql('SELECT * FROM lwhl_ao ORDER BY index',engine)
csv_dwhl = pd.read_sql('SELECT * FROM dwhl_ao ORDER BY index',engine)
csv_ntrd = pd.read_sql('SELECT * FROM ntrd_ao ORDER BY index',engine)
csv_ltrd = pd.read_sql('SELECT * FROM ltrd_ao ORDER BY index',engine)
csv_dtrd = pd.read_sql('SELECT * FROM dtrd_ao ORDER BY index',engine)
csv_nwtr = pd.read_sql('SELECT * FROM nwtr_ao ORDER BY index',engine)
csv_lwtr = pd.read_sql('SELECT * FROM lwtr_ao ORDER BY index',engine)
csv_dwtr = pd.read_sql('SELECT * FROM dwtr_ao ORDER BY index',engine)
csv_nelc = pd.read_sql('SELECT * FROM nelc_ao ORDER BY index',engine)
csv_lelc = pd.read_sql('SELECT * FROM lelc_ao ORDER BY index',engine)
csv_delc = pd.read_sql('SELECT * FROM delc_ao ORDER BY index',engine)
csv_nind = pd.read_sql('SELECT * FROM nind_ao ORDER BY index',engine)
csv_lind = pd.read_sql('SELECT * FROM lind_ao ORDER BY index',engine)
csv_dind = pd.read_sql('SELECT * FROM dind_ao ORDER BY index',engine)
csv_ngds = pd.read_sql('SELECT * FROM ngds_ao ORDER BY index',engine)
csv_lgds = pd.read_sql('SELECT * FROM lgds_ao ORDER BY index',engine)
csv_dgds = pd.read_sql('SELECT * FROM dgds_ao ORDER BY index',engine)


csv_ntrn = pd.read_sql('SELECT * FROM ntrn_prog_ao ORDER BY index',engine)
csv_ltrn = pd.read_sql('SELECT * FROM ltrn_prog_ao ORDER BY index',engine)
csv_dtrn = pd.read_sql('SELECT * FROM dtrn_prog_ao ORDER BY index',engine)
csv_nimt = pd.read_sql('SELECT * FROM nimt_prog_ao ORDER BY index',engine)
csv_limt = pd.read_sql('SELECT * FROM limt_prog_ao ORDER BY index',engine)
csv_dimt = pd.read_sql('SELECT * FROM dimt_prog_ao ORDER BY index',engine)
csv_noth = pd.read_sql('SELECT * FROM noth_prog_ao ORDER BY index',engine)
csv_loth = pd.read_sql('SELECT * FROM loth_prog_ao ORDER BY index',engine)
csv_doth = pd.read_sql('SELECT * FROM doth_prog_ao ORDER BY index',engine)
csv_nest = pd.read_sql('SELECT * FROM nest_prog_ao ORDER BY index',engine)
csv_lest = pd.read_sql('SELECT * FROM lest_prog_ao ORDER BY index',engine)
csv_dest = pd.read_sql('SELECT * FROM dest_prog_ao ORDER BY index',engine)
csv_nsrv = pd.read_sql('SELECT * FROM nsrv_prog_ao ORDER BY index',engine)
csv_lsrv = pd.read_sql('SELECT * FROM lsrv_prog_ao ORDER BY index',engine)
csv_dsrv = pd.read_sql('SELECT * FROM dsrv_prog_ao ORDER BY index',engine)

csv_ntotal = pd.read_sql('SELECT * FROM ntotal_prog_ao ORDER BY index',engine)
csv_ltotal = pd.read_sql('SELECT * FROM ltotal_prog_ao ORDER BY index',engine)
csv_dtotal = pd.read_sql('SELECT * FROM dtotal_prog_ao ORDER BY index',engine)


Ntotal = csv_ntotal['Ntotal_ao'] 
ltotal = csv_ltotal['ltotal_ao']
Dtotal = csv_dtotal['Dtotal_ao']

Nsrv = csv_nsrv['Nsrv_ao']
lsrv = csv_lsrv['lsrv_ao']
Dsrv = csv_dsrv['Dsrv_ao']
Nest = csv_nest['Nest_ao']
lest = csv_lest['lest_ao'] 
Dest = csv_dest['Dest_ao']
Noth = csv_noth['Noth_ao']
loth = csv_loth['loth_ao'] 
Doth = csv_doth['Doth_ao']
Nimt = csv_nimt['Nimt_ao']
limt = csv_limt['limt_ao'] 
Dimt = csv_dimt['Dimt_ao']
Ntrn = csv_ntrn['Ntrn_ao']
ltrn = csv_ltrn['ltrn_ao'] 
Dtrn = csv_dtrn['Dtrn_ao'] 

Ngds = csv_ngds['Ngds_ao']
Dgds = csv_dgds['Dgds_ao']
lgds = csv_lgds['lgds_ao']
Nagr = csv_nagr['Nagr_ao']
Dagr = csv_dagr['Dagr_ao']
lagr = csv_lagr['lagr_ao']
Nmin = csv_nmin['Nmin_ao']
Dmin = csv_dmin['Dmin_ao']
lmin = csv_lmin['lmin_ao']
Ncon = csv_ncon['Ncon_ao']
Dcon = csv_dcon['Dcon_ao']
lcon = csv_lcon['lcon_ao']
Nman = csv_nman['Nman_ao']
Dman = csv_dman['Dman_ao']
lman = csv_lman['lman_ao']
Nret = csv_nret['Nret_ao']
Dret = csv_dret['Dret_ao']
lret = csv_lret['lret_ao']
Nwhl = csv_nwhl['Nwhl_ao']
Dwhl = csv_dwhl['Dwhl_ao']
lwhl = csv_lwhl['lwhl_ao']
Ntrd = csv_ntrd['Ntrd_ao']
Dtrd = csv_dtrd['Dtrd_ao']
ltrd = csv_ltrd['ltrd_ao']
Nwtr = csv_nwtr['Nwtr_ao']
Dwtr = csv_dwtr['Dwtr_ao']
lwtr = csv_lwtr['lwtr_ao']
Nelc = csv_nelc['Nelc_ao']
Delc = csv_delc['Delc_ao']
lelc = csv_lelc['lelc_ao']
Nind = csv_nind['Nind_ao']
Dind = csv_dind['Dind_ao']
lind = csv_lind['lind_ao']

vrp_oblast = csv_nagr.merge(csv_lagr).merge(csv_dagr).merge(csv_nmin).merge(csv_lmin).merge(csv_dmin).merge(csv_ncon).merge(csv_lcon).merge(csv_dcon).merge(csv_nman).merge(csv_lman).merge(csv_dman).merge(csv_nret).merge(csv_lret).merge(csv_dret).merge(csv_nwhl).merge(csv_lwhl).merge(csv_dwhl).merge(csv_ntrd).merge(csv_ltrd).merge(csv_dtrd).merge(csv_nwtr).merge(csv_lwtr).merge(csv_dwtr).merge(csv_nelc).merge(csv_lelc).merge(csv_delc).merge(csv_nind).merge(csv_lind).merge(csv_dind).merge(csv_ngds).merge(csv_lgds).merge(csv_dgds).merge(csv_ntrn).merge(csv_ltrn).merge(csv_dtrn).merge(csv_nimt).merge(csv_limt).merge(csv_dimt).merge(csv_noth).merge(csv_loth).merge(csv_doth).merge(csv_nest).merge(csv_lest).merge(csv_dest).merge(csv_nsrv).merge(csv_lsrv).merge(csv_dsrv).merge(csv_ltotal).merge(csv_dtotal).merge(csv_ntotal)

vrp_oblast.to_sql('vrp_oblast', engine, schema='public',if_exists='replace', index = False)

# %%
vrp_oblast
# Out:
#     index        Nagr_ao     lagr_ao     Dagr_ao       Nmin_ao     lmin_ao  \
# 0       0   75846.538062  104.147609  106.217949  6.570685e+06  103.946411
# 1       1   84243.229552  104.553276  106.233527  6.931166e+06  101.414050
# 2       2   93549.519338  104.543929  106.220352  7.131250e+06  102.897698
# 3       3  102981.762073  104.655914  105.185284  7.324540e+06  102.717071
# 4       4  113753.577681  105.003289  105.196634  8.490604e+06  116.059139
# 5       5  125421.064022  104.827454  105.179325  9.017981e+06  106.245747
# 6       6  138730.037229  105.152564  105.191380  9.206462e+06  102.092341
# 7       7   75846.538062  104.147609  106.217949  6.401701e+06  103.946031
# 8       8   83927.883061  104.553250  105.835891  8.325101e+06  105.508832
# 9       9   92850.389467  104.543861  105.822722  8.548229e+06  102.691070
# 10     10  101825.589362  104.655837  104.787565  8.934245e+06  104.523424
# ...
