# %%
import pandas as pd

import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

Nwhl_inv = pd.read_sql('SELECT * FROM nwhl_vrp_ao ORDER BY index',engine)
Ncon_inv = pd.read_sql('SELECT * FROM ncon_vrp_ao ORDER BY index',engine)

vrp_prog = pd.read_sql('SELECT * FROM vrp_oblast ORDER BY index',engine)

vrp = pd.read_sql('SELECT * FROM vrp_ekz_fact ORDER BY id',engine)
vrp = vrp.drop([0])

Ngds_fact = pd.read_sql('SELECT * FROM ngds_ao_fact ORDER BY index',engine)
Ngds_fact = Ngds_fact.drop([0])
lgds_fact = pd.read_sql('SELECT * FROM lgds_ao_fact ORDER BY index',engine)
lgds_fact = lgds_fact.drop([0])
Ntrd_fact = pd.read_sql('SELECT * FROM ntrd_ao_fact ORDER BY index',engine)
Ntrd_fact = Ntrd_fact.drop([0])
ltrd_fact = pd.read_sql('SELECT * FROM ltrd_ao_fact ORDER BY index',engine)
ltrd_fact = ltrd_fact.drop([0])
Nsrv_fact = pd.read_sql('SELECT * FROM Nsrv_ao_fact ORDER BY index',engine)
Nsrv_fact = Nsrv_fact.drop([0])
lsrv_fact = pd.read_sql('SELECT * FROM lsrv_ao_fact ORDER BY index',engine)
lsrv_fact = lsrv_fact.drop([0])
Nind_fact = pd.read_sql('SELECT * FROM Nind_ao_fact ORDER BY index',engine)
Nind_fact = Nind_fact.drop([0])
lind_fact = pd.read_sql('SELECT * FROM lind_ao_fact ORDER BY index',engine)
lind_fact = lind_fact.drop([0])

Nest = vrp['o_prod_estate']
lest = vrp['o_ifo_estate'] 
Dest=(Nest/Nest.shift(1)/lest) *10000
Noth = vrp['o_prod_other']
loth = vrp['o_ifo_other'] 
Doth=(Noth/Noth.shift(1)/loth) *10000
Nimt = vrp['o_prod_info']
limt = vrp['o_ifo_info'] 
Dimt=(Nimt/Nimt.shift(1)/limt) *10000
Ntrn = vrp['o_prod_transp']
ltrn = vrp['o_ifo_transp'] 
Dtrn=(Ntrn/Ntrn.shift(1)/ltrn) *10000
Nagr = vrp['o_prod_agro']
lagr = vrp['o_ifo_agro']
Dagr=(Nagr/Nagr.shift(1)/lagr) *10000
Nmin = vrp['o_prod_mining']
lmin = vrp['o_ifo_mining']
Dmin=(Nmin/Nmin.shift(1)/lmin) *10000
Ncon = vrp['o_prod_building']
lcon = vrp['o_ifo_building']
Dcon=(Ncon/Ncon.shift(1)/lcon) *10000
Nman = vrp['o_prod_man']
lman = vrp['o_ifo_man']
Dman=(Nman/Nman.shift(1)/lman) *10000
Nret = vrp['o_prod_retail']
lret = vrp['o_ifo_retail']
Dret=(Nret/Nret.shift(1)/lret) *10000
Nwhl = vrp['o_prod_trade']
lwhl = vrp['o_ifo_trade']
Dwhl=(Nwhl/Nwhl.shift(1)/lwhl) *10000
Ntrd = Ntrd_fact['0']
ltrd = ltrd_fact['0']
Dtrd=(Ntrd/Ntrd.shift(1)/ltrd) *10000
Nwtr = vrp['o_prod_water']
lwtr = vrp['o_ifo_water']
Dwtr=(Nwtr/Nwtr.shift(1)/lwtr) *10000
Nelc = vrp['o_prod_energo']
lelc = vrp['o_ifo_energo']
Delc=(Nelc/Nelc.shift(1)/lelc) *10000
Nsrv = Nsrv_fact['0']
lsrv = lsrv_fact['0']
Dsrv=(Nsrv/Nsrv.shift(1)/lsrv) *10000
Ngds = Ngds_fact['Ngds_ao']
lgds = lgds_fact['lgds_ao']
Dgds=(Ngds/Ngds.shift(1)/lgds) *10000
Nind = Nind_fact['0']
lind = lind_fact['0']
Dind=(Nind/Nind.shift(1)/lind) *10000
Ntot = Nsrv+Ngds
ltot = vrp['o_ifo']
Dtot=(Ntot/Ntot.shift(1)/ltot) *10000

ao_b = (vrp_prog['Ntotal_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False).merge(vrp_prog['Ngds_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nagr_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nind_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nmin_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nman_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nelc_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwtr_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ncon_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(Ncon_inv['Ncon'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nsrv_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrd_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nret_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nwhl_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(Nwhl_inv['Nwhl'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Ntrn_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nimt_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Nest_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Noth_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltotal_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lgds_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lagr_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lind_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lmin_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lman_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lelc_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwtr_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lcon_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lsrv_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrd_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lret_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lwhl_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['ltrn_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['limt_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['lest_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['loth_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtotal_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dgds_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dagr_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dind_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dmin_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dman_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Delc_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwtr_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dcon_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dsrv_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrd_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dret_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dwhl_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dtrn_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dimt_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Dest_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False)).merge(vrp_prog['Doth_ao'].loc[vrp_prog.prognoz.str.match(r'базовый')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
ao_o = (vrp_prog['Ntotal_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(Ncon_inv['Ncon'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(Nwhl_inv['Nwhl'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrn_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nimt_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Nest_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Noth_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltotal_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrn_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['limt_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['lest_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['loth_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtotal_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrn_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dimt_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Dest_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False)).merge(vrp_prog['Doth_ao'].loc[vrp_prog.prognoz.str.match(r'оптимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)
ao_p = (vrp_prog['Ntotal_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False).merge(vrp_prog['Ngds_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nagr_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nind_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nmin_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nman_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nelc_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwtr_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ncon_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(Ncon_inv['Ncon'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nsrv_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrd_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nret_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nwhl_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(Nwhl_inv['Nwhl'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Ntrn_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nimt_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Nest_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Noth_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltotal_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lgds_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lagr_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lind_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lmin_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lman_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lelc_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwtr_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lcon_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lsrv_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrd_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lret_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lwhl_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['ltrn_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['limt_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['lest_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['loth_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtotal_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dgds_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dagr_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dind_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dmin_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dman_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Delc_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwtr_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dcon_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dsrv_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrd_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dret_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dwhl_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dtrn_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dimt_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Dest_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False)).merge(vrp_prog['Doth_ao'].loc[vrp_prog.prognoz.str.match(r'пессимистичный')].reset_index(drop = False))).sort_index(kind='mergesort').reset_index(drop = True)

Ntrn_b = Ntrn.append(ao_b['Ntrn_ao']).reset_index(drop = True)
Nimt_b = Nimt.append(ao_b['Nimt_ao']).reset_index(drop = True)
Nest_b = Nest.append(ao_b['Nest_ao']).reset_index(drop = True)
Noth_b = Noth.append(ao_b['Noth_ao']).reset_index(drop = True)

ltrn_b = ltrn.append(ao_b['ltrn_ao']).reset_index(drop = True)
limt_b = limt.append(ao_b['limt_ao']).reset_index(drop = True)
lest_b = lest.append(ao_b['lest_ao']).reset_index(drop = True)
loth_b = loth.append(ao_b['loth_ao']).reset_index(drop = True)

Dtrn_b = Dtrn.append(ao_b['Dtrn_ao']).reset_index(drop = True)
Dimt_b = Dimt.append(ao_b['Dimt_ao']).reset_index(drop = True)
Dest_b = Dest.append(ao_b['Dest_ao']).reset_index(drop = True)
Doth_b = Doth.append(ao_b['Doth_ao']).reset_index(drop = True)


Ntot_b = Ntot.append(ao_b['Ntotal_ao']).reset_index(drop = True)
Ngds_b = Ngds.append(ao_b['Ngds_ao']).reset_index(drop = True)
Nagr_b = Nagr.append(ao_b['Nagr_ao']).reset_index(drop = True)
Nmin_b = Nmin.append(ao_b['Nmin_ao']).reset_index(drop = True)
Ncon_b = Ncon.append(ao_b['Ncon_ao']).reset_index(drop = True)
Ncon_b_i = Ncon.append(ao_b['Ncon']).reset_index(drop = True)
Nman_b = Nman.append(ao_b['Nman_ao']).reset_index(drop = True)
Nret_b = Nret.append(ao_b['Nret_ao']).reset_index(drop = True)
Nwhl_b = Nwhl.append(ao_b['Nwhl_ao']).reset_index(drop = True)
Nwhl_b_i = Nwhl.append(ao_b['Nwhl']).reset_index(drop = True)
Ntrd_b = Ntrd.append(ao_b['Ntrd_ao']).reset_index(drop = True)
Nsrv_b = Nsrv.append(ao_b['Nsrv_ao']).reset_index(drop = True)
Nwtr_b = Nwtr.append(ao_b['Nwtr_ao']).reset_index(drop = True)
Nelc_b = Nelc.append(ao_b['Nelc_ao']).reset_index(drop = True)
Nind_b = Nind.append(ao_b['Nind_ao']).reset_index(drop = True)
ltot_b = ltot.append(ao_b['ltotal_ao']).reset_index(drop = True)
lgds_b = lgds.append(ao_b['lgds_ao']).reset_index(drop = True)
lagr_b = lagr.append(ao_b['lagr_ao']).reset_index(drop = True)
lmin_b = lmin.append(ao_b['lmin_ao']).reset_index(drop = True)
lcon_b = lcon.append(ao_b['lcon_ao']).reset_index(drop = True)
lman_b = lman.append(ao_b['lman_ao']).reset_index(drop = True)
lret_b = lret.append(ao_b['lret_ao']).reset_index(drop = True)
lwhl_b = lwhl.append(ao_b['lwhl_ao']).reset_index(drop = True)
ltrd_b = ltrd.append(ao_b['ltrd_ao']).reset_index(drop = True)
lsrv_b = lsrv.append(ao_b['lsrv_ao']).reset_index(drop = True)
lwtr_b = lwtr.append(ao_b['lwtr_ao']).reset_index(drop = True)
lelc_b = lelc.append(ao_b['lelc_ao']).reset_index(drop = True)
lind_b = lind.append(ao_b['lind_ao']).reset_index(drop = True)
Dtot_b = Dtot.append(ao_b['Dtotal_ao']).reset_index(drop = True)
Dgds_b = Dgds.append(ao_b['Dgds_ao']).reset_index(drop = True)
Dagr_b = Dagr.append(ao_b['Dagr_ao']).reset_index(drop = True)
Dmin_b = Dmin.append(ao_b['Dmin_ao']).reset_index(drop = True)
Dcon_b = Dcon.append(ao_b['Dcon_ao']).reset_index(drop = True)
Dman_b = Dman.append(ao_b['Dman_ao']).reset_index(drop = True)
Dret_b = Dret.append(ao_b['Dret_ao']).reset_index(drop = True)
Dwhl_b = Dwhl.append(ao_b['Dwhl_ao']).reset_index(drop = True)
Dtrd_b = Dtrd.append(ao_b['Dtrd_ao']).reset_index(drop = True)
Dsrv_b = Dsrv.append(ao_b['Dsrv_ao']).reset_index(drop = True)
Dwtr_b = Dwtr.append(ao_b['Dwtr_ao']).reset_index(drop = True)
Delc_b = Delc.append(ao_b['Delc_ao']).reset_index(drop = True)
Dind_b = Dind.append(ao_b['Dind_ao']).reset_index(drop = True)


Ntrn_o = Ntrn.append(ao_o['Ntrn_ao']).reset_index(drop = True)
Nimt_o = Nimt.append(ao_o['Nimt_ao']).reset_index(drop = True)
Nest_o = Nest.append(ao_o['Nest_ao']).reset_index(drop = True)
Noth_o = Noth.append(ao_o['Noth_ao']).reset_index(drop = True)

ltrn_o = ltrn.append(ao_o['ltrn_ao']).reset_index(drop = True)
limt_o = limt.append(ao_o['limt_ao']).reset_index(drop = True)
lest_o = lest.append(ao_o['lest_ao']).reset_index(drop = True)
loth_o = loth.append(ao_o['loth_ao']).reset_index(drop = True)

Dtrn_o = Dtrn.append(ao_o['Dtrn_ao']).reset_index(drop = True)
Dimt_o = Dimt.append(ao_o['Dimt_ao']).reset_index(drop = True)
Dest_o = Dest.append(ao_o['Dest_ao']).reset_index(drop = True)
Doth_o = Doth.append(ao_o['Doth_ao']).reset_index(drop = True)

Ntot_o = Ntot.append(ao_o['Ntotal_ao']).reset_index(drop = True)
Ngds_o = Ngds.append(ao_o['Ngds_ao']).reset_index(drop = True)
Nagr_o = Nagr.append(ao_o['Nagr_ao']).reset_index(drop = True)
Nmin_o = Nmin.append(ao_o['Nmin_ao']).reset_index(drop = True)
Ncon_o = Ncon.append(ao_o['Ncon_ao']).reset_index(drop = True)
Ncon_o_i = Ncon.append(ao_o['Ncon']).reset_index(drop = True)

Nman_o = Nman.append(ao_o['Nman_ao']).reset_index(drop = True)
Nret_o = Nret.append(ao_o['Nret_ao']).reset_index(drop = True)

Nwhl_o = Nwhl.append(ao_o['Nwhl_ao']).reset_index(drop = True)
Nwhl_o_i = Nwhl.append(ao_o['Nwhl']).reset_index(drop = True)

Ntrd_o = Ntrd.append(ao_o['Ntrd_ao']).reset_index(drop = True)
Nsrv_o = Nsrv.append(ao_o['Nsrv_ao']).reset_index(drop = True)
Nwtr_o = Nwtr.append(ao_o['Nwtr_ao']).reset_index(drop = True)
Nelc_o = Nelc.append(ao_o['Nelc_ao']).reset_index(drop = True)
Nind_o = Nind.append(ao_o['Nind_ao']).reset_index(drop = True)
ltot_o = ltot.append(ao_o['ltotal_ao']).reset_index(drop = True)
lgds_o = lgds.append(ao_o['lgds_ao']).reset_index(drop = True)
lagr_o = lagr.append(ao_o['lagr_ao']).reset_index(drop = True)
lmin_o = lmin.append(ao_o['lmin_ao']).reset_index(drop = True)
lcon_o = lcon.append(ao_o['lcon_ao']).reset_index(drop = True)
lman_o = lman.append(ao_o['lman_ao']).reset_index(drop = True)
lret_o = lret.append(ao_o['lret_ao']).reset_index(drop = True)
lwhl_o = lwhl.append(ao_o['lwhl_ao']).reset_index(drop = True)
ltrd_o = ltrd.append(ao_o['ltrd_ao']).reset_index(drop = True)
lsrv_o = lsrv.append(ao_o['lsrv_ao']).reset_index(drop = True)
lwtr_o = lwtr.append(ao_o['lwtr_ao']).reset_index(drop = True)
lelc_o = lelc.append(ao_o['lelc_ao']).reset_index(drop = True)
lind_o = lind.append(ao_o['lind_ao']).reset_index(drop = True)
Dtot_o = Dtot.append(ao_o['Dtotal_ao']).reset_index(drop = True)
Dgds_o = Dgds.append(ao_o['Dgds_ao']).reset_index(drop = True)
Dagr_o = Dagr.append(ao_o['Dagr_ao']).reset_index(drop = True)
Dmin_o = Dmin.append(ao_o['Dmin_ao']).reset_index(drop = True)
Dcon_o = Dcon.append(ao_o['Dcon_ao']).reset_index(drop = True)
Dman_o = Dman.append(ao_o['Dman_ao']).reset_index(drop = True)
Dret_o = Dret.append(ao_o['Dret_ao']).reset_index(drop = True)
Dwhl_o = Dwhl.append(ao_o['Dwhl_ao']).reset_index(drop = True)
Dtrd_o = Dtrd.append(ao_o['Dtrd_ao']).reset_index(drop = True)
Dsrv_o = Dsrv.append(ao_o['Dsrv_ao']).reset_index(drop = True)
Dwtr_o = Dwtr.append(ao_o['Dwtr_ao']).reset_index(drop = True)
Delc_o = Delc.append(ao_o['Delc_ao']).reset_index(drop = True)
Dind_o = Dind.append(ao_o['Dind_ao']).reset_index(drop = True)


Ntrn_p = Ntrn.append(ao_p['Ntrn_ao']).reset_index(drop = True)
Nimt_p = Nimt.append(ao_p['Nimt_ao']).reset_index(drop = True)
Nest_p = Nest.append(ao_p['Nest_ao']).reset_index(drop = True)
Noth_p = Noth.append(ao_p['Noth_ao']).reset_index(drop = True)
ltrn_p = ltrn.append(ao_p['ltrn_ao']).reset_index(drop = True)
limt_p = limt.append(ao_p['limt_ao']).reset_index(drop = True)
lest_p = lest.append(ao_p['lest_ao']).reset_index(drop = True)
loth_p = loth.append(ao_p['loth_ao']).reset_index(drop = True)
Dtrn_p = Dtrn.append(ao_p['Dtrn_ao']).reset_index(drop = True)
Dimt_p = Dimt.append(ao_p['Dimt_ao']).reset_index(drop = True)
Dest_p = Dest.append(ao_p['Dest_ao']).reset_index(drop = True)
Doth_p = Doth.append(ao_p['Doth_ao']).reset_index(drop = True)

Ntot_p = Ntot.append(ao_p['Ntotal_ao']).reset_index(drop = True)
Ngds_p = Ngds.append(ao_p['Ngds_ao']).reset_index(drop = True)
Nagr_p = Nagr.append(ao_p['Nagr_ao']).reset_index(drop = True)
Nmin_p = Nmin.append(ao_p['Nmin_ao']).reset_index(drop = True)
Ncon_p = Ncon.append(ao_p['Ncon_ao']).reset_index(drop = True)
Ncon_p_i = Ncon.append(ao_p['Ncon']).reset_index(drop = True)

Nman_p = Nman.append(ao_p['Nman_ao']).reset_index(drop = True)
Nret_p = Nret.append(ao_p['Nret_ao']).reset_index(drop = True)
Nwhl_p = Nwhl.append(ao_p['Nwhl_ao']).reset_index(drop = True)
Nwhl_p_i = Nwhl.append(ao_p['Nwhl']).reset_index(drop = True)

Ntrd_p = Ntrd.append(ao_p['Ntrd_ao']).reset_index(drop = True)
Nsrv_p = Nsrv.append(ao_p['Nsrv_ao']).reset_index(drop = True)
Nwtr_p = Nwtr.append(ao_p['Nwtr_ao']).reset_index(drop = True)
Nelc_p = Nelc.append(ao_p['Nelc_ao']).reset_index(drop = True)
Nind_p = Nind.append(ao_p['Nind_ao']).reset_index(drop = True)
ltot_p = ltot.append(ao_p['ltotal_ao']).reset_index(drop = True)
lgds_p = lgds.append(ao_p['lgds_ao']).reset_index(drop = True)
lagr_p = lagr.append(ao_p['lagr_ao']).reset_index(drop = True)
lmin_p = lmin.append(ao_p['lmin_ao']).reset_index(drop = True)
lcon_p = lcon.append(ao_p['lcon_ao']).reset_index(drop = True)
lman_p = lman.append(ao_p['lman_ao']).reset_index(drop = True)
lret_p = lret.append(ao_p['lret_ao']).reset_index(drop = True)
lwhl_p = lwhl.append(ao_p['lwhl_ao']).reset_index(drop = True)
ltrd_p = ltrd.append(ao_p['ltrd_ao']).reset_index(drop = True)
lsrv_p = lsrv.append(ao_p['lsrv_ao']).reset_index(drop = True)
lwtr_p = lwtr.append(ao_p['lwtr_ao']).reset_index(drop = True)
lelc_p = lelc.append(ao_p['lelc_ao']).reset_index(drop = True)
lind_p = lind.append(ao_p['lind_ao']).reset_index(drop = True)
Dtot_p = Dtot.append(ao_p['Dtotal_ao']).reset_index(drop = True)
Dgds_p = Dgds.append(ao_p['Dgds_ao']).reset_index(drop = True)
Dagr_p = Dagr.append(ao_p['Dagr_ao']).reset_index(drop = True)
Dmin_p = Dmin.append(ao_p['Dmin_ao']).reset_index(drop = True)
Dcon_p = Dcon.append(ao_p['Dcon_ao']).reset_index(drop = True)
Dman_p = Dman.append(ao_p['Dman_ao']).reset_index(drop = True)
Dret_p = Dret.append(ao_p['Dret_ao']).reset_index(drop = True)
Dwhl_p = Dwhl.append(ao_p['Dwhl_ao']).reset_index(drop = True)
Dtrd_p = Dtrd.append(ao_p['Dtrd_ao']).reset_index(drop = True)
Dsrv_p = Dsrv.append(ao_p['Dsrv_ao']).reset_index(drop = True)
Dwtr_p = Dwtr.append(ao_p['Dwtr_ao']).reset_index(drop = True)
Delc_p = Delc.append(ao_p['Delc_ao']).reset_index(drop = True)
Dind_p = Dind.append(ao_p['Dind_ao']).reset_index(drop = True)

ao_pp = (Ntot_p.append(Ngds_p).append(Nagr_p).append(Nind_p).append(Nmin_p).append(Nman_p).append(Nelc_p).append(Nwtr_p).append(Ncon_p).append(Ncon_p_i).append(Nsrv_p).append(Ntrd_p).append(Nret_p).append(Nwhl_p).append(Nwhl_p_i).append(ltot_p).append(lgds_p).append(lagr_p).append(lind_p).append(lmin_p).append(lman_p).append(lelc_p).append(lwtr_p).append(lcon_p).append(lcon_p).append(lsrv_p).append(ltrd_p).append(lret_p).append(lwhl_p).append(lwhl_p).append(Dtot_p).append(Dgds_p).append(Dagr_p).append(Dind_p).append(Dmin_p).append(Dman_p).append(Delc_p).append(Dwtr_p).append(Dcon_p).append(Dcon_p).append(Dsrv_p).append(Dtrd_p).append(Dret_p).append(Dwhl_p).append(Dwhl_p)).sort_index(kind='mergesort').reset_index(drop = True)
ao_oo = (Ntot_o.append(Ngds_o).append(Nagr_o).append(Nind_o).append(Nmin_o).append(Nman_o).append(Nelc_o).append(Nwtr_o).append(Ncon_o).append(Ncon_o_i).append(Nsrv_o).append(Ntrd_o).append(Nret_o).append(Nwhl_o).append(Nwhl_o_i).append(ltot_o).append(lgds_o).append(lagr_o).append(lind_o).append(lmin_o).append(lman_o).append(lelc_o).append(lwtr_o).append(lcon_o).append(lcon_o).append(lsrv_o).append(ltrd_o).append(lret_o).append(lwhl_o).append(lwhl_o).append(Dtot_o).append(Dgds_o).append(Dagr_o).append(Dind_o).append(Dmin_o).append(Dman_o).append(Delc_o).append(Dwtr_o).append(Dcon_o).append(Dcon_o).append(Dsrv_o).append(Dtrd_o).append(Dret_o).append(Dwhl_o).append(Dwhl_o)).sort_index(kind='mergesort').reset_index(drop = True)
ao_bb = (Ntot_b.append(Ngds_b).append(Nagr_b).append(Nind_b).append(Nmin_b).append(Nman_b).append(Nelc_b).append(Nwtr_b).append(Ncon_b).append(Ncon_b_i).append(Nsrv_b).append(Ntrd_b).append(Nret_b).append(Nwhl_b).append(Nwhl_b_i).append(ltot_b).append(lgds_b).append(lagr_b).append(lind_b).append(lmin_b).append(lman_b).append(lelc_b).append(lwtr_b).append(lcon_b).append(lcon_b).append(lsrv_b).append(ltrd_b).append(lret_b).append(lwhl_b).append(lwhl_b).append(Dtot_b).append(Dgds_b).append(Dagr_b).append(Dind_b).append(Dmin_b).append(Dman_b).append(Delc_b).append(Dwtr_b).append(Dcon_b).append(Dcon_b).append(Dsrv_b).append(Dtrd_b).append(Dret_b).append(Dwhl_b).append(Dwhl_b)).sort_index(kind='mergesort').reset_index(drop = True)

itog = (ao_bb.append(ao_oo).append(ao_pp)).reset_index(drop = True)

Dtot
# Out:
# 1            NaN
# 2     103.673475
# 3     106.094518
# 4     117.719177
# 5     158.833330
# 6     100.289553
# 7     107.926062
# 8     128.143023
# 9      89.366563
# 10    124.087132
# 11    125.587157
# 12     99.687756
# 13    105.359041
# 14    101.976841
# 15     79.190677
# 16    125.186253
# 17    116.666818
# 18    123.862936
# dtype: float64
