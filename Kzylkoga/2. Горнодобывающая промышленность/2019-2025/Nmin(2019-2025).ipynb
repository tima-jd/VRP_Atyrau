# %%
import pandas as pd
import numpy as np

import psycopg2
import io
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

Dmin = pd.read_sql("SELECT * FROM dmin_prog_kzylkoga",engine)
lmin = pd.read_sql("SELECT * FROM lmin_prog_kzylkoga",engine)

Dmin_b = Dmin['Dmin_b']
Dmin_o = Dmin['Dmin_o']
Dmin_p = Dmin['Dmin_p']

lmin_b = lmin['lmin_b']
lmin_o = lmin['lmin_o']
lmin_p = lmin['lmin_p']


newdf = pd.DataFrame(columns=['Nmin_b','Nmin_o','Nmin_p'], index=range(12))

b = 52144.0
o = 52144.0
p = 52144.0
i=0

while i<=len(lmin_b)-1:
    b = b * lmin_b[i] * Dmin_b[i]/10000
    o = o * lmin_o[i] * Dmin_o[i]/10000
    p = p * lmin_p[i] * Dmin_p[i]/10000
    
    newdf.loc[i].Nmin_b = b    
    newdf.loc[i].Nmin_o = o    
    newdf.loc[i].Nmin_p = p    
    i=i+1
newdf.to_sql('nmin_prog_kzylkoga', engine, schema='public',if_exists='replace', index = True)

# %%
# Out:
#     index      lmin_b      lmin_o      lmin_p
# 0       0   88.643494   88.643494   81.665840
# 1       1  103.043107  116.475145   95.573411
# 2       2   95.469143   95.269807   99.528771
# 3       3  101.127795  104.192681   95.909858
# 4       4  107.895990  130.223941   98.291243
# 5       5   98.678860   99.273208  104.173919
# 6       6  105.418666  107.320056  116.328483
# 7       7         NaN         NaN         NaN
# 8       8         NaN         NaN         NaN
# 9       9         NaN         NaN         NaN
# 10     10         NaN         NaN         NaN
# 11     11         NaN         NaN         NaN
