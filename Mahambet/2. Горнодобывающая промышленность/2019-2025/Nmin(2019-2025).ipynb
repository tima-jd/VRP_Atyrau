# %%
import pandas as pd
import numpy as np
csv_file = pd.read_csv('vrp_ekz_prog.csv')
Dmin = pd.read_csv('Dmin(2019-2025).csv')
lmin = pd.read_csv('lmin(2019-2025).csv')

Dmin_b = Dmin['Dmin_b']
Dmin_o = Dmin['Dmin_o']
Dmin_p = Dmin['Dmin_p']

lmin_b = lmin['lmin_b']
lmin_o = lmin['lmin_o']
lmin_p = lmin['lmin_p']


newdf = pd.DataFrame(columns=['Nmin_b','Nmin_o','Nmin_p'], index=range(12))

b = 3771.0
o = 3771.0
p = 3771.0
i=0

while i<=len(lmin_b)-1:
    b = b * lmin_b[i] * Dmin_b[i]/10000
    o = o * lmin_o[i] * Dmin_o[i]/10000
    p = p * lmin_p[i] * Dmin_p[i]/10000
    
    newdf.loc[i].Nmin_b = b    
    newdf.loc[i].Nmin_o = o    
    newdf.loc[i].Nmin_p = p    
    i=i+1
newdf
# Out:
#      Nmin_b   Nmin_o   Nmin_p
# 0   3337.03  3258.05  2033.43
# 1   3668.36  5220.39  2031.81
# 2   3663.32  5205.48  2053.69
# 3   3741.05  5421.18  2239.38
# 4   4399.86  7244.33  2246.31
# 5   4424.63  7313.32  2267.93
# 6    4502.6  7530.58  2889.47
# 7       NaN      NaN      NaN
# 8       NaN      NaN      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN      NaN
# 11      NaN      NaN      NaN

# %%
newdf.to_csv(r'Nmin(2019-2025).csv')
