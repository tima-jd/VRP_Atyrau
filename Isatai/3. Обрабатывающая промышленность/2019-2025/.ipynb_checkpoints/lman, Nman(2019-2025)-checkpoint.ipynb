# %%
import pandas as pd
import psycopg2
import io
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')

csv = pd.read_sql("SELECT * FROM dmin_prog_isatai ORDER BY index",engine)

Dmin_b=csv['Dmin_b']
Dmin_o=csv['Dmin_o']
Dmin_p=csv['Dmin_p']

Dman_b = (Dmin_b-100)*1.1387036451379635+100
Dman_o = (Dmin_o-100)*1.1387036451379635+100
Dman_p = (Dmin_p-100)*1.1387036451379635+100

Dman_b
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError:
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-8b7773814eae> in <module>
#       5 engine = create_engine('postgresql+psycopg2://postgres:2020@localhost:5432/testdb')
#       6
# ----> 7 csv = pd.read_sql("SELECT * FROM dmin_prog_isatai ORDER BY index",engine)
#       8
#       9 Dmin_b=csv['Dmin_b']
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     436             coerce_float=coerce_float,
#     437             parse_dates=parse_dates,
# --> 438             chunksize=chunksize,
#     439         )
#     440
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2179         """
#    2180
# -> 2181         connection = self._contextual_connect(close_with_result=True)
#    2182         return connection.execute(statement, *multiparams, **params)
#    2183
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2240         return self._connection_cls(
#    2241             self,
# -> 2242             self._wrap_pool_connect(self.pool.connect, None),
#    2243             close_with_result=close_with_result,
#    2244             **kwargs
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2278             if connection is None:
#    2279                 Connection._handle_dbapi_exception_noconnection(
# -> 2280                     e, dialect, self
#    2281                 )
#    2282             else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1545             util.raise_from_cause(newraise, exc_info)
#    1546         elif should_wrap:
# -> 1547             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1548         else:
#    1549             util.reraise(*exc_info)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         dialect = self.dialect
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#    2278             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     487
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#     491     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError)
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
import pandas as pd


csv = pd.read_sql("SELECT * FROM vrp_ekz_fact ORDER BY id",engine)
c = pd.read_sql("SELECT * FROM vrp_ekz_prog ORDER BY id",engine)

q = pd.read_sql("SELECT * FROM lagr_prog_isatai ORDER BY index",engine)
w = pd.read_sql("SELECT * FROM lmin_prog_isatai ORDER BY index",engine)
d = pd.read_sql("SELECT * FROM Dmin_prog_isatai ORDER BY index",engine)
e = pd.read_sql("SELECT * FROM Nagr_prog_isatai ORDER BY index",engine)
r = pd.read_sql("SELECT * FROM Nmin_prog_isatai ORDER BY index",engine)

Nmin_b = r['Nmin_b']
Nmin_o = r['Nmin_o']
Nmin_p = r['Nmin_p']

Nagr_b = e['Nagr_b']
Nagr_o = e['Nagr_o']
Nagr_p = e['Nagr_p']

lagr_b = q['lagr_b']
lagr_o = q['lagr_o']
lagr_p = q['lagr_p']


lmin_b = w['lmin_b']
lmin_o = w['lmin_o']
lmin_p = w['lmin_p']

Nagr = csv['o_prod_agro_isatai']
Nmin = csv['o_prod_mining_isatai']
lman= csv['o_ifo_man_isatai']
Nman = csv['o_prod_man_isatai']

year = c['o_year']

lamml_2019_b = (lagr_b[0]*Nagr[18]+lmin_b[0]*Nmin[18]+lman[18]*Nman[17])/(Nagr[18]+Nmin[18]+Nman[17])
lmanS_2019_b = 100*((lamml_2019_b - 100) * 3.330216964833216 + 100)/100
lman_2019_b = lmanS_2019_b/100 * 100
Nman_2019_b=(Nman[18]*lman_2019_b*Dman_b[0])/10000

lamml_2020_b = (lagr_b[1]*Nagr_b[0]+lmin_b[1]*Nmin_b[0]+lman_2019_b*Nman[18])/(Nagr_b[0]+Nmin_b[0]+ Nman[18])
lmanS_2020_b = lmanS_2019_b *((lamml_2020_b - 100) * 3.330216964833216 + 100)/100
lman_2020_b = lmanS_2020_b/lmanS_2019_b * 100
Nman_2020_b =(Nman_2019_b*lman_2020_b*Dmin_b[1])/10000



lamml_2019_o = (lagr_o[0]*Nagr[18]+lmin_o[0]*Nmin[18]+lman[18]*Nman[17])/(Nagr[18]+Nmin[18]+Nman[17])
lmanS_2019_o = 100*((lamml_2019_o - 100) * 3.330216964833216 + 100)/100
lman_2019_o = lmanS_2019_o/100 * 100
Nman_2019_o=(Nman[18]*lman_2019_o*Dman_o[0])/10000

lamml_2020_o = (lagr_o[1]*Nagr_o[0]+lmin_o[1]*Nmin_o[0]+lman_2019_o*Nman[18])/(Nagr_o[0]+Nmin_o[0]+ Nman[18])
lmanS_2020_o = lmanS_2019_o *((lamml_2020_o - 100) * 3.330216964833216 + 100)/100
lman_2020_o = lmanS_2020_o/lmanS_2019_o * 100
Nman_2020_o=(Nman_2019_o*lman_2020_o*Dmin_o[1])/10000



lamml_2019_p = (lagr_p[0]*Nagr[18]+lmin_p[0]*Nmin[18]+lman[18]*Nman[17])/(Nagr[18]+Nmin[18]+Nman[17])
lmanS_2019_p = 100*((lamml_2019_p - 100) * 3.330216964833216 + 100)/100
lman_2019_p = lmanS_2019_p/100 * 100
Nman_2019_p=(Nman[18]*lman_2019_p*Dman_p[0])/10000

lamml_2020_p = (lagr_p[1]*Nagr_p[0]+lmin_p[1]*Nmin_p[0]+lman_2019_p*Nman[18])/(Nagr_p[0]+Nmin_p[0]+ Nman[18])
lmanS_2020_p = lmanS_2019_p *((lamml_2020_p - 100) * 3.330216964833216 + 100)/100
lman_2020_p = lmanS_2020_p/lmanS_2019_p * 100
Nman_2020_p=(Nman_2019_p*lman_2020_p*Dmin_p[1])/10000

b_2019_l =   lman_2019_b
b_2020_l =   lman_2020_b 

b_2019_lS = lmanS_2019_b
b_2020_lS = lmanS_2020_b 

b_2019_ll = lamml_2019_b
b_2020_ll = lamml_2020_b

b_2019_N  = Nman_2019_b



o_2019_l =   lman_2019_o
o_2020_l =   lman_2020_o 

o_2019_lS = lmanS_2019_o
o_2020_lS = lmanS_2020_o 

o_2019_ll = lamml_2019_o
o_2020_ll = lamml_2020_o

o_2019_N  = Nman_2019_o




p_2019_l =   lman_2019_p
p_2020_l =   lman_2020_p 

p_2019_lS = lmanS_2019_p
p_2020_lS = lmanS_2020_p 


p_2019_ll = lamml_2019_p
p_2020_ll = lamml_2020_p

p_2019_N  = Nman_2019_p

# %%
lman_2020_b  = b_2020_l
Nman_2019_b  = b_2019_N
lmanS_2020_b = b_2020_lS

i=0
newdf_1 = pd.DataFrame(columns=['Nman_b','lman_b','lmanS_b', 'lamml_b'], index=range(12))

while i<= len(Dman_b)-3:
    lamml_2020_b = (lagr_b[i+2]*Nagr_b[i+1]+lmin_b[i+2]*Nmin_b[i+1]+lman_2020_b*Nman_2019_b)/(Nagr_b[i+1]+Nmin_b[i+1]+Nman_2019_b)
    lmanS_2021_b = lmanS_2020_b*((lamml_2020_b - 100) * 3.330216964833216 + 100)/100        
    Nman_2019_b = Nman_2019_b*lman_2020_b*Dman_b[i+1]/10000
    lman_2020_b = lmanS_2021_b/lmanS_2020_b * 100
    lmanS_2020_b=lmanS_2021_b
    
    newdf_1.loc[i+1].Nman_b = Nman_2019_b
    newdf_1.loc[i+2].lman_b = lman_2020_b
    newdf_1.loc[i+2].lmanS_b = lmanS_2021_b
    newdf_1.loc[i+2].lamml_b = lamml_2020_b
    i=i+1


Nma = newdf_1['Nman_b']
Nma[0] = b_2019_N
Nman_b = Nma

lma = newdf_1['lman_b']
lma[0] = b_2019_l
lma[1] = b_2020_l
lman_b = lma

lmaS = newdf_1['lmanS_b']
lmaS[0] = b_2019_lS
lmaS[1] = b_2020_lS
lmanS_b = lmaS

lamm = newdf_1['lamml_b']
lamm[0] = b_2019_ll
lamm[1] = b_2020_ll
lamml_b = lamm

newdf_1
# Out:
#      Nman_b   lman_b  lmanS_b  lamml_b
# 0    776.97  89.6396  89.6396   96.889
# 1   734.876  90.5636  81.1808  97.1664
# 2   725.317  98.6991  80.1248  99.6094
# 3   636.935  87.8148  70.3614   96.341
# 4   642.684  100.903  70.9965  100.271
# 5   635.262  98.8451  70.1766  99.6532
# 6   681.315  107.249   75.264  102.177
# 7       NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN

# %%
lman_2020_o =  o_2020_l
Nman_2019_o =  o_2019_N
lmanS_2020_o = o_2020_lS

i=0
newdf_2 = pd.DataFrame(columns=['Nman_o','lman_o','lmanS_o', 'lamml_o'], index=range(12))

while i<=len(Dman_o)-3:
    lamml_2020_o = (lagr_o[i+2]*Nagr_o[i+1]+lmin_o[i+2]*Nmin_o[i+1]+lman_2020_o*Nman_2019_o)/(Nagr_o[i+1]+Nmin_o[i+1]+Nman_2019_o)
    lmanS_2021_o = lmanS_2020_o*((lamml_2020_o - 100) * 3.330216964833216 + 100)/100        
    Nman_2019_o = Nman_2019_o*lman_2020_o*Dman_o[i+1]/10000
    lman_2020_o = lmanS_2021_o/lmanS_2020_o * 100
    lmanS_2020_o=lmanS_2021_o
    
    newdf_2.loc[i+1].Nman_o = Nman_2019_o
    newdf_2.loc[i+2].lman_o = lman_2020_o
    newdf_2.loc[i+2].lmanS_o = lmanS_2021_o
    newdf_2.loc[i+2].lamml_o = lamml_2020_o
    i=i+1
    


Nma = newdf_2['Nman_o']
Nma[0] = o_2019_N
Nman_o = Nma

lma = newdf_2['lman_o']
lma[0] = o_2019_l
lma[1] = o_2020_l
lman_o = lma

lmaS = newdf_2['lmanS_o']
lmaS[0] = o_2019_lS
lmaS[1] = o_2020_lS
lmanS_o = lmaS
    
lamm = newdf_2['lamml_o']
lamm[0] = o_2019_ll
lamm[1] = o_2020_ll
lamml_o = lamm

newdf_2
# Out:
#      Nman_o   lman_o  lmanS_o  lamml_o
# 0   755.202  89.6396  89.6396   96.889
# 1   1000.08  105.612  94.6698  101.685
# 2   990.686  99.0609  93.7807   99.718
# 3   896.935  90.5367   84.906  97.1584
# 4   1105.95  123.303  104.692  106.997
# 5   1110.96  100.453  105.166  100.136
# 6    1209.9  108.905  114.532  102.674
# 7       NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN

# %%
lman_2020_p = p_2020_l
Nman_2019_p = p_2019_N
lmanS_2020_p =p_2020_lS
 
i=0
newdf_3 = pd.DataFrame(columns=['Nman_p','lman_p','lmanS_p', 'lamml_p'], index=range(12))

while i<=len(Dman_p)-3:
    lamml_2020_p = (lagr_p[i+2]*Nagr_p[i+1]+lmin_p[i+2]*Nmin_p[i+1]+lman_2020_p*Nman_2019_p)/(Nagr_p[i+1]+Nmin_p[i+1]+Nman_2019_p)
    lmanS_2021_p = lmanS_2020_p*((lamml_2020_p - 100) * 3.330216964833216 + 100)/100        
    Nman_2019_p = Nman_2019_p*lman_2020_p*Dman_p[i+1]/10000
    lman_2020_p = lmanS_2021_p/lmanS_2020_p * 100
    lmanS_2020_p=lmanS_2021_p
    
    newdf_3.loc[i+1].Nman_p = Nman_2019_p
    newdf_3.loc[i+2].lman_p = lman_2020_p
    newdf_3.loc[i+2].lmanS_p = lmanS_2021_p
    newdf_3.loc[i+2].lamml_p = lamml_2020_p
    i=i+1
    


Nma = newdf_3['Nman_p']
Nma[0] = p_2019_N
Nman_p = Nma

lma = newdf_3['lman_p']
lma[0] = p_2019_l
lma[1] = p_2020_l
lman_p = lma

lmaS = newdf_3['lmanS_p']
lmaS[0] = p_2019_lS 
lmaS[1] = p_2020_lS 
lmanS_p = lmaS
    
lamm = newdf_3['lamml_p']
lamm[0] = p_2019_ll
lamm[1] = p_2020_ll
lamml_p = lamm

newdf_3
# Out:
#      Nman_p   lman_p  lmanS_p  lamml_p
# 0    416.58  69.2194  69.2194  90.7572
# 1   404.496  97.0993  67.2116   99.129
# 2   352.393  87.1189   58.554  96.1321
# 3   319.971  90.7996  53.1668  97.2373
# 4   314.572  98.3126  52.2697  99.4933
# 5   336.316  106.912  55.8827  102.076
# 6   574.676  147.821  82.6066   114.36
# 7       NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN

# %%
newdf = newdf_1.merge(newdf_2, left_index=True, right_index=True).merge(newdf_3, left_index=True, right_index=True)

newdf
# Out:
#      Nman_b   lman_b  lmanS_b  lamml_b   Nman_o   lman_o  lmanS_o  lamml_o  \
# 0    776.97  89.6396  89.6396   96.889  755.202  89.6396  89.6396   96.889
# 1   734.876  90.5636  81.1808  97.1664  1000.08  105.612  94.6698  101.685
# 2   725.317  98.6991  80.1248  99.6094  990.686  99.0609  93.7807   99.718
# 3   636.935  87.8148  70.3614   96.341  896.935  90.5367   84.906  97.1584
# 4   642.684  100.903  70.9965  100.271  1105.95  123.303  104.692  106.997
# 5   635.262  98.8451  70.1766  99.6532  1110.96  100.453  105.166  100.136
# 6   681.315  107.249   75.264  102.177   1209.9  108.905  114.532  102.674
# 7       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Nman_p   lman_p  lmanS_p  lamml_p
# 0    416.58  69.2194  69.2194  90.7572
# 1   404.496  97.0993  67.2116   99.129
# 2   352.393  87.1189   58.554  96.1321
# 3   319.971  90.7996  53.1668  97.2373
# 4   314.572  98.3126  52.2697  99.4933
# 5   336.316  106.912  55.8827  102.076
# 6   574.676  147.821  82.6066   114.36
# 7       NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN

# %%
newdf.to_csv(r'lman, Nman_Isatai(2019-2025).csv', index = False)
